# %% [markdown]
# # 1. Import - 환경설정

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import pyarrow.parquet as pq
import tqdm
import optuna
import gc
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import StandardScaler

# test 데이터 준비 (샘플로 train에서 분리)
from sklearn.model_selection import train_test_split

# 모델 학습 및 평가
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, f1_score

# %% [markdown]
# * 최적화 관련 코드

# %%
# 메모리를 32비트로 변환
def optimize_memory(df):
    for col in df.select_dtypes(include=['number']).columns:
        # 정수형은 가능한 가장 작은 타입으로 (int8, int16 등)
        if df[col].dtype == 'int64':
            df[col] = pd.to_numeric(df[col], downcast='integer')
        # 실수형은 float32로
        elif df[col].dtype == 'float64':
            df[col] = pd.to_numeric(df[col], downcast='float')
    return df

# %% [markdown]
# # 2. 파일을 불러오고, 폴더별로 합치기

# %%
# 함수로 만들어서 넣어버리자 그냥
# 각 폴더명 딕셔너리
HOME = os.getcwd()
def makeFileList(option = "train"):
    folder_name = {1:"1.회원정보", 2:"2.신용정보", 3:"3.승인매출정보", 4:"4.청구입금정보", 5:"5.잔액정보", 6:"6.채널정보", 7:"7.마케팅정보", 8:"8.성과정보"}

    # 현재 디렉터리
    HOME = os.getcwd()

    # 폴더 리스트를 생성하고 폴더 경로들을 리스트로 저장하기
    folder_list = []
    for value in folder_name.values():
        folder_list.append(os.path.join(HOME, "data", option, value))
    print(len(folder_list))

    # 폴더 내 파일 리스트 읽어오기
    fileNameList = {}
    for i in range(len(folder_list)):
        fileNameList[i+1] = os.listdir(folder_list[i])
    print(fileNameList)

    # 파일 경로 리스트 생성
    filePathList = {}
    temp = []
    for i in range(len(folder_list)):
        for j in range(len(fileNameList[i+1])):
            temp.append(os.path.join(folder_list[i], fileNameList[i+1][j]))
        filePathList[i+1] = temp
        temp = []

    return filePathList

# %%
# 240만개의 파일을 이어 붙이기
# 각 폴더에 들어있는 파일들 중 같은 달의 열을 모두 합침
def load_cat(i, filePathList):
    print("현재 진행 상황 : {}".format(i))
    df = optimize_memory(pd.read_parquet(filePathList[i][0]))
    for j in range(1,6):
        print("Debugging1")
        df = pd.concat([df, optimize_memory(pd.read_parquet(filePathList[i][j]))])
    return df

# 공통된 쓸모없는 column 제거 함수=
def drop_useless(df):
    df = df.drop(columns = ["기준년월", "ID"])
    return df
# target인 Segment가 없을시 Segment 추가
def add_target(df, filePathList):# target이 존재하지 않는 df, target명(문자열)
    temp_df = pd.read_parquet(filePathList[1][0])
    for i in range(1, 6):
        temp_df = pd.concat([temp_df, pd.read_parquet(filePathList[1][i])])
    df = pd.merge(temp_df[["기준년월", "ID", "Segment"]], df, on = ["기준년월","ID"],how = "left")
    return df

# 파일을 불러오는 함수
def make_df(i, option = False):# option이 True면 Test데이터도 불러오게 하자.

    # train 데이터 불러오기
    train = makeFileList()
    test = makeFileList(option = "test")
    train = load_cat(i, train)

    # test 데이터 불러오기
    if option == "all":
        train = pd.DataFrame()
        for i in range(1, 9):
            train = pd.concat([train, drop_useless(load_cat(i, makeFileList()))], axis = 1)    
        test = pd.DataFrame()
        for i in range(1, 9):
            test = pd.concat([test, drop_useless(load_cat(i, makeFileList(option = "test")))], axis = 1)
    elif option:
        train = drop_useless(add_target(train, makeFileList()))
        test = drop_useless(load_cat(i, test))

    
    # option 이 True 라면 concat해서 붙여넣기 : if로 하지 않으면 앞에 test를 선언했기 때문에 오류 날 것
    if option:
        print(train.shape)
        print(test.shape)

        result = pd.concat([train, test], ignore_index=True)
        print(result.shape)
        return result
    else :
        print(train.shape)
        if (i > 1) & (i <= 6): train = add_target(train, makeFileList())
        elif i == 1: return drop_useless(train)
        else: print("숫자가 아니거나 할당 없는 카테고리입니다.")
        return drop_useless(train)
    # i 가 1보다 크고 1보다 작을때 사용



# 데이터프레임에서 파라미터를 입력하면 그 파라미터가 포함된 column들을 가져와 새로운 데이터프레임을 반환함
# 연관성 있는 column들을 얻어오기 위해서 사용한다.
def find_R(df, param1):
    columns = list(df.columns)
    new_columns = []
    for column in columns:
        if param1 in column:
            new_columns.append(column)
    return pd.DataFrame(df[new_columns])

# %%
# 0과 1로 이루어진 데이터들 중, 상대적으로 부족한 A, B에 대해서 확실히 평가를 끌어내 줄 수 있지 않을까 싶어서 가져온 자료
def plot_segment_comparison(df, column):
    """
    Segment와 지정된 column의 관계를 stacked bar chart와 heatmap으로 시각화
    1행 2열 subplot
    
    Parameters:
    -----------
    df : DataFrame
        데이터프레임
    column : str
        비교할 column 이름 (예: "회원여부_연체")
    """
    df_reset = df.reset_index(drop=True)
    plt.rcParams['font.family'] = 'Malgun Gothic'
    plt.rcParams['axes.unicode_minus'] = False
    sns.set(font="Malgun Gothic", 
        rc={"axes.unicode_minus": False},
        style='darkgrid')
    fig, axes = plt.subplots(1, 2, figsize=(16, 5))
    
    # 1. Stacked Bar Chart (왼쪽)
    crosstab_pct = pd.crosstab(df_reset["Segment"], df_reset[column], normalize='index') * 100
    crosstab_pct.plot(kind='bar', stacked=True, ax=axes[0], color=['#2ecc71', '#e74c3c'])
    axes[0].set_title(f"Segment별 {column} 비율 (100%)", fontsize=12, fontweight='bold')
    axes[0].set_xlabel("Segment (0=E, 1=D, 2=C, 3=B, 4=A)")
    axes[0].set_ylabel("비율 (%)")
    axes[0].legend(title=column, bbox_to_anchor=(1.05, 1), loc='upper left')
    
    # 2. HeatMap (오른쪽)
    crosstab = pd.crosstab(df_reset["Segment"], df_reset[column])
    sns.heatmap(crosstab, annot=True, fmt='d', cmap='YlOrRd', ax=axes[1], cbar_kws={'label': '빈도'})
    axes[1].set_title(f"Segment별 {column} 매트릭스", fontsize=12, fontweight='bold')
    axes[1].set_xlabel(column)
    axes[1].set_ylabel("Segment (0=E, 1=D, 2=C, 3=B, 4=A)")
    
    plt.tight_layout()
    plt.show()

# 사용 예시
# plot_segment_comparison(df, "회원여부_연체")
# plot_segment_comparison(df, "가입통신회사코드")

# %% [markdown]
# ## 사용하면 되는 함수
# - make_df(i, option = False)
#     - 데이터를 불러와 데이터 프레임을 만들어 내는 함수
#     - i는 폴더를 불러오기 위한 변수
#     - 기본적으로 option = False
#     - option에 아무 값이나 넣으면 True가 되고, 그러면 해당하는 Test값이 들어간다.
#     - option에 "all"이 들어가면 모든 데이터를 합쳐서 만들어줌

# %%
# 만들어둔 함수를 통해, 불러오고 싶은 폴더를 입력하면 데이터를 한번에 불러와준다.
df = make_df(2, option = "all")
# Out:
# 8
# {1: ['201807_train_회원정보.parquet', '201808_train_회원정보.parquet', '201809_train_회원정보.parquet', '201810_train_회원정보.parquet', '201811_train_회원정보.parquet', '201812_train_회원정보.parquet'], 2: ['201807_train_신용정보.parquet', '201808_train_신용정보.parquet', '201809_train_신용정보.parquet', '201810_train_신용정보.parquet', '201811_train_신용정보.parquet', '201812_train_신용정보.parquet'], 3: ['201807_train_승인매출정보.parquet', '201808_train_승인매출정보.parquet', '201809_train_승인매출정보.parquet', '201810_train_승인매출정보.parquet', '201811_train_승인매출정보.parquet', '201812_train_승인매출정보.parquet'], 4: ['201807_train_청구정보.parquet', '201808_train_청구정보.parquet', '201809_train_청구정보.parquet', '201810_train_청구정보.parquet', '201811_train_청구정보.parquet', '201812_train_청구정보.parquet'], 5: ['201807_train_잔액정보.parquet', '201808_train_잔액정보.parquet', '201809_train_잔액정보.parquet', '201810_train_잔액정보.parquet', '201811_train_잔액정보.parquet', '201812_train_잔액정보.parquet'], 6: ['201807_train_채널정보.parquet', '201808_train_채널정보.parquet', '201809_train_채널정보.parquet', '201810_train_채널정보.parquet', '201811_train_채널정보.parquet', '201812_train_채널정보.parquet'], 7: ['201807_train_마케팅정보.parquet', '201808_train_마케팅정보.parquet', '201809_train_마케팅정보.parquet', '201810_train_마케팅정보.parquet', '201811_train_마케팅정보.parquet', '201812_train_마케팅정보.parquet'], 8: ['201807_train_성과정보.parquet', '201808_train_성과정보.parquet', '201809_train_성과정보.parquet', '201810_train_성과정보.parquet', '201811_train_성과정보.parquet', '201812_train_성과정보.parquet']}
# 8
# {1: ['201807_test_회원정보.parquet', '201808_test_회원정보.parquet', '201809_test_회원정보.parquet', '201810_test_회원정보.parquet', '201811_test_회원정보.parquet', '201812_test_회원정보.parquet'], 2: ['201807_test_신용정보.parquet', '201808_test_신용정보.parquet', '201809_test_신용정보.parquet', '201810_test_신용정보.parquet', '201811_test_신용정보.parquet', '201812_test_신용정보.parquet'], 3: ['201807_test_승인매출정보.parquet', '201808_test_승인매출정보.parquet', '201809_test_승인매출정보.parquet', '201810_test_승인매출정보.parquet', '201811_test_승인매출정보.parquet', '201812_test_승인매출정보.parquet'], 4: ['201807_test_청구정보.parquet', '201808_test_청구정보.parquet', '201809_test_청구정보.parquet', '201810_test_청구정보.parquet', '201811_test_청구정보.parquet', '201812_test_청구정보.parquet'], 5: ['201807_test_잔액정보.parquet', '201808_test_잔액정보.parquet', '201809_test_잔액정보.parquet', '201810_test_잔액정보.parquet', '201811_test_잔액정보.parquet', '201812_test_잔액정보.parquet'], 6: ['201807_test_채널정보.parquet', '201808_test_채널정보.parquet', '201809_test_채널정보.parquet', '201810_test_채널정보.parquet', '201811_test_채널정보.parquet', '201812_test_채널정보.parquet'], 7: ['201807_test_마케팅정보.parquet', '201808_test_마케팅정보.parquet', '201809_test_마케팅정보.parquet', '201810_test_마케팅정보.parquet', '201811_test_마케팅정보.parquet', '201812_test_마케팅정보.parquet'], 8: ['201807_test_성과정보.parquet', '201808_test_성과정보.parquet', '201809_test_성과정보.parquet', '201810_test_성과정보.parquet', '201811_test_성과정보.parquet', '201812_test_성과정보.parquet']}
# 현재 진행 상황 : 2
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_train_회원정보.parquet', '201808_train_회원정보.parquet', '201809_train_회원정보.parquet', '201810_train_회원정보.parquet', '201811_train_회원정보.parquet', '201812_train_회원정보.parquet'], 2: ['201807_train_신용정보.parquet', '201808_train_신용정보.parquet', '201809_train_신용정보.parquet', '201810_train_신용정보.parquet', '201811_train_신용정보.parquet', '201812_train_신용정보.parquet'], 3: ['201807_train_승인매출정보.parquet', '201808_train_승인매출정보.parquet', '201809_train_승인매출정보.parquet', '201810_train_승인매출정보.parquet', '201811_train_승인매출정보.parquet', '201812_train_승인매출정보.parquet'], 4: ['201807_train_청구정보.parquet', '201808_train_청구정보.parquet', '201809_train_청구정보.parquet', '201810_train_청구정보.parquet', '201811_train_청구정보.parquet', '201812_train_청구정보.parquet'], 5: ['201807_train_잔액정보.parquet', '201808_train_잔액정보.parquet', '201809_train_잔액정보.parquet', '201810_train_잔액정보.parquet', '201811_train_잔액정보.parquet', '201812_train_잔액정보.parquet'], 6: ['201807_train_채널정보.parquet', '201808_train_채널정보.parquet', '201809_train_채널정보.parquet', '201810_train_채널정보.parquet', '201811_train_채널정보.parquet', '201812_train_채널정보.parquet'], 7: ['201807_train_마케팅정보.parquet', '201808_train_마케팅정보.parquet', '201809_train_마케팅정보.parquet', '201810_train_마케팅정보.parquet', '201811_train_마케팅정보.parquet', '201812_train_마케팅정보.parquet'], 8: ['201807_train_성과정보.parquet', '201808_train_성과정보.parquet', '201809_train_성과정보.parquet', '201810_train_성과정보.parquet', '201811_train_성과정보.parquet', '201812_train_성과정보.parquet']}
# 현재 진행 상황 : 1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_train_회원정보.parquet', '201808_train_회원정보.parquet', '201809_train_회원정보.parquet', '201810_train_회원정보.parquet', '201811_train_회원정보.parquet', '201812_train_회원정보.parquet'], 2: ['201807_train_신용정보.parquet', '201808_train_신용정보.parquet', '201809_train_신용정보.parquet', '201810_train_신용정보.parquet', '201811_train_신용정보.parquet', '201812_train_신용정보.parquet'], 3: ['201807_train_승인매출정보.parquet', '201808_train_승인매출정보.parquet', '201809_train_승인매출정보.parquet', '201810_train_승인매출정보.parquet', '201811_train_승인매출정보.parquet', '201812_train_승인매출정보.parquet'], 4: ['201807_train_청구정보.parquet', '201808_train_청구정보.parquet', '201809_train_청구정보.parquet', '201810_train_청구정보.parquet', '201811_train_청구정보.parquet', '201812_train_청구정보.parquet'], 5: ['201807_train_잔액정보.parquet', '201808_train_잔액정보.parquet', '201809_train_잔액정보.parquet', '201810_train_잔액정보.parquet', '201811_train_잔액정보.parquet', '201812_train_잔액정보.parquet'], 6: ['201807_train_채널정보.parquet', '201808_train_채널정보.parquet', '201809_train_채널정보.parquet', '201810_train_채널정보.parquet', '201811_train_채널정보.parquet', '201812_train_채널정보.parquet'], 7: ['201807_train_마케팅정보.parquet', '201808_train_마케팅정보.parquet', '201809_train_마케팅정보.parquet', '201810_train_마케팅정보.parquet', '201811_train_마케팅정보.parquet', '201812_train_마케팅정보.parquet'], 8: ['201807_train_성과정보.parquet', '201808_train_성과정보.parquet', '201809_train_성과정보.parquet', '201810_train_성과정보.parquet', '201811_train_성과정보.parquet', '201812_train_성과정보.parquet']}
# 현재 진행 상황 : 2
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_train_회원정보.parquet', '201808_train_회원정보.parquet', '201809_train_회원정보.parquet', '201810_train_회원정보.parquet', '201811_train_회원정보.parquet', '201812_train_회원정보.parquet'], 2: ['201807_train_신용정보.parquet', '201808_train_신용정보.parquet', '201809_train_신용정보.parquet', '201810_train_신용정보.parquet', '201811_train_신용정보.parquet', '201812_train_신용정보.parquet'], 3: ['201807_train_승인매출정보.parquet', '201808_train_승인매출정보.parquet', '201809_train_승인매출정보.parquet', '201810_train_승인매출정보.parquet', '201811_train_승인매출정보.parquet', '201812_train_승인매출정보.parquet'], 4: ['201807_train_청구정보.parquet', '201808_train_청구정보.parquet', '201809_train_청구정보.parquet', '201810_train_청구정보.parquet', '201811_train_청구정보.parquet', '201812_train_청구정보.parquet'], 5: ['201807_train_잔액정보.parquet', '201808_train_잔액정보.parquet', '201809_train_잔액정보.parquet', '201810_train_잔액정보.parquet', '201811_train_잔액정보.parquet', '201812_train_잔액정보.parquet'], 6: ['201807_train_채널정보.parquet', '201808_train_채널정보.parquet', '201809_train_채널정보.parquet', '201810_train_채널정보.parquet', '201811_train_채널정보.parquet', '201812_train_채널정보.parquet'], 7: ['201807_train_마케팅정보.parquet', '201808_train_마케팅정보.parquet', '201809_train_마케팅정보.parquet', '201810_train_마케팅정보.parquet', '201811_train_마케팅정보.parquet', '201812_train_마케팅정보.parquet'], 8: ['201807_train_성과정보.parquet', '201808_train_성과정보.parquet', '201809_train_성과정보.parquet', '201810_train_성과정보.parquet', '201811_train_성과정보.parquet', '201812_train_성과정보.parquet']}
# 현재 진행 상황 : 3
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_train_회원정보.parquet', '201808_train_회원정보.parquet', '201809_train_회원정보.parquet', '201810_train_회원정보.parquet', '201811_train_회원정보.parquet', '201812_train_회원정보.parquet'], 2: ['201807_train_신용정보.parquet', '201808_train_신용정보.parquet', '201809_train_신용정보.parquet', '201810_train_신용정보.parquet', '201811_train_신용정보.parquet', '201812_train_신용정보.parquet'], 3: ['201807_train_승인매출정보.parquet', '201808_train_승인매출정보.parquet', '201809_train_승인매출정보.parquet', '201810_train_승인매출정보.parquet', '201811_train_승인매출정보.parquet', '201812_train_승인매출정보.parquet'], 4: ['201807_train_청구정보.parquet', '201808_train_청구정보.parquet', '201809_train_청구정보.parquet', '201810_train_청구정보.parquet', '201811_train_청구정보.parquet', '201812_train_청구정보.parquet'], 5: ['201807_train_잔액정보.parquet', '201808_train_잔액정보.parquet', '201809_train_잔액정보.parquet', '201810_train_잔액정보.parquet', '201811_train_잔액정보.parquet', '201812_train_잔액정보.parquet'], 6: ['201807_train_채널정보.parquet', '201808_train_채널정보.parquet', '201809_train_채널정보.parquet', '201810_train_채널정보.parquet', '201811_train_채널정보.parquet', '201812_train_채널정보.parquet'], 7: ['201807_train_마케팅정보.parquet', '201808_train_마케팅정보.parquet', '201809_train_마케팅정보.parquet', '201810_train_마케팅정보.parquet', '201811_train_마케팅정보.parquet', '201812_train_마케팅정보.parquet'], 8: ['201807_train_성과정보.parquet', '201808_train_성과정보.parquet', '201809_train_성과정보.parquet', '201810_train_성과정보.parquet', '201811_train_성과정보.parquet', '201812_train_성과정보.parquet']}
# 현재 진행 상황 : 4
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_train_회원정보.parquet', '201808_train_회원정보.parquet', '201809_train_회원정보.parquet', '201810_train_회원정보.parquet', '201811_train_회원정보.parquet', '201812_train_회원정보.parquet'], 2: ['201807_train_신용정보.parquet', '201808_train_신용정보.parquet', '201809_train_신용정보.parquet', '201810_train_신용정보.parquet', '201811_train_신용정보.parquet', '201812_train_신용정보.parquet'], 3: ['201807_train_승인매출정보.parquet', '201808_train_승인매출정보.parquet', '201809_train_승인매출정보.parquet', '201810_train_승인매출정보.parquet', '201811_train_승인매출정보.parquet', '201812_train_승인매출정보.parquet'], 4: ['201807_train_청구정보.parquet', '201808_train_청구정보.parquet', '201809_train_청구정보.parquet', '201810_train_청구정보.parquet', '201811_train_청구정보.parquet', '201812_train_청구정보.parquet'], 5: ['201807_train_잔액정보.parquet', '201808_train_잔액정보.parquet', '201809_train_잔액정보.parquet', '201810_train_잔액정보.parquet', '201811_train_잔액정보.parquet', '201812_train_잔액정보.parquet'], 6: ['201807_train_채널정보.parquet', '201808_train_채널정보.parquet', '201809_train_채널정보.parquet', '201810_train_채널정보.parquet', '201811_train_채널정보.parquet', '201812_train_채널정보.parquet'], 7: ['201807_train_마케팅정보.parquet', '201808_train_마케팅정보.parquet', '201809_train_마케팅정보.parquet', '201810_train_마케팅정보.parquet', '201811_train_마케팅정보.parquet', '201812_train_마케팅정보.parquet'], 8: ['201807_train_성과정보.parquet', '201808_train_성과정보.parquet', '201809_train_성과정보.parquet', '201810_train_성과정보.parquet', '201811_train_성과정보.parquet', '201812_train_성과정보.parquet']}
# 현재 진행 상황 : 5
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_train_회원정보.parquet', '201808_train_회원정보.parquet', '201809_train_회원정보.parquet', '201810_train_회원정보.parquet', '201811_train_회원정보.parquet', '201812_train_회원정보.parquet'], 2: ['201807_train_신용정보.parquet', '201808_train_신용정보.parquet', '201809_train_신용정보.parquet', '201810_train_신용정보.parquet', '201811_train_신용정보.parquet', '201812_train_신용정보.parquet'], 3: ['201807_train_승인매출정보.parquet', '201808_train_승인매출정보.parquet', '201809_train_승인매출정보.parquet', '201810_train_승인매출정보.parquet', '201811_train_승인매출정보.parquet', '201812_train_승인매출정보.parquet'], 4: ['201807_train_청구정보.parquet', '201808_train_청구정보.parquet', '201809_train_청구정보.parquet', '201810_train_청구정보.parquet', '201811_train_청구정보.parquet', '201812_train_청구정보.parquet'], 5: ['201807_train_잔액정보.parquet', '201808_train_잔액정보.parquet', '201809_train_잔액정보.parquet', '201810_train_잔액정보.parquet', '201811_train_잔액정보.parquet', '201812_train_잔액정보.parquet'], 6: ['201807_train_채널정보.parquet', '201808_train_채널정보.parquet', '201809_train_채널정보.parquet', '201810_train_채널정보.parquet', '201811_train_채널정보.parquet', '201812_train_채널정보.parquet'], 7: ['201807_train_마케팅정보.parquet', '201808_train_마케팅정보.parquet', '201809_train_마케팅정보.parquet', '201810_train_마케팅정보.parquet', '201811_train_마케팅정보.parquet', '201812_train_마케팅정보.parquet'], 8: ['201807_train_성과정보.parquet', '201808_train_성과정보.parquet', '201809_train_성과정보.parquet', '201810_train_성과정보.parquet', '201811_train_성과정보.parquet', '201812_train_성과정보.parquet']}
# 현재 진행 상황 : 6
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_train_회원정보.parquet', '201808_train_회원정보.parquet', '201809_train_회원정보.parquet', '201810_train_회원정보.parquet', '201811_train_회원정보.parquet', '201812_train_회원정보.parquet'], 2: ['201807_train_신용정보.parquet', '201808_train_신용정보.parquet', '201809_train_신용정보.parquet', '201810_train_신용정보.parquet', '201811_train_신용정보.parquet', '201812_train_신용정보.parquet'], 3: ['201807_train_승인매출정보.parquet', '201808_train_승인매출정보.parquet', '201809_train_승인매출정보.parquet', '201810_train_승인매출정보.parquet', '201811_train_승인매출정보.parquet', '201812_train_승인매출정보.parquet'], 4: ['201807_train_청구정보.parquet', '201808_train_청구정보.parquet', '201809_train_청구정보.parquet', '201810_train_청구정보.parquet', '201811_train_청구정보.parquet', '201812_train_청구정보.parquet'], 5: ['201807_train_잔액정보.parquet', '201808_train_잔액정보.parquet', '201809_train_잔액정보.parquet', '201810_train_잔액정보.parquet', '201811_train_잔액정보.parquet', '201812_train_잔액정보.parquet'], 6: ['201807_train_채널정보.parquet', '201808_train_채널정보.parquet', '201809_train_채널정보.parquet', '201810_train_채널정보.parquet', '201811_train_채널정보.parquet', '201812_train_채널정보.parquet'], 7: ['201807_train_마케팅정보.parquet', '201808_train_마케팅정보.parquet', '201809_train_마케팅정보.parquet', '201810_train_마케팅정보.parquet', '201811_train_마케팅정보.parquet', '201812_train_마케팅정보.parquet'], 8: ['201807_train_성과정보.parquet', '201808_train_성과정보.parquet', '201809_train_성과정보.parquet', '201810_train_성과정보.parquet', '201811_train_성과정보.parquet', '201812_train_성과정보.parquet']}
# 현재 진행 상황 : 7
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_train_회원정보.parquet', '201808_train_회원정보.parquet', '201809_train_회원정보.parquet', '201810_train_회원정보.parquet', '201811_train_회원정보.parquet', '201812_train_회원정보.parquet'], 2: ['201807_train_신용정보.parquet', '201808_train_신용정보.parquet', '201809_train_신용정보.parquet', '201810_train_신용정보.parquet', '201811_train_신용정보.parquet', '201812_train_신용정보.parquet'], 3: ['201807_train_승인매출정보.parquet', '201808_train_승인매출정보.parquet', '201809_train_승인매출정보.parquet', '201810_train_승인매출정보.parquet', '201811_train_승인매출정보.parquet', '201812_train_승인매출정보.parquet'], 4: ['201807_train_청구정보.parquet', '201808_train_청구정보.parquet', '201809_train_청구정보.parquet', '201810_train_청구정보.parquet', '201811_train_청구정보.parquet', '201812_train_청구정보.parquet'], 5: ['201807_train_잔액정보.parquet', '201808_train_잔액정보.parquet', '201809_train_잔액정보.parquet', '201810_train_잔액정보.parquet', '201811_train_잔액정보.parquet', '201812_train_잔액정보.parquet'], 6: ['201807_train_채널정보.parquet', '201808_train_채널정보.parquet', '201809_train_채널정보.parquet', '201810_train_채널정보.parquet', '201811_train_채널정보.parquet', '201812_train_채널정보.parquet'], 7: ['201807_train_마케팅정보.parquet', '201808_train_마케팅정보.parquet', '201809_train_마케팅정보.parquet', '201810_train_마케팅정보.parquet', '201811_train_마케팅정보.parquet', '201812_train_마케팅정보.parquet'], 8: ['201807_train_성과정보.parquet', '201808_train_성과정보.parquet', '201809_train_성과정보.parquet', '201810_train_성과정보.parquet', '201811_train_성과정보.parquet', '201812_train_성과정보.parquet']}
# 현재 진행 상황 : 8
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_test_회원정보.parquet', '201808_test_회원정보.parquet', '201809_test_회원정보.parquet', '201810_test_회원정보.parquet', '201811_test_회원정보.parquet', '201812_test_회원정보.parquet'], 2: ['201807_test_신용정보.parquet', '201808_test_신용정보.parquet', '201809_test_신용정보.parquet', '201810_test_신용정보.parquet', '201811_test_신용정보.parquet', '201812_test_신용정보.parquet'], 3: ['201807_test_승인매출정보.parquet', '201808_test_승인매출정보.parquet', '201809_test_승인매출정보.parquet', '201810_test_승인매출정보.parquet', '201811_test_승인매출정보.parquet', '201812_test_승인매출정보.parquet'], 4: ['201807_test_청구정보.parquet', '201808_test_청구정보.parquet', '201809_test_청구정보.parquet', '201810_test_청구정보.parquet', '201811_test_청구정보.parquet', '201812_test_청구정보.parquet'], 5: ['201807_test_잔액정보.parquet', '201808_test_잔액정보.parquet', '201809_test_잔액정보.parquet', '201810_test_잔액정보.parquet', '201811_test_잔액정보.parquet', '201812_test_잔액정보.parquet'], 6: ['201807_test_채널정보.parquet', '201808_test_채널정보.parquet', '201809_test_채널정보.parquet', '201810_test_채널정보.parquet', '201811_test_채널정보.parquet', '201812_test_채널정보.parquet'], 7: ['201807_test_마케팅정보.parquet', '201808_test_마케팅정보.parquet', '201809_test_마케팅정보.parquet', '201810_test_마케팅정보.parquet', '201811_test_마케팅정보.parquet', '201812_test_마케팅정보.parquet'], 8: ['201807_test_성과정보.parquet', '201808_test_성과정보.parquet', '201809_test_성과정보.parquet', '201810_test_성과정보.parquet', '201811_test_성과정보.parquet', '201812_test_성과정보.parquet']}
# 현재 진행 상황 : 1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_test_회원정보.parquet', '201808_test_회원정보.parquet', '201809_test_회원정보.parquet', '201810_test_회원정보.parquet', '201811_test_회원정보.parquet', '201812_test_회원정보.parquet'], 2: ['201807_test_신용정보.parquet', '201808_test_신용정보.parquet', '201809_test_신용정보.parquet', '201810_test_신용정보.parquet', '201811_test_신용정보.parquet', '201812_test_신용정보.parquet'], 3: ['201807_test_승인매출정보.parquet', '201808_test_승인매출정보.parquet', '201809_test_승인매출정보.parquet', '201810_test_승인매출정보.parquet', '201811_test_승인매출정보.parquet', '201812_test_승인매출정보.parquet'], 4: ['201807_test_청구정보.parquet', '201808_test_청구정보.parquet', '201809_test_청구정보.parquet', '201810_test_청구정보.parquet', '201811_test_청구정보.parquet', '201812_test_청구정보.parquet'], 5: ['201807_test_잔액정보.parquet', '201808_test_잔액정보.parquet', '201809_test_잔액정보.parquet', '201810_test_잔액정보.parquet', '201811_test_잔액정보.parquet', '201812_test_잔액정보.parquet'], 6: ['201807_test_채널정보.parquet', '201808_test_채널정보.parquet', '201809_test_채널정보.parquet', '201810_test_채널정보.parquet', '201811_test_채널정보.parquet', '201812_test_채널정보.parquet'], 7: ['201807_test_마케팅정보.parquet', '201808_test_마케팅정보.parquet', '201809_test_마케팅정보.parquet', '201810_test_마케팅정보.parquet', '201811_test_마케팅정보.parquet', '201812_test_마케팅정보.parquet'], 8: ['201807_test_성과정보.parquet', '201808_test_성과정보.parquet', '201809_test_성과정보.parquet', '201810_test_성과정보.parquet', '201811_test_성과정보.parquet', '201812_test_성과정보.parquet']}
# 현재 진행 상황 : 2
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_test_회원정보.parquet', '201808_test_회원정보.parquet', '201809_test_회원정보.parquet', '201810_test_회원정보.parquet', '201811_test_회원정보.parquet', '201812_test_회원정보.parquet'], 2: ['201807_test_신용정보.parquet', '201808_test_신용정보.parquet', '201809_test_신용정보.parquet', '201810_test_신용정보.parquet', '201811_test_신용정보.parquet', '201812_test_신용정보.parquet'], 3: ['201807_test_승인매출정보.parquet', '201808_test_승인매출정보.parquet', '201809_test_승인매출정보.parquet', '201810_test_승인매출정보.parquet', '201811_test_승인매출정보.parquet', '201812_test_승인매출정보.parquet'], 4: ['201807_test_청구정보.parquet', '201808_test_청구정보.parquet', '201809_test_청구정보.parquet', '201810_test_청구정보.parquet', '201811_test_청구정보.parquet', '201812_test_청구정보.parquet'], 5: ['201807_test_잔액정보.parquet', '201808_test_잔액정보.parquet', '201809_test_잔액정보.parquet', '201810_test_잔액정보.parquet', '201811_test_잔액정보.parquet', '201812_test_잔액정보.parquet'], 6: ['201807_test_채널정보.parquet', '201808_test_채널정보.parquet', '201809_test_채널정보.parquet', '201810_test_채널정보.parquet', '201811_test_채널정보.parquet', '201812_test_채널정보.parquet'], 7: ['201807_test_마케팅정보.parquet', '201808_test_마케팅정보.parquet', '201809_test_마케팅정보.parquet', '201810_test_마케팅정보.parquet', '201811_test_마케팅정보.parquet', '201812_test_마케팅정보.parquet'], 8: ['201807_test_성과정보.parquet', '201808_test_성과정보.parquet', '201809_test_성과정보.parquet', '201810_test_성과정보.parquet', '201811_test_성과정보.parquet', '201812_test_성과정보.parquet']}
# 현재 진행 상황 : 3
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_test_회원정보.parquet', '201808_test_회원정보.parquet', '201809_test_회원정보.parquet', '201810_test_회원정보.parquet', '201811_test_회원정보.parquet', '201812_test_회원정보.parquet'], 2: ['201807_test_신용정보.parquet', '201808_test_신용정보.parquet', '201809_test_신용정보.parquet', '201810_test_신용정보.parquet', '201811_test_신용정보.parquet', '201812_test_신용정보.parquet'], 3: ['201807_test_승인매출정보.parquet', '201808_test_승인매출정보.parquet', '201809_test_승인매출정보.parquet', '201810_test_승인매출정보.parquet', '201811_test_승인매출정보.parquet', '201812_test_승인매출정보.parquet'], 4: ['201807_test_청구정보.parquet', '201808_test_청구정보.parquet', '201809_test_청구정보.parquet', '201810_test_청구정보.parquet', '201811_test_청구정보.parquet', '201812_test_청구정보.parquet'], 5: ['201807_test_잔액정보.parquet', '201808_test_잔액정보.parquet', '201809_test_잔액정보.parquet', '201810_test_잔액정보.parquet', '201811_test_잔액정보.parquet', '201812_test_잔액정보.parquet'], 6: ['201807_test_채널정보.parquet', '201808_test_채널정보.parquet', '201809_test_채널정보.parquet', '201810_test_채널정보.parquet', '201811_test_채널정보.parquet', '201812_test_채널정보.parquet'], 7: ['201807_test_마케팅정보.parquet', '201808_test_마케팅정보.parquet', '201809_test_마케팅정보.parquet', '201810_test_마케팅정보.parquet', '201811_test_마케팅정보.parquet', '201812_test_마케팅정보.parquet'], 8: ['201807_test_성과정보.parquet', '201808_test_성과정보.parquet', '201809_test_성과정보.parquet', '201810_test_성과정보.parquet', '201811_test_성과정보.parquet', '201812_test_성과정보.parquet']}
# 현재 진행 상황 : 4
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_test_회원정보.parquet', '201808_test_회원정보.parquet', '201809_test_회원정보.parquet', '201810_test_회원정보.parquet', '201811_test_회원정보.parquet', '201812_test_회원정보.parquet'], 2: ['201807_test_신용정보.parquet', '201808_test_신용정보.parquet', '201809_test_신용정보.parquet', '201810_test_신용정보.parquet', '201811_test_신용정보.parquet', '201812_test_신용정보.parquet'], 3: ['201807_test_승인매출정보.parquet', '201808_test_승인매출정보.parquet', '201809_test_승인매출정보.parquet', '201810_test_승인매출정보.parquet', '201811_test_승인매출정보.parquet', '201812_test_승인매출정보.parquet'], 4: ['201807_test_청구정보.parquet', '201808_test_청구정보.parquet', '201809_test_청구정보.parquet', '201810_test_청구정보.parquet', '201811_test_청구정보.parquet', '201812_test_청구정보.parquet'], 5: ['201807_test_잔액정보.parquet', '201808_test_잔액정보.parquet', '201809_test_잔액정보.parquet', '201810_test_잔액정보.parquet', '201811_test_잔액정보.parquet', '201812_test_잔액정보.parquet'], 6: ['201807_test_채널정보.parquet', '201808_test_채널정보.parquet', '201809_test_채널정보.parquet', '201810_test_채널정보.parquet', '201811_test_채널정보.parquet', '201812_test_채널정보.parquet'], 7: ['201807_test_마케팅정보.parquet', '201808_test_마케팅정보.parquet', '201809_test_마케팅정보.parquet', '201810_test_마케팅정보.parquet', '201811_test_마케팅정보.parquet', '201812_test_마케팅정보.parquet'], 8: ['201807_test_성과정보.parquet', '201808_test_성과정보.parquet', '201809_test_성과정보.parquet', '201810_test_성과정보.parquet', '201811_test_성과정보.parquet', '201812_test_성과정보.parquet']}
# 현재 진행 상황 : 5
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_test_회원정보.parquet', '201808_test_회원정보.parquet', '201809_test_회원정보.parquet', '201810_test_회원정보.parquet', '201811_test_회원정보.parquet', '201812_test_회원정보.parquet'], 2: ['201807_test_신용정보.parquet', '201808_test_신용정보.parquet', '201809_test_신용정보.parquet', '201810_test_신용정보.parquet', '201811_test_신용정보.parquet', '201812_test_신용정보.parquet'], 3: ['201807_test_승인매출정보.parquet', '201808_test_승인매출정보.parquet', '201809_test_승인매출정보.parquet', '201810_test_승인매출정보.parquet', '201811_test_승인매출정보.parquet', '201812_test_승인매출정보.parquet'], 4: ['201807_test_청구정보.parquet', '201808_test_청구정보.parquet', '201809_test_청구정보.parquet', '201810_test_청구정보.parquet', '201811_test_청구정보.parquet', '201812_test_청구정보.parquet'], 5: ['201807_test_잔액정보.parquet', '201808_test_잔액정보.parquet', '201809_test_잔액정보.parquet', '201810_test_잔액정보.parquet', '201811_test_잔액정보.parquet', '201812_test_잔액정보.parquet'], 6: ['201807_test_채널정보.parquet', '201808_test_채널정보.parquet', '201809_test_채널정보.parquet', '201810_test_채널정보.parquet', '201811_test_채널정보.parquet', '201812_test_채널정보.parquet'], 7: ['201807_test_마케팅정보.parquet', '201808_test_마케팅정보.parquet', '201809_test_마케팅정보.parquet', '201810_test_마케팅정보.parquet', '201811_test_마케팅정보.parquet', '201812_test_마케팅정보.parquet'], 8: ['201807_test_성과정보.parquet', '201808_test_성과정보.parquet', '201809_test_성과정보.parquet', '201810_test_성과정보.parquet', '201811_test_성과정보.parquet', '201812_test_성과정보.parquet']}
# 현재 진행 상황 : 6
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_test_회원정보.parquet', '201808_test_회원정보.parquet', '201809_test_회원정보.parquet', '201810_test_회원정보.parquet', '201811_test_회원정보.parquet', '201812_test_회원정보.parquet'], 2: ['201807_test_신용정보.parquet', '201808_test_신용정보.parquet', '201809_test_신용정보.parquet', '201810_test_신용정보.parquet', '201811_test_신용정보.parquet', '201812_test_신용정보.parquet'], 3: ['201807_test_승인매출정보.parquet', '201808_test_승인매출정보.parquet', '201809_test_승인매출정보.parquet', '201810_test_승인매출정보.parquet', '201811_test_승인매출정보.parquet', '201812_test_승인매출정보.parquet'], 4: ['201807_test_청구정보.parquet', '201808_test_청구정보.parquet', '201809_test_청구정보.parquet', '201810_test_청구정보.parquet', '201811_test_청구정보.parquet', '201812_test_청구정보.parquet'], 5: ['201807_test_잔액정보.parquet', '201808_test_잔액정보.parquet', '201809_test_잔액정보.parquet', '201810_test_잔액정보.parquet', '201811_test_잔액정보.parquet', '201812_test_잔액정보.parquet'], 6: ['201807_test_채널정보.parquet', '201808_test_채널정보.parquet', '201809_test_채널정보.parquet', '201810_test_채널정보.parquet', '201811_test_채널정보.parquet', '201812_test_채널정보.parquet'], 7: ['201807_test_마케팅정보.parquet', '201808_test_마케팅정보.parquet', '201809_test_마케팅정보.parquet', '201810_test_마케팅정보.parquet', '201811_test_마케팅정보.parquet', '201812_test_마케팅정보.parquet'], 8: ['201807_test_성과정보.parquet', '201808_test_성과정보.parquet', '201809_test_성과정보.parquet', '201810_test_성과정보.parquet', '201811_test_성과정보.parquet', '201812_test_성과정보.parquet']}
# 현재 진행 상황 : 7
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_test_회원정보.parquet', '201808_test_회원정보.parquet', '201809_test_회원정보.parquet', '201810_test_회원정보.parquet', '201811_test_회원정보.parquet', '201812_test_회원정보.parquet'], 2: ['201807_test_신용정보.parquet', '201808_test_신용정보.parquet', '201809_test_신용정보.parquet', '201810_test_신용정보.parquet', '201811_test_신용정보.parquet', '201812_test_신용정보.parquet'], 3: ['201807_test_승인매출정보.parquet', '201808_test_승인매출정보.parquet', '201809_test_승인매출정보.parquet', '201810_test_승인매출정보.parquet', '201811_test_승인매출정보.parquet', '201812_test_승인매출정보.parquet'], 4: ['201807_test_청구정보.parquet', '201808_test_청구정보.parquet', '201809_test_청구정보.parquet', '201810_test_청구정보.parquet', '201811_test_청구정보.parquet', '201812_test_청구정보.parquet'], 5: ['201807_test_잔액정보.parquet', '201808_test_잔액정보.parquet', '201809_test_잔액정보.parquet', '201810_test_잔액정보.parquet', '201811_test_잔액정보.parquet', '201812_test_잔액정보.parquet'], 6: ['201807_test_채널정보.parquet', '201808_test_채널정보.parquet', '201809_test_채널정보.parquet', '201810_test_채널정보.parquet', '201811_test_채널정보.parquet', '201812_test_채널정보.parquet'], 7: ['201807_test_마케팅정보.parquet', '201808_test_마케팅정보.parquet', '201809_test_마케팅정보.parquet', '201810_test_마케팅정보.parquet', '201811_test_마케팅정보.parquet', '201812_test_마케팅정보.parquet'], 8: ['201807_test_성과정보.parquet', '201808_test_성과정보.parquet', '201809_test_성과정보.parquet', '201810_test_성과정보.parquet', '201811_test_성과정보.parquet', '201812_test_성과정보.parquet']}
# 현재 진행 상황 : 8
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# (2400000, 856)
# (600000, 855)
# (3000000, 856)

# %% [markdown]
# # 3. 전처리 - concat & merge 및 Feature Engineering

# %%
import pandas as pd
import numpy as np
import gc

# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # 전처리 및 Feauture Engineering

# %% [markdown]
# ### 직접했던 피쳐엔지니어링 (1)
# - 폴더 1 기반 피쳐엔지니어링
# - catboost 모델의 피처 importance를 기반으로, 분류가 가능한 피쳐를 선별해 사용
# - catboost 모델은 XGboost나 LGBW모델과 같은 트리 모델과는 다르게 적은 양의 데이터라도 확실히 구분되는 특성을 가진 데이터가 있다면 이를 중요하게 생각하고 반영하는 특성이 있다.
# - 예를 들어서, 직접 만든 특성인 **'회원_이용가능_점수'** 항목의 시각화를 확인해보면 다음과 같다.
# - 시각화된 왼쪽 자료를 보면 그다지 상관관계가 없어보이는 자료 같지만, 오른쪽을 보면 A, B에서는 회원 이용가능 점수가 0에서는 존재하지 않고, 1에서도 거의 없다고 볼 수 있다. 즉, A,B와 C,D,E를 구분할 수 있는 자료이기 때문에 catboost에서는 더 많은 참고를 한다는 것이다.
# - 이 사실을 기반으로 하여 catboost 기반으로 모델링을 준비했었다.

# %%
def calculate_month_diff(target_ym):
    # 연도 차이와 월 차이를 계산하여 잔여 개월수 도출
    target_year = target_ym // 100
    target_month = target_ym % 100
    
    current_year = 2026
    current_month = 2
    return (target_year - current_year) * 12 + (target_month - current_month)

def Folder1_Feature(df):
    # 소지카드수를 통한 즉시 사용 가능한 비율
    df['카드_즉시가용_비율'] = df['소지카드수_이용가능_신용'] / (df['소지카드수_유효_신용'] + 1)
    
    # 여기서는 '고객의 금융 활동 기간 중 탈회가 얼마나 잦았나'를 측정합니다.
    df['누적탈회밀도'] = df['탈회횟수_누적'] / (df['최종탈회후경과월'] + 1)
    
    # 탈회 원격도: 전체 탈회 중 과거(1년 전) 비중 (A, B 타겟용)
    df['탈회원격도'] = (df['탈회횟수_누적'] - df['탈회횟수_발급1년이내']) / (df['탈회횟수_누적'] + 1)
    
    # 활동 안정성: 마지막 탈회 후 얼마나 오래 버티고 있는가
    df['활동안정성'] = df['최종탈회후경과월'] / (df['입회경과개월수_신용'] + 1)
    
    # 시계열 데이터로 이루어진 데이터를 그냥 월단위로 조절해버리기
    df['잔여유효개월_실이용'] = df['최종유효년월_신용_이용'].apply(calculate_month_diff)

    # 카드사용시 CA, 카드론의 이용가능을 통한 분류 기준 추가
    df['회원_이용가능_점수'] = (
    (df['회원여부_이용가능'] == 1).astype(int) + 
    (df['회원여부_이용가능_CA'] == 1).astype(int)+ 
    (df['회원여부_이용가능_카드론'] == 1).astype(int))
    df = df.drop("회원여부_이용가능", axis = 1)
    df = df.drop("회원여부_이용가능_CA", axis = 1)
    df = df.drop("회원여부_이용가능_카드론", axis = 1)
    return df

df = Folder1_Feature(df)
plot_segment_comparison(df, '회원_이용가능_점수')
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\4093047334.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['카드_즉시가용_비율'] = df['소지카드수_이용가능_신용'] / (df['소지카드수_유효_신용'] + 1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\4093047334.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['누적탈회밀도'] = df['탈회횟수_누적'] / (df['최종탈회후경과월'] + 1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\4093047334.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['탈회원격도'] = (df['탈회횟수_누적'] - df['탈회횟수_발급1년이내']) / (df['탈회횟수_누적'] + 1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\4093047334.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['활동안정성'] = df['최종탈회후경과월'] / (df['입회경과개월수_신용'] + 1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\4093047334.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['잔여유효개월_실이용'] = df['최종유효년월_신용_이용'].apply(calculate_month_diff)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\4093047334.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['회원_이용가능_점수'] = (

# %% [markdown]
# ### 2nd 코드 리뷰 - 피쳐엔지니어링

# %% [markdown]
# #### 1. 이진화

# %%
# 가입통신회사코드 → 가입통신회사_S사여부
df['가입통신회사_S사여부'] = (df['가입통신회사코드'] == 'S사').astype(int)
df = df.drop(columns=['가입통신회사코드'])

# 직장시도명 → 직장_수도권여부
df['직장_수도권여부'] = df['직장시도명'].isin(['서울', '경기']).astype(int)
df = df.drop(columns=['직장시도명'])

# 거주시도명 → 거주지_수도권여부
df['거주지_수도권여부'] = df['거주시도명'].isin(['서울', '경기']).astype(int)
df = df.drop(columns=['거주시도명'])

# 연회비발생카드수_B0M → 연회비발생카드수_B0M_이진
df['연회비발생카드수_B0M_이진'] = df['연회비발생카드수_B0M'].isin(['1개이상']).astype(int)
df = df.drop(columns=['연회비발생카드수_B0M'])

# 'RV전환가능여부' → 'RV전환불가능여부'
df['RV_전환가능여부_이진'] = (df['RV전환가능여부'] == 'N').astype(int)
df = df.drop(columns='RV전환가능여부'
)

#‘한도증액횟수_R12M’ → '한도증액_R12M_여부': '0회' → 0, '1회이상' → 1
df['한도증액_R12M_여부'] = df['한도증액횟수_R12M'].map({
    '0회': 0,
    '1회이상': 1
    }).astype(int)
df.drop(columns=['한도증액횟수_R12M'], inplace=True)

# '카드론동의여부': 'Y' → 1, 'N' → 0
df['카드론동의여부'] = df['카드론동의여부'].map({
    'Y': 1,
    'N': 0
    }).astype(int)

# '한도심사요청건수' → '한도심사요청여부': '0회' → 0, '1회이상' → 1
df['한도심사요청여부'] = df['한도심사요청건수'].map({
    '0회': 0,
    '1회이상': 1
    }).astype(int)
df.drop(columns=['한도심사요청건수'], inplace=True)

# '카드론이용여부' 변수 생성
df['카드론이용여부'] = (
    (df['최초카드론이용경과월'] != 999) &
    (df['최종카드론이용경과월'] != 999)
).astype(int)
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1128169374.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['가입통신회사_S사여부'] = (df['가입통신회사코드'] == 'S사').astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1128169374.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['직장_수도권여부'] = df['직장시도명'].isin(['서울', '경기']).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1128169374.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['거주지_수도권여부'] = df['거주시도명'].isin(['서울', '경기']).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1128169374.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['연회비발생카드수_B0M_이진'] = df['연회비발생카드수_B0M'].isin(['1개이상']).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1128169374.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['RV_전환가능여부_이진'] = (df['RV전환가능여부'] == 'N').astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1128169374.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['한도증액_R12M_여부'] = df['한도증액횟수_R12M'].map({
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1128169374.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['한도심사요청여부'] = df['한도심사요청건수'].map({
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1128169374.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['카드론이용여부'] = (

# %%
# 'RV실사용여부' 변수 추가
df['RV실사용여부'] = (df['RV약정청구율'] > 0).astype(int)

# '강제한도감액횟수_2회이상여부' 변수 추가
df['강제한도감액횟수_2회이상여부'] = (df['강제한도감액횟수_R12M'] > 1).astype(int)

# '강제한도감액금액_R12M_3이상여부' 변수 추가
df['강제한도감액금액_R12M_3이상여부'] = (df['강제한도감액금액_R12M'] > 2).astype(int)

# '상향가능CA한도금액_1여부' 변수 추가
df['상향가능CA한도금액_1여부'] = (df['상향가능CA한도금액'] == 1).astype(int)
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3707840474.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['RV실사용여부'] = (df['RV약정청구율'] > 0).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3707840474.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['강제한도감액횟수_2회이상여부'] = (df['강제한도감액횟수_R12M'] > 1).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3707840474.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['강제한도감액금액_R12M_3이상여부'] = (df['강제한도감액금액_R12M'] > 2).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3707840474.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['상향가능CA한도금액_1여부'] = (df['상향가능CA한도금액'] == 1).astype(int)

# %% [markdown]
# #### 2. 매핑

# %%
# 자발한도감액횟수_R12M: '0회' → 0, '1회' → 1, '2회' → 2
df['자발한도감액횟수_R12M'] = (
    df['자발한도감액횟수_R12M']
    .str.replace('회', '', regex=False)  # '회' 제거
    .astype(int)  # 바로 int로 변환!
)

df['할인건수_R3M'] = df['할인건수_R3M'].map({'1회 이상': 0, '10회 이상': 1, '20회 이상': 2,'30회 이상': 3, '40회 이상': 4})
df['할인건수_B0M'] = df['할인건수_B0M'].map({'1회 이상': 0, '10회 이상': 1})

df['인입횟수_ARS_R6M'] = df['인입횟수_ARS_R6M'].map({'1회 이상': 0, '10회 이상': 1})
df['이용메뉴건수_ARS_R6M'] = df['이용메뉴건수_ARS_R6M'].map({'1회 이상': 0, '10회 이상': 1, '20회 이상': 2, '30회 이상': 3})
df['방문횟수_PC_R6M'] = df['방문횟수_PC_R6M'].map({'1회 이상': 0, '10회 이상': 1, '20회 이상': 2, '30회 이상': 3, '40회 이상': 4})
df['방문일수_PC_R6M'] = df['방문일수_PC_R6M'].map({'1회 이상': 0, '10회 이상': 1, '20회 이상': 2, '30회 이상': 3})
df['방문횟수_앱_R6M'] = df['방문횟수_앱_R6M'].map({'1회 이상': 0, '10회 이상': 1, '20회 이상': 2, '30회 이상': 3, '40회 이상': 4,
                                                                     '50회 이상': 5, '60회 이상': 6, '70회 이상': 7, '80회 이상': 8})


df['캠페인접촉건수_R12M'] = df['캠페인접촉건수_R12M'].map({'1회 이상': 0, '5회 이상': 1,
                                                                             '10회 이상': 2,'15회 이상': 3, '20회 이상': 4, '25회 이상': 5})
                                                                             
df['캠페인접촉일수_R12M'] = df['캠페인접촉일수_R12M'].map({'1일 이상': 0, '5일 이상': 1, '10일 이상': 2,
                                                                             '15일 이상': 3, '20일 이상': 4})

# %% [markdown]
# #### 3. 파생변수 생성

# %%
# '카드이용한도금액_A수준복합' 변수 추가

a_limit = df[df['Segment'] == 'A']['카드이용한도금액_B1M']
q1 = a_limit.quantile(0.25)
q3 = a_limit.quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
a_no_outlier = a_limit[(a_limit >= lower_bound) & (a_limit <= upper_bound)]
a_B1M = a_no_outlier.min()
print(f"A의 이상치 제외 후 최솟값: {a_B1M:,}")  # 170,344

a_limit = df[df['Segment'] == 'A']['카드이용한도금액_B2M']
q1 = a_limit.quantile(0.25)
q3 = a_limit.quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
a_no_outlier = a_limit[(a_limit >= lower_bound) & (a_limit <= upper_bound)]
a_B2M = a_no_outlier.min()
print(f"A의 이상치 제외 후 최솟값: {a_B2M:,}")  # 170,344

def classify_dual_limit(row):
    b1 = row['카드이용한도금액_B1M'] >= a_B1M
    b2 = row['카드이용한도금액_B2M'] >= a_B2M
    if b1 and b2:
        return 2     # 둘 다 170,344 이상
    elif b1 or b2:
        return 1     # 하나만 170,344 이상
    else:
        return 0    # 둘 다 170,344 미만

df['카드이용한도금액_A수준복합'] = df.apply(classify_dual_limit, axis=1)
# Out:
# A의 이상치 제외 후 최솟값: 170,344
# A의 이상치 제외 후 최솟값: 170,344
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3389455459.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['카드이용한도금액_A수준복합'] = df.apply(classify_dual_limit, axis=1)

# %%
#  업종별 변수

# '_n순위업종_AB' 변수 추가 (상관계수 -0.3030)

'''
- 1순위 업종이 쇼핑	+1
- 2순위 업종이 사교활동	+1
- 2순위 업종이 교육	+0.5
- 2순위 업종이 의료	+1.5 (A, B에서 더 강하게 나타나므로)
- 3순위 업종이 사교활동	+1
- 3순위 업종이 의료	+1.5 (A, B에서 더 강하게 나타나므로)

- 2순위 업종이 없음 -1
- 3순위 업종이 없음 -1
- 2순위 업종이 교통 -0.5
- 2순위 업종이 납부 -0.5
'''

def compute_ab_score(row):
    score = 0
    # 가점 조건
    if row['_1순위업종'] == '쇼핑':
        score += 1
    if row['_2순위업종'] == '사교활동':
        score += 1
    if row['_2순위업종'] == '교육':
        score += 0.5
    if row['_2순위업종'] == '의료':
        score += 1
    if row['_3순위업종'] == '사교활동':
        score += 1
    if row['_3순위업종'] == '의료':
        score += 1

    # 감점 조건
    if row['_2순위업종'] == '없음':
        score -= 1
    if row['_3순위업종'] == '없음':
        score -= 1
    if row['_2순위업종'] == '교통':
        score -= 0.5
    if row['_2순위업종'] == '납부':
        score -= 0.5

    return score

df['_n순위업종_AB'] = df.apply(compute_ab_score, axis=1)

# '_n순위쇼핑업종_AB' 변수 추가 (상관계수 -0.3304)

'''
- 1순위 쇼핑업종이 온라인 +1
- 2순위 쇼핑업종이 도소매 +1
- 3순위 쇼핑업종이 마트 +1

- 1순위 쇼핑업종이 없음 -1
- 2순위 쇼핑업종이 슈퍼마켓 -0.5
- 2순위 쇼핑업종이 없음 -0.5
- 3순위 쇼핑업종이 없음 -1
'''

def compute_ab_score(row):
    score = 0
    # 가점 조건
    if row['_1순위쇼핑업종'] == '온라인':
        score += 1
    if row['_2순위쇼핑업종'] == '도소매':
        score += 1
    if row['_3순위쇼핑업종'] == '마트':
        score += 1

    # 감점 조건
    if row['_1순위쇼핑업종'] == '없음':
        score -= 1
    if row['_2순위쇼핑업종'] == '슈퍼마켓':
        score -= 0.5
    if row['_2순위쇼핑업종'] == '없음':
        score -= 0.5
    if row['_3순위쇼핑업종'] == '없음':
        score -= 1

    return score

df['_n순위쇼핑업종_AB'] = df.apply(compute_ab_score, axis=1)

# '_n순위교통업종_AB' 변수 추가 (상관계수 -0.34514)

'''
- 1순위 교통업종이 주유 +1
- 2순위 교통업종이 정비 +1
- 3순위 교통업종이 택시 +0.5
- 3순위 교통업종이 정비 +0.5
- 3순위 교통업종이 철도버스 +0.5

- 1순위 교통업종이 없음 -1
- 2순위 교통업종이 없음 -1
'''

def compute_ab_score(row):
    score = 0
    # 가점 조건
    if row['_1순위교통업종'] == '주유':
        score += 1
    if row['_2순위교통업종'] == '정비':
        score += 1
    if row['_3순위교통업종'] == '택시':
        score += 0.5
    if row['_3순위교통업종'] == '정비':
        score += 0.5
    if row['_3순위교통업종'] == '철도버스':
        score += 0.5

    # 감점 조건
    if row['_1순위교통업종'] == '없음':
        score -= 1
    if row['_2순위교통업종'] == '없음':
        score -= 1

    return score

df['_n순위교통업종_AB'] = df.apply(compute_ab_score, axis=1)

# '_n순위여유업종_AB' 변수 추가 (상관계수 -0.26628)

'''
- 1순위 여유업종이 운동 +1
- 1순위 여유업종이 항공 +1
- 2순위 여유업종이 숙박 +1
- 2순위 여유업종이 공연 +1
- 3순위 여유업종이 숙박 +1
- 3순위 여유업종이 공연 +1
- 3순위 여유업종이 여유기타 +1

- 1순위 여유업종이 없음 -0.5
- 2순위 여유업종이 없음 -0.5
- 3순위 여유업종이 없음 -0.5
'''

def compute_ab_score(row):
    score = 0
    # 가점 조건
    if row['_1순위여유업종'] == '운동':
        score += 1
    if row['_1순위여유업종'] == '항공':
        score += 1
    if row['_2순위여유업종'] == '숙박':
        score += 1
    if row['_2순위여유업종'] == '공연':
        score += 1
    if row['_3순위여유업종'] == '숙박':
        score += 1
    if row['_3순위여유업종'] == '공연':
        score += 1
    if row['_3순위여유업종'] == '여유기타':
        score += 1

    # 감점 조건
    if row['_1순위여유업종'] == '없음':
        score -= 0.5
    if row['_2순위여유업종'] == '없음':
        score -= 0.5
    if row['_3순위여유업종'] == '없음':
        score -= 0.5

    return score

df['_n순위여유업종_AB'] = df.apply(compute_ab_score, axis=1)

# '_n순위납부업종_AB' 변수 추가 (상관계수 -0.2579)

'''
- 1순위 납부업종이 납부기타 +0.5
- 1순위 납부업종이 보험료 +0.5
- 1순위 납부업종이 통신비 +0.5
- 2순위 납부업종이 납부기타 +0.5
- 2순위 납부업종이 보험료 +0.5
- 2순위 납부업종이 통신비 +0.5
- 3순위 납부업종이 납부기타 +0.5

- 1순위 납부업종이 없음 -0.5
- 2순위 납부업종이 없음 -0.5
- 3순위 납부업종이 없음 -0.5
'''

def compute_ab_score(row):
    score = 0
    # 가점 조건
    if row['_1순위납부업종'] == '납부기타':
        score += 0.5
    if row['_1순위납부업종'] == '보험료':
        score += 0.5
    if row['_1순위납부업종'] == '통신비':
        score += 0.5
    if row['_2순위납부업종'] == '납부기타':
        score += 0.5
    if row['_2순위납부업종'] == '보험료':
        score += 0.5
    if row['_2순위납부업종'] == '통신비':
        score += 0.5
    if row['_3순위납부업종'] == '납부기타':
        score += 0.5

    # 감점 조건
    if row['_1순위납부업종'] == '없음':
        score -= 0.5
    if row['_2순위납부업종'] == '없음':
        score -= 0.5
    if row['_3순위납부업종'] == '없음':
        score -= 0.5

    return score

df['_n순위납부업종_AB'] = df.apply(compute_ab_score, axis=1)

# '_n순위@@업종_AB' 5개 변수 합친 변수 '_n순위업종_AB_총합' 추가 (상관계수 -0.3927)
df['_n순위업종_AB_총합'] = (
    df['_n순위업종_AB'] +
    df['_n순위쇼핑업종_AB'] +
    df['_n순위교통업종_AB'] +
    df['_n순위여유업종_AB'] +
    df['_n순위납부업종_AB']
)

# '_n순위@@업종' 변수 삭제
cols_to_drop = [
    '_1순위업종','_2순위업종','_3순위업종',
    '_1순위쇼핑업종','_2순위쇼핑업종','_3순위쇼핑업종',
    '_1순위교통업종','_2순위교통업종','_3순위교통업종',
    '_1순위여유업종','_2순위여유업종','_3순위여유업종',
    '_1순위납부업종','_2순위납부업종','_3순위납부업종'
]

df.drop(columns=cols_to_drop, inplace=True)

# '이용금액대_점수' 변수 생성 (상관계수 -0.6026)
amount_mapping = {
    '01.100만원+': 18,
    '02.50만원+': 5,
    '03.30만원+': 2,
    '04.10만원+': 2,
    '05.10만원-': 1,
    '09.미사용': 1
}

df['이용금액대_점수'] = df['이용금액대'].map(amount_mapping)

# 원래 변수 '이용금액대' 삭제
df = df.drop(columns=['이용금액대'])

# '이용여부_@@' 변수 생성
df['이용여부_기본']   = (df['최종이용일자_기본'] != 10101).astype(int)
df['이용여부_신판']   = (df['최종이용일자_신판'] != 10101).astype(int)
df['이용여부_CA']    = (df['최종이용일자_CA'] != 10101).astype(int)
df['이용여부_카드론'] = (df['최종이용일자_카드론'] != 10101).astype(int)
df['이용여부_체크']   = (df['최종이용일자_체크'] != 10101).astype(int)
df['이용여부_일시불'] = (df['최종이용일자_일시불'] != 10101).astype(int)
df['이용여부_할부']   = (df['최종이용일자_할부'] != 10101).astype(int)

# 원래 '최종이용일자_@@' 변수 삭제
for i in ['최종이용일자_기본','최종이용일자_신판','최종이용일자_CA','최종이용일자_카드론','최종이용일자_체크','최종이용일자_일시불','최종이용일자_할부']:
  df = df.drop(columns=[i])
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['_n순위업종_AB'] = df.apply(compute_ab_score, axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:84: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['_n순위쇼핑업종_AB'] = df.apply(compute_ab_score, axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['_n순위교통업종_AB'] = df.apply(compute_ab_score, axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:167: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['_n순위여유업종_AB'] = df.apply(compute_ab_score, axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:213: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['_n순위납부업종_AB'] = df.apply(compute_ab_score, axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:216: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['_n순위업종_AB_총합'] = (
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:245: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용금액대_점수'] = df['이용금액대'].map(amount_mapping)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:251: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_기본']   = (df['최종이용일자_기본'] != 10101).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:252: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_신판']   = (df['최종이용일자_신판'] != 10101).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:253: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_CA']    = (df['최종이용일자_CA'] != 10101).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:254: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_카드론'] = (df['최종이용일자_카드론'] != 10101).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:255: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_체크']   = (df['최종이용일자_체크'] != 10101).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:256: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_일시불'] = (df['최종이용일자_일시불'] != 10101).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\3397345144.py:257: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_할부']   = (df['최종이용일자_할부'] != 10101).astype(int)

# %%
# 건수별 평균 이용금액 (B0M만) (R12,6,3M 제외)

##### 이용건수 #####

# 데이터 값이 모두 같은 변수 제거
df = df.drop(columns=['이용건수_부분무이자_B0M'])

# '이용건수_신용_B0M' 변수 값 보정
df['이용건수_신용_B0M'] = df['이용건수_신용_B0M'] + df['이용건수_카드론_B0M']



##### 이용금액 #####

# 데이터 값이 모두 같은 변수 제거
df = df.drop(columns=['이용금액_부분무이자_B0M'])

# '이용금액_신용_B0M', '이용금액_신판_B0M' 변수 생성
df['이용금액_신용_B0M'] = df['이용금액_일시불_B0M'] + df['이용금액_할부_B0M'] + df['이용금액_CA_B0M'] + df['이용금액_카드론_B0M']
df['이용금액_신판_B0M'] = df['이용금액_일시불_B0M'] + df['이용금액_할부_B0M']

# 건수별평균이용금액 변수 생성
df['건수별평균이용금액_신용_B0M'] = np.where(
    (df['이용건수_신용_B0M'] == 0) | (df['이용금액_신용_B0M'] == 0), 0,
    df['이용금액_신용_B0M'] / df['이용건수_신용_B0M'].abs()
)

df['건수별평균이용금액_신판_B0M'] = np.where(
    (df['이용건수_신판_B0M'] == 0) | (df['이용금액_신판_B0M'] == 0), 0,
    df['이용금액_신판_B0M'] / df['이용건수_신판_B0M'].abs()
)

df['건수별평균이용금액_일시불_B0M'] = np.where(
    (df['이용건수_일시불_B0M'] == 0) | (df['이용금액_일시불_B0M'] == 0), 0,
    df['이용금액_일시불_B0M'] / df['이용건수_일시불_B0M'].abs()
)

df['건수별평균이용금액_할부_B0M'] = np.where(
    (df['이용건수_할부_B0M'] == 0) | (df['이용금액_할부_B0M'] == 0), 0,
    df['이용금액_할부_B0M'] / df['이용건수_할부_B0M'].abs()
)

df['건수별평균이용금액_할부_유이자_B0M'] = np.where(
    (df['이용건수_할부_유이자_B0M'] == 0) | (df['이용금액_할부_유이자_B0M'] == 0), 0,
    df['이용금액_할부_유이자_B0M'] / df['이용건수_할부_유이자_B0M'].abs()
)

df['건수별평균이용금액_할부_무이자_B0M'] = np.where(
    (df['이용건수_할부_무이자_B0M'] == 0) | (df['이용금액_할부_무이자_B0M'] == 0), 0,
    df['이용금액_할부_무이자_B0M'] / df['이용건수_할부_무이자_B0M'].abs()
)

df['건수별평균이용금액_CA_B0M'] = np.where(
    (df['이용건수_CA_B0M'] == 0) | (df['이용금액_CA_B0M'] == 0), 0,
    df['이용금액_CA_B0M'] / df['이용건수_CA_B0M'].abs()
)

df['건수별평균이용금액_체크_B0M'] = np.where(
    (df['이용건수_체크_B0M'] == 0) | (df['이용금액_체크_B0M'] == 0), 0,
    df['이용금액_체크_B0M'] / df['이용건수_체크_B0M'].abs()
)

df['건수별평균이용금액_카드론_B0M'] = np.where(
    (df['이용건수_카드론_B0M'] == 0) | (df['이용금액_카드론_B0M'] == 0), 0,
    df['이용금액_카드론_B0M'] / df['이용건수_카드론_B0M'].abs()
)
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2011737505.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용금액_신용_B0M'] = df['이용금액_일시불_B0M'] + df['이용금액_할부_B0M'] + df['이용금액_CA_B0M'] + df['이용금액_카드론_B0M']
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2011737505.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용금액_신판_B0M'] = df['이용금액_일시불_B0M'] + df['이용금액_할부_B0M']
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2011737505.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_신용_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2011737505.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_신판_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2011737505.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_일시불_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2011737505.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_할부_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2011737505.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_할부_유이자_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2011737505.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_할부_무이자_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2011737505.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_CA_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2011737505.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_체크_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2011737505.py:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_카드론_B0M'] = np.where(

# %%
# 분야별 총 이용금액 및 카드론 이용여부

# '쇼핑_총이용금액' 변수 생성
shopping_columns = ['쇼핑_도소매_이용금액',
                    '쇼핑_백화점_이용금액',
                    '쇼핑_마트_이용금액',
                    '쇼핑_슈퍼마켓_이용금액',
                    '쇼핑_편의점_이용금액',
                    '쇼핑_아울렛_이용금액',
                    '쇼핑_온라인_이용금액',
                    '쇼핑_기타_이용금액']
df['쇼핑_총이용금액'] = df[shopping_columns].sum(axis=1)

# '교통_총이용금액' 변수 생성
shopping_columns = ['교통_주유이용금액',
                    '교통_정비이용금액',
                    '교통_통행료이용금액',
                    '교통_버스지하철이용금액',
                    '교통_택시이용금액',
                    '교통_철도버스이용금액']
df['교통_총이용금액'] = df[shopping_columns].sum(axis=1)

# '여유_총이용금액' 변수 생성
shopping_columns = ['여유_운동이용금액',
                    '여유_Pet이용금액',
                    '여유_공연이용금액',
                    '여유_공원이용금액',
                    '여유_숙박이용금액',
                    '여유_항공이용금액',
                    '여유_기타이용금액']
df['여유_총이용금액'] = df[shopping_columns].sum(axis=1)

# '납부_총이용금액' 변수 생성
shopping_columns = ['납부_통신비이용금액',
                    '납부_관리비이용금액',
                    '납부_가스전기료이용금액',
                    '납부_보험료이용금액',
                    '납부_기타이용금액']
df['납부_총이용금액'] = df[shopping_columns].sum(axis=1)

# 상관계수 절댓값 0.3 넘는 변수 5개만 합치기
shopping_columns = ['쇼핑_도소매_이용금액',
                    '쇼핑_마트_이용금액',
                    '쇼핑_온라인_이용금액',
                    '교통_주유이용금액',
                    '납부_기타이용금액']
df['0.3이상_총이용금액'] = df[shopping_columns].sum(axis=1)

# 쇼핑/교통/여유/납부 다 합치기
columns = ['쇼핑_총이용금액',
          '교통_총이용금액',
          '여유_총이용금액',
          '납부_총이용금액']
df['총이용금액_쇼핑교통여유납부'] = df[columns].sum(axis=1)

# 기존 변수 다 삭제
columns_to_drop = [
    '쇼핑_도소매_이용금액', '쇼핑_백화점_이용금액', '쇼핑_마트_이용금액',
    '쇼핑_슈퍼마켓_이용금액', '쇼핑_편의점_이용금액', '쇼핑_아울렛_이용금액',
    '쇼핑_온라인_이용금액', '쇼핑_기타_이용금액',

    '교통_주유이용금액', '교통_정비이용금액', '교통_통행료이용금액',
    '교통_버스지하철이용금액', '교통_택시이용금액', '교통_철도버스이용금액',

    '여유_운동이용금액', '여유_Pet이용금액', '여유_공연이용금액',
    '여유_공원이용금액', '여유_숙박이용금액', '여유_여행이용금액',
    '여유_항공이용금액', '여유_기타이용금액',

    '납부_통신비이용금액', '납부_관리비이용금액', '납부_렌탈료이용금액',
    '납부_가스전기료이용금액', '납부_보험료이용금액', '납부_유선방송이용금액',
    '납부_건강연금이용금액', '납부_기타이용금액'
]

# 변수 삭제
df.drop(columns=columns_to_drop, inplace=True)
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1338027226.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['쇼핑_총이용금액'] = df[shopping_columns].sum(axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1338027226.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['교통_총이용금액'] = df[shopping_columns].sum(axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1338027226.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['여유_총이용금액'] = df[shopping_columns].sum(axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1338027226.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['납부_총이용금액'] = df[shopping_columns].sum(axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1338027226.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['0.3이상_총이용금액'] = df[shopping_columns].sum(axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\1338027226.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['총이용금액_쇼핑교통여유납부'] = df[columns].sum(axis=1)

# %% [markdown]
# ### 직접 한 피쳐 엔지니어링

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import platform

# ---------------------------------------------------------
# 1. 폰트 설정
# ---------------------------------------------------------
system_name = platform.system()
if system_name == 'Windows':
    plt.rc('font', family='Malgun Gothic')
elif system_name == 'Darwin':
    plt.rc('font', family='AppleGothic')
else:
    plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False

# ---------------------------------------------------------
# 2. [오류 해결] ID 컬럼 복구 (Index -> Column)
# ---------------------------------------------------------
# merged_df가 정의되어 있다고 가정합니다. (이전 셀 실행 결과)

# 'ID'가 컬럼에 없고, 혹시 인덱스 이름이 'ID'라면 리셋
if 'ID' not in df.columns:
    print("⚠️ 'ID' 컬럼이 보이지 않아 인덱스 초기화를 시도합니다...")
    df = df.reset_index()

# 리셋 후에도 'ID'가 없는 경우 (인덱스 이름이 다른 경우 등)
if 'ID' not in df.columns:
    # 혹시 컬럼명이 'index'로 되어있거나 대소문자가 다른지 확인
    print(f"❌ 여전히 'ID' 컬럼이 없습니다. 현재 컬럼 목록: {list(df.columns)}")
    # 만약 'index'라는 컬럼이 생겼고 그게 ID라면 이름 변경
    if 'index' in df.columns:
        print("ℹ️ 'index' 컬럼을 'ID'로 변경합니다.")
        df.rename(columns={'index': 'ID'}, inplace=True)

# ---------------------------------------------------------
# 3. 데이터 집계 및 시각화 재시도
# ---------------------------------------------------------
if 'ID' in df.columns and 'Segment' in df.columns:
    print("✅ ID 컬럼 확보 완료! 집계 및 시각화를 진행합니다.")

    # (1) ID별 평균 계산
    user_stats_df = df.groupby(['ID', 'Segment'], observed=True).agg({
        '카드이용한도금액': 'mean',
        '잔액_신판최대한도소진율_r3m': 'mean'
    }).reset_index()

    user_stats_df.rename(columns={
        '카드이용한도금액': '평균한도금액',
        '잔액_신판최대한도소진율_r3m': '평균소진율'
    }, inplace=True)

    # (2) 시각화 함수 정의
    def plot_segment_analysis(data, x_col, y_col, title, y_label):
        # 순서 정렬
        if data[x_col].dtype.name != 'category':
            data[x_col] = pd.Categorical(data[x_col], categories=['A', 'B', 'C', 'D', 'E'], ordered=True)
        
        # 통계값 계산
        stats = data.groupby(x_col)[y_col].agg(['count', 'mean', 'min', 'max'])
        
        # 그래프
        fig, ax = plt.subplots(figsize=(12, 9))
        sns.boxplot(x=x_col, y=y_col, data=data, 
                    order=['A', 'B', 'C', 'D', 'E'], 
                    palette='coolwarm', showfliers=False, ax=ax)
        
        ax.set_title(title, fontsize=16, pad=20)
        ax.set_ylabel(y_label, fontsize=12)
        ax.grid(axis='y', linestyle='--', alpha=0.5)
        
        # 표 추가
        cell_text = []
        for row in stats.values:
            if '소진율' in title:
                formatted_row = [f"{int(row[0]):,}", f"{row[1]:.3f}", f"{row[2]:.3f}", f"{row[3]:.3f}"]
            else:
                formatted_row = [f"{x:,.0f}" if i==0 else f"{x:,.0f}" for i, x in enumerate(row)]
            cell_text.append(formatted_row)
            
        the_table = plt.table(cellText=cell_text,
                              rowLabels=stats.index,
                              colLabels=['고객수', '평균', '최소', '최대'],
                              loc='bottom', cellLoc='center',
                              bbox=[0.0, -0.3, 1.0, 0.25])
        
        the_table.auto_set_font_size(False)
        the_table.set_fontsize(11)
        the_table.scale(1, 1.5)

        plt.subplots_adjust(left=0.1, bottom=0.25)
        plt.show()

    # (3) 실행
    # 한도금액
    plot_segment_analysis(user_stats_df, 'Segment', '평균한도금액', 
                          'Segment별 고객 평균 한도금액 분포', '한도금액 (원)')

    # 소진율 (이상치 Cap)
    user_stats_df['시각화용_소진율'] = user_stats_df['평균소진율'].clip(0, 1.2)
    plot_segment_analysis(user_stats_df, 'Segment', '시각화용_소진율', 
                          'Segment별 고객 평균 한도 소진율 (최대소진율 기준)', '소진율 (0.0 ~ 1.2)')

else:
    print("❌ 오류: 'ID' 또는 'Segment' 컬럼을 찾을 수 없습니다.")
    print(f"현재 컬럼 목록: {list(merged_df.columns)}")
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2671730198.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df = df.reset_index()
# ⚠️ 'ID' 컬럼이 보이지 않아 인덱스 초기화를 시도합니다...
# ❌ 여전히 'ID' 컬럼이 없습니다. 현재 컬럼 목록: ['index', '남녀구분코드', '연령', 'Segment', '소지여부_신용', '소지카드수_유효_신용', '소지카드수_이용가능_신용', '입회일자_신용', '입회경과개월수_신용', '회원여부_연체', '이용거절여부_카드론', '동의여부_한도증액안내', '수신거부여부_TM', '수신거부여부_DM', '수신거부여부_메일', '수신거부여부_SMS', '탈회횟수_누적', '최종탈회후경과월', '탈회횟수_발급6개월이내', '탈회횟수_발급1년이내', '마케팅동의여부', '유효카드수_신용체크', '유효카드수_신용', '유효카드수_신용_가족', '유효카드수_체크', '유효카드수_체크_가족', '이용가능카드수_신용체크', '이용가능카드수_신용', '이용가능카드수_신용_가족', '이용가능카드수_체크', '이용가능카드수_체크_가족', '이용카드수_신용체크', '이용카드수_신용', '이용카드수_신용_가족', '이용카드수_체크', '이용카드수_체크_가족', '이용금액_R3M_신용체크', '이용금액_R3M_신용', '이용금액_R3M_신용_가족', '이용금액_R3M_체크', '이용금액_R3M_체크_가족', '_1순위카드이용금액', '_1순위카드이용건수', '_1순위신용체크구분', '_2순위카드이용금액', '_2순위카드이용건수', '_2순위신용체크구분', '최종유효년월_신용_이용가능', '최종유효년월_신용_이용', '최종카드발급일자', '보유여부_해외겸용_본인', '이용가능여부_해외겸용_본인', '이용여부_3M_해외겸용_본인', '보유여부_해외겸용_신용_본인', '이용가능여부_해외겸용_신용_본인', '이용여부_3M_해외겸용_신용_본인', '연회비할인카드수_B0M', '기본연회비_B0M', '제휴연회비_B0M', '할인금액_기본연회비_B0M', '할인금액_제휴연회비_B0M', '청구금액_기본연회비_B0M', '청구금액_제휴연회비_B0M', '상품관련면제카드수_B0M', '임직원면제카드수_B0M', '우수회원면제카드수_B0M', '기타면제카드수_B0M', '카드신청건수', 'Life_Stage', '최종카드발급경과월', '최초한도금액', '카드이용한도금액', 'CA한도금액', '일시상환론한도금액', '월상환론한도금액', 'CA이자율_할인전', 'CL이자율_할인전', 'RV일시불이자율_할인전', 'RV현금서비스이자율_할인전', 'RV신청일자', 'RV약정청구율', 'RV최소결제비율', '자발한도감액횟수_R12M', '자발한도감액금액_R12M', '자발한도감액후경과월', '강제한도감액횟수_R12M', '강제한도감액금액_R12M', '강제한도감액후경과월', '한도증액금액_R12M', '한도증액후경과월', '상향가능한도금액', '상향가능CA한도금액', '카드론동의여부', '월상환론상향가능한도금액', '일시불ONLY전환가능여부', '카드이용한도금액_B1M', '카드이용한도금액_B2M', '특별한도보유여부_R3M', '연체감액여부_R3M', '한도요청거절건수', '한도심사요청후경과월', '한도심사거절후경과월', '시장단기연체여부_R6M', '시장단기연체여부_R3M', '시장연체상환여부_R6M', '시장연체상환여부_R3M', 'rv최초시작후경과일', '이용건수_신용_B0M', '이용건수_신판_B0M', '이용건수_일시불_B0M', '이용건수_할부_B0M', '이용건수_할부_유이자_B0M', '이용건수_할부_무이자_B0M', '이용건수_CA_B0M', '이용건수_체크_B0M', '이용건수_카드론_B0M', '이용금액_일시불_B0M', '이용금액_할부_B0M', '이용금액_할부_유이자_B0M', '이용금액_할부_무이자_B0M', '이용금액_CA_B0M', '이용금액_체크_B0M', '이용금액_카드론_B0M', '이용후경과월_신용', '이용후경과월_신판', '이용후경과월_일시불', '이용후경과월_할부', '이용후경과월_할부_유이자', '이용후경과월_할부_무이자', '이용후경과월_부분무이자', '이용후경과월_CA', '이용후경과월_체크', '이용후경과월_카드론', '이용건수_신용_R12M', '이용건수_신판_R12M', '이용건수_일시불_R12M', '이용건수_할부_R12M', '이용건수_할부_유이자_R12M', '이용건수_할부_무이자_R12M', '이용건수_부분무이자_R12M', '이용건수_CA_R12M', '이용건수_체크_R12M', '이용건수_카드론_R12M', '이용금액_일시불_R12M', '이용금액_할부_R12M', '이용금액_할부_유이자_R12M', '이용금액_할부_무이자_R12M', '이용금액_부분무이자_R12M', '이용금액_CA_R12M', '이용금액_체크_R12M', '이용금액_카드론_R12M', '최대이용금액_일시불_R12M', '최대이용금액_할부_R12M', '최대이용금액_할부_유이자_R12M', '최대이용금액_할부_무이자_R12M', '최대이용금액_부분무이자_R12M', '최대이용금액_CA_R12M', '최대이용금액_체크_R12M', '최대이용금액_카드론_R12M', '이용개월수_신용_R12M', '이용개월수_신판_R12M', '이용개월수_일시불_R12M', '이용개월수_할부_R12M', '이용개월수_할부_유이자_R12M', '이용개월수_할부_무이자_R12M', '이용개월수_부분무이자_R12M', '이용개월수_CA_R12M', '이용개월수_체크_R12M', '이용개월수_카드론_R12M', '이용건수_신용_R6M', '이용건수_신판_R6M', '이용건수_일시불_R6M', '이용건수_할부_R6M', '이용건수_할부_유이자_R6M', '이용건수_할부_무이자_R6M', '이용건수_부분무이자_R6M', '이용건수_CA_R6M', '이용건수_체크_R6M', '이용건수_카드론_R6M', '이용금액_일시불_R6M', '이용금액_할부_R6M', '이용금액_할부_유이자_R6M', '이용금액_할부_무이자_R6M', '이용금액_부분무이자_R6M', '이용금액_CA_R6M', '이용금액_체크_R6M', '이용금액_카드론_R6M', '이용개월수_신용_R6M', '이용개월수_신판_R6M', '이용개월수_일시불_R6M', '이용개월수_할부_R6M', '이용개월수_할부_유이자_R6M', '이용개월수_할부_무이자_R6M', '이용개월수_부분무이자_R6M', '이용개월수_CA_R6M', '이용개월수_체크_R6M', '이용개월수_카드론_R6M', '이용건수_신용_R3M', '이용건수_신판_R3M', '이용건수_일시불_R3M', '이용건수_할부_R3M', '이용건수_할부_유이자_R3M', '이용건수_할부_무이자_R3M', '이용건수_부분무이자_R3M', '이용건수_CA_R3M', '이용건수_체크_R3M', '이용건수_카드론_R3M', '이용금액_일시불_R3M', '이용금액_할부_R3M', '이용금액_할부_유이자_R3M', '이용금액_할부_무이자_R3M', '이용금액_부분무이자_R3M', '이용금액_CA_R3M', '이용금액_체크_R3M', '이용금액_카드론_R3M', '이용개월수_신용_R3M', '이용개월수_신판_R3M', '이용개월수_일시불_R3M', '이용개월수_할부_R3M', '이용개월수_할부_유이자_R3M', '이용개월수_할부_무이자_R3M', '이용개월수_부분무이자_R3M', '이용개월수_CA_R3M', '이용개월수_체크_R3M', '이용개월수_카드론_R3M', '이용가맹점수', '이용금액_해외', '_1순위업종_이용금액', '_2순위업종_이용금액', '_3순위업종_이용금액', '_1순위쇼핑업종_이용금액', '_2순위쇼핑업종_이용금액', '_3순위쇼핑업종_이용금액', '_1순위교통업종_이용금액', '_2순위교통업종_이용금액', '_3순위교통업종_이용금액', '_1순위여유업종_이용금액', '_2순위여유업종_이용금액', '_3순위여유업종_이용금액', '_1순위납부업종_이용금액', '_2순위납부업종_이용금액', '_3순위납부업종_이용금액', '할부건수_3M_R12M', '할부건수_6M_R12M', '할부건수_12M_R12M', '할부건수_14M_R12M', '할부금액_3M_R12M', '할부금액_6M_R12M', '할부금액_12M_R12M', '할부금액_14M_R12M', '할부건수_유이자_3M_R12M', '할부건수_유이 ...
# ℹ️ 'index' 컬럼을 'ID'로 변경합니다.
# ✅ ID 컬럼 확보 완료! 집계 및 시각화를 진행합니다.
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2671730198.py:65: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=x_col, y=y_col, data=data,
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\2671730198.py:65: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=x_col, y=y_col, data=data,

# %%
import numpy as np

# ---------------------------------------------------------
# A/B 구분 필살기 파생변수 생성
# ---------------------------------------------------------

# 1. [1차 필터] 우량 고객 후보군 (Premium Candidate)
# 설명: "한도가 5만 원도 안 되면 절대 A, B가 아니다"라는 규칙을 0/1로 박아줍니다.
# 효과: C, D, E 하위 그룹을 1차적으로 걸러냅니다.
threshold_limit = 50000
user_stats_df['우량후보_여부'] = (user_stats_df['평균한도금액'] >= threshold_limit).astype(int)

# 2. [A/B 분리기] 실질 여유 한도 (Real Spare Limit) ★가장 강력함★
# 공식: 평균한도 * (1 - 소진율)
# 설명: "지금 당장 융통할 수 있는 현금 여력"이 얼마인가?
#   - A (부자 & 절약): 한도(大) * 여유(大) = 결과값 [초대형] (예: 13만원)
#   - B (부자 & 낭비): 한도(中) * 여유(小) = 결과값 [중소형] (예: 6만원)
#   - C/D/E: 한도가 작아서 결과값 [소형/영(0)]
user_stats_df['실질여유한도'] = user_stats_df['평균한도금액'] * (1 - user_stats_df['평균소진율'])

# 3. [공격성 지표] 한도 대비 소비성향 (Limit Aggressiveness)
# 공식: 평균소진율 / log(평균한도)
# 설명: 한도가 큰데 소진율까지 높으면(B) 점수가 확 튀게 만듭니다.
#   - A: 분자(소진율)가 낮아서 점수가 낮음 (안정적)
#   - B: 분자(소진율)가 높고 분모(한도)는 A보다 작아서 점수가 높음 (공격적)
# (log를 씌운 이유는 한도 금액의 단위가 너무 커서 소진율이 묻히는 것을 방지하기 위함입니다)
user_stats_df['한도대비_소비성향'] = user_stats_df['평균소진율'] / np.log1p(user_stats_df['평균한도금액'])

# ---------------------------------------------------------
# 생성된 변수 검증 (A와 B가 잘 벌어졌는지 눈으로 확인)
# ---------------------------------------------------------
print("변수 생성 완료! 등급별 평균값 비교:")
check_cols = ['평균한도금액', '평균소진율', '우량후보_여부', '실질여유한도', '한도대비_소비성향']
display(user_stats_df.groupby('Segment')[check_cols].mean().round(4))
# Out:
# 변수 생성 완료! 등급별 평균값 비교:
#               평균한도금액   평균소진율  우량후보_여부       실질여유한도  한도대비_소비성향
# Segment
# A        197598.8323  0.2694   1.0000  145085.6767     0.0221
# B        126400.1250  0.4108   1.0000   77921.2250     0.0355
# C         98017.1009  0.2616   0.7928   75935.8600        inf
# D         69321.6125  0.2468   0.5877   56116.8822        inf
# E         45248.4548  0.1394   0.3458   40933.9013        inf

# %%
# 4. 장기 우량 고객 (한도 10만 & 입회 10년 이상 가정)
# '입회경과개월수_신용'이 120개월 이상인 사람
df['장기우량고객'] = ((df['카드이용한도금액'] >= 100000) & (df['입회경과개월수_신용'] >= 120)).astype(int)

# 5. 클린 신용 지표 (최근 1년 카드론/CA 이용 0건)
# B등급과 A등급을 가르는 핵심
df['클린신용지표'] = ((df['이용건수_카드론_R12M'] == 0) & (df['이용건수_CA_R12M'] == 0)).astype(int)

# 6. 할부 의존 지표 (일시불 잔액보다 할부 잔액이 많은 경우)
df['할부의존지표'] = (df['잔액_할부_B0M'] > df['잔액_일시불_B0M']).astype(int)

# ---------------------------------------------------------
# [결과 확인] 등급별 이진화 변수 적중률
# ---------------------------------------------------------
check_bin_cols = ['장기우량고객', '클린신용지표', '할부의존지표']
display(df.groupby('Segment')[check_bin_cols].mean().round(3))
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\4040194840.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['장기우량고객'] = ((df['카드이용한도금액'] >= 100000) & (df['입회경과개월수_신용'] >= 120)).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\4040194840.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['클린신용지표'] = ((df['이용건수_카드론_R12M'] == 0) & (df['이용건수_CA_R12M'] == 0)).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\4040194840.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['할부의존지표'] = (df['잔액_할부_B0M'] > df['잔액_일시불_B0M']).astype(int)
#          장기우량고객  클린신용지표  할부의존지표
# Segment
# A         0.769   0.613   0.282
# B         0.208   0.444   0.514
# C         0.197   0.652   0.220
# D         0.081   0.725   0.217
# E         0.027   0.885   0.155

# %%
numeric_cols = ['잔액_리볼빙일시불이월_B0M', '잔액_리볼빙CA이월_B0M', '변동률_잔액_B1M', '혜택수혜율_R3M']

for col in numeric_cols:
    if col in df.columns:
        # 문자열을 숫자로 변환 (오류 방지 핵심)
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

# 7. 리볼빙_사용여부 (자금 압박 상태 확인)
df['리볼빙_사용여부'] = ((df['잔액_리볼빙일시불이월_B0M'] > 0) | (df['잔액_리볼빙CA이월_B0M'] > 0)).astype(int)

# 8. 잔액_급증신호 (단기 부채 급증 감지)
df['잔액_급증신호'] = (df['변동률_잔액_B1M'] > 0.5).astype(int)

# 9. 혜택_고수혜여부 (체리피커 성향 확인)
benefit_mean = df['혜택수혜율_R3M'].mean()
df['혜택_고수혜여부'] = (df['혜택수혜율_R3M'] > benefit_mean).astype(int)

print("📊 [Segment별 파생변수 비중 요약]")
check_cols = ['리볼빙_사용여부', '잔액_급증신호', '혜택_고수혜여부']

# 등급별 평균값 계산 (해당 특성을 가진 고객의 비율)
result_table = df.groupby('Segment', observed=True)[check_cols].mean()

# % 포맷으로 깔끔하게 출력
display(result_table.round(3).style.format("{:.1%}"))
# Out:
# 📊 [Segment별 파생변수 비중 요약]
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\887937689.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['리볼빙_사용여부'] = ((df['잔액_리볼빙일시불이월_B0M'] > 0) | (df['잔액_리볼빙CA이월_B0M'] > 0)).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\887937689.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['잔액_급증신호'] = (df['변동률_잔액_B1M'] > 0.5).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_14700\887937689.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['혜택_고수혜여부'] = (df['혜택수혜율_R3M'] > benefit_mean).astype(int)
# <style type="text/css">
# </style>
# <table id="T_420f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_420f9_level0_col0" class="col_heading level0 col0" >리볼빙_사용여부</th>
#       <th id="T_420f9_level0_col1" class="col_heading level0 col1" >잔액_급증신호</th>
#       <th id="T_420f9_level0_col2" class="col_heading level0 col2" >혜택_고수혜여부</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Segment</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_420f9_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_420f9_row0_col0" class="data row0 col0" >4.3%</td>
#       <td id="T_420f9_row0_col1" class="data row0 col1" >0.2%</td>
#       <td id="T_420f9_row0_col2" class="data row0 col2" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_420f9_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_420f9_row1_col0" class="data row1 col0" >8.3%</td>
#       <td id="T_420f9_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_420f9_row1_col2" class="data row1 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_420f9_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_420f9_row2_col0" class="data row2 col0" >4.8%</td>
#       <td id="T_420f9_row2_col1" class="data row2 col1" >0.7%</td>
#       <td id="T_420f9_row2_col2" class="data row2 col2" >0.8%</td>
#     </tr>
#     <tr>
#       <th id="T_420f9_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_420f9_row3_col0" class="data row3 col0" >5.4%</td>
#       <td id="T_420f9_row3_col1" class="data row3 col1" >0.7%</td>
#       <td id="T_420f9_row3_col2" class="data row3 col2" >1.5%</td>
#     </tr>
#     <tr>
#       <th id="T_420f9_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_420f9_row4_col0" class="data row4 col0" >2.2%</td>
#       <td id="T_420f9_row4_col1" class="data row4 col1" >1.1%</td>
#       <td id="T_420f9_row4_col2" class="data row4 col2" >9.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
#이 코드는 전처리 맨 뒤쪽에 위치해야함

#1. 지나치게 값이 치우친 컬럼 제거 (모든 값이 동일한 컬럼도 여기에 포함)

threshold = 0.95 # 기준 설정 (한 값이 95% 이상 차지하면 불균형으로 간주)
imbalanced_col_names = []

print(f"[데이터 불균형 체크: 비중 {threshold*100}% 이상]")

for col in df.columns:
    if df[col].value_counts(normalize=True).iloc[0] >= threshold:
        imbalanced_col_names.append(col) 

print(f"\n불균형 컬럼 리스트: {imbalanced_col_names}")

#2. 지나치게 결측치가 많은 컬럼 제거
# 컬럼별 결측치 비율 확인 (%) / 50% 이상이면 삭제
missing_ratio = df.isnull().mean() * 100
over_50_missing_cols = missing_ratio[missing_ratio > 50].index.tolist()
print(missing_ratio[missing_ratio > 0].sort_values(ascending=False))


#3. 제거할 컬럼 적용
drop_cols = list(set(over_50_missing_cols) | set(imbalanced_col_names))
df = df.drop(columns=drop_cols)
# Out:
# [데이터 불균형 체크: 비중 95.0% 이상]
#
# 불균형 컬럼 리스트: ['소지여부_신용', '회원여부_연체', '탈회횟수_발급6개월이내', '유효카드수_신용_가족', '유효카드수_체크_가족', '이용가능카드수_신용_가족', '이용가능카드수_체크_가족', '이용카드수_신용_가족', '이용카드수_체크_가족', '이용금액_R3M_신용_가족', '이용금액_R3M_체크_가족', '_1순위신용체크구분', '연회비할인카드수_B0M', '기본연회비_B0M', '제휴연회비_B0M', '할인금액_기본연회비_B0M', '할인금액_제휴연회비_B0M', '청구금액_기본연회비_B0M', '청구금액_제휴연회비_B0M', '상품관련면제카드수_B0M', '임직원면제카드수_B0M', '우수회원면제카드수_B0M', '기타면제카드수_B0M', '자발한도감액횟수_R12M', '자발한도감액금액_R12M', '자발한도감액후경과월', '특별한도보유여부_R3M', '연체감액여부_R3M', '한도요청거절건수', '한도심사요청후경과월', '한도심사거절후경과월', '시장단기연체여부_R6M', '시장단기연체여부_R3M', '시장연체상환여부_R6M', '시장연체상환여부_R3M', '이용건수_할부_유이자_B0M', '이용건수_CA_B0M', '이용건수_카드론_B0M', '이용금액_할부_유이자_B0M', '이용금액_CA_B0M', '이용금액_카드론_B0M', '이용후경과월_부분무이자', '이용후경과월_카드론', '이용건수_부분무이자_R12M', '이용금액_부분무이자_R12M', '이용금액_카드론_R12M', '최대이용금액_부분무이자_R12M', '최대이용금액_카드론_R12M', '이용개월수_부분무이자_R12M', '이용건수_부분무이자_R6M', '이용건수_카드론_R6M', '이용금액_카드론_R6M', '이용개월수_부분무이자_R6M', '이용개월수_카드론_R6M', '이용건수_부분무이자_R3M', '이용건수_카드론_R3M', '이용금액_할부_유이자_R3M', '이용금액_카드론_R3M', '이용개월수_부분무이자_R3M', '이용개월수_카드론_R3M', '_2순위여유업종_이용금액', '_3순위여유업종_이용금액', '_3순위납부업종_이용금액', '할부건수_12M_R12M', '할부건수_14M_R12M', '할부금액_14M_R12M', '할부건수_유이자_6M_R12M', '할부건수_유이자_12M_R12M', '할부건수_유이자_14M_R12M', '할부금액_유이자_12M_R12M', '할부금액_유이자_14M_R12M', '할부건수_무이자_12M_R12M', '할부건수_무이자_14M_R12M', '할부금액_무이자_12M_R12M', '할부금액_무이자_14M_R12M', '할부건수_부분_3M_R12M', '할부건수_부분_6M_R12M', '할부건수_부분_12M_R12M', '할부건수_부분_14M_R12M', '할부금액_부분_3M_R12M', '할부금액_부분_6M_R12M', '할부금액_부분_12M_R12M', '할부금액_부분_14M_R12M', 'RP건수_아파트_B0M', 'RP건수_렌탈_B0M', 'RP건수_가스_B0M', 'RP건수_전기_B0M', 'RP건수_보험_B0M', 'RP건수_학습비_B0M', 'RP건수_유선방송_B0M', 'RP건수_건강_B0M', 'RP후경과월_아파트', 'RP후경과월_렌탈', 'RP후경과월_가스', 'RP후경과월_전기', 'RP후경과월_보험', 'RP후경과월_학습비', 'RP후경과월_유선방송', 'RP후경과월_건강', '증감_RP유형건수_전월', '증감_RP건수_통신_전월', '증감_RP건수_아파트_전월', '증감_RP건수_제휴사서비스직접판매_전월', '증감_RP건수_렌탈_전월', '증감_RP건수_가스_전월', '증감_RP건수_전기_전월', '증감_RP건수_보험_전월', '증감_RP건수_학습비_전월', '증감_RP건수_유선방송_전월', '증감_RP건수_건강_전월', '최종카드론_거치개월수', '이용개월수_당사페이_R6M', '이용개월수_당사기타_R6M', '이용개월수_B페이_R6M', '이용개월수_C페이_R6M', '이용개월수_D페이_R6M', '이용금액_당사페이_R6M', '이용금액_당사기타_R6M', '이용금액_B페이_R6M', '이용금액_C페이_R6M', '이용금액_D페이_R6M', '이용건수_당사페이_R6M', '이용건수_당사기타_R6M', '이용건수_B페이_R6M', '이용건수_C페이_R6M', '이용건수_D페이_R6M', '이용금액_당사페이_R3M', '이용금액_당사기타_R3M', '이용금액_B페이_R3M', '이용금액_C페이_R3M', '이용금액_D페이_R3M', '이용건수_당사페이_R3M', '이용건수_당사기타_R3M', '이용건수_B페이_R3M', '이용건수_C페이_R3M', '이용건수_D페이_R3M', '이용금액_당사페이_B0M', '이용금액_당사기타_B0M', '이용금액_B페이_B0M', '이용금액_C페이_B0M', '이용금액_D페이_B0M', '이용건수_당사페이_B0M', '이용건수_당사기타_B0M', '이용건수_B페이_B0M', '이용건수_C페이_B0M', '이용건수_D페이_B0M', '이용건수_선결제_R3M', '이용횟수_선결제_B0M', '이용금액_선결제_B0M', '이용건수_선결제_B0M', '이용횟수_연체_B0M', '이용금액_연체_B0M', '건수_할부전환_R6M', '건수_할부전환_R3M', '금액_할부전환_R6M', '금액_할부전환_R3M', '신청건수_ATM_CA_B0', '신청건수_ATM_CL_B0', '신청건수_ATM_CL_R6M', '승인거절건수_B0M', '승인거절건수_한도초과_B0M', '승인거절건수_BL_B0M', '승인거절건수_입력오류_B0M', '승인거절건수_기타_B0M', '승인거절건수_R3M', '승인거절건수_한도초과_R3M', '승인거절건수_BL_R3M', '승인거절건수_입력오류_R3M', '승인거절건수_기타_R3M', '대표결제방법코드', '포인트_마일리지_건별_B0M', '포인트_마일리지_건별_R3M', '포인트_마일리지_월적립_B0M', '포인트_마일리지_월적립_R3M', '포인트_포인트_월적립_B0M', '포인트_포인트_월적립_R3M', '포인트_잔여포인트_B0M', '마일_적립포인트_R12M', '마일_이용포인트_R12M', '마일_이용포인트_R3M', '마일_잔여포인트_B0M', '할인건수_B0M', '포인트_마일리지_환산_B0M', '잔액_현금서비스_B0M', '잔액_리볼빙일시불이월_B0M', '잔액_리볼빙CA이월_B0M', '카드론잔액_최종경과월', '연체잔액_B0M', '연체잔액_일시불_B0M', '연체잔액_할부_B0M', '연체잔액_현금서비스_B0M', '연체잔액_카드론_B0M', '연체잔액_대환론_B0M', '연체원금_B1M', '연체원금_B2M', '연체일수_최근', '연체원금_최근', '매각잔액_B1M', '최종연체개월수_R15M', 'RV_평균잔액_R6M', 'RV_최대잔액_R6M', 'RV_평균잔액_R3M', 'RV_최대잔액_R3M', 'RV잔액이월횟수_R6M', 'RV잔액이월횟수_R3M', '잔액_할부_해외_B0M', '연체잔액_일시불_해외_B0M', '연체잔액_RV일시불_B0M', '연체잔액_RV일시불_해외_B0M', '연체잔액_할부_해외_B0M', '연체잔액_CA_B0M', '연체잔액_CA_해외_B0M', '평잔_RV일시불_해외_3M', '평잔_할부_해외_3M', '평잔_CA_해외_3M', '평잔_RV일시불_해외_6M', '평잔_할부_해외_6M', '평잔_CA_해외_6M', '인입횟수_ARS_R6M', '이용메뉴건수_ARS_R6M', '방문횟수_모바일웹_R6M', '방문일수_모바일웹_R6M', '방문월수_모바일웹_R6M', '방문후경과월_모바일웹_R6M', '방문횟수_모바일웹_B0M', '방문일수_모바일웹_B0M', '인입횟수_금융_IB_R6M', '인입횟수_IB_B0M', '인입일수_IB_B0M', '이용메뉴건수_IB_B0M', '인입불만횟수_IB_R6M', '인입불만일수_IB_R6M', '인입불만월수_IB_R6M', '인입불만후경과월_IB_R6M', '인입불만횟수_IB_B0M', '인입불만일수_IB_B0M', '상담건수_B0M', 'IB문의건수_사용승인내역_B0M', 'IB문의건수_한도_B0M', 'IB문의건수_선결 ...
# 연체일자_B0M          99.764700
# 최종카드론_대출일자        82.862267
# 최종카드론_신청경로코드      81.600300
# 최종카드론_금융상환방식코드    81.596567
# RV신청일자            81.291800
# OS구분코드            68.040600
# _2순위신용체크구분        39.933433
# 혜택수혜율_B0M         23.210600
# 최종유효년월_신용_이용      22.301600
# 잔여유효개월_실이용        22.301600
# Segment           20.000000
# 최종유효년월_신용_이용가능     8.786533
# 최종카드발급일자           1.760633
# _1순위신용체크구분         1.172700
# dtype: float64

# %% [markdown]
# ### 나머지 과정 전처리

# %%
# 문자열 관련 부분 제거 혹은 변경
# 직접 확인해봤었던만큼, 상관관계나 분류에 관련된 부분은 찾을 수 없었다.
df = df.drop(['연령', '_2순위신용체크구분', 'Life_Stage', '대표청구지고객주소구분코드', '대표청구서수령지구분코드',
       '청구서수령방법'], axis=1)

# %%
train_df = df[df["Segment"].notna()]
test_df = df[df["Segment"].isna()]

# %%
# 결측치 확인
print("=== 결측치 현황 ===")
print(train_df.isnull().sum())

# 수정된 결측치 제거 코드
print("\n=== 결측치 제거 시작 ===")
for col in train_df.columns:
    null_count = train_df[col].isnull().sum()
    if null_count > 0:
        mode_value = train_df[col].mode()
        if len(mode_value) > 0:
            # 핵심 변경 부분: 직접 할당
            train_df[col] = train_df[col].fillna(mode_value[0])
            
            # 제대로 채워졌는지 바로 확인
            remaining = train_df[col].isnull().sum()
            print(f"{col}: {null_count} → {remaining} (남은 결측치)")

print(f"\n=== 결측치 제거 완료 ===")
print(f"전체 남은 결측치 개수: {train_df.isnull().sum().sum()}")
# Out:
# === 결측치 현황 ===
# ID                0
# 남녀구분코드            0
# Segment           0
# 소지카드수_유효_신용       0
# 소지카드수_이용가능_신용     0
#                  ..
# 0.3이상_총이용금액       0
# 총이용금액_쇼핑교통여유납부    0
# 클린신용지표            0
# 할부의존지표            0
# 혜택_고수혜여부          0
# Length: 486, dtype: int64
#
# === 결측치 제거 시작 ===
# 최종유효년월_신용_이용가능: 210447 → 0 (남은 결측치)
# 최종유효년월_신용_이용: 534231 → 0 (남은 결측치)
# 최종카드발급일자: 41965 → 0 (남은 결측치)
# 혜택수혜율_B0M: 555522 → 0 (남은 결측치)
# 잔여유효개월_실이용: 534231 → 0 (남은 결측치)
#
# === 결측치 제거 완료 ===
# 전체 남은 결측치 개수: 0

# %%
df.to_parquet("backup.parquet")

# %%
df = pd.read_parquet('./backup.parquet') # 본인 경로에 맞게 수정

# %% [markdown]
# # 4. Modeling(1) - feature importance

# %%
import pandas as pd
import numpy as np
import gc

# from google.colab import drive
# drive.mount('/content/drive')

import sklearn
from sklearn.utils.class_weight import compute_class_weight
import imblearn
from imblearn.over_sampling import SMOTE
import xgboost as xgb
from xgboost import XGBClassifier

# %%
df = pd.read_parquet('./backup.parquet') # 본인 경로에 맞게 수정
# 백업파일 명 "backup.parquet"
train_df = df[df["Segment"].notna()]
test_df = df[df["Segment"].isna()]

# 결측치 확인
print("=== 결측치 현황 ===")
print(train_df.isnull().sum())

# 수정된 결측치 제거 코드
print("\n=== 결측치 제거 시작 ===")
for col in train_df.columns:
    null_count = train_df[col].isnull().sum()
    if null_count > 0:
        mode_value = train_df[col].mode()
        if len(mode_value) > 0:
            # 핵심 변경 부분: 직접 할당
            train_df[col] = train_df[col].fillna(mode_value[0])
            
            # 제대로 채워졌는지 바로 확인
            remaining = train_df[col].isnull().sum()
            print(f"{col}: {null_count} → {remaining} (남은 결측치)")

print(f"\n=== 결측치 제거 완료 ===")
print(f"전체 남은 결측치 개수: {train_df.isnull().sum().sum()}")

# 최적화, df 날려버리기 : 백업 파일 있으니 필요하면 사용할 것
del df
gc.collect()

feature_cols = [col for col in train_df.columns if col not in ["ID", "Segment"]]
X = train_df[feature_cols].copy()
y = train_df["Segment"].copy()
y = y.map({'A':0, 'B':1,'C':2,'D':3,'E':4})

del train_df
gc.collect()
# Out:
# === 결측치 현황 ===
# ID                0
# 남녀구분코드            0
# Segment           0
# 소지카드수_유효_신용       0
# 소지카드수_이용가능_신용     0
#                  ..
# 0.3이상_총이용금액       0
# 총이용금액_쇼핑교통여유납부    0
# 클린신용지표            0
# 할부의존지표            0
# 혜택_고수혜여부          0
# Length: 486, dtype: int64
#
# === 결측치 제거 시작 ===
# 최종유효년월_신용_이용가능: 210447 → 0 (남은 결측치)
# 최종유효년월_신용_이용: 534231 → 0 (남은 결측치)
# 최종카드발급일자: 41965 → 0 (남은 결측치)
# 혜택수혜율_B0M: 555522 → 0 (남은 결측치)
# 잔여유효개월_실이용: 534231 → 0 (남은 결측치)
#
# === 결측치 제거 완료 ===
# 전체 남은 결측치 개수: 0
# 0

# %%
# 클래스 weight 계산
classes = np.unique(y)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y)
class_weights = dict(zip(classes, weights))

# 각 샘플에 대해 weight 매핑
w_train = pd.Series(y).map(class_weights)

# 전체 feature로 XGBoost 학습 (변수 중요도 추출용)
temp_model = xgb.XGBClassifier(
    objective='multi:softprob',
    num_class=5,
    eval_metric='mlogloss',
    n_estimators=700,
    tree_method='hist',
    device='cuda',
    random_state=42
    )

temp_model.fit(X, y, sample_weight = w_train, verbose=False)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=700, n_jobs=None, num_class=5, ...)

# %%
# XGBoost 기준 중요도 상위 450개 변수 추출
importance_df = pd.DataFrame({
    'feature': X.columns,
    'importance': temp_model.feature_importances_
}).sort_values(by='importance', ascending=False)

top450_features = importance_df.head(450)['feature'].tolist()

print(top450_features)

top450_df = pd.DataFrame({'feature': top450_features})
top450_df.to_csv(
    "./data/top450_features_XGB_balanced.csv", # 저장 경로(본인꺼)
    index=False,
    encoding="utf-8-sig"
)
# Out:
# ['카드이용한도금액_A수준복합', '선입금원금_B5M', '할부금액_무이자_3M_R12M', '정상청구원금_B5M', '이용금액_체크_B0M', '카드이용한도금액_B1M', '할인금액_청구서_R3M', 'CA한도금액', '정상청구원금_B0M', '카드이용한도금액_B2M', '이용금액_선결제_R3M', '정상청구원금_B2M', '이용금액_R3M_신용체크', '최대이용금액_체크_R12M', '평잔_CA_3M', '방문일수_앱_B0M', '이용개월수_할부_R3M', '이용금액_할부_무이자_R12M', 'rv최초시작후경과일', '이용개월수_할부_무이자_R6M', '연체입금원금_B5M', '이용금액_체크_R12M', '탈회횟수_발급1년이내', '여유_총이용금액', '평잔_할부_3M', '이용여부_CA', '이용금액_오프라인_B0M', '증감율_이용금액_신용_전월', '연속유실적개월수_기본_24M_카드', '이용카드수_체크', '이용금액_CA_R6M', '이용개월수_할부_유이자_R6M', 'CA이자율_할인전', '건수별평균이용금액_체크_B0M', '이용금액_할부_무이자_B0M', '카드이용한도금액', '입회일자_신용', '이용개월수_체크_R12M', '최대이용금액_CA_R12M', '잔액_현금서비스_B2M', '할인금액_R3M', '최대이용금액_일시불_R12M', '이용개월수_할부_R12M', '입회경과개월수_신용', '이용금액_체크_R6M', '이용건수_신용_R12M', '이용개월수_결제일_R6M', '이용개월수_CA_R6M', '이용후경과월_신용', '강제한도감액후경과월', '컨택건수_이용유도_LMS_B0M', '이용금액_할부_무이자_R6M', '소지카드수_유효_신용', '최대이용금액_할부_R12M', '이용금액_신용_B0M', '강제한도감액금액_R12M', '이용금액_일시불_B0M', '이용후경과월_신판', '상향가능CA한도금액_1여부', '할인금액_청구서_B0M', 'RV현금서비스이자율_할인전', '잔액_현금서비스_B1M', '건수별평균이용금액_할부_무이자_B0M', '이용금액대_점수', '정상입금원금_B2M', '이용건수_카드론_R12M', '건수별평균이용금액_신용_B0M', '이용개월수_신용_R12M', '할부건수_무이자_3M_R12M', '유효카드수_신용체크', '이용금액_해외', '이용금액_일시불_R12M', '_2순위카드이용건수', '컨택건수_이용유도_청구서_R6M', '이용금액_체크_R3M', '한도증액_R12M_여부', '최대이용금액_할부_무이자_R12M', '월상환론한도금액', '_n순위납부업종_AB', '_1순위쇼핑업종_이용금액', '카드론이용월수_누적', 'RV일시불이자율_할인전', '이용여부_할부', '월중평잔_CA', '이용건수_할부_유이자_R12M', '_1순위카드이용금액', '이용개월수_페이_오프라인_R6M', '이용후경과월_할부_유이자', '강제한도감액횟수_R12M', '소지카드수_이용가능_신용', '평잔_일시불_6M', '할부의존지표', '_1순위카드이용건수', '최초한도금액', '증감율_이용금액_신판_분기', '최종카드론이용경과월', '연체입금원금_B0M', '수신거부여부_TM', '잔액_신판ca평균한도소진율_r3m', '최종카드론_대출금액', '_2순위카드이용금액', '혜택수혜율_R3M', '평잔_RV일시불_6M', '변동률_RVCA평잔', '홈페이지_금융건수_R6M', '최종카드발급일자', '월중평잔_RV일시불', '이용개월수_체크_R3M', '증감율_이용금액_일시불_분기', '이용건수_일시불_R6M', '한도증액후경과월', '마일_적립포인트_R3M', '변동률_카드론평잔', '이용건수_할부_유이자_R6M', '청구금액_R6M', '이용건수_간편결제_B0M', '연체입금원금_B2M', '이용금액_일시불_R6M', '이용금액_오프라인_R6M', '유효카드수_신용', '평잔_3M', '증감율_이용금액_체크_분기', '이용금액_할부_유이자_R12M', '이용건수_간편결제_R3M', '평잔_할부_6M', '일시상환론한도금액', '이용개월수_카드론_R12M', '가맹점매출금액_B2M', '포인트_적립포인트_R12M', '이용개월수_체크_R6M', '이용금액_할부_R12M', '컨택건수_이용유도_LMS_R6M', '이용건수_CA_R6M', '할부금액_6M_R12M', '최종카드발급경과월', '이용가능카드수_신용체크', '이용건수_A페이_R6M', '당사멤버쉽_방문횟수_B0M', 'RP후경과월_제휴사서비스직접판매', '이용건수_페이_온라인_R6M', '평잔_6M', '이용금액_오프라인_R3M', '이용개월수_신판_R12M', '이용건수_신판_R6M', '한도증액금액_R12M', '평잔_CA_6M', '동의여부_한도증액안내', '방문일수_앱_R6M', '이용개월수_CA_R12M', '컨택건수_이용유도_EM_B0M', '_1순위여유업종_이용금액', '이용개월수_간편결제_R6M', '이용금액_신판_B0M', '잔액_신판ca최대한도소진율_r6m', '연속무실적개월수_기본_24M_카드', '_n순위업종_AB_총합', '상환개월수_결제일_R6M', '월중평잔_할부_B0M', '정상입금원금_B5M', '혜택수혜금액', '이용건수_간편결제_R6M', '최종카드론_대출이율', '남녀구분코드', '이용금액_부분무이자_R3M', '최대이용금액_할부_유이자_R12M', '이용금액_CA_R12M', '당사멤버쉽_방문월수_R6M', '이용건수_할부_R3M', '카드_즉시가용_비율', '이용건수_신판_R12M', '포인트_포인트_건별_R3M', '이용건수_할부_무이자_R3M', '할부건수_유이자_3M_R12M', '변동률_일시불평잔', '보유여부_해외겸용_본인', 'RP건수_B0M', '수신거부여부_메일', '건수별평균이용금액_할부_B0M', '이용카드수_신용체크', '_2순위업종_이용금액', '건수별평균이용금액_일시불_B0M', '잔액_신판최대한도소진율_r6m', '이용개월수_할부_유이자_R12M', '혜택수혜금액_R3M', '평잔_일시불_해외_6M', '이용후경과월_체크', '회원_이용가능_점수', '이용건수_CA_R12M', '평잔_RV일시불_3M', '쇼핑_총이용금액', '이용건수_할부_R12M', '연체건수_R6M', '잔액_신판평균한도소진율_r6m', '마케팅동의여부', '대표결제일', '최초카드론이용경과월', '컨택건수_보험_TM_R6M', '최종유효년월_신용_이용가능', '이용건수_일시불_R12M', '할부금액_3M_R12M', '이용건수_온라인_B0M', 'RV_전환가능여부_이진', '청구금액_R3M', '이용건수_신용_R6M', '컨택건수_CA_LMS_R6M', '선입금원금_B2M', '이용가맹점수', '선결제건수_R6M', '변동률_CA평잔', '_2순위쇼핑업종_이용금액', '이용건수_할부_무이자_R12M', '불만제기후경과월_R12M', '이용가능여부_해외겸용_신용_본인', '이용여부_체크', '할부건수_6M_R12M', '월중평잔_CA_B0M', '컨택건수_이용유도_청구서_B0M', 'RP후경과월_교통', '잔액_신판ca평균한도소진율_r6m', 'RP후경과월', '카드론이용금액_누적', '이용건수_신판_B0M', '이용건수_할부_유이자_R3M', '연체건수_R3M', '잔액_신판평균한도소진율_r3m', '이용금액_할부_유이자_R6M', '포인트_이용포인트_R3M', '할인건수_R3M', '이용금액_할부_무이자_R3M', '이용건수_오프라인_B0M', '_n순위교통업종_AB', 'CL이자율_할인전', '월상환론상향가능한도금액', '탈회횟수_누적', 'RP건수_제휴사서비스직접판매_B0M', '카드신청건수', '방문월수_앱_R6M', '이용건수_일시불_B0M', '이용건수_온라인_R3M', '유효카드수_체크', '수신거부여부_SMS', '이용건수_페이_온라인_B0M', '누적탈회밀도', '증감율_이용금액_일시불_전월', '포인트_포인트_건별_B0M', '잔액_할부_B0M', '포인트_이용포인트_R12M', 'RP금액_B0M', '홈페이지_선결제건수_R3M', '증감_RP건수_교통_전월', '클린신용지표', '컨택건수_이용유도_인터넷_R6M', '이용횟수_연체_R6M', '건수별평균이용금액_신판_B0M', '_2순위 ...

# %% [markdown]
# # 5. 표준화

# %%
top450_df
# Out:
#               feature
# 0      카드이용한도금액_A수준복합
# 1           선입금원금_B5M
# 2    할부금액_무이자_3M_R12M
# 3          정상청구원금_B5M
# 4         이용금액_체크_B0M
# ..                ...
# 445    이용금액_부분무이자_R6M
# 446   증감율_이용건수_일시불_전월
# 447    증감율_이용건수_할부_분기
# 448       이용금액_연체_R6M
# 449    이용메뉴건수_ARS_B0M
#
# [450 rows x 1 columns]

# %%
# 트리모델의 경우, 최적화가 영향을거의 미치지 않아서 굳이 할 필요 없다고 함
# scaler = StandardScaler()
# scaler.fit(df)

# 파일을 따로 저장해서 메모리 사용량을 줄인다.
df= pd.read_parquet("backup.parquet", engine = "fastparquet")
train_df = df.loc[df["Segment"].notna()]
for col in train_df.columns:
    null_count = train_df[col].isnull().sum()
    if null_count > 0:
        mode_value = train_df[col].mode()
        if len(mode_value) > 0:
            # 핵심 변경 부분: 직접 할당
            train_df[col] = train_df[col].fillna(mode_value[0])
            
            # 제대로 채워졌는지 바로 확인
            remaining = train_df[col].isnull().sum()
            print(f"{col}: {null_count} → {remaining} (남은 결측치)")

train_df.to_parquet("train_data.parquet")
df.loc[df["Segment"].isnull()].to_parquet("test_data.parquet")
# Out:
# 최종유효년월_신용_이용가능: 210447 → 0 (남은 결측치)
# 최종유효년월_신용_이용: 534231 → 0 (남은 결측치)
# 최종카드발급일자: 41965 → 0 (남은 결측치)
# 혜택수혜율_B0M: 555522 → 0 (남은 결측치)
# 잔여유효개월_실이용: 534231 → 0 (남은 결측치)

# %%
# 최적화 코드
del df
gc.collect()
# Out:
# 20

# %% [markdown]
# # 6. Modeling(2) - final model train

# %% [markdown]
# ## XGBoost 모델 학습

# %%
import pandas as pd
import numpy as np
import gc
import os

# [수정] 구글 드라이브 마운트 코드 삭제 (로컬에서는 불필요)
# from google.colab import drive
# drive.mount('/content/drive')

import sklearn
from sklearn.utils.class_weight import compute_class_weight
import imblearn
from imblearn.over_sampling import SMOTE
import xgboost as xgb
from xgboost import XGBClassifier

# 현재 버전 및 준비 상태 확인
print(f"XGBoost version: {xgb.__version__}")
print("환경 준비 완료! 이제 데이터를 로드하세요.")
# Out:
# XGBoost version: 3.1.3
# 환경 준비 완료! 이제 데이터를 로드하세요.

# %%
train_df = pd.read_parquet('./train_data.parquet') # 본인 경로에 맞게 수정

feature_cols = [col for col in train_df.columns if col not in ["ID", "Segment"]]
X = train_df[feature_cols].copy()
y = train_df["Segment"].copy()
y = y.map({'A':0, 'B':1,'C':2,'D':3,'E':4})
inverse_label_map = {0: 'A', 1: 'B', 2: 'C', 3: 'D', 4: 'E'}

# 변수 450개 사용
top450_df = pd.read_csv("./data/top450_features_XGB_balanced.csv") # 본인 경로에 맞게 수정
top450_features = top450_df['feature'].tolist()
X_top450 = X[top450_features]

# 오버샘플링
smote = SMOTE(sampling_strategy={0: 30000, 1: 30000, 2: 250000}, random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_top450, y)

# 클래스별 weight 계산
classes = np.unique(y_resampled)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_resampled)
class_weights = dict(zip(classes, weights))
sample_weights = pd.Series(y_resampled).map(class_weights)

for cls in sorted(class_weights):
    print(f"클래스 {cls}: weight = {class_weights[cls]:.2f}")
# Out:
# 클래스 0: weight = 17.21
# 클래스 1: weight = 17.21
# 클래스 2: weight = 2.07
# 클래스 3: weight = 1.48
# 클래스 4: weight = 0.27

# %%
xgb_model = xgb.XGBClassifier(
    objective='multi:softprob',
    num_class=5,
    eval_metric='mlogloss',
    n_estimators=5000,
    tree_method='hist',
    device='cuda',
    random_state=42
    )

# 모델 학습 (검증 없이 전체 데이터 사용)
xgb_model.fit(
    X_resampled, y_resampled,
    sample_weight=sample_weights,
    verbose=False
)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=5000, n_jobs=None, num_class=5, ...)

# %%
xgb_model.save_model('./data/softvoting_xgb_xgb변수_3_3_25.json')

# %% [markdown]
# ## LightGBM 모델 학습

# %%
import pandas as pd
import numpy as np
import gc
import sklearn
from sklearn.utils.class_weight import compute_class_weight
import imblearn
from imblearn.over_sampling import SMOTE
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation, LGBMClassifier

# 버전 확인 (이미 설치한 GPU 버전이 잘 나오는지 확인)
print(f"LightGBM 버전: {lgb.__version__}")

# from google.colab import drive
# drive.mount('/content/drive')

# # LightGBM을 위한 GPU driver 설치 코드
# !mkdir -p /etc/OpenCL/vendors && echo "libnvidia-opencl.so.1" > /etc/OpenCL/vendors/nvidia.icd
# !sudo apt install nvidia-driver-460 nvidia-cuda-toolkit clinfo
# !apt-get update --fix-missing
# !pip install -q  lightgbm==4.1.0 \
#   --config-settings=cmake.define.USE_GPU=ON \
#   --config-settings=cmake.define.OpenCL_INCLUDE_DIR="/usr/local/cuda/include/" \
#   --config-settings=cmake.define.OpenCL_LIBRARY="/usr/local/cuda/lib64/libOpenCL.so"
# Out:
# LightGBM 버전: 4.6.0

# %%
train_df = pd.read_parquet('./train_data.parquet')

feature_cols = [col for col in train_df.columns if col not in ["ID", "Segment"]]
X = train_df[feature_cols].copy()
y = train_df["Segment"].copy()
y = y.map({'A':0, 'B':1,'C':2,'D':3,'E':4})
inverse_label_map = {0: 'A', 1: 'B', 2: 'C', 3: 'D', 4: 'E'}

# 변수 450개 사용
top450_df = pd.read_csv("./data/top450_features_XGB_balanced.csv")
top450_features = top450_df['feature'].tolist()
X_top450 = X[top450_features]

# 오버샘플링
smote = SMOTE(sampling_strategy={0: 30000, 1: 30000, 2: 250000}, random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_top450, y)

# 클래스별 weight 계산
classes = np.unique(y_resampled)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_resampled)
class_weights = dict(zip(classes, weights))
sample_weights = pd.Series(y_resampled).map(class_weights)

for cls in sorted(class_weights):
    print(f"클래스 {cls}: weight = {class_weights[cls]:.2f}")
# Out:
# 클래스 0: weight = 17.21
# 클래스 1: weight = 17.21
# 클래스 2: weight = 2.07
# 클래스 3: weight = 1.48
# 클래스 4: weight = 0.27

# %%
lgb_model = LGBMClassifier(
    objective='multiclass',
    boosting_type = 'gbdt',
    metric = 'multi_logloss',
    verbosity = -1,
    random_state = 42,
    device = 'gpu',
    num_class = 5,
    gpu_platform_id = 0,
    gpu_device_id = 0,

    num_boost_round = 3348, # n_estimators
    learning_rate = 0.16304239034369372,
    num_leaves = 260,
    max_depth = 6,
    min_data_in_leaf = 1200,
    bagging_fraction = 0.8999999999999999,
    bagging_freq = 4,
    feature_fraction = 0.8,
    lambda_l1 = 4.4610495762623494e-05,
    lambda_l2 = 0.6898684039866835,
    min_gain_to_split = 0.3944497642389666
    )

# 모델 학습 (검증 없이 전체 데이터 사용)
lgb_model.fit(
    X_resampled, y_resampled,
    sample_weight=sample_weights,
    callbacks=[
        log_evaluation(period=0)  # ✅ verbose_eval=False랑 같음!
        ]
)
# Out:
# LGBMClassifier(bagging_fraction=0.8999999999999999, bagging_freq=4,
#                device='gpu', feature_fraction=0.8, gpu_device_id=0,
#                gpu_platform_id=0, lambda_l1=4.4610495762623494e-05,
#                lambda_l2=0.6898684039866835, learning_rate=0.16304239034369372,
#                max_depth=6, metric='multi_logloss', min_data_in_leaf=1200,
#                min_gain_to_split=0.3944497642389666, num_boost_round=3348,
#                num_class=5, num_leaves=260, objective='multiclass',
#                random_state=42, verbosity=-1)

# %%
lgb_model.booster_.save_model('./data/softvoting_lgbm_model_3_3_25.txt')
print("모델 저장 완료!")
# Out:
# 모델 저장 완료!

# %% [markdown]
# ## CatBoost 모델 학습

# %%
import pandas as pd
import numpy as np
import gc

# from google.colab import drive
# drive.mount('/content/drive')

# # catboost 설치
# !pip install catboost

import sklearn
from sklearn.utils.class_weight import compute_class_weight
import imblearn
from imblearn.over_sampling import SMOTE
import xgboost as xgb
from xgboost import XGBClassifier
import catboost
from catboost import CatBoostClassifier

print(f"CatBoost 버전: {catboost.__version__}")
print("환경 준비 완료!")
# Out:
# CatBoost 버전: 1.2.8
# 환경 준비 완료!

# %%
train_df = pd.read_parquet('./train_data.parquet')

feature_cols = [col for col in train_df.columns if col not in ["ID", "Segment"]]
X = train_df[feature_cols].copy()
y = train_df["Segment"].copy()
y = y.map({'A':0, 'B':1,'C':2,'D':3,'E':4})
inverse_label_map = {0: 'A', 1: 'B', 2: 'C', 3: 'D', 4: 'E'}

# 변수 450개 사용
top450_df = pd.read_csv("./data/top450_features_XGB_balanced.csv")
top450_features = top450_df['feature'].tolist()
X_top450 = X[top450_features]

# 오버샘플링
smote = SMOTE(sampling_strategy={0: 60000, 1: 120000, 2: 240000}, random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_top450, y)

# 클래스별 weight 계산
classes = np.unique(y_resampled)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_resampled)
class_weights = dict(zip(classes, weights))
sample_weights = pd.Series(y_resampled).map(class_weights)

for cls in sorted(class_weights):
    print(f"클래스 {cls}: weight = {class_weights[cls]:.2f}")
# Out:
# 클래스 0: weight = 8.97
# 클래스 1: weight = 4.49
# 클래스 2: weight = 2.24
# 클래스 3: weight = 1.54
# 클래스 4: weight = 0.28

# %%
cat_model = CatBoostClassifier(
    task_type='GPU',
    devices='0',
    random_state=42,
    class_weights=weights.tolist(),
    iterations = 5000
)

# 모델 학습
cat_model.fit(X_resampled, y_resampled)
# Out:
# Learning rate set to 0.085066
# 0:	learn: 1.4418350	total: 350ms	remaining: 29m 7s
# 1:	learn: 1.3198794	total: 555ms	remaining: 23m 6s
# 2:	learn: 1.2211887	total: 739ms	remaining: 20m 30s
# 3:	learn: 1.1391459	total: 931ms	remaining: 19m 23s
# 4:	learn: 1.0739263	total: 1.15s	remaining: 19m 12s
# 5:	learn: 1.0164595	total: 1.34s	remaining: 18m 33s
# 6:	learn: 0.9649881	total: 1.52s	remaining: 18m 8s
# 7:	learn: 0.9200882	total: 1.74s	remaining: 18m 5s
# 8:	learn: 0.8822447	total: 1.98s	remaining: 18m 20s
# 9:	learn: 0.8462403	total: 2.21s	remaining: 18m 24s
# 10:	learn: 0.8131447	total: 2.42s	remaining: 18m 19s
# 11:	learn: 0.7838568	total: 2.66s	remaining: 18m 24s
# 12:	learn: 0.7588684	total: 2.82s	remaining: 18m 2s
# 13:	learn: 0.7349982	total: 3.09s	remaining: 18m 20s
# 14:	learn: 0.7126846	total: 3.34s	remaining: 18m 29s
# 15:	learn: 0.6925828	total: 3.58s	remaining: 18m 33s
# 16:	learn: 0.6753526	total: 3.76s	remaining: 18m 23s
# 17:	learn: 0.6585588	total: 4.01s	remaining: 18m 31s
# 18:	learn: 0.6424607	total: 4.23s	remaining: 18m 28s
# 19:	learn: 0.6286595	total: 4.42s	remaining: 18m 21s
# 20:	learn: 0.6158865	total: 4.62s	remaining: 18m 15s
# 21:	learn: 0.6039643	total: 4.86s	remaining: 18m 20s
# 22:	learn: 0.5925288	total: 5.14s	remaining: 18m 31s
# 23:	learn: 0.5817633	total: 5.48s	remaining: 18m 56s
# 24:	learn: 0.5722542	total: 5.83s	remaining: 19m 19s
# 25:	learn: 0.5634510	total: 6.58s	remaining: 20m 58s
# 26:	learn: 0.5551263	total: 6.86s	remaining: 21m 3s
# 27:	learn: 0.5474582	total: 7.28s	remaining: 21m 32s
# 28:	learn: 0.5395755	total: 7.67s	remaining: 21m 55s
# 29:	learn: 0.5320998	total: 8.08s	remaining: 22m 19s
# 30:	learn: 0.5260168	total: 8.6s	remaining: 22m 57s
# 31:	learn: 0.5191877	total: 9.22s	remaining: 23m 51s
# 32:	learn: 0.5138316	total: 9.68s	remaining: 24m 16s
# 33:	learn: 0.5074496	total: 10s	remaining: 24m 25s
# 34:	learn: 0.5032497	total: 10.5s	remaining: 24m 53s
# 35:	learn: 0.4985037	total: 10.8s	remaining: 24m 54s
# 36:	learn: 0.4934722	total: 11s	remaining: 24m 35s
# 37:	learn: 0.4897675	total: 11.2s	remaining: 24m 20s
# 38:	learn: 0.4853911	total: 11.4s	remaining: 24m 9s
# 39:	learn: 0.4807571	total: 11.7s	remaining: 24m 7s
# 40:	learn: 0.4776280	total: 12s	remaining: 24m 9s
# 41:	learn: 0.4734299	total: 12.4s	remaining: 24m 18s
# 42:	learn: 0.4706296	total: 12.6s	remaining: 24m 13s
# 43:	learn: 0.4663693	total: 12.8s	remaining: 23m 57s
# 44:	learn: 0.4632692	total: 13s	remaining: 23m 46s
# 45:	learn: 0.4597207	total: 13.1s	remaining: 23m 34s
# 46:	learn: 0.4569300	total: 13.3s	remaining: 23m 20s
# 47:	learn: 0.4534101	total: 13.5s	remaining: 23m 13s
# 48:	learn: 0.4507704	total: 13.7s	remaining: 23m 1s
# 49:	learn: 0.4482605	total: 13.9s	remaining: 22m 59s
# 50:	learn: 0.4462102	total: 14.1s	remaining: 22m 52s
# 51:	learn: 0.4432140	total: 14.4s	remaining: 22m 46s
# 52:	learn: 0.4402176	total: 14.5s	remaining: 22m 33s
# 53:	learn: 0.4380461	total: 14.7s	remaining: 22m 30s
# 54:	learn: 0.4352810	total: 14.9s	remaining: 22m 23s
# 55:	learn: 0.4327912	total: 15.2s	remaining: 22m 23s
# 56:	learn: 0.4307734	total: 15.5s	remaining: 22m 20s
# 57:	learn: 0.4283397	total: 15.7s	remaining: 22m 21s
# 58:	learn: 0.4255644	total: 16s	remaining: 22m 22s
# 59:	learn: 0.4236600	total: 16.3s	remaining: 22m 24s
# 60:	learn: 0.4221815	total: 16.5s	remaining: 22m 13s
# 61:	learn: 0.4199598	total: 16.7s	remaining: 22m 8s
# 62:	learn: 0.4177303	total: 16.9s	remaining: 22m 1s
# 63:	learn: 0.4159885	total: 17.2s	remaining: 22m 5s
# 64:	learn: 0.4143164	total: 17.4s	remaining: 22m 4s
# 65:	learn: 0.4121228	total: 17.6s	remaining: 21m 56s
# 66:	learn: 0.4107193	total: 17.8s	remaining: 21m 49s
# 67:	learn: 0.4096900	total: 18s	remaining: 21m 47s
# 68:	learn: 0.4080348	total: 18.2s	remaining: 21m 38s
# 69:	learn: 0.4058712	total: 18.4s	remaining: 21m 35s
# 70:	learn: 0.4046024	total: 18.6s	remaining: 21m 32s
# 71:	learn: 0.4033201	total: 18.8s	remaining: 21m 26s
# 72:	learn: 0.4015933	total: 19s	remaining: 21m 22s
# 73:	learn: 0.4003079	total: 19.2s	remaining: 21m 19s
# 74:	learn: 0.3990824	total: 19.5s	remaining: 21m 19s
# 75:	learn: 0.3970936	total: 19.6s	remaining: 21m 11s
# 76:	learn: 0.3961816	total: 19.8s	remaining: 21m 5s
# 77:	learn: 0.3950809	total: 20s	remaining: 21m 2s
# 78:	learn: 0.3940718	total: 20.2s	remaining: 20m 57s
# 79:	learn: 0.3932842	total: 20.4s	remaining: 20m 56s
# 80:	learn: 0.3912129	total: 20.6s	remaining: 20m 53s
# 81:	learn: 0.3899352	total: 20.8s	remaining: 20m 46s
# 82:	learn: 0.3881491	total: 21.1s	remaining: 20m 47s
# 83:	learn: 0.3867593	total: 21.3s	remaining: 20m 48s
# 84:	learn: 0.3859961	total: 21.5s	remaining: 20m 45s
# 85:	learn: 0.3849490	total: 21.7s	remaining: 20m 37s
# 86:	learn: 0.3839855	total: 21.9s	remaining: 20m 36s
# 87:	learn: 0.3827712	total: 22s	remaining: 20m 29s
# 88:	learn: 0.3814145	total: 22.2s	remaining: 20m 25s
# 89:	learn: 0.3803289	total: 22.5s	remaining: 20m 26s
# 90:	learn: 0.3792321	total: 22.6s	remaining: 20m 21s
# 91:	learn: 0.3782746	total: 22.9s	remaining: 20m 21s
# 92:	learn: 0.3767512	total: 23.1s	remaining: 20m 19s
# 93:	learn: 0.3759931	total: 23.4s	remaining: 20m 18s
# 94:	learn: 0.3744264	total: 23.6s	remaining: 20m 16s
# 95:	learn: 0.3735498	total: 23.8s	remaining: 20m 14s
# 96:	learn: 0.3726468	total: 24s	remaining: 20m 12s
# 97:	learn: 0.3715166	total: 24.1s	remaining: 20m 5s
# 98:	learn: 0.3706390	total: 24.3s	remaining: 20m 1s
# 99:	learn: 0.3698040	total: 24.5s	remaining: 19m 59s
# 100:	learn: 0.3690366	total: 24.6s	remaining: 19m 54s
# 101:	learn: 0.3677423	total: 24.8s	remaining: 19m 49s
# 102:	learn: 0.3665106	total: 25s	remaining: 19m 47s
# 103:	learn: 0.3657568	total: 25.2s	remaining: 19m 47s
# 104:	learn: 0.3650787	total: 25.4s	remaining: 19m 44s
# 105:	learn: 0.3642762	total: 25.7s	remaining: 19m 46s
# 106:	learn: 0.3634602	total: 25.9s	remaining: 19m 45s
# 107:	learn: 0.3623666	total: 26.1s	remaining: 19m 41s
# 108:	learn: 0.3614889	total: 26.3s	remaining: 19m 37s
# 109:	learn: 0.3602039	total: 26.5s	remaining: 19m 36s
# 110:	learn: 0.3595487	total: 26.7s	remaining: 19m 37s
# 111:	learn: 0.3585640	total: 26.9s	remaining: 19m 34s
# 112:	learn: 0.3577770	total: 27.2s	remaining: 19m 34s
# 113:	learn: 0.3571218	total: 27.3s	remaining: 19m 30s
# 114:	learn: 0.3565588	total: 27.6s	remaining: 19m 30s
# 115:	learn: 0.3555784	total: 27.7s	remaining: 19m 28s
# 116:	learn: 0.3545578	total: 28s	remaining: 19m 27s
# 117:	learn: 0.3540949	total: 28.1s	remaining: 19m 23s
# 118:	learn: 0.3530129	total: 28.3s	remaining: 19m 21s
# 119:	learn: 0.3523958	total: 28.5s	remaining: 19m 19s
# 120:	learn: 0.3517197	total: 28.8s	remaining: 19m 20s
# 121:	learn: 0.3508083	total: 29s	remaining: 19m 18s
# 122:	learn: 0.3498915	total: 29.2s	remaining: 19m 16s
# 123:	learn: 0.3489828	total: 29.4s	remaining: 19m 17s
# 124:	learn: 0.3483303	total: 29.7s	remaining: 19m 16s
# 125:	learn: 0.3477868	total: 29.8s	remaining: 19m 12s
# 126:	learn: 0.3471730	total: 30s	remaining: 19m 11s
# 127:	learn: 0.3462920	total: 30.6s	remaining: 19m 25s
# 128:	learn: 0.3458409	total: 30.8s	remaining: 19m 22s
# 129:	learn: 0.3449599	total: 30.9s	remaining: 19m 19s
# 130:	learn: 0.3441692	total: 31.2s	remaining: 19m 21s
# 131:	learn: 0.3436955	total: 31.4s	remaining: 19m 19s
# 132:	learn: 0.3432354	total: 31.6s	remaining: 19m 15s
# 133:	learn: 0.3427101	total: 31.9s	remaining: 19m 17s
# 134:	learn: 0.3421957	total: 32s	remaining: 19m 14s
# 135:	learn: 0.3412739	total: 32.3s	remaining: 19m 14s
# 136:	learn: 0.3409436	total: 32.4s	remaining: 19m 10s
# 137:	learn: 0.3402415	total: 32.6s	remaining: 19m 8s
# 138:	learn: 0.3394764	total: 32.8s	remaining: 19m 7s
# 139:	learn: 0.3387927	total: 33.1s	remaining: 19m 7s
# 140:	learn: 0.3380052	total: 33.3s	remaining: 19m 6s
# 141:	learn: 0.3375789	total: 33.5s	remaining: 19m 4s
# 142:	learn: 0.3371150	total: 33.7s	remaining: 19m 3s
# 143:	learn: 0.3363523	total: 33.9s	remaining: 19m 4s
# 144:	learn: 0.3356650	total: 34.5s	remaining: 19m 15s
# 145:	learn: 0.3348978	total: 34.9s	remaining: 19m 19s
# 146:	learn: 0.3344115	total: 35.4s	remaining: 19m 29s
# 147:	learn: 0.3337468	total: 35.6s	remaining: 19m 26s
# 148:	learn: 0.3331258	total: 35.7s	remaining: 19m 23s
# 149:	learn: 0.3324590	total: 36s	remaining: 19m 23s
# 150:	learn: 0.3320464	total: 36.2s	remaining: 19m 22s
# 151:	learn: 0.3315773	total: 36.4s	remaining: 19m 21s
# 152:	learn: 0.3311628	total: 36.6s	remaining: 19m 18s
# 153:	learn: 0.3305962	total: 36.7s	remaining: 19m 16s
# 154:	learn: 0.3301376	total: 37s	remaining: 19m 17s
# 155:	learn: 0.3294841	total: 37.2s	remaining: 19m 14s
# 156:	learn: 0.3290282	total: 37.4s	remaining: 19m 12s
# 157:	learn: 0.3283395	total: 37.5s	remaining: 19m 9s
# 158:	learn: 0.3278562	total: 37.7s	remaining: 19m 7s
# 159:	learn: 0.3273760	total: 37.9s	remaining: 19m 7s
# 160:	learn: 0.3269618	total: 38.1s	remaining: 19m 5s
# 161:	learn: 0.3267264	total: 38.2s	remaining: 19m 1s
# 162:	learn: 0.3262801	total: 38.4s	remaining: 18m 59s
# 163:	learn: 0.3254995	total: 38.6s	remaining: 18m 56s
# 164:	learn: 0.3249521	total: 38.8s	remaining: 18m 57s
# 165:	learn: 0.3243228	total: 39s	remaining: 18m 55s
# 166:	learn: 0.3236914	total: 39.2s	remaining: 18m 54s
# 167:	learn: 0.3232346	total: 39.5s	remaining: 18m 55s
# 168:	learn: 0.3228413	total: 39.6s	remaining: 18m 51s
# 169:	learn: 0.3222317	total: 39.8s	remaining: 18m 51s
# 170:	learn: 0.3217699	total: 40s	remaining: 18m 50s
# 171:	learn: 0.3214369	total: 40.9s	remaining: 19m 9s
# 172:	learn: 0.3210777	total: 41.1s	remaining: 19m 7s
# 173:	learn: 0.3207058	total: 41.4s	remaining: 19m 7s
# 174:	learn: 0.3202634	total: 41.5s	remaining: 19m 4s
# 175:	learn: 0.3196941	total: 41.8s	remaining: 19m 4s
# 176:	learn: 0.3193144	total: 42s	remaining: 19m 3s
# 177:	learn: 0.3189099	total: 42.3s	remaining: 19m 5s
# 178:	learn: 0.3186350	total: 42.4s	remaining: 19m 1s
# 179:	learn: 0.3182793	total: 42.5s	remaining: 18m 58s
# 180:	learn: 0.3178110	total: 42.7s	remaining: 18m 57s
# 181:	learn: 0.3172089	total: 42.9s	remaining: 18m 56s
# 182:	learn: 0.3167574	total: 43.2s	remaining: 18m 56s
# 183:	learn: 0.3163161	total: 43.4s	remaining: 18m 56s
# 184:	learn: 0.3159951	total: 43.6s	remaining: 18m 53s
# 185:	learn: 0.3154393	total: 43.7s	remaining: 18m 52s
# 186:	learn: 0.3149644	total: 44s	remaining: 18m 53s
# 187:	learn: 0.3146536	total: 44.3s	remaining: 18m 52s
# 188:	learn: 0.3143884	total: 44.4s	remaining: 18m 50s
# 189:	learn: 0.3139103	total: 44.6s	remaining: 18m 49s
# 190:	learn: 0.3133535	total: 44.8s	remaining: 18m 49s
# 191:	learn: 0.3130445	total: 45.1s	remaining: 18m 48s
# 192:	learn: 0.3126869	total: 45.2s	remaining: 18m 46s
# 193:	learn: 0.3124369	total: 45.4s	remaining: 18m 44s
# 194:	learn: 0.3119404	total: 45.6s	remaining: 18m 43s
# 195:	learn: 0.3117276	total: 45.9s	remaining: 18m 45s
# 196:	learn: 0.3114385	total: 46s	remaining: 18m 41s
# 197:	learn: 0.3111254	total: 46.2s	remaining: 18m 41s
# 198:	learn: 0.3108354	total: 46.4s	remaining: 18m 40s
# 199:	learn: 0.3104489	total: 46.8s	remaining: 18m 42s
# 200:	learn: 0.3098623	total: 47.2s	remaining: 18m 46s
# 201:	learn: 0.3094033	total: 47.4s	remaining: 18m 45s
# 202:	learn: 0.3090510	total: 47.6s	remaining: 18m 44s
# 203:	learn: 0.3086224	total: 47.9s	remaining: 18m 47s
# 204:	learn: 0.3083429	total: 48.1s	remaining: 18m 46s
# 205:	learn: 0.3081109	total: 48.3s	remaining: 18m 44s
# 206:	learn: 0.3078311	total: 48.5s	remaining: 18m 41s
# 207:	learn: 0.3074859	total: 48.7s	remaining: 18m 41s
# 208:	learn: 0.3068851	total: 48.8s	remaining: 18m 39s
# 209:	learn: 0.3063473	total: 49s	remaining: 18m 38s
# 210:	learn: 0.3060024	total: 49.1s	remaining: 18m 35s
# 211:	learn: 0.3057956	total: 49.3s	remaining: 18m 33s
# 212:	learn: 0.3053596	total: 49.5s	remaining: 18m 32s
# 213:	learn: 0.3049869	total: 49.8s	remaining: 18m 32s
# 214:	learn: 0.3044103	total: 50s	remaining: 18m 32s
# 215:	learn: 0.3038329	total: 50.3s	remaining: 18m 32s
# 216:	learn: 0.3035877	total: 50.4s	remaining: 18m 31s
# 217:	learn: 0.3033257	total: 50.6s	remaining: 18m 30s
# 218:	learn: 0.3029651	total: 50.8s	remaining: 18m 29s
# 219:	learn: 0.3027190	total: 51s	remaining: 18m 27s
# 220:	learn: 0.3023887	total: 51.2s	remaining: 18m 27s
# 221:	learn: 0.3020599	total: 51.4s	remaining: 18m 27s
# 222:	learn: 0.3015745	total: 51.6s	remaining: 18m 25s
# 223:	learn: 0.3011406	total: 51.9s	remaining: 18m 26s
# 224:	learn: 0.3007145	total: 52s	remaining: 18m 23s
# 225:	learn: 0.3002836	total: 52.2s	remaining: 18m 21s
# 226:	learn: 0.2999577	total: 52.4s	remaining: 18m 20s
# 227:	learn: 0.2997695	total: 52.5s	remaining: 18m 18s
# 228:	learn: 0.2995332	total: 52.7s	remaining: 18m 18s
# 229:	learn: 0.2989827	total: 52.9s	remaining: 18m 17s
# 230:	learn: 0.2986744	total: 53.1s	remaining: 18m 15s
# 231:	learn: 0.2983971	total: 53.3s	remaining: 18m 15s
# 232:	learn: 0.2981252	total: 53.5s	remaining: 18m 14s
# 233:	learn: 0.2978458	total: 53.7s	remaining: 18m 13s
# 234:	learn: 0.2976100	total: 53.8s	remaining: 18m 10s
# 235:	learn: 0.2973513	total: 54s	remaining: 18m 9s
# 236:	learn: 0.2970513	total: 54.2s	remaining: 18m 8s
# 237:	learn: 0.2967684	total: 54.3s	remaining: 18m 6s
# 238:	learn: 0.2965421	total: 54.5s	remaining: 18m 4s
# 239:	learn: 0.2962276	total: 54.7s	remaining: 18m 4s
# 240:	learn: 0.2960005	total: 54.8s	remaining: 18m 2s
# 241:	learn: 0.2956932	total: 55.1s	remaining: 18m 2s
# 242:	learn: 0.2953512	total: 55.2s	remaining: 18m 1s
# 243:	learn: 0.2951231	total: 55.5s	remaining: 18m 2s
# 244:	learn: 0.2947831	total: 55.8s	remaining: 18m 2s
# 245:	learn: 0.2944203	total: 55.9s	remaining: 18m
# 246:	learn: 0.2942021	total: 56.2s	remaining: 18m 1s
# 247:	learn: 0.2939685	total: 56.4s	remaining: 18m
# 248:	learn: 0.2937150	total: 56.7s	remaining: 18m 1s
# 249:	learn: 0.2934961	total: 56.8s	remaining: 17m 59s
# 250:	learn: 0.2931483	total: 57s	remaining: 17m 58s
# 251:	learn: 0.2928409	total: 57.2s	remaining: 17m 57s
# 252:	learn: 0.2925951	total: 57.4s	remaining: 17m 57s
# 253:	learn: 0.2923429	total: 57.6s	remaining: 17m 56s
# 254:	learn: 0.2921708	total: 57.7s	remaining: 17m 54s
# 255:	learn: 0.2918825	total: 57.9s	remaining: 17m 52s
# 256:	learn: 0.2916177	total: 58s	remaining: 17m 50s
# 257:	learn: 0.2914559	total: 58.1s	remaining: 17m 48s
# 258:	learn: 0.2911742	total: 58.8s	remaining: 17m 55s
# 259:	learn: 0.2908903	total: 58.9s	remaining: 17m 54s
# 260:	learn: 0.2907139	total: 59.2s	remaining: 17m 54s
# 261:	learn: 0.2902642	total: 59.4s	remaining: 17m 54s
# 262:	learn: 0.2899086	total: 59.6s	remaining: 17m 52s
# 263:	learn: 0.2894856	total: 59.8s	remaining: 17m 53s
# 264:	learn: 0.2891868	total: 60s	remaining: 17m 51s
# 265:	learn: 0.2889574	total: 1m	remaining: 17m 52s
# 266:	learn: 0.2886078	total: 1m	remaining: 17m 50s
# 267:	learn: 0.2883679	total: 1m	remaining: 17m 52s
# 268:	learn: 0.2881899	total: 1m	remaining: 17m 51s
# 269:	learn: 0.2879701	total: 1m 1s	remaining: 17m 50s
# 270:	learn: 0.2877806	total: 1m 1s	remaining: 17m 50s
# 271:	learn: 0.2875895	total: 1m 1s	remaining: 17m 49s
# 272:	learn: 0.2872824	total: 1m 1s	remaining: 17m 48s
# 273:	learn: 0.2868744	total: 1m 1s	remaining: 17m 49s
# 274:	learn: 0.2865442	total: 1m 2s	remaining: 17m 47s
# 275:	learn: 0.2862789	total: 1m 2s	remaining: 17m 46s
# 276:	learn: 0.2859417	total: 1m 2s	remaining: 17m 45s
# 277:	learn: 0.2857429	total: 1m 2s	remaining: 17m 44s
# 278:	learn: 0.2855622	total: 1m 2s	remaining: 17m 43s
# 279:	learn: 0.2852841	total: 1m 3s	remaining: 17m 44s
# 280:	learn: 0.2850620	total: 1m 3s	remaining: 17m 49s
# 281:	learn: 0.2849081	total: 1m 3s	remaining: 17m 49s
# 282:	learn: 0.2847077	total: 1m 4s	remaining: 17m 51s
# 283:	learn: 0.2845157	total: 1m 4s	remaining: 17m 49s
# 284:	learn: 0.2843149	total: 1m 4s	remaining: 17m 48s
# 285:	learn: 0.2840303	total: 1m 4s	remaining: 17m 46s
# 286:	learn: 0.2838174	total: 1m 4s	remaining: 17m 44s
# 287:	learn: 0.2834342	total: 1m 5s	remaining: 17m 44s
# 288:	learn: 0.2831418	total: 1m 5s	remaining: 17m 43s
# 289:	learn: 0.2829556	total: 1m 5s	remaining: 17m 40s
# 290:	learn: 0.2827020	total: 1m 5s	remaining: 17m 40s
# 291:	learn: 0.2824776	total: 1m 5s	remaining: 17m 38s
# 292:	learn: 0.2822868	total: 1m 5s	remaining: 17m 39s
# 293:	learn: 0.2821073	total: 1m 6s	remaining: 17m 37s
# 294:	learn: 0.2819063	total: 1m 6s	remaining: 17m 36s
# 295:	learn: 0.2816963	total: 1m 6s	remaining: 17m 36s
# 296:	learn: 0.2815189	total: 1m 6s	remaining: 17m 35s
# 297:	learn: 0.2812704	total: 1m 6s	remaining: 17m 34s
# 298:	learn: 0.2810331	total: 1m 7s	remaining: 17m 33s
# 299:	learn: 0.2807613	total: 1m 7s	remaining: 17m 32s
# 300:	learn: 0.2805562	total: 1m 7s	remaining: 17m 31s
# 301:	learn: 0.2803245	total: 1m 7s	remaining: 17m 30s
# 302:	learn: 0.2799898	total: 1m 7s	remaining: 17m 29s
# 303:	learn: 0.2797414	total: 1m 7s	remaining: 17m 28s
# 304:	learn: 0.2795236	total: 1m 8s	remaining: 17m 26s
# 305:	learn: 0.2792354	total: 1m 8s	remaining: 17m 25s
# 306:	learn: 0.2789048	total: 1m 8s	remaining: 17m 24s
# 307:	learn: 0.2787558	total: 1m 8s	remaining: 17m 23s
# 308:	learn: 0.2785458	total: 1m 8s	remaining: 17m 21s
# 309:	learn: 0.2784112	total: 1m 8s	remaining: 17m 19s
# 310:	learn: 0.2782949	total: 1m 8s	remaining: 17m 18s
# 311:	learn: 0.2781261	total: 1m 9s	remaining: 17m 17s
# 312:	learn: 0.2778848	total: 1m 9s	remaining: 17m 16s
# 313:	learn: 0.2776847	total: 1m 9s	remaining: 17m 16s
# 314:	learn: 0.2774294	total: 1m 9s	remaining: 17m 15s
# 315:	learn: 0.2770352	total: 1m 9s	remaining: 17m 14s
# 316:	learn: 0.2767699	total: 1m 9s	remaining: 17m 12s
# 317:	learn: 0.2765769	total: 1m 10s	remaining: 17m 11s
# 318:	learn: 0.2763198	total: 1m 10s	remaining: 17m 9s
# 319:	learn: 0.2760952	total: 1m 10s	remaining: 17m 9s
# 320:	learn: 0.2758787	total: 1m 10s	remaining: 17m 8s
# 321:	learn: 0.2757674	total: 1m 10s	remaining: 17m 7s
# 322:	learn: 0.2755845	total: 1m 10s	remaining: 17m 7s
# 323:	learn: 0.2754713	total: 1m 11s	remaining: 17m 5s
# 324:	learn: 0.2751859	total: 1m 11s	remaining: 17m 4s
# 325:	learn: 0.2749809	total: 1m 11s	remaining: 17m 5s
# 326:	learn: 0.2748343	total: 1m 11s	remaining: 17m 4s
# 327:	learn: 0.2746682	total: 1m 11s	remaining: 17m 2s
# 328:	learn: 0.2744047	total: 1m 11s	remaining: 17m 1s
# 329:	learn: 0.2741477	total: 1m 12s	remaining: 17m 2s
# 330:	learn: 0.2739456	total: 1m 12s	remaining: 17m
# 331:	learn: 0.2738009	total: 1m 12s	remaining: 16m 59s
# 332:	learn: 0.2736241	total: 1m 12s	remaining: 16m 58s
# 333:	learn: 0.2734418	total: 1m 12s	remaining: 16m 57s
# 334:	learn: 0.2732664	total: 1m 13s	remaining: 16m 56s
# 335:	learn: 0.2731432	total: 1m 13s	remaining: 16m 55s
# 336:	learn: 0.2729952	total: 1m 13s	remaining: 16m 55s
# 337:	learn: 0.2726907	total: 1m 13s	remaining: 16m 55s
# 338:	learn: 0.2724740	total: 1m 13s	remaining: 16m 54s
# 339:	learn: 0.2722829	total: 1m 13s	remaining: 16m 53s
# 340:	learn: 0.2720782	total: 1m 14s	remaining: 16m 52s
# 341:	learn: 0.2718896	total: 1m 14s	remaining: 16m 52s
# 342:	learn: 0.2716898	total: 1m 14s	remaining: 16m 51s
# 343:	learn: 0.2715237	total: 1m 14s	remaining: 16m 51s
# 344:	learn: 0.2711930	total: 1m 14s	remaining: 16m 50s
# 345:	learn: 0.2710185	total: 1m 15s	remaining: 16m 50s
# 346:	learn: 0.2707944	total: 1m 15s	remaining: 16m 49s
# 347:	learn: 0.2706555	total: 1m 15s	remaining: 16m 49s
# 348:	learn: 0.2705356	total: 1m 15s	remaining: 16m 47s
# 349:	learn: 0.2703599	total: 1m 15s	remaining: 16m 46s
# 350:	learn: 0.2702114	total: 1m 16s	remaining: 16m 46s
# 351:	learn: 0.2699820	total: 1m 16s	remaining: 16m 46s
# 352:	learn: 0.2697924	total: 1m 16s	remaining: 16m 45s
# 353:	learn: 0.2695778	total: 1m 16s	remaining: 16m 45s
# 354:	learn: 0.2694351	total: 1m 16s	remaining: 16m 45s
# 355:	learn: 0.2692155	total: 1m 17s	remaining: 16m 44s
# 356:	learn: 0.2689234	total: 1m 17s	remaining: 16m 43s
# 357:	learn: 0.2687412	total: 1m 17s	remaining: 16m 43s
# 358:	learn: 0.2686210	total: 1m 17s	remaining: 16m 42s
# 359:	learn: 0.2685031	total: 1m 17s	remaining: 16m 42s
# 360:	learn: 0.2682561	total: 1m 17s	remaining: 16m 41s
# 361:	learn: 0.2681077	total: 1m 18s	remaining: 16m 41s
# 362:	learn: 0.2679409	total: 1m 18s	remaining: 16m 40s
# 363:	learn: 0.2677581	total: 1m 18s	remaining: 16m 39s
# 364:	learn: 0.2673845	total: 1m 18s	remaining: 16m 39s
# 365:	learn: 0.2671522	total: 1m 18s	remaining: 16m 39s
# 366:	learn: 0.2669052	total: 1m 19s	remaining: 16m 38s
# 367:	learn: 0.2667587	total: 1m 19s	remaining: 16m 37s
# 368:	learn: 0.2665399	total: 1m 19s	remaining: 16m 37s
# 369:	learn: 0.2664287	total: 1m 19s	remaining: 16m 36s
# 370:	learn: 0.2662847	total: 1m 19s	remaining: 16m 35s
# 371:	learn: 0.2659525	total: 1m 20s	remaining: 16m 36s
# 372:	learn: 0.2657371	total: 1m 20s	remaining: 16m 34s
# 373:	learn: 0.2655996	total: 1m 20s	remaining: 16m 34s
# 374:	learn: 0.2654773	total: 1m 20s	remaining: 16m 34s
# 375:	learn: 0.2653420	total: 1m 20s	remaining: 16m 32s
# 376:	learn: 0.2651707	total: 1m 21s	remaining: 16m 33s
# 377:	learn: 0.2649682	total: 1m 21s	remaining: 16m 32s
# 378:	learn: 0.2648245	total: 1m 21s	remaining: 16m 31s
# 379:	learn: 0.2647202	total: 1m 21s	remaining: 16m 30s
# 380:	learn: 0.2646029	total: 1m 21s	remaining: 16m 32s
# 381:	learn: 0.2644402	total: 1m 22s	remaining: 16m 32s
# 382:	learn: 0.2642943	total: 1m 22s	remaining: 16m 33s
# 383:	learn: 0.2640655	total: 1m 22s	remaining: 16m 32s
# 384:	learn: 0.2639566	total: 1m 22s	remaining: 16m 31s
# 385:	learn: 0.2637807	total: 1m 22s	remaining: 16m 30s
# 386:	learn: 0.2636349	total: 1m 23s	remaining: 16m 30s
# 387:	learn: 0.2634937	total: 1m 23s	remaining: 16m 29s
# 388:	learn: 0.2633810	total: 1m 23s	remaining: 16m 29s
# 389:	learn: 0.2632195	total: 1m 23s	remaining: 16m 27s
# 390:	learn: 0.2630391	total: 1m 23s	remaining: 16m 28s
# 391:	learn: 0.2629197	total: 1m 23s	remaining: 16m 27s
# 392:	learn: 0.2627495	total: 1m 24s	remaining: 16m 27s
# 393:	learn: 0.2625407	total: 1m 24s	remaining: 16m 26s
# 394:	learn: 0.2624080	total: 1m 24s	remaining: 16m 25s
# 395:	learn: 0.2623103	total: 1m 24s	remaining: 16m 24s
# 396:	learn: 0.2621610	total: 1m 24s	remaining: 16m 23s
# 397:	learn: 0.2619266	total: 1m 25s	remaining: 16m 24s
# 398:	learn: 0.2617427	total: 1m 25s	remaining: 16m 25s
# 399:	learn: 0.2615132	total: 1m 25s	remaining: 16m 24s
# 400:	learn: 0.2613695	total: 1m 25s	remaining: 16m 24s
# 401:	learn: 0.2611382	total: 1m 26s	remaining: 16m 26s
# 402:	learn: 0.2609635	total: 1m 26s	remaining: 16m 25s
# 403:	learn: 0.2607491	total: 1m 26s	remaining: 16m 25s
# 404:	learn: 0.2606353	total: 1m 26s	remaining: 16m 25s
# 405:	learn: 0.2605148	total: 1m 27s	remaining: 16m 25s
# 406:	learn: 0.2603705	total: 1m 27s	remaining: 16m 24s
# 407:	learn: 0.2602211	total: 1m 27s	remaining: 16m 23s
# 408:	learn: 0.2601029	total: 1m 27s	remaining: 16m 23s
# 409:	learn: 0.2599693	total: 1m 27s	remaining: 16m 22s
# 410:	learn: 0.2598496	total: 1m 27s	remaining: 16m 21s
# 411:	learn: 0.2596717	total: 1m 28s	remaining: 16m 20s
# 412:	learn: 0.2594622	total: 1m 28s	remaining: 16m 19s
# 413:	learn: 0.2593532	total: 1m 28s	remaining: 16m 18s
# 414:	learn: 0.2592127	total: 1m 28s	remaining: 16m 18s
# 415:	learn: 0.2591011	total: 1m 28s	remaining: 16m 17s
# 416:	learn: 0.2589607	total: 1m 28s	remaining: 16m 17s
# 417:	learn: 0.2588251	total: 1m 29s	remaining: 16m 17s
# 418:	learn: 0.2586508	total: 1m 29s	remaining: 16m 17s
# 419:	learn: 0.2583767	total: 1m 29s	remaining: 16m 16s
# 420:	learn: 0.2582081	total: 1m 29s	remaining: 16m 14s
# 421:	learn: 0.2580492	total: 1m 29s	remaining: 16m 14s
# 422:	learn: 0.2579707	total: 1m 29s	remaining: 16m 13s
# 423:	learn: 0.2578043	total: 1m 30s	remaining: 16m 13s
# 424:	learn: 0.2576506	total: 1m 30s	remaining: 16m 12s
# 425:	learn: 0.2575234	total: 1m 30s	remaining: 16m 11s
# 426:	learn: 0.2573851	total: 1m 30s	remaining: 16m 10s
# 427:	learn: 0.2571576	total: 1m 30s	remaining: 16m 9s
# 428:	learn: 0.2570266	total: 1m 30s	remaining: 16m 9s
# 429:	learn: 0.2569063	total: 1m 31s	remaining: 16m 8s
# 430:	learn: 0.2567680	total: 1m 31s	remaining: 16m 8s
# 431:	learn: 0.2566788	total: 1m 31s	remaining: 16m 7s
# 432:	learn: 0.2565737	total: 1m 31s	remaining: 16m 7s
# 433:	learn: 0.2563504	total: 1m 31s	remaining: 16m 7s
# 434:	learn: 0.2562361	total: 1m 32s	remaining: 16m 7s
# 435:	learn: 0.2561287	total: 1m 32s	remaining: 16m 8s
# 436:	learn: 0.2560045	total: 1m 32s	remaining: 16m 11s
# 437:	learn: 0.2558732	total: 1m 33s	remaining: 16m 10s
# 438:	learn: 0.2557272	total: 1m 33s	remaining: 16m 10s
# 439:	learn: 0.2556115	total: 1m 33s	remaining: 16m 8s
# 440:	learn: 0.2555213	total: 1m 33s	remaining: 16m 8s
# 441:	learn: 0.2553960	total: 1m 33s	remaining: 16m 7s
# 442:	learn: 0.2552478	total: 1m 33s	remaining: 16m 6s
# 443:	learn: 0.2551455	total: 1m 34s	remaining: 16m 5s
# 444:	learn: 0.2550436	total: 1m 34s	remaining: 16m 5s
# 445:	learn: 0.2549387	total: 1m 34s	remaining: 16m 5s
# 446:	learn: 0.2548442	total: 1m 34s	remaining: 16m 4s
# 447:	learn: 0.2546756	total: 1m 34s	remaining: 16m 3s
# 448:	learn: 0.2544948	total: 1m 34s	remaining: 16m 2s
# 449:	learn: 0.2543786	total: 1m 35s	remaining: 16m 2s
# 450:	learn: 0.2542628	total: 1m 35s	remaining: 16m 1s
# 451:	learn: 0.2541165	total: 1m 35s	remaining: 16m 1s
# 452:	learn: 0.2540000	total: 1m 35s	remaining: 16m
# 453:	learn: 0.2539030	total: 1m 35s	remaining: 15m 59s
# 454:	learn: 0.2538134	total: 1m 35s	remaining: 15m 58s
# 455:	learn: 0.2536360	total: 1m 36s	remaining: 15m 58s
# 456:	learn: 0.2534891	total: 1m 36s	remaining: 15m 58s
# 457:	learn: 0.2534089	total: 1m 36s	remaining: 15m 57s
# 458:	learn: 0.2532784	total: 1m 36s	remaining: 15m 57s
# 459:	learn: 0.2530363	total: 1m 36s	remaining: 15m 57s
# 460:	learn: 0.2529290	total: 1m 37s	remaining: 15m 56s
# 461:	learn: 0.2528352	total: 1m 37s	remaining: 15m 56s
# 462:	learn: 0.2526893	total: 1m 37s	remaining: 15m 55s
# 463:	learn: 0.2525913	total: 1m 37s	remaining: 15m 54s
# 464:	learn: 0.2524836	total: 1m 37s	remaining: 15m 54s
# 465:	learn: 0.2523996	total: 1m 38s	remaining: 15m 53s
# 466:	learn: 0.2522901	total: 1m 38s	remaining: 15m 52s
# 467:	learn: 0.2521701	total: 1m 38s	remaining: 15m 52s
# 468:	learn: 0.2520722	total: 1m 38s	remaining: 15m 51s
# 469:	learn: 0.2519113	total: 1m 38s	remaining: 15m 50s
# 470:	learn: 0.2517683	total: 1m 38s	remaining: 15m 49s
# 471:	learn: 0.2515817	total: 1m 38s	remaining: 15m 48s
# 472:	learn: 0.2514737	total: 1m 39s	remaining: 15m 48s
# 473:	learn: 0.2513842	total: 1m 39s	remaining: 15m 48s
# 474:	learn: 0.2512631	total: 1m 39s	remaining: 15m 48s
# 475:	learn: 0.2511721	total: 1m 39s	remaining: 15m 48s
# 476:	learn: 0.2510576	total: 1m 39s	remaining: 15m 47s
# 477:	learn: 0.2509617	total: 1m 40s	remaining: 15m 46s
# 478:	learn: 0.2508849	total: 1m 40s	remaining: 15m 46s
# 479:	learn: 0.2507884	total: 1m 40s	remaining: 15m 45s
# 480:	learn: 0.2506094	total: 1m 40s	remaining: 15m 44s
# 481:	learn: 0.2504657	total: 1m 40s	remaining: 15m 44s
# 482:	learn: 0.2503711	total: 1m 40s	remaining: 15m 44s
# 483:	learn: 0.2502227	total: 1m 41s	remaining: 15m 43s
# 484:	learn: 0.2500823	total: 1m 41s	remaining: 15m 42s
# 485:	learn: 0.2499340	total: 1m 41s	remaining: 15m 41s
# 486:	learn: 0.2498540	total: 1m 41s	remaining: 15m 41s
# 487:	learn: 0.2497148	total: 1m 41s	remaining: 15m 41s
# 488:	learn: 0.2495737	total: 1m 41s	remaining: 15m 40s
# 489:	learn: 0.2495109	total: 1m 42s	remaining: 15m 40s
# 490:	learn: 0.2493898	total: 1m 42s	remaining: 15m 39s
# 491:	learn: 0.2492684	total: 1m 42s	remaining: 15m 38s
# 492:	learn: 0.2491260	total: 1m 42s	remaining: 15m 38s
# 493:	learn: 0.2490043	total: 1m 42s	remaining: 15m 37s
# 494:	learn: 0.2488509	total: 1m 43s	remaining: 15m 38s
# 495:	learn: 0.2487088	total: 1m 43s	remaining: 15m 37s
# 496:	learn: 0.2485799	total: 1m 43s	remaining: 15m 36s
# 497:	learn: 0.2483395	total: 1m 43s	remaining: 15m 36s
# 498:	learn: 0.2482311	total: 1m 43s	remaining: 15m 36s
# 499:	learn: 0.2481171	total: 1m 43s	remaining: 15m 35s
# 500:	learn: 0.2480144	total: 1m 44s	remaining: 15m 34s
# 501:	learn: 0.2479129	total: 1m 44s	remaining: 15m 33s
# 502:	learn: 0.2478288	total: 1m 44s	remaining: 15m 33s
# 503:	learn: 0.2476451	total: 1m 44s	remaining: 15m 32s
# 504:	learn: 0.2474861	total: 1m 44s	remaining: 15m 32s
# 505:	learn: 0.2473421	total: 1m 44s	remaining: 15m 32s
# 506:	learn: 0.2472261	total: 1m 45s	remaining: 15m 31s
# 507:	learn: 0.2471560	total: 1m 45s	remaining: 15m 31s
# 508:	learn: 0.2470611	total: 1m 45s	remaining: 15m 31s
# 509:	learn: 0.2469411	total: 1m 45s	remaining: 15m 30s
# 510:	learn: 0.2468543	total: 1m 46s	remaining: 15m 31s
# 511:	learn: 0.2467692	total: 1m 46s	remaining: 15m 31s
# 512:	learn: 0.2466180	total: 1m 46s	remaining: 15m 32s
# 513:	learn: 0.2464808	total: 1m 46s	remaining: 15m 32s
# 514:	learn: 0.2463712	total: 1m 47s	remaining: 15m 32s
# 515:	learn: 0.2462900	total: 1m 47s	remaining: 15m 32s
# 516:	learn: 0.2461713	total: 1m 47s	remaining: 15m 32s
# 517:	learn: 0.2460244	total: 1m 47s	remaining: 15m 31s
# 518:	learn: 0.2459380	total: 1m 47s	remaining: 15m 30s
# 519:	learn: 0.2457501	total: 1m 47s	remaining: 15m 30s
# 520:	learn: 0.2456541	total: 1m 48s	remaining: 15m 29s
# 521:	learn: 0.2454591	total: 1m 48s	remaining: 15m 29s
# 522:	learn: 0.2453779	total: 1m 48s	remaining: 15m 29s
# 523:	learn: 0.2452828	total: 1m 48s	remaining: 15m 28s
# 524:	learn: 0.2451766	total: 1m 48s	remaining: 15m 27s
# 525:	learn: 0.2450361	total: 1m 49s	remaining: 15m 27s
# 526:	learn: 0.2449714	total: 1m 49s	remaining: 15m 26s
# 527:	learn: 0.2448383	total: 1m 49s	remaining: 15m 25s
# 528:	learn: 0.2447232	total: 1m 49s	remaining: 15m 25s
# 529:	learn: 0.2445864	total: 1m 49s	remaining: 15m 25s
# 530:	learn: 0.2445186	total: 1m 49s	remaining: 15m 24s
# 531:	learn: 0.2443937	total: 1m 49s	remaining: 15m 23s
# 532:	learn: 0.2442871	total: 1m 50s	remaining: 15m 23s
# 533:	learn: 0.2442119	total: 1m 50s	remaining: 15m 23s
# 534:	learn: 0.2440333	total: 1m 50s	remaining: 15m 22s
# 535:	learn: 0.2438764	total: 1m 50s	remaining: 15m 21s
# 536:	learn: 0.2437902	total: 1m 50s	remaining: 15m 21s
# 537:	learn: 0.2436498	total: 1m 51s	remaining: 15m 21s
# 538:	learn: 0.2435027	total: 1m 51s	remaining: 15m 20s
# 539:	learn: 0.2434080	total: 1m 51s	remaining: 15m 21s
# 540:	learn: 0.2433263	total: 1m 51s	remaining: 15m 20s
# 541:	learn: 0.2432362	total: 1m 51s	remaining: 15m 19s
# 542:	learn: 0.2430962	total: 1m 51s	remaining: 15m 18s
# 543:	learn: 0.2430388	total: 1m 52s	remaining: 15m 19s
# 544:	learn: 0.2429209	total: 1m 52s	remaining: 15m 18s
# 545:	learn: 0.2427718	total: 1m 52s	remaining: 15m 18s
# 546:	learn: 0.2427002	total: 1m 52s	remaining: 15m 17s
# 547:	learn: 0.2426049	total: 1m 52s	remaining: 15m 17s
# 548:	learn: 0.2425326	total: 1m 53s	remaining: 15m 17s
# 549:	learn: 0.2424470	total: 1m 53s	remaining: 15m 17s
# 550:	learn: 0.2423582	total: 1m 53s	remaining: 15m 16s
# 551:	learn: 0.2422969	total: 1m 53s	remaining: 15m 16s
# 552:	learn: 0.2422212	total: 1m 53s	remaining: 15m 16s
# 553:	learn: 0.2420350	total: 1m 54s	remaining: 15m 16s
# 554:	learn: 0.2419604	total: 1m 54s	remaining: 15m 15s
# 555:	learn: 0.2418531	total: 1m 55s	remaining: 15m 20s
# 556:	learn: 0.2417502	total: 1m 55s	remaining: 15m 21s
# 557:	learn: 0.2416622	total: 1m 55s	remaining: 15m 20s
# 558:	learn: 0.2414887	total: 1m 55s	remaining: 15m 19s
# 559:	learn: 0.2414247	total: 1m 55s	remaining: 15m 19s
# 560:	learn: 0.2413118	total: 1m 56s	remaining: 15m 19s
# 561:	learn: 0.2411884	total: 1m 56s	remaining: 15m 19s
# 562:	learn: 0.2410568	total: 1m 56s	remaining: 15m 19s
# 563:	learn: 0.2409843	total: 1m 56s	remaining: 15m 19s
# 564:	learn: 0.2409168	total: 1m 57s	remaining: 15m 19s
# 565:	learn: 0.2408369	total: 1m 57s	remaining: 15m 18s
# 566:	learn: 0.2407142	total: 1m 57s	remaining: 15m 18s
# 567:	learn: 0.2406431	total: 1m 57s	remaining: 15m 17s
# 568:	learn: 0.2405317	total: 1m 57s	remaining: 15m 17s
# 569:	learn: 0.2404551	total: 1m 58s	remaining: 15m 18s
# 570:	learn: 0.2403734	total: 1m 58s	remaining: 15m 17s
# 571:	learn: 0.2402822	total: 1m 58s	remaining: 15m 19s
# 572:	learn: 0.2402089	total: 1m 58s	remaining: 15m 18s
# 573:	learn: 0.2401059	total: 1m 59s	remaining: 15m 17s
# 574:	learn: 0.2400157	total: 1m 59s	remaining: 15m 17s
# 575:	learn: 0.2399359	total: 1m 59s	remaining: 15m 17s
# 576:	learn: 0.2397961	total: 1m 59s	remaining: 15m 17s
# 577:	learn: 0.2396950	total: 1m 59s	remaining: 15m 16s
# 578:	learn: 0.2396169	total: 1m 59s	remaining: 15m 15s
# 579:	learn: 0.2395360	total: 2m	remaining: 15m 15s
# 580:	learn: 0.2394418	total: 2m	remaining: 15m 15s
# 581:	learn: 0.2393394	total: 2m	remaining: 15m 15s
# 582:	learn: 0.2392609	total: 2m	remaining: 15m 14s
# 583:	learn: 0.2391537	total: 2m	remaining: 15m 14s
# 584:	learn: 0.2390777	total: 2m 1s	remaining: 15m 13s
# 585:	learn: 0.2390012	total: 2m 1s	remaining: 15m 13s
# 586:	learn: 0.2389186	total: 2m 1s	remaining: 15m 13s
# 587:	learn: 0.2388424	total: 2m 1s	remaining: 15m 12s
# 588:	learn: 0.2387908	total: 2m 1s	remaining: 15m 11s
# 589:	learn: 0.2387070	total: 2m 1s	remaining: 15m 10s
# 590:	learn: 0.2386303	total: 2m 2s	remaining: 15m 11s
# 591:	learn: 0.2385579	total: 2m 2s	remaining: 15m 13s
# 592:	learn: 0.2384356	total: 2m 3s	remaining: 15m 15s
# 593:	learn: 0.2383869	total: 2m 3s	remaining: 15m 15s
# 594:	learn: 0.2383105	total: 2m 3s	remaining: 15m 16s
# 595:	learn: 0.2382393	total: 2m 3s	remaining: 15m 15s
# 596:	learn: 0.2381689	total: 2m 4s	remaining: 15m 15s
# 597:	learn: 0.2380973	total: 2m 4s	remaining: 15m 14s
# 598:	learn: 0.2380125	total: 2m 4s	remaining: 15m 13s
# 599:	learn: 0.2379112	total: 2m 4s	remaining: 15m 13s
# 600:	learn: 0.2378365	total: 2m 4s	remaining: 15m 12s
# 601:	learn: 0.2377471	total: 2m 4s	remaining: 15m 12s
# 602:	learn: 0.2376639	total: 2m 5s	remaining: 15m 11s
# 603:	learn: 0.2375494	total: 2m 5s	remaining: 15m 11s
# 604:	learn: 0.2374673	total: 2m 5s	remaining: 15m 10s
# 605:	learn: 0.2373907	total: 2m 5s	remaining: 15m 10s
# 606:	learn: 0.2372364	total: 2m 5s	remaining: 15m 10s
# 607:	learn: 0.2371502	total: 2m 5s	remaining: 15m 9s
# 608:	learn: 0.2369553	total: 2m 6s	remaining: 15m 9s
# 609:	learn: 0.2368187	total: 2m 6s	remaining: 15m 8s
# 610:	learn: 0.2367456	total: 2m 6s	remaining: 15m 8s
# 611:	learn: 0.2366803	total: 2m 6s	remaining: 15m 7s
# 612:	learn: 0.2365684	total: 2m 6s	remaining: 15m 7s
# 613:	learn: 0.2364877	total: 2m 6s	remaining: 15m 6s
# 614:	learn: 0.2364229	total: 2m 7s	remaining: 15m 6s
# 615:	learn: 0.2363253	total: 2m 7s	remaining: 15m 6s
# 616:	learn: 0.2362664	total: 2m 7s	remaining: 15m 5s
# 617:	learn: 0.2362047	total: 2m 7s	remaining: 15m 4s
# 618:	learn: 0.2360727	total: 2m 7s	remaining: 15m 3s
# 619:	learn: 0.2359670	total: 2m 7s	remaining: 15m 3s
# 620:	learn: 0.2358618	total: 2m 8s	remaining: 15m 2s
# 621:	learn: 0.2357205	total: 2m 8s	remaining: 15m 1s
# 622:	learn: 0.2356572	total: 2m 8s	remaining: 15m 1s
# 623:	learn: 0.2355712	total: 2m 8s	remaining: 15m
# 624:	learn: 0.2355040	total: 2m 8s	remaining: 14m 59s
# 625:	learn: 0.2354380	total: 2m 8s	remaining: 14m 59s
# 626:	learn: 0.2352492	total: 2m 8s	remaining: 14m 58s
# 627:	learn: 0.2351328	total: 2m 9s	remaining: 14m 58s
# 628:	learn: 0.2350342	total: 2m 9s	remaining: 14m 57s
# 629:	learn: 0.2349611	total: 2m 9s	remaining: 14m 57s
# 630:	learn: 0.2348826	total: 2m 9s	remaining: 14m 56s
# 631:	learn: 0.2348019	total: 2m 9s	remaining: 14m 56s
# 632:	learn: 0.2347202	total: 2m 9s	remaining: 14m 55s
# 633:	learn: 0.2346278	total: 2m 10s	remaining: 14m 55s
# 634:	learn: 0.2345139	total: 2m 10s	remaining: 14m 55s
# 635:	learn: 0.2344301	total: 2m 10s	remaining: 14m 54s
# 636:	learn: 0.2343365	total: 2m 10s	remaining: 14m 53s
# 637:	learn: 0.2342733	total: 2m 10s	remaining: 14m 53s
# 638:	learn: 0.2341734	total: 2m 10s	remaining: 14m 52s
# 639:	learn: 0.2340842	total: 2m 10s	remaining: 14m 51s
# 640:	learn: 0.2340133	total: 2m 11s	remaining: 14m 51s
# 641:	learn: 0.2339067	total: 2m 11s	remaining: 14m 55s
# 642:	learn: 0.2338405	total: 2m 12s	remaining: 14m 54s
# 643:	learn: 0.2337678	total: 2m 12s	remaining: 14m 54s
# 644:	learn: 0.2336955	total: 2m 12s	remaining: 14m 55s
# 645:	learn: 0.2336163	total: 2m 12s	remaining: 14m 54s
# 646:	learn: 0.2335581	total: 2m 12s	remaining: 14m 54s
# 647:	learn: 0.2334204	total: 2m 13s	remaining: 14m 53s
# 648:	learn: 0.2333452	total: 2m 13s	remaining: 14m 52s
# 649:	learn: 0.2332795	total: 2m 13s	remaining: 14m 52s
# 650:	learn: 0.2331713	total: 2m 13s	remaining: 14m 54s
# 651:	learn: 0.2331109	total: 2m 14s	remaining: 14m 56s
# 652:	learn: 0.2330601	total: 2m 14s	remaining: 14m 56s
# 653:	learn: 0.2329220	total: 2m 15s	remaining: 14m 57s
# 654:	learn: 0.2328480	total: 2m 15s	remaining: 14m 56s
# 655:	learn: 0.2327225	total: 2m 15s	remaining: 14m 55s
# 656:	learn: 0.2326676	total: 2m 15s	remaining: 14m 54s
# 657:	learn: 0.2325642	total: 2m 15s	remaining: 14m 54s
# 658:	learn: 0.2325040	total: 2m 15s	remaining: 14m 54s
# 659:	learn: 0.2324148	total: 2m 15s	remaining: 14m 53s
# 660:	learn: 0.2323506	total: 2m 16s	remaining: 14m 53s
# 661:	learn: 0.2322201	total: 2m 16s	remaining: 14m 53s
# 662:	learn: 0.2321478	total: 2m 16s	remaining: 14m 52s
# 663:	learn: 0.2320868	total: 2m 16s	remaining: 14m 52s
# 664:	learn: 0.2320164	total: 2m 16s	remaining: 14m 51s
# 665:	learn: 0.2319519	total: 2m 16s	remaining: 14m 51s
# 666:	learn: 0.2318534	total: 2m 17s	remaining: 14m 50s
# 667:	learn: 0.2317963	total: 2m 17s	remaining: 14m 49s
# 668:	learn: 0.2317226	total: 2m 17s	remaining: 14m 49s
# 669:	learn: 0.2315857	total: 2m 17s	remaining: 14m 48s
# 670:	learn: 0.2315022	total: 2m 17s	remaining: 14m 48s
# 671:	learn: 0.2314347	total: 2m 17s	remaining: 14m 48s
# 672:	learn: 0.2313277	total: 2m 18s	remaining: 14m 48s
# 673:	learn: 0.2312607	total: 2m 18s	remaining: 14m 48s
# 674:	learn: 0.2311856	total: 2m 18s	remaining: 14m 47s
# 675:	learn: 0.2311162	total: 2m 18s	remaining: 14m 47s
# 676:	learn: 0.2310543	total: 2m 18s	remaining: 14m 46s
# 677:	learn: 0.2309772	total: 2m 19s	remaining: 14m 46s
# 678:	learn: 0.2309121	total: 2m 19s	remaining: 14m 45s
# 679:	learn: 0.2308133	total: 2m 19s	remaining: 14m 45s
# 680:	learn: 0.2307130	total: 2m 19s	remaining: 14m 45s
# 681:	learn: 0.2306453	total: 2m 19s	remaining: 14m 44s
# 682:	learn: 0.2305915	total: 2m 19s	remaining: 14m 44s
# 683:	learn: 0.2305041	total: 2m 20s	remaining: 14m 43s
# 684:	learn: 0.2304508	total: 2m 20s	remaining: 14m 43s
# 685:	learn: 0.2303874	total: 2m 20s	remaining: 14m 42s
# 686:	learn: 0.2303222	total: 2m 20s	remaining: 14m 41s
# 687:	learn: 0.2302589	total: 2m 20s	remaining: 14m 41s
# 688:	learn: 0.2301760	total: 2m 20s	remaining: 14m 41s
# 689:	learn: 0.2300179	total: 2m 20s	remaining: 14m 40s
# 690:	learn: 0.2299487	total: 2m 21s	remaining: 14m 39s
# 691:	learn: 0.2298731	total: 2m 21s	remaining: 14m 39s
# 692:	learn: 0.2298331	total: 2m 21s	remaining: 14m 38s
# 693:	learn: 0.2297645	total: 2m 21s	remaining: 14m 38s
# 694:	learn: 0.2297201	total: 2m 21s	remaining: 14m 37s
# 695:	learn: 0.2296586	total: 2m 21s	remaining: 14m 37s
# 696:	learn: 0.2295972	total: 2m 21s	remaining: 14m 36s
# 697:	learn: 0.2294939	total: 2m 22s	remaining: 14m 36s
# 698:	learn: 0.2294230	total: 2m 22s	remaining: 14m 35s
# 699:	learn: 0.2293435	total: 2m 22s	remaining: 14m 35s
# 700:	learn: 0.2292732	total: 2m 22s	remaining: 14m 34s
# 701:	learn: 0.2292180	total: 2m 22s	remaining: 14m 34s
# 702:	learn: 0.2290840	total: 2m 22s	remaining: 14m 33s
# 703:	learn: 0.2290265	total: 2m 23s	remaining: 14m 33s
# 704:	learn: 0.2289329	total: 2m 23s	remaining: 14m 32s
# 705:	learn: 0.2288478	total: 2m 23s	remaining: 14m 32s
# 706:	learn: 0.2287961	total: 2m 23s	remaining: 14m 32s
# 707:	learn: 0.2287256	total: 2m 23s	remaining: 14m 32s
# 708:	learn: 0.2286045	total: 2m 24s	remaining: 14m 31s
# 709:	learn: 0.2285416	total: 2m 24s	remaining: 14m 31s
# 710:	learn: 0.2284446	total: 2m 24s	remaining: 14m 30s
# 711:	learn: 0.2283900	total: 2m 24s	remaining: 14m 30s
# 712:	learn: 0.2283334	total: 2m 24s	remaining: 14m 30s
# 713:	learn: 0.2282705	total: 2m 24s	remaining: 14m 29s
# 714:	learn: 0.2281688	total: 2m 25s	remaining: 14m 29s
# 715:	learn: 0.2281163	total: 2m 25s	remaining: 14m 28s
# 716:	learn: 0.2280686	total: 2m 25s	remaining: 14m 28s
# 717:	learn: 0.2280006	total: 2m 25s	remaining: 14m 28s
# 718:	learn: 0.2279329	total: 2m 25s	remaining: 14m 27s
# 719:	learn: 0.2278701	total: 2m 25s	remaining: 14m 27s
# 720:	learn: 0.2278124	total: 2m 26s	remaining: 14m 26s
# 721:	learn: 0.2277575	total: 2m 26s	remaining: 14m 26s
# 722:	learn: 0.2276576	total: 2m 26s	remaining: 14m 25s
# 723:	learn: 0.2275914	total: 2m 26s	remaining: 14m 25s
# 724:	learn: 0.2275315	total: 2m 26s	remaining: 14m 24s
# 725:	learn: 0.2274780	total: 2m 26s	remaining: 14m 23s
# 726:	learn: 0.2274307	total: 2m 26s	remaining: 14m 23s
# 727:	learn: 0.2273612	total: 2m 27s	remaining: 14m 23s
# 728:	learn: 0.2272601	total: 2m 27s	remaining: 14m 22s
# 729:	learn: 0.2271404	total: 2m 27s	remaining: 14m 22s
# 730:	learn: 0.2270792	total: 2m 27s	remaining: 14m 21s
# 731:	learn: 0.2270200	total: 2m 27s	remaining: 14m 21s
# 732:	learn: 0.2269425	total: 2m 27s	remaining: 14m 21s
# 733:	learn: 0.2268799	total: 2m 28s	remaining: 14m 20s
# 734:	learn: 0.2267678	total: 2m 28s	remaining: 14m 19s
# 735:	learn: 0.2266447	total: 2m 28s	remaining: 14m 19s
# 736:	learn: 0.2265918	total: 2m 28s	remaining: 14m 18s
# 737:	learn: 0.2265219	total: 2m 28s	remaining: 14m 18s
# 738:	learn: 0.2264173	total: 2m 28s	remaining: 14m 17s
# 739:	learn: 0.2263760	total: 2m 28s	remaining: 14m 17s
# 740:	learn: 0.2263165	total: 2m 29s	remaining: 14m 17s
# 741:	learn: 0.2262643	total: 2m 29s	remaining: 14m 16s
# 742:	learn: 0.2261736	total: 2m 29s	remaining: 14m 16s
# 743:	learn: 0.2261285	total: 2m 29s	remaining: 14m 15s
# 744:	learn: 0.2260220	total: 2m 29s	remaining: 14m 15s
# 745:	learn: 0.2259576	total: 2m 29s	remaining: 14m 14s
# 746:	learn: 0.2258973	total: 2m 30s	remaining: 14m 14s
# 747:	learn: 0.2258173	total: 2m 30s	remaining: 14m 13s
# 748:	learn: 0.2257526	total: 2m 30s	remaining: 14m 13s
# 749:	learn: 0.2256935	total: 2m 30s	remaining: 14m 12s
# 750:	learn: 0.2256267	total: 2m 30s	remaining: 14m 12s
# 751:	learn: 0.2255437	total: 2m 30s	remaining: 14m 11s
# 752:	learn: 0.2254808	total: 2m 30s	remaining: 14m 11s
# 753:	learn: 0.2254388	total: 2m 31s	remaining: 14m 10s
# 754:	learn: 0.2253435	total: 2m 31s	remaining: 14m 10s
# 755:	learn: 0.2252068	total: 2m 31s	remaining: 14m 10s
# 756:	learn: 0.2251278	total: 2m 31s	remaining: 14m 9s
# 757:	learn: 0.2250581	total: 2m 31s	remaining: 14m 9s
# 758:	learn: 0.2249781	total: 2m 31s	remaining: 14m 8s
# 759:	learn: 0.2249068	total: 2m 32s	remaining: 14m 8s
# 760:	learn: 0.2248144	total: 2m 32s	remaining: 14m 7s
# 761:	learn: 0.2247484	total: 2m 32s	remaining: 14m 6s
# 762:	learn: 0.2246358	total: 2m 32s	remaining: 14m 6s
# 763:	learn: 0.2245137	total: 2m 32s	remaining: 14m 6s
# 764:	learn: 0.2244703	total: 2m 32s	remaining: 14m 5s
# 765:	learn: 0.2244068	total: 2m 32s	remaining: 14m 5s
# 766:	learn: 0.2243484	total: 2m 33s	remaining: 14m 4s
# 767:	learn: 0.2243035	total: 2m 33s	remaining: 14m 4s
# 768:	learn: 0.2242189	total: 2m 33s	remaining: 14m 4s
# 769:	learn: 0.2241134	total: 2m 33s	remaining: 14m 4s
# 770:	learn: 0.2239643	total: 2m 33s	remaining: 14m 3s
# 771:	learn: 0.2239000	total: 2m 34s	remaining: 14m 3s
# 772:	learn: 0.2238296	total: 2m 34s	remaining: 14m 3s
# 773:	learn: 0.2237627	total: 2m 34s	remaining: 14m 2s
# 774:	learn: 0.2236845	total: 2m 34s	remaining: 14m 2s
# 775:	learn: 0.2236012	total: 2m 34s	remaining: 14m 2s
# 776:	learn: 0.2235119	total: 2m 34s	remaining: 14m 1s
# 777:	learn: 0.2234039	total: 2m 35s	remaining: 14m 1s
# 778:	learn: 0.2233453	total: 2m 35s	remaining: 14m
# 779:	learn: 0.2232907	total: 2m 35s	remaining: 14m
# 780:	learn: 0.2232384	total: 2m 35s	remaining: 14m
# 781:	learn: 0.2231739	total: 2m 35s	remaining: 13m 59s
# 782:	learn: 0.2230947	total: 2m 35s	remaining: 13m 59s
# 783:	learn: 0.2230489	total: 2m 36s	remaining: 13m 58s
# 784:	learn: 0.2229921	total: 2m 36s	remaining: 13m 58s
# 785:	learn: 0.2229291	total: 2m 36s	remaining: 13m 57s
# 786:	learn: 0.2228592	total: 2m 36s	remaining: 13m 57s
# 787:	learn: 0.2227463	total: 2m 36s	remaining: 13m 57s
# 788:	learn: 0.2226817	total: 2m 36s	remaining: 13m 56s
# 789:	learn: 0.2226209	total: 2m 36s	remaining: 13m 56s
# 790:	learn: 0.2225385	total: 2m 37s	remaining: 13m 56s
# 791:	learn: 0.2224855	total: 2m 37s	remaining: 13m 55s
# 792:	learn: 0.2224167	total: 2m 37s	remaining: 13m 55s
# 793:	learn: 0.2223301	total: 2m 37s	remaining: 13m 54s
# 794:	learn: 0.2222629	total: 2m 37s	remaining: 13m 54s
# 795:	learn: 0.2221625	total: 2m 37s	remaining: 13m 54s
# 796:	learn: 0.2220650	total: 2m 38s	remaining: 13m 54s
# 797:	learn: 0.2219985	total: 2m 38s	remaining: 13m 53s
# 798:	learn: 0.2219216	total: 2m 38s	remaining: 13m 53s
# 799:	learn: 0.2218661	total: 2m 38s	remaining: 13m 52s
# 800:	learn: 0.2217992	total: 2m 38s	remaining: 13m 52s
# 801:	learn: 0.2217157	total: 2m 39s	remaining: 13m 52s
# 802:	learn: 0.2216739	total: 2m 39s	remaining: 13m 51s
# 803:	learn: 0.2215840	total: 2m 39s	remaining: 13m 51s
# 804:	learn: 0.2215163	total: 2m 39s	remaining: 13m 51s
# 805:	learn: 0.2214320	total: 2m 39s	remaining: 13m 50s
# 806:	learn: 0.2213679	total: 2m 39s	remaining: 13m 50s
# 807:	learn: 0.2213152	total: 2m 40s	remaining: 13m 50s
# 808:	learn: 0.2212464	total: 2m 40s	remaining: 13m 50s
# 809:	learn: 0.2211702	total: 2m 40s	remaining: 13m 49s
# 810:	learn: 0.2210815	total: 2m 40s	remaining: 13m 49s
# 811:	learn: 0.2210432	total: 2m 40s	remaining: 13m 48s
# 812:	learn: 0.2209983	total: 2m 40s	remaining: 13m 48s
# 813:	learn: 0.2209510	total: 2m 41s	remaining: 13m 48s
# 814:	learn: 0.2209101	total: 2m 41s	remaining: 13m 47s
# 815:	learn: 0.2208182	total: 2m 41s	remaining: 13m 47s
# 816:	learn: 0.2207282	total: 2m 41s	remaining: 13m 46s
# 817:	learn: 0.2206783	total: 2m 41s	remaining: 13m 46s
# 818:	learn: 0.2206269	total: 2m 41s	remaining: 13m 46s
# 819:	learn: 0.2205657	total: 2m 42s	remaining: 13m 45s
# 820:	learn: 0.2205163	total: 2m 42s	remaining: 13m 45s
# 821:	learn: 0.2204621	total: 2m 42s	remaining: 13m 45s
# 822:	learn: 0.2204067	total: 2m 42s	remaining: 13m 44s
# 823:	learn: 0.2203323	total: 2m 42s	remaining: 13m 44s
# 824:	learn: 0.2202605	total: 2m 42s	remaining: 13m 43s
# 825:	learn: 0.2202188	total: 2m 42s	remaining: 13m 43s
# 826:	learn: 0.2201772	total: 2m 43s	remaining: 13m 42s
# 827:	learn: 0.2200482	total: 2m 43s	remaining: 13m 42s
# 828:	learn: 0.2199844	total: 2m 43s	remaining: 13m 42s
# 829:	learn: 0.2199386	total: 2m 43s	remaining: 13m 41s
# 830:	learn: 0.2198683	total: 2m 43s	remaining: 13m 41s
# 831:	learn: 0.2198004	total: 2m 43s	remaining: 13m 40s
# 832:	learn: 0.2197300	total: 2m 44s	remaining: 13m 40s
# 833:	learn: 0.2196903	total: 2m 44s	remaining: 13m 39s
# 834:	learn: 0.2196383	total: 2m 44s	remaining: 13m 39s
# 835:	learn: 0.2195592	total: 2m 44s	remaining: 13m 38s
# 836:	learn: 0.2195066	total: 2m 44s	remaining: 13m 38s
# 837:	learn: 0.2194214	total: 2m 44s	remaining: 13m 38s
# 838:	learn: 0.2193335	total: 2m 44s	remaining: 13m 37s
# 839:	learn: 0.2192521	total: 2m 45s	remaining: 13m 37s
# 840:	learn: 0.2192036	total: 2m 45s	remaining: 13m 36s
# 841:	learn: 0.2191444	total: 2m 45s	remaining: 13m 36s
# 842:	learn: 0.2190702	total: 2m 45s	remaining: 13m 36s
# 843:	learn: 0.2190004	total: 2m 45s	remaining: 13m 36s
# 844:	learn: 0.2189082	total: 2m 45s	remaining: 13m 35s
# 845:	learn: 0.2188430	total: 2m 46s	remaining: 13m 35s
# 846:	learn: 0.2187752	total: 2m 46s	remaining: 13m 35s
# 847:	learn: 0.2187269	total: 2m 46s	remaining: 13m 34s
# 848:	learn: 0.2186327	total: 2m 46s	remaining: 13m 34s
# 849:	learn: 0.2185760	total: 2m 46s	remaining: 13m 34s
# 850:	learn: 0.2185311	total: 2m 46s	remaining: 13m 34s
# 851:	learn: 0.2184904	total: 2m 47s	remaining: 13m 33s
# 852:	learn: 0.2184465	total: 2m 47s	remaining: 13m 33s
# 853:	learn: 0.2183854	total: 2m 47s	remaining: 13m 33s
# 854:	learn: 0.2183403	total: 2m 47s	remaining: 13m 32s
# 855:	learn: 0.2182589	total: 2m 47s	remaining: 13m 32s
# 856:	learn: 0.2181923	total: 2m 48s	remaining: 13m 32s
# 857:	learn: 0.2181514	total: 2m 48s	remaining: 13m 31s
# 858:	learn: 0.2181035	total: 2m 48s	remaining: 13m 31s
# 859:	learn: 0.2180608	total: 2m 48s	remaining: 13m 31s
# 860:	learn: 0.2180040	total: 2m 48s	remaining: 13m 31s
# 861:	learn: 0.2179446	total: 2m 48s	remaining: 13m 30s
# 862:	learn: 0.2178835	total: 2m 49s	remaining: 13m 30s
# 863:	learn: 0.2178312	total: 2m 49s	remaining: 13m 30s
# 864:	learn: 0.2177848	total: 2m 49s	remaining: 13m 30s
# 865:	learn: 0.2177326	total: 2m 49s	remaining: 13m 30s
# 866:	learn: 0.2176819	total: 2m 49s	remaining: 13m 29s
# 867:	learn: 0.2176434	total: 2m 49s	remaining: 13m 29s
# 868:	learn: 0.2175901	total: 2m 50s	remaining: 13m 29s
# 869:	learn: 0.2175415	total: 2m 50s	remaining: 13m 28s
# 870:	learn: 0.2174906	total: 2m 50s	remaining: 13m 28s
# 871:	learn: 0.2174402	total: 2m 50s	remaining: 13m 27s
# 872:	learn: 0.2173816	total: 2m 50s	remaining: 13m 27s
# 873:	learn: 0.2173379	total: 2m 50s	remaining: 13m 26s
# 874:	learn: 0.2172826	total: 2m 51s	remaining: 13m 26s
# 875:	learn: 0.2172241	total: 2m 51s	remaining: 13m 26s
# 876:	learn: 0.2171880	total: 2m 51s	remaining: 13m 25s
# 877:	learn: 0.2170977	total: 2m 51s	remaining: 13m 24s
# 878:	learn: 0.2170424	total: 2m 51s	remaining: 13m 24s
# 879:	learn: 0.2169962	total: 2m 51s	remaining: 13m 24s
# 880:	learn: 0.2169532	total: 2m 51s	remaining: 13m 23s
# 881:	learn: 0.2169104	total: 2m 52s	remaining: 13m 23s
# 882:	learn: 0.2168365	total: 2m 52s	remaining: 13m 23s
# 883:	learn: 0.2167793	total: 2m 52s	remaining: 13m 22s
# 884:	learn: 0.2167221	total: 2m 52s	remaining: 13m 22s
# ...
# 4710:	learn: 0.1340015	total: 33m 23s	remaining: 2m 2s
# 4711:	learn: 0.1339889	total: 33m 23s	remaining: 2m 2s
# 4712:	learn: 0.1339842	total: 33m 24s	remaining: 2m 2s
# 4713:	learn: 0.1339743	total: 33m 24s	remaining: 2m 1s
# 4714:	learn: 0.1339684	total: 33m 24s	remaining: 2m 1s
# 4715:	learn: 0.1339603	total: 33m 25s	remaining: 2m
# 4716:	learn: 0.1339485	total: 33m 25s	remaining: 2m
# 4717:	learn: 0.1339402	total: 33m 26s	remaining: 1m 59s
# 4718:	learn: 0.1339241	total: 33m 26s	remaining: 1m 59s
# 4719:	learn: 0.1339166	total: 33m 27s	remaining: 1m 59s
# 4720:	learn: 0.1339033	total: 33m 27s	remaining: 1m 58s
# 4721:	learn: 0.1338946	total: 33m 28s	remaining: 1m 58s
# 4722:	learn: 0.1338842	total: 33m 28s	remaining: 1m 57s
# 4723:	learn: 0.1338747	total: 33m 29s	remaining: 1m 57s
# 4724:	learn: 0.1338547	total: 33m 29s	remaining: 1m 56s
# 4725:	learn: 0.1338484	total: 33m 30s	remaining: 1m 56s
# 4726:	learn: 0.1338380	total: 33m 30s	remaining: 1m 56s
# 4727:	learn: 0.1338215	total: 33m 31s	remaining: 1m 55s
# 4728:	learn: 0.1338110	total: 33m 31s	remaining: 1m 55s
# 4729:	learn: 0.1338021	total: 33m 32s	remaining: 1m 54s
# 4730:	learn: 0.1337939	total: 33m 32s	remaining: 1m 54s
# 4731:	learn: 0.1337856	total: 33m 32s	remaining: 1m 54s
# 4732:	learn: 0.1337726	total: 33m 33s	remaining: 1m 53s
# 4733:	learn: 0.1337581	total: 33m 33s	remaining: 1m 53s
# 4734:	learn: 0.1337460	total: 33m 34s	remaining: 1m 52s
# 4735:	learn: 0.1337318	total: 33m 35s	remaining: 1m 52s
# 4736:	learn: 0.1337165	total: 33m 35s	remaining: 1m 51s
# 4737:	learn: 0.1337099	total: 33m 36s	remaining: 1m 51s
# 4738:	learn: 0.1337047	total: 33m 36s	remaining: 1m 51s
# 4739:	learn: 0.1336976	total: 33m 36s	remaining: 1m 50s
# 4740:	learn: 0.1336872	total: 33m 37s	remaining: 1m 50s
# 4741:	learn: 0.1336719	total: 33m 37s	remaining: 1m 49s
# 4742:	learn: 0.1336603	total: 33m 38s	remaining: 1m 49s
# 4743:	learn: 0.1336469	total: 33m 38s	remaining: 1m 48s
# 4744:	learn: 0.1336388	total: 33m 39s	remaining: 1m 48s
# 4745:	learn: 0.1336288	total: 33m 39s	remaining: 1m 48s
# 4746:	learn: 0.1336141	total: 33m 40s	remaining: 1m 47s
# 4747:	learn: 0.1336085	total: 33m 40s	remaining: 1m 47s
# 4748:	learn: 0.1335992	total: 33m 40s	remaining: 1m 46s
# 4749:	learn: 0.1335905	total: 33m 41s	remaining: 1m 46s
# 4750:	learn: 0.1335825	total: 33m 41s	remaining: 1m 45s
# 4751:	learn: 0.1335709	total: 33m 42s	remaining: 1m 45s
# 4752:	learn: 0.1335597	total: 33m 43s	remaining: 1m 45s
# 4753:	learn: 0.1335494	total: 33m 43s	remaining: 1m 44s
# 4754:	learn: 0.1335342	total: 33m 44s	remaining: 1m 44s
# 4755:	learn: 0.1335287	total: 33m 44s	remaining: 1m 43s
# 4756:	learn: 0.1335204	total: 33m 45s	remaining: 1m 43s
# 4757:	learn: 0.1335145	total: 33m 45s	remaining: 1m 43s
# 4758:	learn: 0.1335009	total: 33m 46s	remaining: 1m 42s
# 4759:	learn: 0.1334864	total: 33m 46s	remaining: 1m 42s
# 4760:	learn: 0.1334763	total: 33m 46s	remaining: 1m 41s
# 4761:	learn: 0.1334653	total: 33m 47s	remaining: 1m 41s
# 4762:	learn: 0.1334519	total: 33m 47s	remaining: 1m 40s
# 4763:	learn: 0.1334423	total: 33m 48s	remaining: 1m 40s
# 4764:	learn: 0.1334313	total: 33m 48s	remaining: 1m 40s
# 4765:	learn: 0.1334266	total: 33m 49s	remaining: 1m 39s
# 4766:	learn: 0.1334179	total: 33m 49s	remaining: 1m 39s
# 4767:	learn: 0.1334129	total: 33m 49s	remaining: 1m 38s
# 4768:	learn: 0.1333952	total: 33m 50s	remaining: 1m 38s
# 4769:	learn: 0.1333859	total: 33m 50s	remaining: 1m 37s
# 4770:	learn: 0.1333758	total: 33m 51s	remaining: 1m 37s
# 4771:	learn: 0.1333699	total: 33m 51s	remaining: 1m 37s
# 4772:	learn: 0.1333602	total: 33m 52s	remaining: 1m 36s
# 4773:	learn: 0.1333499	total: 33m 52s	remaining: 1m 36s
# 4774:	learn: 0.1333398	total: 33m 53s	remaining: 1m 35s
# 4775:	learn: 0.1333293	total: 33m 53s	remaining: 1m 35s
# 4776:	learn: 0.1333205	total: 33m 54s	remaining: 1m 34s
# 4777:	learn: 0.1333160	total: 33m 54s	remaining: 1m 34s
# 4778:	learn: 0.1332902	total: 33m 55s	remaining: 1m 34s
# 4779:	learn: 0.1332767	total: 33m 55s	remaining: 1m 33s
# 4780:	learn: 0.1332643	total: 33m 56s	remaining: 1m 33s
# 4781:	learn: 0.1332482	total: 33m 56s	remaining: 1m 32s
# 4782:	learn: 0.1332372	total: 33m 57s	remaining: 1m 32s
# 4783:	learn: 0.1332314	total: 33m 57s	remaining: 1m 32s
# 4784:	learn: 0.1332252	total: 33m 58s	remaining: 1m 31s
# 4785:	learn: 0.1332192	total: 33m 58s	remaining: 1m 31s
# 4786:	learn: 0.1332127	total: 33m 59s	remaining: 1m 30s
# 4787:	learn: 0.1331982	total: 33m 59s	remaining: 1m 30s
# 4788:	learn: 0.1331883	total: 33m 59s	remaining: 1m 29s
# 4789:	learn: 0.1331793	total: 34m	remaining: 1m 29s
# 4790:	learn: 0.1331682	total: 34m 1s	remaining: 1m 29s
# 4791:	learn: 0.1331603	total: 34m 1s	remaining: 1m 28s
# 4792:	learn: 0.1331445	total: 34m 2s	remaining: 1m 28s
# 4793:	learn: 0.1331233	total: 34m 2s	remaining: 1m 27s
# 4794:	learn: 0.1331128	total: 34m 3s	remaining: 1m 27s
# 4795:	learn: 0.1331044	total: 34m 3s	remaining: 1m 26s
# 4796:	learn: 0.1330960	total: 34m 3s	remaining: 1m 26s
# 4797:	learn: 0.1330855	total: 34m 4s	remaining: 1m 26s
# 4798:	learn: 0.1330736	total: 34m 5s	remaining: 1m 25s
# 4799:	learn: 0.1330611	total: 34m 5s	remaining: 1m 25s
# 4800:	learn: 0.1330541	total: 34m 6s	remaining: 1m 24s
# 4801:	learn: 0.1330475	total: 34m 6s	remaining: 1m 24s
# 4802:	learn: 0.1330382	total: 34m 7s	remaining: 1m 23s
# 4803:	learn: 0.1330279	total: 34m 7s	remaining: 1m 23s
# 4804:	learn: 0.1330052	total: 34m 7s	remaining: 1m 23s
# 4805:	learn: 0.1329977	total: 34m 8s	remaining: 1m 22s
# 4806:	learn: 0.1329916	total: 34m 9s	remaining: 1m 22s
# 4807:	learn: 0.1329672	total: 34m 9s	remaining: 1m 21s
# 4808:	learn: 0.1329659	total: 34m 10s	remaining: 1m 21s
# 4809:	learn: 0.1329544	total: 34m 10s	remaining: 1m 21s
# 4810:	learn: 0.1329487	total: 34m 11s	remaining: 1m 20s
# 4811:	learn: 0.1329346	total: 34m 11s	remaining: 1m 20s
# 4812:	learn: 0.1329225	total: 34m 12s	remaining: 1m 19s
# 4813:	learn: 0.1329068	total: 34m 12s	remaining: 1m 19s
# 4814:	learn: 0.1328908	total: 34m 13s	remaining: 1m 18s
# 4815:	learn: 0.1328773	total: 34m 13s	remaining: 1m 18s
# 4816:	learn: 0.1328619	total: 34m 14s	remaining: 1m 18s
# 4817:	learn: 0.1328432	total: 34m 14s	remaining: 1m 17s
# 4818:	learn: 0.1328337	total: 34m 15s	remaining: 1m 17s
# 4819:	learn: 0.1328224	total: 34m 16s	remaining: 1m 16s
# 4820:	learn: 0.1328113	total: 34m 16s	remaining: 1m 16s
# 4821:	learn: 0.1328034	total: 34m 17s	remaining: 1m 15s
# 4822:	learn: 0.1327964	total: 34m 17s	remaining: 1m 15s
# 4823:	learn: 0.1327824	total: 34m 17s	remaining: 1m 15s
# 4824:	learn: 0.1327755	total: 34m 18s	remaining: 1m 14s
# 4825:	learn: 0.1327704	total: 34m 18s	remaining: 1m 14s
# 4826:	learn: 0.1327635	total: 34m 19s	remaining: 1m 13s
# 4827:	learn: 0.1327564	total: 34m 19s	remaining: 1m 13s
# 4828:	learn: 0.1327478	total: 34m 19s	remaining: 1m 12s
# 4829:	learn: 0.1327442	total: 34m 20s	remaining: 1m 12s
# 4830:	learn: 0.1327395	total: 34m 20s	remaining: 1m 12s
# 4831:	learn: 0.1327119	total: 34m 21s	remaining: 1m 11s
# 4832:	learn: 0.1326938	total: 34m 22s	remaining: 1m 11s
# 4833:	learn: 0.1326878	total: 34m 22s	remaining: 1m 10s
# 4834:	learn: 0.1326751	total: 34m 23s	remaining: 1m 10s
# 4835:	learn: 0.1326619	total: 34m 23s	remaining: 1m 9s
# 4836:	learn: 0.1326455	total: 34m 24s	remaining: 1m 9s
# 4837:	learn: 0.1326330	total: 34m 24s	remaining: 1m 9s
# 4838:	learn: 0.1326248	total: 34m 25s	remaining: 1m 8s
# 4839:	learn: 0.1326152	total: 34m 26s	remaining: 1m 8s
# 4840:	learn: 0.1326018	total: 34m 26s	remaining: 1m 7s
# 4841:	learn: 0.1325965	total: 34m 26s	remaining: 1m 7s
# 4842:	learn: 0.1325910	total: 34m 27s	remaining: 1m 7s
# 4843:	learn: 0.1325711	total: 34m 27s	remaining: 1m 6s
# 4844:	learn: 0.1325659	total: 34m 28s	remaining: 1m 6s
# 4845:	learn: 0.1325600	total: 34m 28s	remaining: 1m 5s
# 4846:	learn: 0.1325529	total: 34m 28s	remaining: 1m 5s
# 4847:	learn: 0.1325417	total: 34m 29s	remaining: 1m 4s
# 4848:	learn: 0.1325328	total: 34m 29s	remaining: 1m 4s
# 4849:	learn: 0.1325292	total: 34m 30s	remaining: 1m 4s
# 4850:	learn: 0.1325228	total: 34m 30s	remaining: 1m 3s
# 4851:	learn: 0.1325122	total: 34m 30s	remaining: 1m 3s
# 4852:	learn: 0.1325079	total: 34m 31s	remaining: 1m 2s
# 4853:	learn: 0.1324974	total: 34m 31s	remaining: 1m 2s
# 4854:	learn: 0.1324879	total: 34m 32s	remaining: 1m 1s
# 4855:	learn: 0.1324816	total: 34m 32s	remaining: 1m 1s
# 4856:	learn: 0.1324740	total: 34m 33s	remaining: 1m 1s
# 4857:	learn: 0.1324696	total: 34m 33s	remaining: 1m
# 4858:	learn: 0.1324574	total: 34m 34s	remaining: 1m
# 4859:	learn: 0.1324525	total: 34m 34s	remaining: 59.8s
# 4860:	learn: 0.1324429	total: 34m 35s	remaining: 59.3s
# 4861:	learn: 0.1324327	total: 34m 35s	remaining: 58.9s
# 4862:	learn: 0.1324220	total: 34m 36s	remaining: 58.5s
# 4863:	learn: 0.1324060	total: 34m 36s	remaining: 58.1s
# 4864:	learn: 0.1323926	total: 34m 37s	remaining: 57.6s
# 4865:	learn: 0.1323767	total: 34m 37s	remaining: 57.2s
# 4866:	learn: 0.1323622	total: 34m 37s	remaining: 56.8s
# 4867:	learn: 0.1323583	total: 34m 38s	remaining: 56.4s
# 4868:	learn: 0.1323516	total: 34m 38s	remaining: 55.9s
# 4869:	learn: 0.1323446	total: 34m 39s	remaining: 55.5s
# 4870:	learn: 0.1323412	total: 34m 39s	remaining: 55.1s
# 4871:	learn: 0.1323341	total: 34m 40s	remaining: 54.7s
# 4872:	learn: 0.1323263	total: 34m 40s	remaining: 54.2s
# 4873:	learn: 0.1323183	total: 34m 40s	remaining: 53.8s
# 4874:	learn: 0.1323051	total: 34m 41s	remaining: 53.4s
# 4875:	learn: 0.1322944	total: 34m 42s	remaining: 53s
# 4876:	learn: 0.1322792	total: 34m 42s	remaining: 52.5s
# 4877:	learn: 0.1322696	total: 34m 43s	remaining: 52.1s
# 4878:	learn: 0.1322609	total: 34m 43s	remaining: 51.7s
# 4879:	learn: 0.1322472	total: 34m 44s	remaining: 51.2s
# 4880:	learn: 0.1322380	total: 34m 44s	remaining: 50.8s
# 4881:	learn: 0.1322312	total: 34m 45s	remaining: 50.4s
# 4882:	learn: 0.1322225	total: 34m 45s	remaining: 50s
# 4883:	learn: 0.1322162	total: 34m 46s	remaining: 49.6s
# 4884:	learn: 0.1322005	total: 34m 47s	remaining: 49.1s
# 4885:	learn: 0.1321919	total: 34m 48s	remaining: 48.7s
# 4886:	learn: 0.1321786	total: 34m 48s	remaining: 48.3s
# 4887:	learn: 0.1321680	total: 34m 49s	remaining: 47.9s
# 4888:	learn: 0.1321615	total: 34m 49s	remaining: 47.4s
# 4889:	learn: 0.1321541	total: 34m 50s	remaining: 47s
# 4890:	learn: 0.1321437	total: 34m 50s	remaining: 46.6s
# 4891:	learn: 0.1321356	total: 34m 51s	remaining: 46.2s
# 4892:	learn: 0.1321249	total: 34m 51s	remaining: 45.7s
# 4893:	learn: 0.1321155	total: 34m 52s	remaining: 45.3s
# 4894:	learn: 0.1321103	total: 34m 52s	remaining: 44.9s
# 4895:	learn: 0.1321002	total: 34m 53s	remaining: 44.5s
# 4896:	learn: 0.1320888	total: 34m 53s	remaining: 44s
# 4897:	learn: 0.1320825	total: 34m 54s	remaining: 43.6s
# 4898:	learn: 0.1320730	total: 34m 54s	remaining: 43.2s
# 4899:	learn: 0.1320571	total: 34m 55s	remaining: 42.8s
# 4900:	learn: 0.1320480	total: 34m 56s	remaining: 42.3s
# 4901:	learn: 0.1320417	total: 34m 56s	remaining: 41.9s
# 4902:	learn: 0.1320324	total: 34m 57s	remaining: 41.5s
# 4903:	learn: 0.1320272	total: 34m 57s	remaining: 41.1s
# 4904:	learn: 0.1320217	total: 34m 58s	remaining: 40.6s
# 4905:	learn: 0.1320132	total: 34m 58s	remaining: 40.2s
# 4906:	learn: 0.1320022	total: 34m 59s	remaining: 39.8s
# 4907:	learn: 0.1319927	total: 34m 59s	remaining: 39.4s
# 4908:	learn: 0.1319755	total: 34m 59s	remaining: 38.9s
# 4909:	learn: 0.1319664	total: 35m	remaining: 38.5s
# 4910:	learn: 0.1319589	total: 35m	remaining: 38.1s
# 4911:	learn: 0.1319467	total: 35m 1s	remaining: 37.6s
# 4912:	learn: 0.1319370	total: 35m 1s	remaining: 37.2s
# 4913:	learn: 0.1319192	total: 35m 2s	remaining: 36.8s
# 4914:	learn: 0.1319130	total: 35m 2s	remaining: 36.4s
# 4915:	learn: 0.1319055	total: 35m 3s	remaining: 35.9s
# 4916:	learn: 0.1318917	total: 35m 3s	remaining: 35.5s
# 4917:	learn: 0.1318820	total: 35m 4s	remaining: 35.1s
# 4918:	learn: 0.1318728	total: 35m 4s	remaining: 34.7s
# 4919:	learn: 0.1318603	total: 35m 5s	remaining: 34.2s
# 4920:	learn: 0.1318528	total: 35m 5s	remaining: 33.8s
# 4921:	learn: 0.1318395	total: 35m 6s	remaining: 33.4s
# 4922:	learn: 0.1318258	total: 35m 6s	remaining: 33s
# 4923:	learn: 0.1318082	total: 35m 7s	remaining: 32.5s
# 4924:	learn: 0.1317961	total: 35m 8s	remaining: 32.1s
# 4925:	learn: 0.1317868	total: 35m 8s	remaining: 31.7s
# 4926:	learn: 0.1317725	total: 35m 9s	remaining: 31.2s
# 4927:	learn: 0.1317687	total: 35m 9s	remaining: 30.8s
# 4928:	learn: 0.1317609	total: 35m 9s	remaining: 30.4s
# 4929:	learn: 0.1317519	total: 35m 10s	remaining: 30s
# 4930:	learn: 0.1317455	total: 35m 11s	remaining: 29.5s
# 4931:	learn: 0.1317389	total: 35m 11s	remaining: 29.1s
# 4932:	learn: 0.1317201	total: 35m 12s	remaining: 28.7s
# 4933:	learn: 0.1317131	total: 35m 12s	remaining: 28.3s
# 4934:	learn: 0.1317029	total: 35m 12s	remaining: 27.8s
# 4935:	learn: 0.1316915	total: 35m 13s	remaining: 27.4s
# 4936:	learn: 0.1316727	total: 35m 14s	remaining: 27s
# 4937:	learn: 0.1316702	total: 35m 14s	remaining: 26.6s
# 4938:	learn: 0.1316594	total: 35m 15s	remaining: 26.1s
# 4939:	learn: 0.1316537	total: 35m 15s	remaining: 25.7s
# 4940:	learn: 0.1316434	total: 35m 15s	remaining: 25.3s
# 4941:	learn: 0.1316306	total: 35m 16s	remaining: 24.8s
# 4942:	learn: 0.1316145	total: 35m 16s	remaining: 24.4s
# 4943:	learn: 0.1316022	total: 35m 17s	remaining: 24s
# 4944:	learn: 0.1315900	total: 35m 18s	remaining: 23.6s
# 4945:	learn: 0.1315822	total: 35m 18s	remaining: 23.1s
# 4946:	learn: 0.1315723	total: 35m 19s	remaining: 22.7s
# 4947:	learn: 0.1315622	total: 35m 20s	remaining: 22.3s
# 4948:	learn: 0.1315500	total: 35m 20s	remaining: 21.9s
# 4949:	learn: 0.1315419	total: 35m 22s	remaining: 21.4s
# 4950:	learn: 0.1315291	total: 35m 23s	remaining: 21s
# 4951:	learn: 0.1315195	total: 35m 23s	remaining: 20.6s
# 4952:	learn: 0.1315098	total: 35m 23s	remaining: 20.2s
# 4953:	learn: 0.1314956	total: 35m 24s	remaining: 19.7s
# 4954:	learn: 0.1314826	total: 35m 24s	remaining: 19.3s
# 4955:	learn: 0.1314707	total: 35m 25s	remaining: 18.9s
# 4956:	learn: 0.1314550	total: 35m 25s	remaining: 18.4s
# 4957:	learn: 0.1314462	total: 35m 25s	remaining: 18s
# 4958:	learn: 0.1314354	total: 35m 26s	remaining: 17.6s
# 4959:	learn: 0.1314232	total: 35m 26s	remaining: 17.2s
# 4960:	learn: 0.1314121	total: 35m 27s	remaining: 16.7s
# 4961:	learn: 0.1314077	total: 35m 27s	remaining: 16.3s
# 4962:	learn: 0.1313940	total: 35m 28s	remaining: 15.9s
# 4963:	learn: 0.1313833	total: 35m 29s	remaining: 15.4s
# 4964:	learn: 0.1313729	total: 35m 29s	remaining: 15s
# 4965:	learn: 0.1313599	total: 35m 30s	remaining: 14.6s
# 4966:	learn: 0.1313479	total: 35m 30s	remaining: 14.2s
# 4967:	learn: 0.1313403	total: 35m 31s	remaining: 13.7s
# 4968:	learn: 0.1313357	total: 35m 31s	remaining: 13.3s
# 4969:	learn: 0.1313221	total: 35m 32s	remaining: 12.9s
# 4970:	learn: 0.1313152	total: 35m 32s	remaining: 12.4s
# 4971:	learn: 0.1313057	total: 35m 33s	remaining: 12s
# 4972:	learn: 0.1313010	total: 35m 33s	remaining: 11.6s
# 4973:	learn: 0.1312889	total: 35m 33s	remaining: 11.2s
# 4974:	learn: 0.1312738	total: 35m 34s	remaining: 10.7s
# 4975:	learn: 0.1312633	total: 35m 34s	remaining: 10.3s
# 4976:	learn: 0.1312549	total: 35m 34s	remaining: 9.87s
# 4977:	learn: 0.1312502	total: 35m 35s	remaining: 9.44s
# 4978:	learn: 0.1312414	total: 35m 35s	remaining: 9.01s
# 4979:	learn: 0.1312322	total: 35m 36s	remaining: 8.58s
# 4980:	learn: 0.1312285	total: 35m 36s	remaining: 8.15s
# 4981:	learn: 0.1312252	total: 35m 36s	remaining: 7.72s
# 4982:	learn: 0.1312158	total: 35m 37s	remaining: 7.29s
# 4983:	learn: 0.1312102	total: 35m 37s	remaining: 6.86s
# 4984:	learn: 0.1312004	total: 35m 37s	remaining: 6.43s
# 4985:	learn: 0.1311905	total: 35m 38s	remaining: 6s
# 4986:	learn: 0.1311872	total: 35m 38s	remaining: 5.58s
# 4987:	learn: 0.1311799	total: 35m 39s	remaining: 5.14s
# 4988:	learn: 0.1311622	total: 35m 39s	remaining: 4.72s
# 4989:	learn: 0.1311566	total: 35m 39s	remaining: 4.29s
# 4990:	learn: 0.1311455	total: 35m 40s	remaining: 3.86s
# 4991:	learn: 0.1311351	total: 35m 40s	remaining: 3.43s
# 4992:	learn: 0.1311250	total: 35m 40s	remaining: 3s
# 4993:	learn: 0.1311160	total: 35m 41s	remaining: 2.57s
# 4994:	learn: 0.1311099	total: 35m 41s	remaining: 2.14s
# 4995:	learn: 0.1310979	total: 35m 41s	remaining: 1.71s
# 4996:	learn: 0.1310789	total: 35m 42s	remaining: 1.29s
# 4997:	learn: 0.1310607	total: 35m 42s	remaining: 857ms
# 4998:	learn: 0.1310513	total: 35m 43s	remaining: 429ms
# 4999:	learn: 0.1310445	total: 35m 43s	remaining: 0us

# %%
cat_model.save_model('./data/softvoting_cat_xgb변수_6_12_24.cbm')

# %% [markdown]
# # 7. 모델예측 - Soft voting

# %%
test_df = pd.read_parquet("./test_data.parquet")

# 변수 450개 사용
top450_df = pd.read_csv("./data/top450_features_XGB_balanced.csv")
top450_features = top450_df['feature'].tolist()

# %%
# 학습한 모델들 불러오기
xgb_model_loaded = xgb.XGBClassifier()
xgb_model_loaded.load_model('./data/softvoting_xgb_xgb변수_3_3_25.json')

lgb_model_loaded = lgb.Booster(model_file='./data/softvoting_lgbm_model_3_3_25.txt')

cat_model_loaded = CatBoostClassifier()
cat_model_loaded.load_model('./data/softvoting_cat_xgb변수_6_12_24.cbm')

# %%
# test 데이터 준비
X_test = test_df[top450_features]

# XGB predict_proba (iteration_range)
proba_xgb = xgb_model_loaded.predict_proba(X_test, iteration_range=(0, 5000))

# LGB Booster (predict가 proba)
proba_lgb = lgb_model_loaded.predict(X_test, num_iteration=3348)

# CAT predict_proba
proba_cat = cat_model_loaded.predict_proba(X_test)

# soft voting
ensemble_proba = (0.4 * proba_xgb) + (0.3 * proba_lgb) + (0.3 * proba_cat)
ensemble_preds = np.argmax(ensemble_proba, axis=1)
inverse_label_map = {0: 'A', 1: 'B', 2: 'C', 3: 'D', 4: 'E'}
ensemble_preds_label = pd.Series(ensemble_preds).map(inverse_label_map)

# %%
pred = pd.read_csv("./data/sample_submission.csv")

# %%
pred["Segment"] = ensemble_preds_label.iloc[0:100000]
pred.to_csv("./data/submission.csv", index=False)

# %% [markdown]
# ## 8. 제출

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 📊 2등 코드 변수 개수별 성능 및 편차 비교
#
# | 변수 개수 | Public 점수 | Private 점수 | 점수 편차 (Gap) | 비고 |
# | :--- | :--- | :--- | :--- | :--- |
# | **300개** | 0.6887 | 0.6757 | 0.0130 | 2등 파일 제출 건 |
# | **350개** | 0.6835 | 0.6774 | 0.0061 | |
# | **400개** | **0.6983** | **0.6860** | 0.0123 | **현재 최고 성능** |
# | **450개** | 0.6881 | 0.6719 | 0.0162 | |

# %%
import matplotlib.pyplot as plt

# 한글 폰트 설정 (Windows 기준)
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 데이터 설정
features = [300, 350, 400, 450]
public_scores = [0.6887, 0.6835, 0.6983, 0.6881]
private_scores = [0.6757, 0.6774, 0.6860, 0.6719]
gaps = [round(pub - pri, 4) for pub, pri in zip(public_scores, private_scores)]

fig, ax1 = plt.subplots(figsize=(12, 7))

# 1. 왼쪽 축: Public/Private 점수 (선 그래프)
line1 = ax1.plot(features, public_scores, marker='o', color='#1f77b4', label='Public 점수', linewidth=2)
line2 = ax1.plot(features, private_scores, marker='s', color='#ff7f0e', label='Private 점수', linewidth=2, linestyle='--')
ax1.set_xlabel('상위 변수 개수', fontsize=12)
ax1.set_ylabel('점수', fontsize=12)
ax1.set_ylim(0.66, 0.71) # 점수 범위를 적절히 조절

# 2. 오른쪽 축: 점수 편차 (막대 그래프)
ax2 = ax1.twinx()
bars = ax2.bar(features, gaps, color='gray', alpha=0.2, label='점수 편차', width=15)
ax2.set_ylabel('점수 편차', fontsize=12, color='gray')
ax2.set_ylim(0, 0.08) # 점수 편차 범위를 조절하여 막대가 너무 높지 않게 설정

# 수치 표시 (점수 편차 값)
for i, gap in enumerate(gaps):
    ax2.text(features[i], gap + 0.0005, f'{gap}', ha='center', color='gray', fontsize=10)

# 최고점 강조
ax1.scatter(400, 0.6983, color='red', s=100, zorder=5)
ax1.annotate('Best (400)', (400, 0.6983), xytext=(400, 0.703), ha='center', weight='bold', color='red')

# 합쳐진 범례 만들기
lines = line1 + line2 + [bars]
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='upper left')

plt.title('상위 변수 개수에 따른 Public/Private 점수 및 편차 분석', fontsize=15, pad=20)
ax1.grid(True, axis='y', linestyle=':', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📊 2등 코드 변수 개수별 성능 및 편차 비교
#
# | 변수 개수 | Public 점수 | Private 점수 | 점수 편차 (Gap) | 비고 |
# | :--- | :--- | :--- | :--- | :--- |
# | **300개** | 0.6887 | 0.6757 | 0.0130 | 2등 파일 제출 건 |
# | **350개** | 0.6835 | 0.6774 | 0.0061 | |
# | **400개** | **0.6983** | **0.6860** | 0.0123 | **현재 최고 성능** |
# | **450개** | 0.6881 | 0.6719 | 0.0162 | |

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 데이터 분석 결과
# * 300개 : 변수 350개를 썼을 때보다 Public 점수가 오히려 더 높습니다. 이는 변수를 줄이는 것이 노이즈가 섞인 변수가 생기는 것을 방지하여 모델의 복잡도를 낮추어 더 나은 일반화 성능을 낸 것으로 확인됩니다. 하지만, Private 점수는 350개 일 때가 더 높으므로, 300개 모델은 Public 리더보드에 약간 더 유리하다는 것을 확인할 수 있습니다.
# * 350개 : 점수 편차가 0.0061로 가장 작습니다. 이는 Public 점수와 Private 점수가 매우 유사하므로 모델이 매우 안정적이며, 신뢰도 높은 모델임을 뜻합니다.
# * 400개(최적의 지점) : 400개 지점에서 Public/Private 모두 정점을 찍습니다. 이는 350개에서 400개로 늘어날 때 추가된 50개의 변수들이 모델의 예측력을 높이는 핵심적인 유의미한 정보(Signal)가 많이 추가되었기 때문입니다.
# * 450개(과적합) : 450개를 썼을 때 오히려 점수가 하락하는 것을 확인할 수 있습니다. 특히, 점수 편차가 0.0162로 가장 큽니다. 이는 중요도가 낮은 변수들이 추가되면서 모델이 학습 데이터의 노이즈까지 학습하게 되었고, 이로 인해 새로운 데이터(Public/Private)에 대한 대응 능력이 떨어졌기 때문입니다.

# %% [markdown]
# ### 📊 우리 팀 코드 변수 개수별 성능 및 편차 비교
#
# | 변수 개수 | Public 점수 | Private 점수 | 점수 편차 (Gap) | 비고 |
# | :--- | :---: | :---: | :---: | :--- |
# | 300개 | 0.6805 | 0.6715 | 0.0090 | |
# | 350개 | 0.6862 | 0.6691 | 0.0172 | |
# | 400개 | 0.6926 | 0.6720 | 0.0206 | |
# | **450개** | **0.6929** | **0.6748** | **0.0181** | **현재 최고 성능** |

# %%
import matplotlib.pyplot as plt

# 한글 폰트 설정 (Windows 기준 - 환경에 따라 'AppleGothic' 등으로 변경 가능)
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 1. 이미지에서 추출한 실제 데이터 설정
features = [300, 350, 400, 450]
public_scores = [0.6804714023, 0.686240929, 0.6926074555, 0.692910344]
private_scores = [0.6714971101, 0.6690735974, 0.672017231, 0.6747877019]

# Public과 Private의 차이(Overfitting 지표) 계산
gaps = [round(pub - pri, 4) for pub, pri in zip(public_scores, private_scores)]

fig, ax1 = plt.subplots(figsize=(12, 7))

# 2. 왼쪽 축: Public/Private 점수 (선 그래프)
line1 = ax1.plot(features, public_scores, marker='o', color='#1f77b4', label='Public 점수', linewidth=2.5)
line2 = ax1.plot(features, private_scores, marker='s', color='#ff7f0e', label='Private 점수', linewidth=2.5, linestyle='--')
ax1.set_xlabel('상위 변수 개수', fontsize=12)
ax1.set_ylabel('점수', fontsize=12)
ax1.set_ylim(0.66, 0.70) # 데이터 범위에 맞춰 조정

# 3. 오른쪽 축: 점수 편차 (막대 그래프)
ax2 = ax1.twinx()
bars = ax2.bar(features, gaps, color='gray', alpha=0.15, label='점수 편차', width=15)
ax2.set_ylabel('점수 편차', fontsize=12, color='gray')
ax2.set_ylim(0, 0.04) # 편차를 보기 쉽게 범위 조정

# 수치 표시 (점수 편차 값)
for i, gap in enumerate(gaps):
    ax2.text(features[i], gap + 0.0005, f'{gap}', ha='center', color='gray', fontsize=10)

# 최고점 강조 (이미지 데이터 상 450개가 Best)
best_idx = 3 # 450개 데이터 위치
ax1.scatter(features[best_idx], public_scores[best_idx], color='red', s=120, zorder=5, edgecolors='black')
ax1.annotate(f'Best ({features[best_idx]})', 
             (features[best_idx], public_scores[best_idx]), 
             xytext=(0, 15), textcoords='offset points',
             ha='center', weight='bold', color='red', fontsize=12)

# 범례 통합
lines = line1 + line2 + [bars]
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='upper left', frameon=True, shadow=True)

plt.title('상위 변수 개수에 따른 Public/Private 점수 및 편차 분석', fontsize=16, pad=20, weight='bold')
ax1.grid(True, axis='y', linestyle=':', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 데이터 분석 결과
# * 300개 : 점수 자체는 다른 실험군에 비해 낮지만, 점수 편차(0.0090)가 가장 작습니다. 이는 모델이 과적합되지 않고 매우 안정적임을 뜻하며, 2등 파일을 기록했을 만큼 탄탄한 일반화 성능을 보여줍니다.
# * 350개 ~ 400개 : 변수 개수가 늘어남에 따라 Public 점수가 가파르게 상승합니다. 300개에서 400개로 넘어오며 추가된 변수들이 모델의 예측력을 높이는 유의미한 정보(Signal)를 포함하고 있음을 알 수 있습니다. 다만, 이 과정에서 점수 편차(Gap)가 함께 커지는 것으로 보아 모델의 복잡도도 동시에 증가하고 있습니다.
# * 450개(최적의 지점) : Public(0.6929)과 Private(0.6748) 점수 모두에서 정점을 찍는 **스위트 스팟(Sweet Spot)**입니다. 특히 고무적인 부분은 400개일 때보다 변수는 늘었음에도 불구하고 **점수 편차는 오히려 감소(0.0206 → 0.0181)**했다는 점입니다. 이는 450개까지의 변수 조합이 노이즈를 효과적으로 억제하면서도 데이터의 본질적인 패턴을 가장 잘 설명하고 있음을 시사합니다.
