# %% [markdown]
# # 1. Import - 환경설정

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import pyarrow.parquet as pq
import tqdm
import optuna
import gc
from sklearn.metrics import accuracy_score, f1_score
from sklearn.preprocessing import StandardScaler

# test 데이터 준비 (샘플로 train에서 분리)
from sklearn.model_selection import train_test_split

# 모델 학습 및 평가
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, f1_score

# %% [markdown]
# * 최적화 관련 코드

# %%
# 메모리를 32비트로 변환
def optimize_memory(df):
    for col in df.select_dtypes(include=['number']).columns:
        # 정수형은 가능한 가장 작은 타입으로 (int8, int16 등)
        if df[col].dtype == 'int64':
            df[col] = pd.to_numeric(df[col], downcast='integer')
        # 실수형은 float32로
        elif df[col].dtype == 'float64':
            df[col] = pd.to_numeric(df[col], downcast='float')
    return df

# %% [markdown]
# # 2. 파일을 불러오고, 폴더별로 합치기

# %%
# 함수로 만들어서 넣어버리자 그냥
# 각 폴더명 딕셔너리
HOME = os.getcwd()
def makeFileList(option = "train"):
    folder_name = {1:"1.회원정보", 2:"2.신용정보", 3:"3.승인매출정보", 4:"4.청구입금정보", 5:"5.잔액정보", 6:"6.채널정보", 7:"7.마케팅정보", 8:"8.성과정보"}

    # 현재 디렉터리
    HOME = os.getcwd()

    # 폴더 리스트를 생성하고 폴더 경로들을 리스트로 저장하기
    folder_list = []
    for value in folder_name.values():
        folder_list.append(os.path.join(HOME, "data", option, value))
    print(len(folder_list))

    # 폴더 내 파일 리스트 읽어오기
    fileNameList = {}
    for i in range(len(folder_list)):
        fileNameList[i+1] = os.listdir(folder_list[i])
    print(fileNameList)

    # 파일 경로 리스트 생성
    filePathList = {}
    temp = []
    for i in range(len(folder_list)):
        for j in range(len(fileNameList[i+1])):
            temp.append(os.path.join(folder_list[i], fileNameList[i+1][j]))
        filePathList[i+1] = temp
        temp = []

    return filePathList

# %%
# 240만개의 파일을 이어 붙이기
# 각 폴더에 들어있는 파일들 중 같은 달의 열을 모두 합침
def load_cat(i, filePathList):
    print("현재 진행 상황 : {}".format(i))
    df = optimize_memory(pd.read_parquet(filePathList[i][0]))
    for j in range(1,6):
        print("Debugging1")
        df = pd.concat([df, optimize_memory(pd.read_parquet(filePathList[i][j]))])
    return df

# 공통된 쓸모없는 column 제거 함수=
def drop_useless(df):
    df = df.drop(columns = ["기준년월", "ID"])
    return df
# target인 Segment가 없을시 Segment 추가
def add_target(df, filePathList):# target이 존재하지 않는 df, target명(문자열)
    temp_df = pd.read_parquet(filePathList[1][0])
    for i in range(1, 6):
        temp_df = pd.concat([temp_df, pd.read_parquet(filePathList[1][i])])
    df = pd.merge(temp_df[["기준년월", "ID", "Segment"]], df, on = ["기준년월","ID"],how = "left")
    return df

# 파일을 불러오는 함수
def make_df(i, option = False):# option이 True면 Test데이터도 불러오게 하자.

    # train 데이터 불러오기
    train = makeFileList()
    test = makeFileList(option = "test")
    train = load_cat(i, train)

    # test 데이터 불러오기
    if option == "all":
        train = pd.DataFrame()
        for i in range(1, 9):
            train = pd.concat([train, drop_useless(load_cat(i, makeFileList()))], axis = 1)    
        test = pd.DataFrame()
        for i in range(1, 9):
            test = pd.concat([test, drop_useless(load_cat(i, makeFileList(option = "test")))], axis = 1)
    elif option:
        train = drop_useless(add_target(train, makeFileList()))
        test = drop_useless(load_cat(i, test))

    
    # option 이 True 라면 concat해서 붙여넣기 : if로 하지 않으면 앞에 test를 선언했기 때문에 오류 날 것
    if option:
        print(train.shape)
        print(test.shape)

        result = pd.concat([train, test], ignore_index=True)
        print(result.shape)
        return result
    else :
        print(train.shape)
        if (i > 1) & (i <= 6): train = add_target(train, makeFileList())
        elif i == 1: return drop_useless(train)
        else: print("숫자가 아니거나 할당 없는 카테고리입니다.")
        return drop_useless(train)
    # i 가 1보다 크고 1보다 작을때 사용



# 데이터프레임에서 파라미터를 입력하면 그 파라미터가 포함된 column들을 가져와 새로운 데이터프레임을 반환함
# 연관성 있는 column들을 얻어오기 위해서 사용한다.
def find_R(df, param1):
    columns = list(df.columns)
    new_columns = []
    for column in columns:
        if param1 in column:
            new_columns.append(column)
    return pd.DataFrame(df[new_columns])

# %%
# 0과 1로 이루어진 데이터들 중, 상대적으로 부족한 A, B에 대해서 확실히 평가를 끌어내 줄 수 있지 않을까 싶어서 가져온 자료
def plot_segment_comparison(df, column):
    """
    Segment와 지정된 column의 관계를 stacked bar chart와 heatmap으로 시각화
    1행 2열 subplot
    
    Parameters:
    -----------
    df : DataFrame
        데이터프레임
    column : str
        비교할 column 이름 (예: "회원여부_연체")
    """
    df_reset = df.reset_index(drop=True)
    plt.rcParams['font.family'] = 'Malgun Gothic'
    plt.rcParams['axes.unicode_minus'] = False
    sns.set(font="Malgun Gothic", 
        rc={"axes.unicode_minus": False},
        style='darkgrid')
    fig, axes = plt.subplots(1, 2, figsize=(16, 5))
    
    # 1. Stacked Bar Chart (왼쪽)
    crosstab_pct = pd.crosstab(df_reset["Segment"], df_reset[column], normalize='index') * 100
    crosstab_pct.plot(kind='bar', stacked=True, ax=axes[0], color=['#2ecc71', '#e74c3c'])
    axes[0].set_title(f"Segment별 {column} 비율 (100%)", fontsize=12, fontweight='bold')
    axes[0].set_xlabel("Segment (0=E, 1=D, 2=C, 3=B, 4=A)")
    axes[0].set_ylabel("비율 (%)")
    axes[0].legend(title=column, bbox_to_anchor=(1.05, 1), loc='upper left')
    
    # 2. HeatMap (오른쪽)
    crosstab = pd.crosstab(df_reset["Segment"], df_reset[column])
    sns.heatmap(crosstab, annot=True, fmt='d', cmap='YlOrRd', ax=axes[1], cbar_kws={'label': '빈도'})
    axes[1].set_title(f"Segment별 {column} 매트릭스", fontsize=12, fontweight='bold')
    axes[1].set_xlabel(column)
    axes[1].set_ylabel("Segment (0=E, 1=D, 2=C, 3=B, 4=A)")
    
    plt.tight_layout()
    plt.show()

# 사용 예시
# plot_segment_comparison(df, "회원여부_연체")
# plot_segment_comparison(df, "가입통신회사코드")

# %% [markdown]
# ## 사용하면 되는 함수
# - make_df(i, option = False)
#     - 데이터를 불러와 데이터 프레임을 만들어 내는 함수
#     - i는 폴더를 불러오기 위한 변수
#     - 기본적으로 option = False
#     - option에 아무 값이나 넣으면 True가 되고, 그러면 해당하는 Test값이 들어간다.
#     - option에 "all"이 들어가면 모든 데이터를 합쳐서 만들어줌

# %%
# 만들어둔 함수를 통해, 불러오고 싶은 폴더를 입력하면 데이터를 한번에 불러와준다.
df = make_df(2, option = "all")
# Out:
# 8
# {1: ['201807_train_회원정보.parquet', '201808_train_회원정보.parquet', '201809_train_회원정보.parquet', '201810_train_회원정보.parquet', '201811_train_회원정보.parquet', '201812_train_회원정보.parquet'], 2: ['201807_train_신용정보.parquet', '201808_train_신용정보.parquet', '201809_train_신용정보.parquet', '201810_train_신용정보.parquet', '201811_train_신용정보.parquet', '201812_train_신용정보.parquet'], 3: ['201807_train_승인매출정보.parquet', '201808_train_승인매출정보.parquet', '201809_train_승인매출정보.parquet', '201810_train_승인매출정보.parquet', '201811_train_승인매출정보.parquet', '201812_train_승인매출정보.parquet'], 4: ['201807_train_청구정보.parquet', '201808_train_청구정보.parquet', '201809_train_청구정보.parquet', '201810_train_청구정보.parquet', '201811_train_청구정보.parquet', '201812_train_청구정보.parquet'], 5: ['201807_train_잔액정보.parquet', '201808_train_잔액정보.parquet', '201809_train_잔액정보.parquet', '201810_train_잔액정보.parquet', '201811_train_잔액정보.parquet', '201812_train_잔액정보.parquet'], 6: ['201807_train_채널정보.parquet', '201808_train_채널정보.parquet', '201809_train_채널정보.parquet', '201810_train_채널정보.parquet', '201811_train_채널정보.parquet', '201812_train_채널정보.parquet'], 7: ['201807_train_마케팅정보.parquet', '201808_train_마케팅정보.parquet', '201809_train_마케팅정보.parquet', '201810_train_마케팅정보.parquet', '201811_train_마케팅정보.parquet', '201812_train_마케팅정보.parquet'], 8: ['201807_train_성과정보.parquet', '201808_train_성과정보.parquet', '201809_train_성과정보.parquet', '201810_train_성과정보.parquet', '201811_train_성과정보.parquet', '201812_train_성과정보.parquet']}
# 8
# {1: ['201807_test_회원정보.parquet', '201808_test_회원정보.parquet', '201809_test_회원정보.parquet', '201810_test_회원정보.parquet', '201811_test_회원정보.parquet', '201812_test_회원정보.parquet'], 2: ['201807_test_신용정보.parquet', '201808_test_신용정보.parquet', '201809_test_신용정보.parquet', '201810_test_신용정보.parquet', '201811_test_신용정보.parquet', '201812_test_신용정보.parquet'], 3: ['201807_test_승인매출정보.parquet', '201808_test_승인매출정보.parquet', '201809_test_승인매출정보.parquet', '201810_test_승인매출정보.parquet', '201811_test_승인매출정보.parquet', '201812_test_승인매출정보.parquet'], 4: ['201807_test_청구정보.parquet', '201808_test_청구정보.parquet', '201809_test_청구정보.parquet', '201810_test_청구정보.parquet', '201811_test_청구정보.parquet', '201812_test_청구정보.parquet'], 5: ['201807_test_잔액정보.parquet', '201808_test_잔액정보.parquet', '201809_test_잔액정보.parquet', '201810_test_잔액정보.parquet', '201811_test_잔액정보.parquet', '201812_test_잔액정보.parquet'], 6: ['201807_test_채널정보.parquet', '201808_test_채널정보.parquet', '201809_test_채널정보.parquet', '201810_test_채널정보.parquet', '201811_test_채널정보.parquet', '201812_test_채널정보.parquet'], 7: ['201807_test_마케팅정보.parquet', '201808_test_마케팅정보.parquet', '201809_test_마케팅정보.parquet', '201810_test_마케팅정보.parquet', '201811_test_마케팅정보.parquet', '201812_test_마케팅정보.parquet'], 8: ['201807_test_성과정보.parquet', '201808_test_성과정보.parquet', '201809_test_성과정보.parquet', '201810_test_성과정보.parquet', '201811_test_성과정보.parquet', '201812_test_성과정보.parquet']}
# 현재 진행 상황 : 2
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_train_회원정보.parquet', '201808_train_회원정보.parquet', '201809_train_회원정보.parquet', '201810_train_회원정보.parquet', '201811_train_회원정보.parquet', '201812_train_회원정보.parquet'], 2: ['201807_train_신용정보.parquet', '201808_train_신용정보.parquet', '201809_train_신용정보.parquet', '201810_train_신용정보.parquet', '201811_train_신용정보.parquet', '201812_train_신용정보.parquet'], 3: ['201807_train_승인매출정보.parquet', '201808_train_승인매출정보.parquet', '201809_train_승인매출정보.parquet', '201810_train_승인매출정보.parquet', '201811_train_승인매출정보.parquet', '201812_train_승인매출정보.parquet'], 4: ['201807_train_청구정보.parquet', '201808_train_청구정보.parquet', '201809_train_청구정보.parquet', '201810_train_청구정보.parquet', '201811_train_청구정보.parquet', '201812_train_청구정보.parquet'], 5: ['201807_train_잔액정보.parquet', '201808_train_잔액정보.parquet', '201809_train_잔액정보.parquet', '201810_train_잔액정보.parquet', '201811_train_잔액정보.parquet', '201812_train_잔액정보.parquet'], 6: ['201807_train_채널정보.parquet', '201808_train_채널정보.parquet', '201809_train_채널정보.parquet', '201810_train_채널정보.parquet', '201811_train_채널정보.parquet', '201812_train_채널정보.parquet'], 7: ['201807_train_마케팅정보.parquet', '201808_train_마케팅정보.parquet', '201809_train_마케팅정보.parquet', '201810_train_마케팅정보.parquet', '201811_train_마케팅정보.parquet', '201812_train_마케팅정보.parquet'], 8: ['201807_train_성과정보.parquet', '201808_train_성과정보.parquet', '201809_train_성과정보.parquet', '201810_train_성과정보.parquet', '201811_train_성과정보.parquet', '201812_train_성과정보.parquet']}
# 현재 진행 상황 : 1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# 8
# {1: ['201807_train_회원정보.parquet', '201808_train_회원정보.parquet', '201809_train_회원정보.parquet', '201810_train_회원정보.parquet', '201811_train_회원정보.parquet', '201812_train_회원정보.parquet'], 2: ['201807_train_신용정보.parquet', '201808_train_신용정보.parquet', '201809_train_신용정보.parquet', '201810_train_신용정보.parquet', '201811_train_신용정보.parquet', '201812_train_신용정보.parquet'], 3: ['201807_train_승인매출정보.parquet', '201808_train_승인매출정보.parquet', '201809_train_승인매출정보.parquet', '201810_train_승인매출정보.parquet', '201811_train_승인매출정보.parquet', '201812_train_승인매출정보.parquet'], 4: ['201807_train_청구정보.parquet', '201808_train_청구정보.parquet', '201809_train_청구정보.parquet', '201810_train_청구정보.parquet
# 현재 진행 상황 : 8
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# Debugging1
# (2400000, 856)
# (600000, 855)
# (3000000, 856)

# %% [markdown]
# # 3. 전처리 - concat & merge 및 Feature Engineering

# %%
import pandas as pd
import numpy as np
import gc

# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# # 전처리 및 Feauture Engineering

# %% [markdown]
# ### 직접했던 피쳐엔지니어링 (1)
# - 폴더 1 기반 피쳐엔지니어링
# - catboost 모델의 피처 importance를 기반으로, 분류가 가능한 피쳐를 선별해 사용
# - catboost 모델은 XGboost나 LGBW모델과 같은 트리 모델과는 다르게 적은 양의 데이터라도 확실히 구분되는 특성을 가진 데이터가 있다면 이를 중요하게 생각하고 반영하는 특성이 있다.
# - 예를 들어서, 직접 만든 특성인 **'회원_이용가능_점수'** 항목의 시각화를 확인해보면 다음과 같다.
# - 시각화된 왼쪽 자료를 보면 그다지 상관관계가 없어보이는 자료 같지만, 오른쪽을 보면 A, B에서는 회원 이용가능 점수가 0에서는 존재하지 않고, 1에서도 거의 없다고 볼 수 있다. 즉, A,B와 C,D,E를 구분할 수 있는 자료이기 때문에 catboost에서는 더 많은 참고를 한다는 것이다.
# - 이 사실을 기반으로 하여 catboost 기반으로 모델링을 준비했었다.

# %%
def calculate_month_diff(target_ym):
    # 연도 차이와 월 차이를 계산하여 잔여 개월수 도출
    target_year = target_ym // 100
    target_month = target_ym % 100
    
    current_year = 2026
    current_month = 2
    return (target_year - current_year) * 12 + (target_month - current_month)

def Folder1_Feature(df):
    # 소지카드수를 통한 즉시 사용 가능한 비율
    df['카드_즉시가용_비율'] = df['소지카드수_이용가능_신용'] / (df['소지카드수_유효_신용'] + 1)
    
    # 여기서는 '고객의 금융 활동 기간 중 탈회가 얼마나 잦았나'를 측정합니다.
    df['누적탈회밀도'] = df['탈회횟수_누적'] / (df['최종탈회후경과월'] + 1)
    
    # 탈회 원격도: 전체 탈회 중 과거(1년 전) 비중 (A, B 타겟용)
    df['탈회원격도'] = (df['탈회횟수_누적'] - df['탈회횟수_발급1년이내']) / (df['탈회횟수_누적'] + 1)
    
    # 활동 안정성: 마지막 탈회 후 얼마나 오래 버티고 있는가
    df['활동안정성'] = df['최종탈회후경과월'] / (df['입회경과개월수_신용'] + 1)
    
    # 시계열 데이터로 이루어진 데이터를 그냥 월단위로 조절해버리기
    df['잔여유효개월_실이용'] = df['최종유효년월_신용_이용'].apply(calculate_month_diff)

    # 카드사용시 CA, 카드론의 이용가능을 통한 분류 기준 추가
    df['회원_이용가능_점수'] = (
    (df['회원여부_이용가능'] == 1).astype(int) + 
    (df['회원여부_이용가능_CA'] == 1).astype(int)+ 
    (df['회원여부_이용가능_카드론'] == 1).astype(int))
    df = df.drop("회원여부_이용가능", axis = 1)
    df = df.drop("회원여부_이용가능_CA", axis = 1)
    df = df.drop("회원여부_이용가능_카드론", axis = 1)
    return df

df = Folder1_Feature(df)
plot_segment_comparison(df, '회원_이용가능_점수')
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4093047334.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['카드_즉시가용_비율'] = df['소지카드수_이용가능_신용'] / (df['소지카드수_유효_신용'] + 1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4093047334.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['누적탈회밀도'] = df['탈회횟수_누적'] / (df['최종탈회후경과월'] + 1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4093047334.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['탈회원격도'] = (df['탈회횟수_누적'] - df['탈회횟수_발급1년이내']) / (df['탈회횟수_누적'] + 1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4093047334.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['활동안정성'] = df['최종탈회후경과월'] / (df['입회경과개월수_신용'] + 1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4093047334.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['잔여유효개월_실이용'] = df['최종유효년월_신용_이용'].apply(calculate_month_diff)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4093047334.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['회원_이용가능_점수'] = (

# %% [markdown]
# ### 2nd 코드에서 가져온 피쳐 엔지니어링

# %% [markdown]
# #### 1. 회원정보

# %%
# 가입통신회사코드 → 가입통신회사_S사여부
df['가입통신회사_S사여부'] = (df['가입통신회사코드'] == 'S사').astype(int)
df = df.drop(columns=['가입통신회사코드'])

# 직장시도명 → 직장_수도권여부
df['직장_수도권여부'] = df['직장시도명'].isin(['서울', '경기']).astype(int)
df = df.drop(columns=['직장시도명'])

# 거주시도명 → 거주지_수도권여부
df['거주지_수도권여부'] = df['거주시도명'].isin(['서울', '경기']).astype(int)
df = df.drop(columns=['거주시도명'])

# 연회비발생카드수_B0M → 연회비발생카드수_B0M_이진
df['연회비발생카드수_B0M_이진'] = df['연회비발생카드수_B0M'].isin(['1개이상']).astype(int)
df = df.drop(columns=['연회비발생카드수_B0M'])
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\1370701547.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['가입통신회사_S사여부'] = (df['가입통신회사코드'] == 'S사').astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\1370701547.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['직장_수도권여부'] = df['직장시도명'].isin(['서울', '경기']).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\1370701547.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['거주지_수도권여부'] = df['거주시도명'].isin(['서울', '경기']).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\1370701547.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['연회비발생카드수_B0M_이진'] = df['연회비발생카드수_B0M'].isin(['1개이상']).astype(int)

# %% [markdown]
# #### 2. 신용정보

# %%
# 'RV전환가능여부' → 'RV전환불가능여부'
df['RV_전환가능여부_이진'] = (df['RV전환가능여부'] == 'N').astype(int)
df = df.drop(columns='RV전환가능여부')

# 자발한도감액횟수_R12M: '0회' → 0, '1회' → 1, '2회' → 2
df['자발한도감액횟수_R12M'] = (
    df['자발한도감액횟수_R12M']
    .str.replace('회', '', regex=False)  # '회' 제거
    .astype(int)  # 바로 int로 변환!
)

#‘한도증액횟수_R12M’ → '한도증액_R12M_여부': '0회' → 0, '1회이상' → 1
df['한도증액_R12M_여부'] = df['한도증액횟수_R12M'].map({
    '0회': 0,
    '1회이상': 1
    }).astype(int)
df.drop(columns=['한도증액횟수_R12M'], inplace=True)

# '카드론동의여부': 'Y' → 1, 'N' → 0
df['카드론동의여부'] = df['카드론동의여부'].map({
    'Y': 1,
    'N': 0
    }).astype(int)

# '한도심사요청건수' → '한도심사요청여부': '0회' → 0, '1회이상' → 1
df['한도심사요청여부'] = df['한도심사요청건수'].map({
    '0회': 0,
    '1회이상': 1
    }).astype(int)
df.drop(columns=['한도심사요청건수'], inplace=True)

# 'RV실사용여부' 변수 추가
df['RV실사용여부'] = (df['RV약정청구율'] > 0).astype(int)

# '강제한도감액횟수_2회이상여부' 변수 추가
df['강제한도감액횟수_2회이상여부'] = (df['강제한도감액횟수_R12M'] > 1).astype(int)

# '강제한도감액금액_R12M_3이상여부' 변수 추가
df['강제한도감액금액_R12M_3이상여부'] = (df['강제한도감액금액_R12M'] > 2).astype(int)

# '상향가능CA한도금액_1여부' 변수 추가
df['상향가능CA한도금액_1여부'] = (df['상향가능CA한도금액'] == 1).astype(int)

# '카드이용한도금액_A수준복합' 변수 추가
a_limit = df[df['Segment'] == 'A']['카드이용한도금액_B1M']
q1 = a_limit.quantile(0.25)
q3 = a_limit.quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
a_no_outlier = a_limit[(a_limit >= lower_bound) & (a_limit <= upper_bound)]
a_B1M = a_no_outlier.min()
print(f"A의 이상치 제외 후 최솟값: {a_B1M:,}")  # 170,344

a_limit = df[df['Segment'] == 'A']['카드이용한도금액_B2M']
q1 = a_limit.quantile(0.25)
q3 = a_limit.quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
a_no_outlier = a_limit[(a_limit >= lower_bound) & (a_limit <= upper_bound)]
a_B2M = a_no_outlier.min()
print(f"A의 이상치 제외 후 최솟값: {a_B2M:,}")  # 170,344

def classify_dual_limit(row):
    b1 = row['카드이용한도금액_B1M'] >= a_B1M
    b2 = row['카드이용한도금액_B2M'] >= a_B2M
    if b1 and b2:
        return 2     # 둘 다 170,344 이상
    elif b1 or b2:
        return 1     # 하나만 170,344 이상
    else:
        return 0    # 둘 다 170,344 미만

df['카드이용한도금액_A수준복합'] = df.apply(classify_dual_limit, axis=1)
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4256075634.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['RV_전환가능여부_이진'] = (df['RV전환가능여부'] == 'N').astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4256075634.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['한도증액_R12M_여부'] = df['한도증액횟수_R12M'].map({
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4256075634.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['한도심사요청여부'] = df['한도심사요청건수'].map({
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4256075634.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['RV실사용여부'] = (df['RV약정청구율'] > 0).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4256075634.py:36: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['강제한도감액횟수_2회이상여부'] = (df['강제한도감액횟수_R12M'] > 1).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4256075634.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['강제한도감액금액_R12M_3이상여부'] = (df['강제한도감액금액_R12M'] > 2).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4256075634.py:42: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['상향가능CA한도금액_1여부'] = (df['상향가능CA한도금액'] == 1).astype(int)
# A의 이상치 제외 후 최솟값: 170,344
# A의 이상치 제외 후 최솟값: 170,344
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4256075634.py:75: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['카드이용한도금액_A수준복합'] = df.apply(classify_dual_limit, axis=1)

# %% [markdown]
# #### 3. 승인매출정보

# %%
#  업종별 변수

# '_n순위업종_AB' 변수 추가 (상관계수 -0.3030)

'''
- 1순위 업종이 쇼핑	+1
- 2순위 업종이 사교활동	+1
- 2순위 업종이 교육	+0.5
- 2순위 업종이 의료	+1.5 (A, B에서 더 강하게 나타나므로)
- 3순위 업종이 사교활동	+1
- 3순위 업종이 의료	+1.5 (A, B에서 더 강하게 나타나므로)

- 2순위 업종이 없음 -1
- 3순위 업종이 없음 -1
- 2순위 업종이 교통 -0.5
- 2순위 업종이 납부 -0.5
'''

def compute_ab_score(row):
    score = 0
    # 가점 조건
    if row['_1순위업종'] == '쇼핑':
        score += 1
    if row['_2순위업종'] == '사교활동':
        score += 1
    if row['_2순위업종'] == '교육':
        score += 0.5
    if row['_2순위업종'] == '의료':
        score += 1
    if row['_3순위업종'] == '사교활동':
        score += 1
    if row['_3순위업종'] == '의료':
        score += 1

    # 감점 조건
    if row['_2순위업종'] == '없음':
        score -= 1
    if row['_3순위업종'] == '없음':
        score -= 1
    if row['_2순위업종'] == '교통':
        score -= 0.5
    if row['_2순위업종'] == '납부':
        score -= 0.5

    return score

df['_n순위업종_AB'] = df.apply(compute_ab_score, axis=1)

# '_n순위쇼핑업종_AB' 변수 추가 (상관계수 -0.3304)

'''
- 1순위 쇼핑업종이 온라인 +1
- 2순위 쇼핑업종이 도소매 +1
- 3순위 쇼핑업종이 마트 +1

- 1순위 쇼핑업종이 없음 -1
- 2순위 쇼핑업종이 슈퍼마켓 -0.5
- 2순위 쇼핑업종이 없음 -0.5
- 3순위 쇼핑업종이 없음 -1
'''

def compute_ab_score(row):
    score = 0
    # 가점 조건
    if row['_1순위쇼핑업종'] == '온라인':
        score += 1
    if row['_2순위쇼핑업종'] == '도소매':
        score += 1
    if row['_3순위쇼핑업종'] == '마트':
        score += 1

    # 감점 조건
    if row['_1순위쇼핑업종'] == '없음':
        score -= 1
    if row['_2순위쇼핑업종'] == '슈퍼마켓':
        score -= 0.5
    if row['_2순위쇼핑업종'] == '없음':
        score -= 0.5
    if row['_3순위쇼핑업종'] == '없음':
        score -= 1

    return score

df['_n순위쇼핑업종_AB'] = df.apply(compute_ab_score, axis=1)

# '_n순위교통업종_AB' 변수 추가 (상관계수 -0.34514)

'''
- 1순위 교통업종이 주유 +1
- 2순위 교통업종이 정비 +1
- 3순위 교통업종이 택시 +0.5
- 3순위 교통업종이 정비 +0.5
- 3순위 교통업종이 철도버스 +0.5

- 1순위 교통업종이 없음 -1
- 2순위 교통업종이 없음 -1
'''

def compute_ab_score(row):
    score = 0
    # 가점 조건
    if row['_1순위교통업종'] == '주유':
        score += 1
    if row['_2순위교통업종'] == '정비':
        score += 1
    if row['_3순위교통업종'] == '택시':
        score += 0.5
    if row['_3순위교통업종'] == '정비':
        score += 0.5
    if row['_3순위교통업종'] == '철도버스':
        score += 0.5

    # 감점 조건
    if row['_1순위교통업종'] == '없음':
        score -= 1
    if row['_2순위교통업종'] == '없음':
        score -= 1

    return score

df['_n순위교통업종_AB'] = df.apply(compute_ab_score, axis=1)

# '_n순위여유업종_AB' 변수 추가 (상관계수 -0.26628)

'''
- 1순위 여유업종이 운동 +1
- 1순위 여유업종이 항공 +1
- 2순위 여유업종이 숙박 +1
- 2순위 여유업종이 공연 +1
- 3순위 여유업종이 숙박 +1
- 3순위 여유업종이 공연 +1
- 3순위 여유업종이 여유기타 +1

- 1순위 여유업종이 없음 -0.5
- 2순위 여유업종이 없음 -0.5
- 3순위 여유업종이 없음 -0.5
'''

def compute_ab_score(row):
    score = 0
    # 가점 조건
    if row['_1순위여유업종'] == '운동':
        score += 1
    if row['_1순위여유업종'] == '항공':
        score += 1
    if row['_2순위여유업종'] == '숙박':
        score += 1
    if row['_2순위여유업종'] == '공연':
        score += 1
    if row['_3순위여유업종'] == '숙박':
        score += 1
    if row['_3순위여유업종'] == '공연':
        score += 1
    if row['_3순위여유업종'] == '여유기타':
        score += 1

    # 감점 조건
    if row['_1순위여유업종'] == '없음':
        score -= 0.5
    if row['_2순위여유업종'] == '없음':
        score -= 0.5
    if row['_3순위여유업종'] == '없음':
        score -= 0.5

    return score

df['_n순위여유업종_AB'] = df.apply(compute_ab_score, axis=1)

# '_n순위납부업종_AB' 변수 추가 (상관계수 -0.2579)

'''
- 1순위 납부업종이 납부기타 +0.5
- 1순위 납부업종이 보험료 +0.5
- 1순위 납부업종이 통신비 +0.5
- 2순위 납부업종이 납부기타 +0.5
- 2순위 납부업종이 보험료 +0.5
- 2순위 납부업종이 통신비 +0.5
- 3순위 납부업종이 납부기타 +0.5

- 1순위 납부업종이 없음 -0.5
- 2순위 납부업종이 없음 -0.5
- 3순위 납부업종이 없음 -0.5
'''

def compute_ab_score(row):
    score = 0
    # 가점 조건
    if row['_1순위납부업종'] == '납부기타':
        score += 0.5
    if row['_1순위납부업종'] == '보험료':
        score += 0.5
    if row['_1순위납부업종'] == '통신비':
        score += 0.5
    if row['_2순위납부업종'] == '납부기타':
        score += 0.5
    if row['_2순위납부업종'] == '보험료':
        score += 0.5
    if row['_2순위납부업종'] == '통신비':
        score += 0.5
    if row['_3순위납부업종'] == '납부기타':
        score += 0.5

    # 감점 조건
    if row['_1순위납부업종'] == '없음':
        score -= 0.5
    if row['_2순위납부업종'] == '없음':
        score -= 0.5
    if row['_3순위납부업종'] == '없음':
        score -= 0.5

    return score

df['_n순위납부업종_AB'] = df.apply(compute_ab_score, axis=1)

# '_n순위@@업종_AB' 5개 변수 합친 변수 '_n순위업종_AB_총합' 추가 (상관계수 -0.3927)
df['_n순위업종_AB_총합'] = (
    df['_n순위업종_AB'] +
    df['_n순위쇼핑업종_AB'] +
    df['_n순위교통업종_AB'] +
    df['_n순위여유업종_AB'] +
    df['_n순위납부업종_AB']
)

# '_n순위@@업종' 변수 삭제
cols_to_drop = [
    '_1순위업종','_2순위업종','_3순위업종',
    '_1순위쇼핑업종','_2순위쇼핑업종','_3순위쇼핑업종',
    '_1순위교통업종','_2순위교통업종','_3순위교통업종',
    '_1순위여유업종','_2순위여유업종','_3순위여유업종',
    '_1순위납부업종','_2순위납부업종','_3순위납부업종'
]

df.drop(columns=cols_to_drop, inplace=True)

# '이용금액대_점수' 변수 생성 (상관계수 -0.6026)
amount_mapping = {
    '01.100만원+': 18,
    '02.50만원+': 5,
    '03.30만원+': 2,
    '04.10만원+': 2,
    '05.10만원-': 1,
    '09.미사용': 1
}

df['이용금액대_점수'] = df['이용금액대'].map(amount_mapping)

# 원래 변수 '이용금액대' 삭제
df = df.drop(columns=['이용금액대'])

# '이용여부_@@' 변수 생성
df['이용여부_기본']   = (df['최종이용일자_기본'] != 10101).astype(int)
df['이용여부_신판']   = (df['최종이용일자_신판'] != 10101).astype(int)
df['이용여부_CA']    = (df['최종이용일자_CA'] != 10101).astype(int)
df['이용여부_카드론'] = (df['최종이용일자_카드론'] != 10101).astype(int)
df['이용여부_체크']   = (df['최종이용일자_체크'] != 10101).astype(int)
df['이용여부_일시불'] = (df['최종이용일자_일시불'] != 10101).astype(int)
df['이용여부_할부']   = (df['최종이용일자_할부'] != 10101).astype(int)

# 원래 '최종이용일자_@@' 변수 삭제
for i in ['최종이용일자_기본','최종이용일자_신판','최종이용일자_CA','최종이용일자_카드론','최종이용일자_체크','최종이용일자_일시불','최종이용일자_할부']:
  df = df.drop(columns=[i])
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['_n순위업종_AB'] = df.apply(compute_ab_score, axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:84: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['_n순위쇼핑업종_AB'] = df.apply(compute_ab_score, axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:121: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['_n순위교통업종_AB'] = df.apply(compute_ab_score, axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:167: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['_n순위여유업종_AB'] = df.apply(compute_ab_score, axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:213: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['_n순위납부업종_AB'] = df.apply(compute_ab_score, axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:216: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['_n순위업종_AB_총합'] = (
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:245: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용금액대_점수'] = df['이용금액대'].map(amount_mapping)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:251: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_기본']   = (df['최종이용일자_기본'] != 10101).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:252: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_신판']   = (df['최종이용일자_신판'] != 10101).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:253: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_CA']    = (df['최종이용일자_CA'] != 10101).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:254: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_카드론'] = (df['최종이용일자_카드론'] != 10101).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:255: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_체크']   = (df['최종이용일자_체크'] != 10101).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:256: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_일시불'] = (df['최종이용일자_일시불'] != 10101).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3397345144.py:257: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용여부_할부']   = (df['최종이용일자_할부'] != 10101).astype(int)

# %%
# 건수별 평균 이용금액 (B0M만) (R12,6,3M 제외)

##### 이용건수 #####

# 데이터 값이 모두 같은 변수 제거
df = df.drop(columns=['이용건수_부분무이자_B0M'])

# '이용건수_신용_B0M' 변수 값 보정
df['이용건수_신용_B0M'] = df['이용건수_신용_B0M'] + df['이용건수_카드론_B0M']



##### 이용금액 #####

# 데이터 값이 모두 같은 변수 제거
df = df.drop(columns=['이용금액_부분무이자_B0M'])

# '이용금액_신용_B0M', '이용금액_신판_B0M' 변수 생성
df['이용금액_신용_B0M'] = df['이용금액_일시불_B0M'] + df['이용금액_할부_B0M'] + df['이용금액_CA_B0M'] + df['이용금액_카드론_B0M']
df['이용금액_신판_B0M'] = df['이용금액_일시불_B0M'] + df['이용금액_할부_B0M']

# 건수별평균이용금액 변수 생성
df['건수별평균이용금액_신용_B0M'] = np.where(
    (df['이용건수_신용_B0M'] == 0) | (df['이용금액_신용_B0M'] == 0), 0,
    df['이용금액_신용_B0M'] / df['이용건수_신용_B0M'].abs()
)

df['건수별평균이용금액_신판_B0M'] = np.where(
    (df['이용건수_신판_B0M'] == 0) | (df['이용금액_신판_B0M'] == 0), 0,
    df['이용금액_신판_B0M'] / df['이용건수_신판_B0M'].abs()
)

df['건수별평균이용금액_일시불_B0M'] = np.where(
    (df['이용건수_일시불_B0M'] == 0) | (df['이용금액_일시불_B0M'] == 0), 0,
    df['이용금액_일시불_B0M'] / df['이용건수_일시불_B0M'].abs()
)

df['건수별평균이용금액_할부_B0M'] = np.where(
    (df['이용건수_할부_B0M'] == 0) | (df['이용금액_할부_B0M'] == 0), 0,
    df['이용금액_할부_B0M'] / df['이용건수_할부_B0M'].abs()
)

df['건수별평균이용금액_할부_유이자_B0M'] = np.where(
    (df['이용건수_할부_유이자_B0M'] == 0) | (df['이용금액_할부_유이자_B0M'] == 0), 0,
    df['이용금액_할부_유이자_B0M'] / df['이용건수_할부_유이자_B0M'].abs()
)

df['건수별평균이용금액_할부_무이자_B0M'] = np.where(
    (df['이용건수_할부_무이자_B0M'] == 0) | (df['이용금액_할부_무이자_B0M'] == 0), 0,
    df['이용금액_할부_무이자_B0M'] / df['이용건수_할부_무이자_B0M'].abs()
)

df['건수별평균이용금액_CA_B0M'] = np.where(
    (df['이용건수_CA_B0M'] == 0) | (df['이용금액_CA_B0M'] == 0), 0,
    df['이용금액_CA_B0M'] / df['이용건수_CA_B0M'].abs()
)

df['건수별평균이용금액_체크_B0M'] = np.where(
    (df['이용건수_체크_B0M'] == 0) | (df['이용금액_체크_B0M'] == 0), 0,
    df['이용금액_체크_B0M'] / df['이용건수_체크_B0M'].abs()
)

df['건수별평균이용금액_카드론_B0M'] = np.where(
    (df['이용건수_카드론_B0M'] == 0) | (df['이용금액_카드론_B0M'] == 0), 0,
    df['이용금액_카드론_B0M'] / df['이용건수_카드론_B0M'].abs()
)
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2011737505.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용금액_신용_B0M'] = df['이용금액_일시불_B0M'] + df['이용금액_할부_B0M'] + df['이용금액_CA_B0M'] + df['이용금액_카드론_B0M']
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2011737505.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['이용금액_신판_B0M'] = df['이용금액_일시불_B0M'] + df['이용금액_할부_B0M']
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2011737505.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_신용_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2011737505.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_신판_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2011737505.py:33: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_일시불_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2011737505.py:38: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_할부_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2011737505.py:43: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_할부_유이자_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2011737505.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_할부_무이자_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2011737505.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_CA_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2011737505.py:58: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_체크_B0M'] = np.where(
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2011737505.py:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['건수별평균이용금액_카드론_B0M'] = np.where(

# %%
# 분야별 총 이용금액 및 카드론 이용여부

# '쇼핑_총이용금액' 변수 생성
shopping_columns = ['쇼핑_도소매_이용금액',
                    '쇼핑_백화점_이용금액',
                    '쇼핑_마트_이용금액',
                    '쇼핑_슈퍼마켓_이용금액',
                    '쇼핑_편의점_이용금액',
                    '쇼핑_아울렛_이용금액',
                    '쇼핑_온라인_이용금액',
                    '쇼핑_기타_이용금액']
df['쇼핑_총이용금액'] = df[shopping_columns].sum(axis=1)

# '교통_총이용금액' 변수 생성
shopping_columns = ['교통_주유이용금액',
                    '교통_정비이용금액',
                    '교통_통행료이용금액',
                    '교통_버스지하철이용금액',
                    '교통_택시이용금액',
                    '교통_철도버스이용금액']
df['교통_총이용금액'] = df[shopping_columns].sum(axis=1)

# '여유_총이용금액' 변수 생성
shopping_columns = ['여유_운동이용금액',
                    '여유_Pet이용금액',
                    '여유_공연이용금액',
                    '여유_공원이용금액',
                    '여유_숙박이용금액',
                    '여유_항공이용금액',
                    '여유_기타이용금액']
df['여유_총이용금액'] = df[shopping_columns].sum(axis=1)

# '납부_총이용금액' 변수 생성
shopping_columns = ['납부_통신비이용금액',
                    '납부_관리비이용금액',
                    '납부_가스전기료이용금액',
                    '납부_보험료이용금액',
                    '납부_기타이용금액']
df['납부_총이용금액'] = df[shopping_columns].sum(axis=1)

# 상관계수 절댓값 0.3 넘는 변수 5개만 합치기
shopping_columns = ['쇼핑_도소매_이용금액',
                    '쇼핑_마트_이용금액',
                    '쇼핑_온라인_이용금액',
                    '교통_주유이용금액',
                    '납부_기타이용금액']
df['0.3이상_총이용금액'] = df[shopping_columns].sum(axis=1)

# 쇼핑/교통/여유/납부 다 합치기
columns = ['쇼핑_총이용금액',
          '교통_총이용금액',
          '여유_총이용금액',
          '납부_총이용금액']
df['총이용금액_쇼핑교통여유납부'] = df[columns].sum(axis=1)

# 기존 변수 다 삭제
columns_to_drop = [
    '쇼핑_도소매_이용금액', '쇼핑_백화점_이용금액', '쇼핑_마트_이용금액',
    '쇼핑_슈퍼마켓_이용금액', '쇼핑_편의점_이용금액', '쇼핑_아울렛_이용금액',
    '쇼핑_온라인_이용금액', '쇼핑_기타_이용금액',

    '교통_주유이용금액', '교통_정비이용금액', '교통_통행료이용금액',
    '교통_버스지하철이용금액', '교통_택시이용금액', '교통_철도버스이용금액',

    '여유_운동이용금액', '여유_Pet이용금액', '여유_공연이용금액',
    '여유_공원이용금액', '여유_숙박이용금액', '여유_여행이용금액',
    '여유_항공이용금액', '여유_기타이용금액',

    '납부_통신비이용금액', '납부_관리비이용금액', '납부_렌탈료이용금액',
    '납부_가스전기료이용금액', '납부_보험료이용금액', '납부_유선방송이용금액',
    '납부_건강연금이용금액', '납부_기타이용금액'
]

# 변수 삭제
df.drop(columns=columns_to_drop, inplace=True)

# '카드론이용여부' 변수 생성
df['카드론이용여부'] = (
    (df['최초카드론이용경과월'] != 999) &
    (df['최종카드론이용경과월'] != 999)
).astype(int)
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3404545468.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['쇼핑_총이용금액'] = df[shopping_columns].sum(axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3404545468.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['교통_총이용금액'] = df[shopping_columns].sum(axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3404545468.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['여유_총이용금액'] = df[shopping_columns].sum(axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3404545468.py:39: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['납부_총이용금액'] = df[shopping_columns].sum(axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3404545468.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['0.3이상_총이용금액'] = df[shopping_columns].sum(axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3404545468.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['총이용금액_쇼핑교통여유납부'] = df[columns].sum(axis=1)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\3404545468.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['카드론이용여부'] = (

# %% [markdown]
# #### 4.청구입금정보 , 6.채널정보 , 7.마케팅정보 (구간별 매핑)

# %%
df['할인건수_R3M'] = df['할인건수_R3M'].map({'1회 이상': 0, '10회 이상': 1, '20회 이상': 2,'30회 이상': 3, '40회 이상': 4})
df['할인건수_B0M'] = df['할인건수_B0M'].map({'1회 이상': 0, '10회 이상': 1})

df['인입횟수_ARS_R6M'] = df['인입횟수_ARS_R6M'].map({'1회 이상': 0, '10회 이상': 1})
df['이용메뉴건수_ARS_R6M'] = df['이용메뉴건수_ARS_R6M'].map({'1회 이상': 0, '10회 이상': 1, '20회 이상': 2, '30회 이상': 3})
df['방문횟수_PC_R6M'] = df['방문횟수_PC_R6M'].map({'1회 이상': 0, '10회 이상': 1, '20회 이상': 2, '30회 이상': 3, '40회 이상': 4})
df['방문일수_PC_R6M'] = df['방문일수_PC_R6M'].map({'1회 이상': 0, '10회 이상': 1, '20회 이상': 2, '30회 이상': 3})
df['방문횟수_앱_R6M'] = df['방문횟수_앱_R6M'].map({'1회 이상': 0, '10회 이상': 1, '20회 이상': 2, '30회 이상': 3, '40회 이상': 4,
                                                                     '50회 이상': 5, '60회 이상': 6, '70회 이상': 7, '80회 이상': 8})

df['캠페인접촉건수_R12M'] = df['캠페인접촉건수_R12M'].map({'1회 이상': 0, '5회 이상': 1,
                                                                             '10회 이상': 2,'15회 이상': 3, '20회 이상': 4, '25회 이상': 5})
df['캠페인접촉일수_R12M'] = df['캠페인접촉일수_R12M'].map({'1일 이상': 0, '5일 이상': 1, '10일 이상': 2,
                                                                             '15일 이상': 3, '20일 이상': 4})

# %% [markdown]
# ### 직접 한 피쳐 엔지니어링

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import platform

# ---------------------------------------------------------
# 1. 폰트 설정
# ---------------------------------------------------------
system_name = platform.system()
if system_name == 'Windows':
    plt.rc('font', family='Malgun Gothic')
elif system_name == 'Darwin':
    plt.rc('font', family='AppleGothic')
else:
    plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False

# ---------------------------------------------------------
# 2. [오류 해결] ID 컬럼 복구 (Index -> Column)
# ---------------------------------------------------------
# merged_df가 정의되어 있다고 가정합니다. (이전 셀 실행 결과)

# 'ID'가 컬럼에 없고, 혹시 인덱스 이름이 'ID'라면 리셋
if 'ID' not in df.columns:
    print("⚠️ 'ID' 컬럼이 보이지 않아 인덱스 초기화를 시도합니다...")
    df = df.reset_index()

# 리셋 후에도 'ID'가 없는 경우 (인덱스 이름이 다른 경우 등)
if 'ID' not in df.columns:
    # 혹시 컬럼명이 'index'로 되어있거나 대소문자가 다른지 확인
    print(f"❌ 여전히 'ID' 컬럼이 없습니다. 현재 컬럼 목록: {list(df.columns)}")
    # 만약 'index'라는 컬럼이 생겼고 그게 ID라면 이름 변경
    if 'index' in df.columns:
        print("ℹ️ 'index' 컬럼을 'ID'로 변경합니다.")
        df.rename(columns={'index': 'ID'}, inplace=True)

# ---------------------------------------------------------
# 3. 데이터 집계 및 시각화 재시도
# ---------------------------------------------------------
if 'ID' in df.columns and 'Segment' in df.columns:
    print("✅ ID 컬럼 확보 완료! 집계 및 시각화를 진행합니다.")

    # (1) ID별 평균 계산
    user_stats_df = df.groupby(['ID', 'Segment'], observed=True).agg({
        '카드이용한도금액': 'mean',
        '잔액_신판최대한도소진율_r3m': 'mean'
    }).reset_index()

    user_stats_df.rename(columns={
        '카드이용한도금액': '평균한도금액',
        '잔액_신판최대한도소진율_r3m': '평균소진율'
    }, inplace=True)

    # (2) 시각화 함수 정의
    def plot_segment_analysis(data, x_col, y_col, title, y_label):
        # 순서 정렬
        if data[x_col].dtype.name != 'category':
            data[x_col] = pd.Categorical(data[x_col], categories=['A', 'B', 'C', 'D', 'E'], ordered=True)
        
        # 통계값 계산
        stats = data.groupby(x_col)[y_col].agg(['count', 'mean', 'min', 'max'])
        
        # 그래프
        fig, ax = plt.subplots(figsize=(12, 9))
        sns.boxplot(x=x_col, y=y_col, data=data, 
                    order=['A', 'B', 'C', 'D', 'E'], 
                    palette='coolwarm', showfliers=False, ax=ax)
        
        ax.set_title(title, fontsize=16, pad=20)
        ax.set_ylabel(y_label, fontsize=12)
        ax.grid(axis='y', linestyle='--', alpha=0.5)
        
        # 표 추가
        cell_text = []
        for row in stats.values:
            if '소진율' in title:
                formatted_row = [f"{int(row[0]):,}", f"{row[1]:.3f}", f"{row[2]:.3f}", f"{row[3]:.3f}"]
            else:
                formatted_row = [f"{x:,.0f}" if i==0 else f"{x:,.0f}" for i, x in enumerate(row)]
            cell_text.append(formatted_row)
            
        the_table = plt.table(cellText=cell_text,
                              rowLabels=stats.index,
                              colLabels=['고객수', '평균', '최소', '최대'],
                              loc='bottom', cellLoc='center',
                              bbox=[0.0, -0.3, 1.0, 0.25])
        
        the_table.auto_set_font_size(False)
        the_table.set_fontsize(11)
        the_table.scale(1, 1.5)

        plt.subplots_adjust(left=0.1, bottom=0.25)
        plt.show()

    # (3) 실행
    # 한도금액
    plot_segment_analysis(user_stats_df, 'Segment', '평균한도금액', 
                          'Segment별 고객 평균 한도금액 분포', '한도금액 (원)')

    # 소진율 (이상치 Cap)
    user_stats_df['시각화용_소진율'] = user_stats_df['평균소진율'].clip(0, 1.2)
    plot_segment_analysis(user_stats_df, 'Segment', '시각화용_소진율', 
                          'Segment별 고객 평균 한도 소진율 (최대소진율 기준)', '소진율 (0.0 ~ 1.2)')

else:
    print("❌ 오류: 'ID' 또는 'Segment' 컬럼을 찾을 수 없습니다.")
    print(f"현재 컬럼 목록: {list(merged_df.columns)}")
# Out:
# ⚠️ 'ID' 컬럼이 보이지 않아 인덱스 초기화를 시도합니다...
# ❌ 여전히 'ID' 컬럼이 없습니다. 현재 컬럼 목록: ['index', '남녀구분코드', '연령', 'Segment', '소지여부_신용', '소지카드수_유효_신용', '소지카드수_이용가능_신용', '입회일자_신용', '입회경과개월수_신용', '회원여부_연체', '이용거절여부_카드론', '동의여부_한도증액안내', '수신거부여부_TM', '수신거부여부_DM', '수신거부여부_메일', '수신거부여부_SMS', '탈회횟수_누적', '최종탈회후경과월', '탈회횟수_발급6개월
_이용금액', '_3순위여유업종_이용금액', '_1순위납부업종_이용금액', '_2순위납부업종_이용금액', '_3순위납부업종_이용금액', '할부건수_3M_R12M', '할부건수_6M_R12M', '할부건수_12M_R12M', '할부건수_14M_R12M', '할부금액_3M_R12M', '할부금액_6M_R12M', '할부금액_12M_R12M', '할부금액_14M_R12M', '할부건수_유이자_3M_R12M', '할부건수_유이 ...
# ℹ️ 'index' 컬럼을 'ID'로 변경합니다.
# ✅ ID 컬럼 확보 완료! 집계 및 시각화를 진행합니다.
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2671730198.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df = df.reset_index()
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2671730198.py:65: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=x_col, y=y_col, data=data,
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\2671730198.py:65: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=x_col, y=y_col, data=data,

# %%
import numpy as np

# ---------------------------------------------------------
# A/B 구분 필살기 파생변수 생성
# ---------------------------------------------------------

# 1. [1차 필터] 우량 고객 후보군 (Premium Candidate)
# 설명: "한도가 5만 원도 안 되면 절대 A, B가 아니다"라는 규칙을 0/1로 박아줍니다.
# 효과: C, D, E 하위 그룹을 1차적으로 걸러냅니다.
threshold_limit = 50000
user_stats_df['우량후보_여부'] = (user_stats_df['평균한도금액'] >= threshold_limit).astype(int)

# 2. [A/B 분리기] 실질 여유 한도 (Real Spare Limit) ★가장 강력함★
# 공식: 평균한도 * (1 - 소진율)
# 설명: "지금 당장 융통할 수 있는 현금 여력"이 얼마인가?
#   - A (부자 & 절약): 한도(大) * 여유(大) = 결과값 [초대형] (예: 13만원)
#   - B (부자 & 낭비): 한도(中) * 여유(小) = 결과값 [중소형] (예: 6만원)
#   - C/D/E: 한도가 작아서 결과값 [소형/영(0)]
user_stats_df['실질여유한도'] = user_stats_df['평균한도금액'] * (1 - user_stats_df['평균소진율'])

# 3. [공격성 지표] 한도 대비 소비성향 (Limit Aggressiveness)
# 공식: 평균소진율 / log(평균한도)
# 설명: 한도가 큰데 소진율까지 높으면(B) 점수가 확 튀게 만듭니다.
#   - A: 분자(소진율)가 낮아서 점수가 낮음 (안정적)
#   - B: 분자(소진율)가 높고 분모(한도)는 A보다 작아서 점수가 높음 (공격적)
# (log를 씌운 이유는 한도 금액의 단위가 너무 커서 소진율이 묻히는 것을 방지하기 위함입니다)
user_stats_df['한도대비_소비성향'] = user_stats_df['평균소진율'] / np.log1p(user_stats_df['평균한도금액'])

# ---------------------------------------------------------
# 생성된 변수 검증 (A와 B가 잘 벌어졌는지 눈으로 확인)
# ---------------------------------------------------------
print("변수 생성 완료! 등급별 평균값 비교:")
check_cols = ['평균한도금액', '평균소진율', '우량후보_여부', '실질여유한도', '한도대비_소비성향']
display(user_stats_df.groupby('Segment')[check_cols].mean().round(4))
# Out:
# 변수 생성 완료! 등급별 평균값 비교:
#               평균한도금액   평균소진율  우량후보_여부       실질여유한도  한도대비_소비성향
# Segment
# A        197598.8323  0.2694   1.0000  145085.6767     0.0221
# B        126400.1250  0.4108   1.0000   77921.2250     0.0355
# C         98017.1009  0.2616   0.7928   75935.8600        inf
# D         69321.6125  0.2468   0.5877   56116.8822        inf
# E         45248.4548  0.1394   0.3458   40933.9013        inf

# %%
# 4. 장기 우량 고객 (한도 10만 & 입회 10년 이상 가정)
# '입회경과개월수_신용'이 120개월 이상인 사람
df['장기우량고객'] = ((df['카드이용한도금액'] >= 100000) & (df['입회경과개월수_신용'] >= 120)).astype(int)

# 5. 클린 신용 지표 (최근 1년 카드론/CA 이용 0건)
# B등급과 A등급을 가르는 핵심
df['클린신용지표'] = ((df['이용건수_카드론_R12M'] == 0) & (df['이용건수_CA_R12M'] == 0)).astype(int)

# 6. 할부 의존 지표 (일시불 잔액보다 할부 잔액이 많은 경우)
df['할부의존지표'] = (df['잔액_할부_B0M'] > df['잔액_일시불_B0M']).astype(int)

# ---------------------------------------------------------
# [결과 확인] 등급별 이진화 변수 적중률
# ---------------------------------------------------------
check_bin_cols = ['장기우량고객', '클린신용지표', '할부의존지표']
display(df.groupby('Segment')[check_bin_cols].mean().round(3))
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4040194840.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['장기우량고객'] = ((df['카드이용한도금액'] >= 100000) & (df['입회경과개월수_신용'] >= 120)).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4040194840.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['클린신용지표'] = ((df['이용건수_카드론_R12M'] == 0) & (df['이용건수_CA_R12M'] == 0)).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\4040194840.py:10: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['할부의존지표'] = (df['잔액_할부_B0M'] > df['잔액_일시불_B0M']).astype(int)
#          장기우량고객  클린신용지표  할부의존지표
# Segment
# A         0.769   0.613   0.282
# B         0.208   0.444   0.514
# C         0.197   0.652   0.220
# D         0.081   0.725   0.217
# E         0.027   0.885   0.155

# %%
numeric_cols = ['잔액_리볼빙일시불이월_B0M', '잔액_리볼빙CA이월_B0M', '변동률_잔액_B1M', '혜택수혜율_R3M']

for col in numeric_cols:
    if col in df.columns:
        # 문자열을 숫자로 변환 (오류 방지 핵심)
        df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

# 7. 리볼빙_사용여부 (자금 압박 상태 확인)
df['리볼빙_사용여부'] = ((df['잔액_리볼빙일시불이월_B0M'] > 0) | (df['잔액_리볼빙CA이월_B0M'] > 0)).astype(int)

# 8. 잔액_급증신호 (단기 부채 급증 감지)
df['잔액_급증신호'] = (df['변동률_잔액_B1M'] > 0.5).astype(int)

# 9. 혜택_고수혜여부 (체리피커 성향 확인)
benefit_mean = df['혜택수혜율_R3M'].mean()
df['혜택_고수혜여부'] = (df['혜택수혜율_R3M'] > benefit_mean).astype(int)

print("📊 [Segment별 파생변수 비중 요약]")
check_cols = ['리볼빙_사용여부', '잔액_급증신호', '혜택_고수혜여부']

# 등급별 평균값 계산 (해당 특성을 가진 고객의 비율)
result_table = df.groupby('Segment', observed=True)[check_cols].mean()

# % 포맷으로 깔끔하게 출력
display(result_table.round(3).style.format("{:.1%}"))
# Out:
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\887937689.py:9: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['리볼빙_사용여부'] = ((df['잔액_리볼빙일시불이월_B0M'] > 0) | (df['잔액_리볼빙CA이월_B0M'] > 0)).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\887937689.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['잔액_급증신호'] = (df['변동률_잔액_B1M'] > 0.5).astype(int)
# C:\Users\Brain\AppData\Local\Temp\ipykernel_17144\887937689.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df['혜택_고수혜여부'] = (df['혜택수혜율_R3M'] > benefit_mean).astype(int)
# 📊 [Segment별 파생변수 비중 요약]
# <style type="text/css">
# </style>
# <table id="T_cb72d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb72d_level0_col0" class="col_heading level0 col0" >리볼빙_사용여부</th>
#       <th id="T_cb72d_level0_col1" class="col_heading level0 col1" >잔액_급증신호</th>
#       <th id="T_cb72d_level0_col2" class="col_heading level0 col2" >혜택_고수혜여부</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Segment</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb72d_level0_row0" class="row_heading level0 row0" >A</th>
#       <td id="T_cb72d_row0_col0" class="data row0 col0" >4.3%</td>
#       <td id="T_cb72d_row0_col1" class="data row0 col1" >0.2%</td>
#       <td id="T_cb72d_row0_col2" class="data row0 col2" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_cb72d_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_cb72d_row1_col0" class="data row1 col0" >8.3%</td>
#       <td id="T_cb72d_row1_col1" class="data row1 col1" >0.0%</td>
#       <td id="T_cb72d_row1_col2" class="data row1 col2" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_cb72d_level0_row2" class="row_heading level0 row2" >C</th>
#       <td id="T_cb72d_row2_col0" class="data row2 col0" >4.8%</td>
#       <td id="T_cb72d_row2_col1" class="data row2 col1" >0.7%</td>
#       <td id="T_cb72d_row2_col2" class="data row2 col2" >0.8%</td>
#     </tr>
#     <tr>
#       <th id="T_cb72d_level0_row3" class="row_heading level0 row3" >D</th>
#       <td id="T_cb72d_row3_col0" class="data row3 col0" >5.4%</td>
#       <td id="T_cb72d_row3_col1" class="data row3 col1" >0.7%</td>
#       <td id="T_cb72d_row3_col2" class="data row3 col2" >1.5%</td>
#     </tr>
#     <tr>
#       <th id="T_cb72d_level0_row4" class="row_heading level0 row4" >E</th>
#       <td id="T_cb72d_row4_col0" class="data row4 col0" >2.2%</td>
#       <td id="T_cb72d_row4_col1" class="data row4 col1" >1.1%</td>
#       <td id="T_cb72d_row4_col2" class="data row4 col2" >9.7%</td>
#     </tr>
#   </tbody>
# </table>

# %%
#이 코드는 전처리 맨 뒤쪽에 위치해야함

#1. 지나치게 값이 치우친 컬럼 제거 (모든 값이 동일한 컬럼도 여기에 포함)

threshold = 0.95 # 기준 설정 (한 값이 95% 이상 차지하면 불균형으로 간주)
imbalanced_col_names = []

print(f"[데이터 불균형 체크: 비중 {threshold*100}% 이상]")

for col in df.columns:
    if df[col].value_counts(normalize=True).iloc[0] >= threshold:
        imbalanced_col_names.append(col) 

print(f"\n불균형 컬럼 리스트: {imbalanced_col_names}")

#2. 지나치게 결측치가 많은 컬럼 제거
# 컬럼별 결측치 비율 확인 (%) / 50% 이상이면 삭제
missing_ratio = df.isnull().mean() * 100
over_50_missing_cols = missing_ratio[missing_ratio > 50].index.tolist()
print(missing_ratio[missing_ratio > 0].sort_values(ascending=False))


#3. 제거할 컬럼 적용
drop_cols = list(set(over_50_missing_cols) | set(imbalanced_col_names))
df = df.drop(columns=drop_cols)
# Out:
# [데이터 불균형 체크: 비중 95.0% 이상]
#
# 불균형 컬럼 리스트: ['소지여부_신용', '회원여부_연체', '탈회횟수_발급6개월이내', '유효카드수_신용_가족', '유효카드수_체크_가족', '이용가능카드수_신용_가족', '이용가능카드수_체크_가족', '이용카드수_신용_가족', '이용카드수_체크_가족', '이용금액_R3M_신용_가족', '이용금액_R3M_체크_가족', '_1순위신용체크구분', '연회비할인카드수_B0M', '기본연회비_B0M', '제휴연회비_B0M', '할인금액_기본연회비_B0M', '할인금액_제휴연회비_B0M', '청구금액_기본연회비_B0M', '청구금액_제휴연회비_B0M', '상품관련면제카드수_B0M', '임직원면제카드수_B0M', '우수회원면제카드수_B0M', '기타면제카드수_B0M', '자발한도감액횟수_R12M', '자발한도감액금액_R12M', '자발한도감액후경과월', '특별한도보유여부_R3M', '연체감액여부_R3M', '한도요청거절건수', '한도심사요청후경과월', '한도심사거절후경과월', '시장단기연체여부_R6M', '시장단기연체여부_R3M', '시장연체상환여부_R6M', '시장연체상환여부_R3M', '이용건수_할부_유이자_B0M', '이용건수_CA_B0M', '이용건수_카드론_B0M', '이용금액_할부_유이자_B0M', '이용금액_CA_B0M', '이용금액_카드론_B0M', '이용후경과월_부분무이자', '이용후경과월_카드론', '이용건수_부분무이자_R12M', '이용금액_부분무이자_R12M', '이용금액_카드론_R12M', '최대이용금액_부분무이자_R12M', '최대이용금액_카드론_R12M', '이용개월수_부분무이자_R12M', '이용건수_부분무이자_R6M', '이용건수_카드론_R6M', '이용금액_카드론_R6M', '이용개월수_부분무이자_R6M', '이용개월수_카드론_R6M', '이용건수_부분무이자_R3M', '이용건수_카드론_R3M', '이용금액_할부_유이자_R3M', '이용금액_카드론_R3M', '이용개월수_부분무이자_R3M', '이용개월수_카드론_R3M', '_2순위여유업종_이용금액', '_3순위여유업종_이용금액', '_3순위납부업종_이용금액', '할부건수_12M_R12M', '할부건수_14M_R12M', '할부금액_14M_R12M', '할부건수_유이자_6M_R12M', '할부건수_유이자_12M_R12M', '할부건수_유이자_14M_R12M', '할부금액_유이자_12M_R12M', '할부금액_유이자_14M_R12M', '할부건수_무이자_12M_R12M', '할부건수_무이자_14M_R12M', '할부금액_무이자_12M_R12M', '할부금액_무이자_14M_R12M', '할부건수_부분_3M_R12M', '할부건수_부분_6M_R12M', '할부건수_부분_12M_R12M', '할부건수_부분_14M_R12M', '할부금액_부분_3M_R12M', '할부금액_부분_6M_R12M', '할부금액_부분_12M_R12M', '할부금액_부분_14M_R12M', 'RP건수_아파트_B0M', 'RP건수_렌탈_B0M', 'RP건수_가스
'연체잔액_할부_B0M', '연체잔액_현금서비스_B0M', '연체잔액_카드론_B0M', '연체잔액_대환론_B0M', '연체원금_B1M', '연체원금_B2M', '연체일수_최근', '연체원금_최근', '매각잔액_B1M', '최종연체개월수_R15M', 'RV_평균잔액_R6M', 'RV_최대잔액_R6M', 'RV_평균잔액_R3M', 'RV_최대잔액_R3M', 'RV잔액이월횟수_R6M', 'RV잔액이월횟수_R3M', '잔액_할부_해외_B0M', '연체잔액_일시불_해외_B0M', '연체잔액_RV일시불_B0M', '연체잔액_RV일시불_해외_B0M', '연체잔액_할부_해외_B0M', '연체잔액_CA_B0M', '연체잔액_CA_해외_B0M', '평잔_RV일시불_해외_3M', '평잔_할부_해외_3M', '평잔_CA_해외_3M', '평잔_RV일시불_해외_6M', '평잔_할부_해외_6M', '평잔_CA_해외_6M', '인입횟수_ARS_R6M', '이용메뉴건수_ARS_R6M', '방문횟수_모바일웹_R6M', '방문일수_모바일웹_R6M', '방문월수_모바일웹_R6M', '방문후경과월_모바일웹_R6M', '방문횟수_모바일웹_B0M', '방문일수_모바일웹_B0M', '인입횟수_금융_IB_R6M', '인입횟수_IB_B0M', '인입일수_IB_B0M', '이용메뉴건수_IB_B0M', '인입불만횟수_IB_R6M', '인입불만일수_IB_R6M', '인입불만월수_IB_R6M', '인입불만후경과월_IB_R6M', '인입불만횟수_IB_B0M', '인입불만일수_IB_B0M', '상담건수_B0M', 'IB문의건수_사용승인내역_B0M', 'IB문의건수_한도_B0M', 'IB문의건수_선결 ...
# 연체일자_B0M          99.764700
# 최종카드론_대출일자        82.862267
# 최종카드론_신청경로코드      81.600300
# 최종카드론_금융상환방식코드    81.596567
# RV신청일자            81.291800
# OS구분코드            68.040600
# _2순위신용체크구분        39.933433
# 혜택수혜율_B0M         23.210600
# 최종유효년월_신용_이용      22.301600
# 잔여유효개월_실이용        22.301600
# Segment           20.000000
# 최종유효년월_신용_이용가능     8.786533
# 최종카드발급일자           1.760633
# _1순위신용체크구분         1.172700
# dtype: float64

# %% [markdown]
# ### 나머지 과정 전처리

# %%
# 문자열 관련 부분 제거 혹은 변경
# 직접 확인해봤었던만큼, 상관관계나 분류에 관련된 부분은 찾을 수 없었다.
df = df.drop(['연령', '_2순위신용체크구분', 'Life_Stage', '대표청구지고객주소구분코드', '대표청구서수령지구분코드',
       '청구서수령방법'], axis=1)

# %%
train_df = df[df["Segment"].notna()]
test_df = df[df["Segment"].isna()]

# %%
# 결측치 확인
print("=== 결측치 현황 ===")
print(train_df.isnull().sum())

# 수정된 결측치 제거 코드
print("\n=== 결측치 제거 시작 ===")
for col in train_df.columns:
    null_count = train_df[col].isnull().sum()
    if null_count > 0:
        mode_value = train_df[col].mode()
        if len(mode_value) > 0:
            # 핵심 변경 부분: 직접 할당
            train_df[col] = train_df[col].fillna(mode_value[0])
            
            # 제대로 채워졌는지 바로 확인
            remaining = train_df[col].isnull().sum()
            print(f"{col}: {null_count} → {remaining} (남은 결측치)")

print(f"\n=== 결측치 제거 완료 ===")
print(f"전체 남은 결측치 개수: {train_df.isnull().sum().sum()}")
# Out:
# === 결측치 현황 ===
# ID                0
# 남녀구분코드            0
# Segment           0
# 소지카드수_유효_신용       0
# 소지카드수_이용가능_신용     0
#                  ..
# 총이용금액_쇼핑교통여유납부    0
# 카드론이용여부           0
# 클린신용지표            0
# 할부의존지표            0
# 혜택_고수혜여부          0
# Length: 486, dtype: int64
#
# === 결측치 제거 시작 ===
# 최종유효년월_신용_이용가능: 210447 → 0 (남은 결측치)
# 최종유효년월_신용_이용: 534231 → 0 (남은 결측치)
# 최종카드발급일자: 41965 → 0 (남은 결측치)
# 혜택수혜율_B0M: 555522 → 0 (남은 결측치)
# 잔여유효개월_실이용: 534231 → 0 (남은 결측치)
#
# === 결측치 제거 완료 ===
# 전체 남은 결측치 개수: 0

# %%
df.to_parquet("backup.parquet")

# %%
df = pd.read_parquet('./backup.parquet') # 본인 경로에 맞게 수정

# %% [markdown]
# # 4. Modeling(1) - feature importance

# %%
import pandas as pd
import numpy as np
import gc

# from google.colab import drive
# drive.mount('/content/drive')

import sklearn
from sklearn.utils.class_weight import compute_class_weight
import imblearn
from imblearn.over_sampling import SMOTE
import xgboost as xgb
from xgboost import XGBClassifier

# %%
df = pd.read_parquet('./backup.parquet') # 본인 경로에 맞게 수정
# 백업파일 명 "backup.parquet"
train_df = df[df["Segment"].notna()]
test_df = df[df["Segment"].isna()]

# 결측치 확인
print("=== 결측치 현황 ===")
print(train_df.isnull().sum())

# 수정된 결측치 제거 코드
print("\n=== 결측치 제거 시작 ===")
for col in train_df.columns:
    null_count = train_df[col].isnull().sum()
    if null_count > 0:
        mode_value = train_df[col].mode()
        if len(mode_value) > 0:
            # 핵심 변경 부분: 직접 할당
            train_df[col] = train_df[col].fillna(mode_value[0])
            
            # 제대로 채워졌는지 바로 확인
            remaining = train_df[col].isnull().sum()
            print(f"{col}: {null_count} → {remaining} (남은 결측치)")

print(f"\n=== 결측치 제거 완료 ===")
print(f"전체 남은 결측치 개수: {train_df.isnull().sum().sum()}")

# 최적화, df 날려버리기 : 백업 파일 있으니 필요하면 사용할 것
del df
gc.collect()

feature_cols = [col for col in train_df.columns if col not in ["ID", "Segment"]]
X = train_df[feature_cols].copy()
y = train_df["Segment"].copy()
y = y.map({'A':0, 'B':1,'C':2,'D':3,'E':4})

del train_df
gc.collect()
# Out:
# === 결측치 현황 ===
# ID                0
# 남녀구분코드            0
# Segment           0
# 소지카드수_유효_신용       0
# 소지카드수_이용가능_신용     0
#                  ..
# 총이용금액_쇼핑교통여유납부    0
# 카드론이용여부           0
# 클린신용지표            0
# 할부의존지표            0
# 혜택_고수혜여부          0
# Length: 486, dtype: int64
#
# === 결측치 제거 시작 ===
# 최종유효년월_신용_이용가능: 210447 → 0 (남은 결측치)
# 최종유효년월_신용_이용: 534231 → 0 (남은 결측치)
# 최종카드발급일자: 41965 → 0 (남은 결측치)
# 혜택수혜율_B0M: 555522 → 0 (남은 결측치)
# 잔여유효개월_실이용: 534231 → 0 (남은 결측치)
#
# === 결측치 제거 완료 ===
# 전체 남은 결측치 개수: 0
# 0

# %%
# 클래스 weight 계산
classes = np.unique(y)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y)
class_weights = dict(zip(classes, weights))

# 각 샘플에 대해 weight 매핑
w_train = pd.Series(y).map(class_weights)

# 전체 feature로 XGBoost 학습 (변수 중요도 추출용)
temp_model = xgb.XGBClassifier(
    objective='multi:softprob',
    num_class=5,
    eval_metric='mlogloss',
    n_estimators=700,
    tree_method='hist',
    device='cuda',
    random_state=42
    )

temp_model.fit(X, y, sample_weight = w_train, verbose=False)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=700, n_jobs=None, num_class=5, ...)

# %%
# XGBoost 기준 중요도 상위 400개 변수 추출
importance_df = pd.DataFrame({
    'feature': X.columns,
    'importance': temp_model.feature_importances_
}).sort_values(by='importance', ascending=False)

top400_features = importance_df.head(400)['feature'].tolist()

print(top400_features)

top400_df = pd.DataFrame({'feature': top400_features})
top400_df.to_csv(
    "./data/top400_features_XGB_balanced.csv", # 저장 경로(본인꺼)
    index=False,
    encoding="utf-8-sig"
)
# Out:
# ['카드이용한도금액_A수준복합', '선입금원금_B5M', '할부금액_무이자_3M_R12M', '정상청구원금_B5M', '카드이용한도금액_B1M', '이용금액_체크_B0M', '할인금액_청구서_R3M', '정상청구원금_B0M', 'CA한도금액', '카드이용한도금액_B2M', '이용개월수_할부_R3M', '이용금액_선결제_R3M', '정상청구원금_B2M', '이용금액_R3M_신용체크', '평잔_CA_3M', '최대이용금액_체크_R12M', '방문일수_앱_B0M', '이용금액_할부_무이자_R12M', '이용개월수_할부_무이자_R6M', 'rv최초시작후경과일', '탈회횟수_발급1년이내', '여유_총이용금액', '이용금액_체크_R12M', '연체입금원금_B5M', '평잔_할부_3M', '이용금액_오프라인_B0M', '이용여부_CA', '이용개월수_할부_유이자_R6M', '증감율_이용금액_신용_전월', '이용개월수_할부_R12M', 'CA이자율_할인전', '연속유실적개월수_기본_24M_카드', '이용금액_CA_R6M', '입회일자_신용', '이용개월수_체크_R12M', '카드이용한도금액', '이용금액_할부_무이자_B0M', '이용개월수_CA_R6M', '할인금액_R3M', '건수별평균이용금액_체크_B0M', '최대이용금액_일시불_R12M', '최대이용금액_CA_R12M', '입회경과개월수_신용', '잔액_현금서비스_B2M', '이용카드수_체크', '이용금액_체크_R6M', '이용개월수_결제일_R6M', '이용건수_신용_R12M', '이용건수_페이_오프라인_B0M', '강제한도감액후경과월', '이용후경과월_신용', '이용금액_일시불_B0M', '이용금액_할부_무이자_R6M', '잔액_현금서비스_B1M', '최대이용금액_할부_R12M', '강제한도감액금액_R12M', '컨택건수_이용유도_LMS_B0M', '소지카드수_유효_신용', '할인금액_청구서_B0M', '이용금액_신용_B0M', '건수별평균이용금액_할부_무이자_B0M', '정상입금원금_B2M', '이용건수_카드론_R12M', '상향가능CA한도금액_1여부', 'RV현금서비스이자율_할인전', '이용후경과월_신판', '할부건수_무이자_3M_R12M', '유효카드수_신용체크', '이용금액대_점수', '이용개월수_신용_R12M', '이용금액_일시불_R12M', '이용금액_체크_R3M', '건수별평균이용금액_신용_B0M', '이용금액_해외', '컨택건수_이용유도_청구서_R6M', '_2순위카드이용건수', '최대이용금액_할부_무이자_R12M', 'RV일시불이자율_할인전', '월상환론한도금액', '카드론이용월수_누적', '_n순위납부업종_AB', '이용개월수_페이_오프라인_R6M', '변동률_RVCA평잔', '이용여부_할부', '월중평잔_CA', '한도증액_R12M_여부', '이용후경과월_할부_유이자', '_1순위쇼핑업종_이용금액', '이용개월수_체크_R3M', '이용건수_할부_유이자_R12M', '_1순위카드이용금액', '최초한도금액', '강제한도감액횟수_R12M', '최종카드론이용경과월', '최종카드론_대출금액', '잔액_신판ca평균한도소진율_r3m', '_2순위카드이용금액', '이용건수_간편결제_R3M', '평잔_일시불_6M', '연체입금원금_B0M', '증감율_이용금액_신판_분기', '_1순위카드이용건수', '변동률_카드론평잔', '최종카드발급일자', '소지카드수_이용가능_신용', '혜택수혜율_R3M', '마일_적립포인트_R3M', '수신거부여부_TM', '평잔_RV일시불_6M', '증감율_이용금액_일시불_분기', '유효카드수_신용', '청구금액_R6M', '이용건수_일시불_R6M', '_1순위여유업종_이용금액', '이용가능카드수_신용체크', '연체입금원금_B2M', '이용건수_할부_유이자_R6M', '월중평잔_RV일시불', '이용금액_오프라인_R6M', '이용건수_페이_오프라인_R3M', '포인트_적립포인트_R12M', '홈페이지_금융건수_R6M', '이용금액_일시불_R6M', 'RP후경과월_제휴사서비스직접판매', '할부금액_6M_R12M', '이용건수_간편결제_R6M', '이용건수_신판_R6M', '평잔_할부_6M', '평잔_3M', '가맹점매출금액_B2M', '이용금액_할부_유이자_R12M', '한도증액후경과월', '일시상환론한도금액', '이용건수_할부_R3M', '당사멤버쉽_방문횟수_B0M', '컨택건수_이용유도_LMS_R6M', '이용금액_할부_R12M', '이용건수_신판_R12M', '이용개월수_CA_R12M', '이용금액_신판_B0M', '방문일수_앱_R6M', '평잔_6M', '동의여부_한도증액안내', '이용건수_A페이_R6M', '할부건수_유이자_3M_R12M', '이용금액_오프라인_R3M', '정상입금원금_B5M', '당사멤버쉽_방문월수_R6M', '이용개월수_신판_R12M', '수신거부여부_메일', '할인금액_B0M', '최종카드론_대출이율', '증감율_이용금액_체크_분기', '이용건수_페이_온라인_R6M', '남녀구분코드', '이용금액_CA_R12M', '월중평잔_할부_B0M', '_n순위업종_AB_총합', '한도증액금액_R12M', '컨택건수_이용유도_EM_B0M', '할부의존지표', 'RP건수_B0M', '이용금액_부분무이자_R3M', '이용개월수_간편결제_R6M', '혜택수혜금액', '최대이용금액_할부_유이자_R12M', '카드_즉시가용_비율', '연속무실적개월수_기본_24M_카드', '보유여부_해외겸용_본인', '건수별평균이용금액_일시불_B0M', '_2순위업종_이용금액', '잔액_신판ca최대한도소진율_r6m', '혜택수혜금액_R3M', '이용카드수_신용체크', '최종카드발급경과월', '평잔_일시불_해외_6M', '포인트_포인트_건별_R3M', '컨택건수_보험_TM_R6M', '이용후경과월_체크', '이용건수_신용_R6M', '잔액_신판평균한도소진율_r6m', '변동률_일시불평잔', '회원_이용가능_점수', '평잔_CA_6M', '마케팅동의여부', '이용개월수_할부_유이자_R12M', '연체건수_R6M', '불만제기후경과월_R12M', '건수별평균이용금액_할부_B0M', '평잔_RV일시불_3M', '이용건수_할부_무이자_B0M', '이용건수_할부_R12M', '이용건수_CA_R12M', '대표결제일', '이용건수_일시불_R12M', '이용개월수_체크_R6M', '유효카드수_체크', '이용건수_온라인_B0M', '최초카드론이용경과월', '선결제건수_R6M', '할부금액_3M_R12M', '쇼핑_총이용금액', '최종유효년월_신용_이용가능', '상환개월수_결제일_R6M', '이용금액_할부_무이자_R3M', '잔액_신판최대한도소진율_r6m', '이용개월수_카드론_R12M', '최종연체회차', '클린신용지표', '건수별평균이용금액_신판_B0M', '_2순위쇼핑업종_이용금액', '잔액_신판ca평균한도소진율_r6m', '연체건수_R3M', '방문월수_앱_R6M', '변동률_CA평잔', '카드신청건수', '이용가능여부_해외겸용_신용_본인', '카드론이용금액_누적', '컨택건수_이용유도_청구서_B0M', '이용건수_페이_온라인_B0M', '잔액_할부_무이자_B0M', '홈페이지_선결제건수_R3M', '청구금액_R3M', '이용금액_할부_유이자_R6M', '이용개월수_결제일_R3M', '이용가맹점수', 'CL이자율_할인전', '할부건수_6M_R12M', '증감율_이용금액_일시불_전월', '이용여부_체크', 'RV_전환가능여부_이진', '컨택건수_이용유도_인터넷_R6M', '이용건수_일시불_B0M', '이용건수_오프라인_B0M', '_n순위여유업종_AB', '월중평잔_CA_B0M', '카드론이용건수_누적', '_3순위쇼핑업종_이용금액', '탈회횟수_누적', '컨택건수_CA_LMS_R6M', '이용건수_할부_무이자_R12M', 'RP금액_B0M', '이용건수_신판_B0M', '누적탈회밀도', '이용금액_간편결제_B0M', '잔액_신판평균한도소진율_r3m', 'RP건수_제휴사서비스직접판매_B0M', '이용개월수_일시불_R12M', '이용건수_오프라인_R3M', '이용금액_R3M_신용', '잔액_할부_B0M', '총이용금액_쇼핑교통여유납부', 'RP후경과월_교통', '이용건수_체크_R ...

# %% [markdown]
# # 5. 표준화

# %%
top400_df
# Out:
#               feature
# 0      카드이용한도금액_A수준복합
# 1           선입금원금_B5M
# 2    할부금액_무이자_3M_R12M
# 3          정상청구원금_B5M
# 4        카드이용한도금액_B1M
# ..                ...
# 395       변동률_RV일시불평잔
# 396  할부건수_무이자_6M_R12M
# 397       이용건수_체크_B0M
# 398      이용개월수_신판_R3M
# 399   증감율_이용건수_일시불_분기
#
# [400 rows x 1 columns]

# %%
# 트리모델의 경우, 최적화가 영향을거의 미치지 않아서 굳이 할 필요 없다고 함
# scaler = StandardScaler()
# scaler.fit(df)

# 파일을 따로 저장해서 메모리 사용량을 줄인다.
df= pd.read_parquet("backup.parquet", engine = "fastparquet")
train_df = df.loc[df["Segment"].notna()]
for col in train_df.columns:
    null_count = train_df[col].isnull().sum()
    if null_count > 0:
        mode_value = train_df[col].mode()
        if len(mode_value) > 0:
            # 핵심 변경 부분: 직접 할당
            train_df[col] = train_df[col].fillna(mode_value[0])
            
            # 제대로 채워졌는지 바로 확인
            remaining = train_df[col].isnull().sum()
            print(f"{col}: {null_count} → {remaining} (남은 결측치)")

train_df.to_parquet("train_data.parquet")
df.loc[df["Segment"].isnull()].to_parquet("test_data.parquet")
# Out:
# 최종유효년월_신용_이용가능: 210447 → 0 (남은 결측치)
# 최종유효년월_신용_이용: 534231 → 0 (남은 결측치)
# 최종카드발급일자: 41965 → 0 (남은 결측치)
# 혜택수혜율_B0M: 555522 → 0 (남은 결측치)
# 잔여유효개월_실이용: 534231 → 0 (남은 결측치)

# %%
# 최적화 코드
del df
gc.collect()
# Out:
# 20

# %% [markdown]
# # 6. Modeling(2) - final model train

# %% [markdown]
# ## XGBoost 모델 학습

# %%
import pandas as pd
import numpy as np
import gc
import os

# [수정] 구글 드라이브 마운트 코드 삭제 (로컬에서는 불필요)
# from google.colab import drive
# drive.mount('/content/drive')

import sklearn
from sklearn.utils.class_weight import compute_class_weight
import imblearn
from imblearn.over_sampling import SMOTE
import xgboost as xgb
from xgboost import XGBClassifier

# 현재 버전 및 준비 상태 확인
print(f"XGBoost version: {xgb.__version__}")
print("환경 준비 완료! 이제 데이터를 로드하세요.")
# Out:
# XGBoost version: 3.1.3
# 환경 준비 완료! 이제 데이터를 로드하세요.

# %%
train_df = pd.read_parquet('./train_data.parquet') # 본인 경로에 맞게 수정

feature_cols = [col for col in train_df.columns if col not in ["ID", "Segment"]]
X = train_df[feature_cols].copy()
y = train_df["Segment"].copy()
y = y.map({'A':0, 'B':1,'C':2,'D':3,'E':4})
inverse_label_map = {0: 'A', 1: 'B', 2: 'C', 3: 'D', 4: 'E'}

# 변수 400개 사용
top400_df = pd.read_csv("./data/top400_features_XGB_balanced.csv") # 본인 경로에 맞게 수정
top400_features = top400_df['feature'].tolist()
X_top400 = X[top400_features]

# 오버샘플링
smote = SMOTE(sampling_strategy={0: 30000, 1: 30000, 2: 250000}, random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_top400, y)

# 클래스별 weight 계산
classes = np.unique(y_resampled)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_resampled)
class_weights = dict(zip(classes, weights))
sample_weights = pd.Series(y_resampled).map(class_weights)

for cls in sorted(class_weights):
    print(f"클래스 {cls}: weight = {class_weights[cls]:.2f}")
# Out:
# 클래스 0: weight = 17.21
# 클래스 1: weight = 17.21
# 클래스 2: weight = 2.07
# 클래스 3: weight = 1.48
# 클래스 4: weight = 0.27

# %%
xgb_model = xgb.XGBClassifier(
    objective='multi:softprob',
    num_class=5,
    eval_metric='mlogloss',
    n_estimators=5000,
    tree_method='hist',
    device='cuda',
    random_state=42
    )

# 모델 학습 (검증 없이 전체 데이터 사용)
xgb_model.fit(
    X_resampled, y_resampled,
    sample_weight=sample_weights,
    verbose=False
)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=5000, n_jobs=None, num_class=5, ...)

# %%
xgb_model.save_model('./data/softvoting_xgb_xgb변수_3_3_25.json')

# %% [markdown]
# ## LightGBM 모델 학습

# %%
import pandas as pd
import numpy as np
import gc
import sklearn
from sklearn.utils.class_weight import compute_class_weight
import imblearn
from imblearn.over_sampling import SMOTE
import lightgbm as lgb
from lightgbm import early_stopping, log_evaluation, LGBMClassifier

# 버전 확인 (이미 설치한 GPU 버전이 잘 나오는지 확인)
print(f"LightGBM 버전: {lgb.__version__}")

# from google.colab import drive
# drive.mount('/content/drive')

# # LightGBM을 위한 GPU driver 설치 코드
# !mkdir -p /etc/OpenCL/vendors && echo "libnvidia-opencl.so.1" > /etc/OpenCL/vendors/nvidia.icd
# !sudo apt install nvidia-driver-460 nvidia-cuda-toolkit clinfo
# !apt-get update --fix-missing
# !pip install -q  lightgbm==4.1.0 \
#   --config-settings=cmake.define.USE_GPU=ON \
#   --config-settings=cmake.define.OpenCL_INCLUDE_DIR="/usr/local/cuda/include/" \
#   --config-settings=cmake.define.OpenCL_LIBRARY="/usr/local/cuda/lib64/libOpenCL.so"
# Out:
# LightGBM 버전: 4.6.0

# %%
train_df = pd.read_parquet('./train_data.parquet')

feature_cols = [col for col in train_df.columns if col not in ["ID", "Segment"]]
X = train_df[feature_cols].copy()
y = train_df["Segment"].copy()
y = y.map({'A':0, 'B':1,'C':2,'D':3,'E':4})
inverse_label_map = {0: 'A', 1: 'B', 2: 'C', 3: 'D', 4: 'E'}

# 변수 400개 사용
top400_df = pd.read_csv("./data/top400_features_XGB_balanced.csv")
top400_features = top400_df['feature'].tolist()
X_top400 = X[top400_features]

# 오버샘플링
smote = SMOTE(sampling_strategy={0: 30000, 1: 30000, 2: 250000}, random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_top400, y)

# 클래스별 weight 계산
classes = np.unique(y_resampled)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_resampled)
class_weights = dict(zip(classes, weights))
sample_weights = pd.Series(y_resampled).map(class_weights)

for cls in sorted(class_weights):
    print(f"클래스 {cls}: weight = {class_weights[cls]:.2f}")
# Out:
# 클래스 0: weight = 17.21
# 클래스 1: weight = 17.21
# 클래스 2: weight = 2.07
# 클래스 3: weight = 1.48
# 클래스 4: weight = 0.27

# %%
lgb_model = LGBMClassifier(
    objective='multiclass',
    boosting_type = 'gbdt',
    metric = 'multi_logloss',
    verbosity = -1,
    random_state = 42,
    device = 'gpu',
    num_class = 5,
    gpu_platform_id = 0,
    gpu_device_id = 0,

    num_boost_round = 3348, # n_estimators
    learning_rate = 0.16304239034369372,
    num_leaves = 260,
    max_depth = 6,
    min_data_in_leaf = 1200,
    bagging_fraction = 0.8999999999999999,
    bagging_freq = 4,
    feature_fraction = 0.8,
    lambda_l1 = 4.4610495762623494e-05,
    lambda_l2 = 0.6898684039866835,
    min_gain_to_split = 0.3944497642389666
    )

# 모델 학습 (검증 없이 전체 데이터 사용)
lgb_model.fit(
    X_resampled, y_resampled,
    sample_weight=sample_weights,
    callbacks=[
        log_evaluation(period=0)  # ✅ verbose_eval=False랑 같음!
        ]
)
# Out:
# LGBMClassifier(bagging_fraction=0.8999999999999999, bagging_freq=4,
#                device='gpu', feature_fraction=0.8, gpu_device_id=0,
#                gpu_platform_id=0, lambda_l1=4.4610495762623494e-05,
#                lambda_l2=0.6898684039866835, learning_rate=0.16304239034369372,
#                max_depth=6, metric='multi_logloss', min_data_in_leaf=1200,
#                min_gain_to_split=0.3944497642389666, num_boost_round=3348,
#                num_class=5, num_leaves=260, objective='multiclass',
#                random_state=42, verbosity=-1)

# %%
lgb_model.booster_.save_model('./data/softvoting_lgbm_model_3_3_25.txt')
print("모델 저장 완료!")
# Out:
# 모델 저장 완료!

# %% [markdown]
# ## CatBoost 모델 학습

# %%
import pandas as pd
import numpy as np
import gc

# from google.colab import drive
# drive.mount('/content/drive')

# # catboost 설치
# !pip install catboost

import sklearn
from sklearn.utils.class_weight import compute_class_weight
import imblearn
from imblearn.over_sampling import SMOTE
import xgboost as xgb
from xgboost import XGBClassifier
import catboost
from catboost import CatBoostClassifier

print(f"CatBoost 버전: {catboost.__version__}")
print("환경 준비 완료!")
# Out:
# CatBoost 버전: 1.2.8
# 환경 준비 완료!

# %%
train_df = pd.read_parquet('./train_data.parquet')

feature_cols = [col for col in train_df.columns if col not in ["ID", "Segment"]]
X = train_df[feature_cols].copy()
y = train_df["Segment"].copy()
y = y.map({'A':0, 'B':1,'C':2,'D':3,'E':4})
inverse_label_map = {0: 'A', 1: 'B', 2: 'C', 3: 'D', 4: 'E'}

# 변수 400개 사용
top400_df = pd.read_csv("./data/top400_features_XGB_balanced.csv")
top400_features = top400_df['feature'].tolist()
X_top400 = X[top400_features]

# 오버샘플링
smote = SMOTE(sampling_strategy={0: 60000, 1: 120000, 2: 240000}, random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_top400, y)

# 클래스별 weight 계산
classes = np.unique(y_resampled)
weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_resampled)
class_weights = dict(zip(classes, weights))
sample_weights = pd.Series(y_resampled).map(class_weights)

for cls in sorted(class_weights):
    print(f"클래스 {cls}: weight = {class_weights[cls]:.2f}")
# Out:
# 클래스 0: weight = 8.97
# 클래스 1: weight = 4.49
# 클래스 2: weight = 2.24
# 클래스 3: weight = 1.54
# 클래스 4: weight = 0.28

# %%
cat_model = CatBoostClassifier(
    task_type='GPU',
    devices='0',
    random_state=42,
    class_weights=weights.tolist(),
    iterations = 5000
)

# 모델 학습
cat_model.fit(X_resampled, y_resampled)
# Out:
# Learning rate set to 0.085066
# 0:	learn: 1.4418213	total: 410ms	remaining: 34m 8s
# 1:	learn: 1.3198921	total: 638ms	remaining: 26m 35s
# 2:	learn: 1.2211442	total: 900ms	remaining: 24m 59s
# 3:	learn: 1.1412086	total: 1.16s	remaining: 24m 14s
# 4:	learn: 1.0732060	total: 1.41s	remaining: 23m 30s
# 5:	learn: 1.0172773	total: 1.75s	remaining: 24m 17s
# 6:	learn: 0.9657936	total: 2.09s	remaining: 24m 52s
# 7:	learn: 0.9235306	total: 2.4s	remaining: 24m 54s
# 8:	learn: 0.8833493	total: 2.7s	remaining: 24m 58s
# 9:	learn: 0.8479018	total: 2.93s	remaining: 24m 23s
# 146:	learn: 0.3360235	total: 29.6s	remaining: 16m 16s
# 147:	learn: 0.3352186	total: 29.7s	remaining: 16m 13s
# 148:	learn: 0.3346743	total: 29.8s	remaining: 16m 10s
# 149:	learn: 0.3343369	total: 29.9s	remaining: 16m 7s
# 150:	learn: 0.3338801	total: 30.1s	remaining: 16m 5s
# 151:	learn: 0.3334342	total: 30.3s	remaining: 16m 5s
# 152:	learn: 0.3327609	total: 30.4s	remaining: 16m 2s
# 153:	learn: 0.3320435	total: 30.5s	remaining: 15m 59s
# 154:	learn: 0.3315867	total: 30.7s	remaining: 15m 59s
# 155:	learn: 0.3311112	total: 30.9s	remaining: 15m 58s
# 156:	learn: 0.3302621	total: 31s	remaining: 15m 55s
# 157:	learn: 0.3296406	total: 31.1s	remaining: 15m 52s
# 158:	learn: 0.3292432	total: 31.3s	remaining: 15m 51s
# 159:	learn: 0.3288803	total: 31.3s	remaining: 15m 48s
# 160:	learn: 0.3285650	total: 31.5s	remaining: 15m 47s
# 161:	learn: 0.3282277	total: 31.7s	remaining: 15m 45s
# 162:	learn: 0.3275492	total: 31.8s	remaining: 15m 44s
# 163:	learn: 0.3271513	total: 31.9s	remaining: 15m 41s
# 164:	learn: 0.3268118	total: 32.2s	remaining: 15m 42s
# 165:	learn: 0.3263274	total: 32.3s	remaining: 15m 39s
# 166:	learn: 0.3257271	total: 32.4s	remaining: 15m 38s
# 167:	learn: 0.3250055	total: 32.5s	remaining: 15m 35s
# 168:	learn: 0.3245924	total: 32.7s	remaining: 15m 33s
# 169:	learn: 0.3242451	total: 32.8s	remaining: 15m 31s
# 170:	learn: 0.3237442	total: 32.9s	remaining: 15m 29s
# 171:	learn: 0.3231274	total: 33.1s	remaining: 15m 27s
# 172:	learn: 0.3225267	total: 33.2s	remaining: 15m 27s
# 173:	learn: 0.3216659	total: 33.4s	remaining: 15m 25s
# 174:	learn: 0.3212631	total: 33.5s	remaining: 15m 23s
# 175:	learn: 0.3209428	total: 33.6s	remaining: 15m 21s
# 176:	learn: 0.3204761	total: 33.8s	remaining: 15m 20s
# 177:	learn: 0.3201167	total: 33.9s	remaining: 15m 18s
# 178:	learn: 0.3194114	total: 34s	remaining: 15m 16s
# 179:	learn: 0.3190097	total: 34.2s	remaining: 15m 15s
# 180:	learn: 0.3184615	total: 34.3s	remaining: 15m 13s
# 181:	learn: 0.3179998	total: 34.4s	remaining: 15m 10s
# 182:	learn: 0.3175326	total: 34.6s	remaining: 15m 9s
# 183:	learn: 0.3172425	total: 34.7s	remaining: 15m 8s
# 184:	learn: 0.3169245	total: 34.9s	remaining: 15m 8s
# 185:	learn: 0.3165682	total: 35.1s	remaining: 15m 7s
# 186:	learn: 0.3161842	total: 35.3s	remaining: 15m 7s
# 187:	learn: 0.3159160	total: 35.4s	remaining: 15m 5s
# 188:	learn: 0.3153587	total: 35.5s	remaining: 15m 2s
# 189:	learn: 0.3149971	total: 35.6s	remaining: 15m 1s
# 190:	learn: 0.3146633	total: 35.7s	remaining: 14m 59s
# 191:	learn: 0.3143508	total: 35.9s	remaining: 14m 59s
# 192:	learn: 0.3138586	total: 36.1s	remaining: 14m 58s
# 193:	learn: 0.3135606	total: 36.2s	remaining: 14m 56s
# 194:	learn: 0.3132302	total: 36.3s	remaining: 14m 53s
# 195:	learn: 0.3130141	total: 36.3s	remaining: 14m 50s
# 196:	learn: 0.3127017	total: 36.5s	remaining: 14m 50s
# 197:	learn: 0.3124336	total: 36.7s	remaining: 14m 49s
# 198:	learn: 0.3120009	total: 36.8s	remaining: 14m 48s
# 199:	learn: 0.3114220	total: 36.9s	remaining: 14m 46s
# 200:	learn: 0.3111799	total: 37s	remaining: 14m 44s
# 201:	learn: 0.3108175	total: 37.2s	remaining: 14m 42s
# 202:	learn: 0.3105824	total: 37.3s	remaining: 14m 40s
# 203:	learn: 0.3103339	total: 37.4s	remaining: 14m 38s
# 204:	learn: 0.3098833	total: 37.5s	remaining: 14m 36s
# 205:	learn: 0.3095898	total: 37.6s	remaining: 14m 34s
# 206:	learn: 0.3092714	total: 37.7s	remaining: 14m 33s
# 207:	learn: 0.3089980	total: 37.8s	remaining: 14m 31s
# 208:	learn: 0.3086809	total: 38s	remaining: 14m 30s
# 209:	learn: 0.3082239	total: 38.1s	remaining: 14m 30s
# 210:	learn: 0.3079638	total: 38.2s	remaining: 14m 27s
# 211:	learn: 0.3073212	total: 38.4s	remaining: 14m 26s
# 212:	learn: 0.3069180	total: 38.5s	remaining: 14m 24s
# 213:	learn: 0.3066506	total: 38.7s	remaining: 14m 25s
# 214:	learn: 0.3061809	total: 38.8s	remaining: 14m 23s
# 215:	learn: 0.3058796	total: 39s	remaining: 14m 23s
# 216:	learn: 0.3054071	total: 39.1s	remaining: 14m 22s
# 217:	learn: 0.3049830	total: 39.3s	remaining: 14m 22s
# 218:	learn: 0.3046358	total: 39.5s	remaining: 14m 21s
# 219:	learn: 0.3043005	total: 39.6s	remaining: 14m 20s
# 220:	learn: 0.3039173	total: 39.7s	remaining: 14m 18s
# 221:	learn: 0.3034672	total: 39.8s	remaining: 14m 16s
# 222:	learn: 0.3032640	total: 39.9s	remaining: 14m 15s
# 223:	learn: 0.3029463	total: 40s	remaining: 14m 13s
# 224:	learn: 0.3025559	total: 40.2s	remaining: 14m 12s
# 225:	learn: 0.3021194	total: 40.4s	remaining: 14m 12s
# 226:	learn: 0.3018546	total: 40.5s	remaining: 14m 11s
# 227:	learn: 0.3016207	total: 40.7s	remaining: 14m 10s
# 228:	learn: 0.3012851	total: 40.8s	remaining: 14m 9s
# 229:	learn: 0.3009214	total: 40.9s	remaining: 14m 8s
# 230:	learn: 0.3005699	total: 41.1s	remaining: 14m 7s
# 231:	learn: 0.3001866	total: 41.2s	remaining: 14m 6s
# 232:	learn: 0.2998900	total: 41.3s	remaining: 14m 4s
# 233:	learn: 0.2996703	total: 41.4s	remaining: 14m 3s
# 234:	learn: 0.2992334	total: 41.5s	remaining: 14m 2s
# 235:	learn: 0.2988173	total: 41.7s	remaining: 14m 1s
# 236:	learn: 0.2985897	total: 41.9s	remaining: 14m 1s
# 237:	learn: 0.2983088	total: 42s	remaining: 14m 1s
# 238:	learn: 0.2981586	total: 42.1s	remaining: 13m 59s
# 239:	learn: 0.2978686	total: 42.3s	remaining: 13m 58s
# 240:	learn: 0.2976180	total: 42.4s	remaining: 13m 58s
# 241:	learn: 0.2974415	total: 42.6s	remaining: 13m 56s
# 242:	learn: 0.2972377	total: 42.7s	remaining: 13m 56s
# 243:	learn: 0.2969365	total: 42.9s	remaining: 13m 55s
# 244:	learn: 0.2964498	total: 43s	remaining: 13m 54s
# 245:	learn: 0.2961890	total: 43.1s	remaining: 13m 53s
# 246:	learn: 0.2959231	total: 43.3s	remaining: 13m 53s
# 247:	learn: 0.2956289	total: 43.5s	remaining: 13m 53s
# 248:	learn: 0.2952841	total: 43.7s	remaining: 13m 53s
# 249:	learn: 0.2950841	total: 43.8s	remaining: 13m 52s
# 250:	learn: 0.2948317	total: 44s	remaining: 13m 51s
# 251:	learn: 0.2945415	total: 44.1s	remaining: 13m 51s
# 252:	learn: 0.2941921	total: 44.3s	remaining: 13m 50s
# 253:	learn: 0.2939500	total: 44.4s	remaining: 13m 49s
# 254:	learn: 0.2936033	total: 44.5s	remaining: 13m 48s
# 255:	learn: 0.2933379	total: 44.7s	remaining: 13m 48s
# 256:	learn: 0.2930761	total: 44.9s	remaining: 13m 48s
# 257:	learn: 0.2928827	total: 45s	remaining: 13m 46s
# 258:	learn: 0.2926672	total: 45.1s	remaining: 13m 45s
# 259:	learn: 0.2924130	total: 45.2s	remaining: 13m 44s
# 260:	learn: 0.2920111	total: 45.3s	remaining: 13m 42s
# 261:	learn: 0.2917516	total: 45.5s	remaining: 13m 42s
# 262:	learn: 0.2914956	total: 45.7s	remaining: 13m 42s
# 263:	learn: 0.2913261	total: 45.8s	remaining: 13m 41s
# 264:	learn: 0.2911801	total: 45.9s	remaining: 13m 39s
# 265:	learn: 0.2908963	total: 46s	remaining: 13m 38s
# 266:	learn: 0.2905446	total: 46.1s	remaining: 13m 37s
# 267:	learn: 0.2902991	total: 46.3s	remaining: 13m 37s
# 268:	learn: 0.2900837	total: 46.5s	remaining: 13m 37s
# 269:	learn: 0.2897066	total: 46.6s	remaining: 13m 36s
# 270:	learn: 0.2895159	total: 46.7s	remaining: 13m 35s
# 271:	learn: 0.2891878	total: 46.9s	remaining: 13m 35s
# 272:	learn: 0.2889053	total: 47.1s	remaining: 13m 35s
# 273:	learn: 0.2886047	total: 47.2s	remaining: 13m 34s
# 274:	learn: 0.2883233	total: 47.4s	remaining: 13m 33s
# 275:	learn: 0.2880598	total: 47.5s	remaining: 13m 33s
# 276:	learn: 0.2878319	total: 47.7s	remaining: 13m 32s
# 277:	learn: 0.2876822	total: 47.8s	remaining: 13m 32s
# 278:	learn: 0.2873862	total: 48s	remaining: 13m 31s
# 279:	learn: 0.2871159	total: 48.1s	remaining: 13m 31s
# 280:	learn: 0.2869182	total: 48.2s	remaining: 13m 29s
# 281:	learn: 0.2867685	total: 48.4s	remaining: 13m 29s
# 282:	learn: 0.2864385	total: 48.5s	remaining: 13m 28s
# 283:	learn: 0.2862843	total: 48.7s	remaining: 13m 27s
# 284:	learn: 0.2860830	total: 48.8s	remaining: 13m 27s
# 285:	learn: 0.2859616	total: 48.9s	remaining: 13m 26s
# 286:	learn: 0.2855793	total: 49.1s	remaining: 13m 25s
# 287:	learn: 0.2854090	total: 49.2s	remaining: 13m 25s
# 288:	learn: 0.2852159	total: 49.4s	remaining: 13m 25s
# 289:	learn: 0.2849688	total: 49.5s	remaining: 13m 23s
# 290:	learn: 0.2847568	total: 49.7s	remaining: 13m 23s
# 291:	learn: 0.2845609	total: 49.8s	remaining: 13m 22s
# 292:	learn: 0.2843960	total: 49.9s	remaining: 13m 21s
# 293:	learn: 0.2841112	total: 50s	remaining: 13m 20s
# 294:	learn: 0.2839559	total: 50.2s	remaining: 13m 20s
# 295:	learn: 0.2837509	total: 50.3s	remaining: 13m 18s
# 296:	learn: 0.2835470	total: 50.5s	remaining: 13m 18s
# 297:	learn: 0.2833217	total: 50.6s	remaining: 13m 18s
# 298:	learn: 0.2831636	total: 50.7s	remaining: 13m 17s
# 299:	learn: 0.2829293	total: 50.9s	remaining: 13m 16s
# 300:	learn: 0.2827809	total: 51s	remaining: 13m 16s
# 301:	learn: 0.2825300	total: 51.2s	remaining: 13m 15s
# 302:	learn: 0.2822107	total: 51.3s	remaining: 13m 14s
# 303:	learn: 0.2820243	total: 51.4s	remaining: 13m 13s
# 304:	learn: 0.2818031	total: 51.5s	remaining: 13m 13s
# 305:	learn: 0.2815454	total: 51.6s	remaining: 13m 12s
# 306:	learn: 0.2813771	total: 51.8s	remaining: 13m 12s
# 307:	learn: 0.2811515	total: 52s	remaining: 13m 11s
# 308:	learn: 0.2808877	total: 52.2s	remaining: 13m 12s
# 309:	learn: 0.2807526	total: 52.3s	remaining: 13m 10s
# 310:	learn: 0.2805550	total: 52.8s	remaining: 13m 15s
# 311:	learn: 0.2803510	total: 53.3s	remaining: 13m 21s
# 312:	learn: 0.2801846	total: 54s	remaining: 13m 28s
# 313:	learn: 0.2800017	total: 54.6s	remaining: 13m 34s
# 314:	learn: 0.2797206	total: 54.7s	remaining: 13m 34s
# 315:	learn: 0.2793734	total: 54.9s	remaining: 13m 34s
# 316:	learn: 0.2792318	total: 55.4s	remaining: 13m 37s
# 317:	learn: 0.2789774	total: 55.5s	remaining: 13m 36s
# 318:	learn: 0.2787797	total: 55.8s	remaining: 13m 38s
# 319:	learn: 0.2785418	total: 55.9s	remaining: 13m 37s
# 320:	learn: 0.2783678	total: 56s	remaining: 13m 36s
# 321:	learn: 0.2781443	total: 56.3s	remaining: 13m 37s
# 322:	learn: 0.2779337	total: 56.4s	remaining: 13m 36s
# 323:	learn: 0.2777015	total: 56.5s	remaining: 13m 35s
# 324:	learn: 0.2774900	total: 56.7s	remaining: 13m 35s
# 325:	learn: 0.2773148	total: 56.9s	remaining: 13m 35s
# 326:	learn: 0.2770048	total: 57s	remaining: 13m 34s
# 327:	learn: 0.2767252	total: 57.1s	remaining: 13m 33s
# 328:	learn: 0.2765732	total: 57.3s	remaining: 13m 33s
# 329:	learn: 0.2763939	total: 57.4s	remaining: 13m 32s
# 330:	learn: 0.2761161	total: 57.5s	remaining: 13m 31s
# 331:	learn: 0.2759526	total: 57.7s	remaining: 13m 30s
# 332:	learn: 0.2757487	total: 57.8s	remaining: 13m 30s
# 333:	learn: 0.2754608	total: 58s	remaining: 13m 30s
# 334:	learn: 0.2753091	total: 58.1s	remaining: 13m 29s
# 335:	learn: 0.2751674	total: 58.3s	remaining: 13m 28s
# 336:	learn: 0.2750265	total: 58.4s	remaining: 13m 28s
# 337:	learn: 0.2748378	total: 58.5s	remaining: 13m 27s
# 338:	learn: 0.2746581	total: 58.7s	remaining: 13m 26s
# 339:	learn: 0.2744758	total: 58.8s	remaining: 13m 25s
# 340:	learn: 0.2742677	total: 58.9s	remaining: 13m 24s
# 341:	learn: 0.2740966	total: 59s	remaining: 13m 23s
# 342:	learn: 0.2739687	total: 59.2s	remaining: 13m 23s
# 343:	learn: 0.2738042	total: 59.3s	remaining: 13m 22s
# 344:	learn: 0.2734480	total: 59.4s	remaining: 13m 21s
# 345:	learn: 0.2732437	total: 59.6s	remaining: 13m 21s
# 346:	learn: 0.2729862	total: 59.7s	remaining: 13m 19s
# 347:	learn: 0.2728846	total: 59.8s	remaining: 13m 19s
# 348:	learn: 0.2726574	total: 60s	remaining: 13m 19s
# 349:	learn: 0.2725099	total: 1m	remaining: 13m 19s
# 350:	learn: 0.2723124	total: 1m	remaining: 13m 21s
# 351:	learn: 0.2721682	total: 1m	remaining: 13m 20s
# 352:	learn: 0.2719947	total: 1m	remaining: 13m 20s
# 353:	learn: 0.2718752	total: 1m	remaining: 13m 19s
# 354:	learn: 0.2717617	total: 1m 1s	remaining: 13m 19s
# 355:	learn: 0.2716211	total: 1m 1s	remaining: 13m 18s
# 356:	learn: 0.2714576	total: 1m 1s	remaining: 13m 18s
# 357:	learn: 0.2713024	total: 1m 1s	remaining: 13m 17s
# 358:	learn: 0.2711760	total: 1m 1s	remaining: 13m 17s
# 359:	learn: 0.2710024	total: 1m 1s	remaining: 13m 16s
# 360:	learn: 0.2708231	total: 1m 1s	remaining: 13m 15s
# 361:	learn: 0.2706574	total: 1m 2s	remaining: 13m 15s
# 362:	learn: 0.2705502	total: 1m 2s	remaining: 13m 15s
# 363:	learn: 0.2701828	total: 1m 2s	remaining: 13m 14s
# 364:	learn: 0.2700471	total: 1m 2s	remaining: 13m 14s
# 365:	learn: 0.2699204	total: 1m 2s	remaining: 13m 13s
# 366:	learn: 0.2697555	total: 1m 2s	remaining: 13m 12s
# 367:	learn: 0.2695370	total: 1m 2s	remaining: 13m 12s
# 368:	learn: 0.2693295	total: 1m 3s	remaining: 13m 11s
# 369:	learn: 0.2691528	total: 1m 3s	remaining: 13m 10s
# 370:	learn: 0.2689036	total: 1m 3s	remaining: 13m 9s
# 371:	learn: 0.2687808	total: 1m 3s	remaining: 13m 9s
# 372:	learn: 0.2685867	total: 1m 3s	remaining: 13m 8s
# 373:	learn: 0.2684291	total: 1m 3s	remaining: 13m 8s
# 374:	learn: 0.2682501	total: 1m 3s	remaining: 13m 7s
# 375:	learn: 0.2680310	total: 1m 3s	remaining: 13m 6s
# 376:	learn: 0.2678566	total: 1m 4s	remaining: 13m 6s
# 377:	learn: 0.2676959	total: 1m 4s	remaining: 13m 6s
# 378:	learn: 0.2675818	total: 1m 4s	remaining: 13m 5s
# 379:	learn: 0.2673938	total: 1m 4s	remaining: 13m 4s
# 380:	learn: 0.2670752	total: 1m 4s	remaining: 13m 4s
# 381:	learn: 0.2669347	total: 1m 4s	remaining: 13m 3s
# 382:	learn: 0.2667907	total: 1m 4s	remaining: 13m 3s
# 383:	learn: 0.2666600	total: 1m 5s	remaining: 13m 2s
# 384:	learn: 0.2664622	total: 1m 5s	remaining: 13m 1s
# 385:	learn: 0.2662451	total: 1m 5s	remaining: 13m 1s
# 386:	learn: 0.2660826	total: 1m 5s	remaining: 13m
# 387:	learn: 0.2658957	total: 1m 5s	remaining: 13m
# 388:	learn: 0.2656826	total: 1m 5s	remaining: 12m 59s
# 389:	learn: 0.2655436	total: 1m 5s	remaining: 12m 58s
# 390:	learn: 0.2652998	total: 1m 5s	remaining: 12m 57s
# 391:	learn: 0.2650953	total: 1m 6s	remaining: 12m 57s
# 392:	learn: 0.2649315	total: 1m 6s	remaining: 12m 55s
# 393:	learn: 0.2648211	total: 1m 6s	remaining: 12m 55s
# 394:	learn: 0.2647277	total: 1m 6s	remaining: 12m 54s
# 395:	learn: 0.2645284	total: 1m 6s	remaining: 12m 56s
# 396:	learn: 0.2644252	total: 1m 6s	remaining: 12m 55s
# 397:	learn: 0.2642724	total: 1m 7s	remaining: 12m 54s
# 398:	learn: 0.2641032	total: 1m 7s	remaining: 12m 54s
# 399:	learn: 0.2639758	total: 1m 7s	remaining: 12m 55s
# 400:	learn: 0.2637668	total: 1m 7s	remaining: 12m 54s
# 401:	learn: 0.2636380	total: 1m 7s	remaining: 12m 54s
# 402:	learn: 0.2635325	total: 1m 7s	remaining: 12m 53s
# 403:	learn: 0.2633040	total: 1m 7s	remaining: 12m 53s
# 404:	learn: 0.2631799	total: 1m 8s	remaining: 12m 52s
# 405:	learn: 0.2630534	total: 1m 8s	remaining: 12m 51s
# 406:	learn: 0.2627893	total: 1m 8s	remaining: 12m 51s
# 407:	learn: 0.2626177	total: 1m 8s	remaining: 12m 51s
# 408:	learn: 0.2624793	total: 1m 8s	remaining: 12m 50s
# 409:	learn: 0.2623654	total: 1m 8s	remaining: 12m 49s
# 410:	learn: 0.2622017	total: 1m 8s	remaining: 12m 48s
# 411:	learn: 0.2620269	total: 1m 9s	remaining: 12m 48s
# 412:	learn: 0.2618774	total: 1m 9s	remaining: 12m 47s
# 413:	learn: 0.2617726	total: 1m 9s	remaining: 12m 46s
# 414:	learn: 0.2615265	total: 1m 9s	remaining: 12m 45s
# 415:	learn: 0.2614217	total: 1m 9s	remaining: 12m 45s
# 416:	learn: 0.2612990	total: 1m 9s	remaining: 12m 44s
# 417:	learn: 0.2610902	total: 1m 9s	remaining: 12m 43s
# 418:	learn: 0.2609316	total: 1m 9s	remaining: 12m 43s
# 419:	learn: 0.2606525	total: 1m 9s	remaining: 12m 42s
# 420:	learn: 0.2604379	total: 1m 10s	remaining: 12m 41s
# 421:	learn: 0.2602646	total: 1m 10s	remaining: 12m 41s
# 422:	learn: 0.2601913	total: 1m 10s	remaining: 12m 40s
# 423:	learn: 0.2600678	total: 1m 10s	remaining: 12m 40s
# 424:	learn: 0.2599603	total: 1m 10s	remaining: 12m 39s
# 425:	learn: 0.2598607	total: 1m 10s	remaining: 12m 39s
# 426:	learn: 0.2597516	total: 1m 10s	remaining: 12m 38s
# 427:	learn: 0.2596257	total: 1m 10s	remaining: 12m 38s
# 428:	learn: 0.2595032	total: 1m 11s	remaining: 12m 38s
# 429:	learn: 0.2592576	total: 1m 11s	remaining: 12m 37s
# 430:	learn: 0.2591285	total: 1m 11s	remaining: 12m 37s
# 431:	learn: 0.2589478	total: 1m 11s	remaining: 12m 37s
# 432:	learn: 0.2588383	total: 1m 11s	remaining: 12m 36s
# 433:	learn: 0.2586355	total: 1m 11s	remaining: 12m 35s
# 434:	learn: 0.2584689	total: 1m 11s	remaining: 12m 35s
# 435:	learn: 0.2582745	total: 1m 12s	remaining: 12m 34s
# 436:	learn: 0.2581930	total: 1m 12s	remaining: 12m 34s
# 437:	learn: 0.2580768	total: 1m 12s	remaining: 12m 33s
# 438:	learn: 0.2578784	total: 1m 12s	remaining: 12m 33s
# 439:	learn: 0.2577734	total: 1m 12s	remaining: 12m 32s
# 440:	learn: 0.2576801	total: 1m 12s	remaining: 12m 31s
# 441:	learn: 0.2575690	total: 1m 12s	remaining: 12m 31s
# 442:	learn: 0.2573928	total: 1m 13s	remaining: 12m 30s
# 443:	learn: 0.2572836	total: 1m 13s	remaining: 12m 29s
# 444:	learn: 0.2571637	total: 1m 13s	remaining: 12m 29s
# 445:	learn: 0.2570065	total: 1m 13s	remaining: 12m 29s
# 446:	learn: 0.2569140	total: 1m 13s	remaining: 12m 28s
# 447:	learn: 0.2568164	total: 1m 13s	remaining: 12m 27s
# 448:	learn: 0.2567028	total: 1m 13s	remaining: 12m 27s
# 449:	learn: 0.2564096	total: 1m 13s	remaining: 12m 26s
# 450:	learn: 0.2562718	total: 1m 14s	remaining: 12m 26s
# 451:	learn: 0.2561523	total: 1m 14s	remaining: 12m 26s
# 452:	learn: 0.2559790	total: 1m 14s	remaining: 12m 25s
# 453:	learn: 0.2558735	total: 1m 14s	remaining: 12m 25s
# 454:	learn: 0.2557182	total: 1m 14s	remaining: 12m 24s
# 455:	learn: 0.2556119	total: 1m 14s	remaining: 12m 24s
# 456:	learn: 0.2555147	total: 1m 14s	remaining: 12m 24s
# 457:	learn: 0.2553919	total: 1m 15s	remaining: 12m 24s
# 458:	learn: 0.2552887	total: 1m 15s	remaining: 12m 23s
# 459:	learn: 0.2551678	total: 1m 15s	remaining: 12m 23s
# 460:	learn: 0.2550782	total: 1m 15s	remaining: 12m 23s
# 461:	learn: 0.2549262	total: 1m 15s	remaining: 12m 23s
# 462:	learn: 0.2548102	total: 1m 15s	remaining: 12m 22s
# 463:	learn: 0.2545548	total: 1m 15s	remaining: 12m 22s
# 464:	learn: 0.2544289	total: 1m 16s	remaining: 12m 22s
# 465:	learn: 0.2543542	total: 1m 16s	remaining: 12m 21s
# 466:	learn: 0.2542279	total: 1m 16s	remaining: 12m 20s
# 467:	learn: 0.2540600	total: 1m 16s	remaining: 12m 20s
# 468:	learn: 0.2539728	total: 1m 16s	remaining: 12m 19s
# 469:	learn: 0.2537913	total: 1m 16s	remaining: 12m 19s
# 470:	learn: 0.2536261	total: 1m 16s	remaining: 12m 18s
# 471:	learn: 0.2535022	total: 1m 17s	remaining: 12m 18s
# 472:	learn: 0.2534105	total: 1m 17s	remaining: 12m 18s
# 473:	learn: 0.2532808	total: 1m 17s	remaining: 12m 17s
# 474:	learn: 0.2532078	total: 1m 17s	remaining: 12m 17s
# 475:	learn: 0.2531112	total: 1m 17s	remaining: 12m 17s
# 476:	learn: 0.2530004	total: 1m 17s	remaining: 12m 16s
# 477:	learn: 0.2528944	total: 1m 17s	remaining: 12m 16s
# 478:	learn: 0.2527822	total: 1m 17s	remaining: 12m 15s
# 479:	learn: 0.2526940	total: 1m 18s	remaining: 12m 15s
# 480:	learn: 0.2525368	total: 1m 18s	remaining: 12m 15s
# 481:	learn: 0.2524248	total: 1m 18s	remaining: 12m 14s
# 482:	learn: 0.2523081	total: 1m 18s	remaining: 12m 14s
# 483:	learn: 0.2520940	total: 1m 18s	remaining: 12m 14s
# 484:	learn: 0.2519810	total: 1m 18s	remaining: 12m 13s
# 485:	learn: 0.2519084	total: 1m 18s	remaining: 12m 13s
# 486:	learn: 0.2517242	total: 1m 19s	remaining: 12m 12s
# 487:	learn: 0.2515945	total: 1m 19s	remaining: 12m 12s
# 488:	learn: 0.2515037	total: 1m 19s	remaining: 12m 11s
# 489:	learn: 0.2514004	total: 1m 19s	remaining: 12m 11s
# 490:	learn: 0.2512970	total: 1m 19s	remaining: 12m 10s
# 491:	learn: 0.2512086	total: 1m 19s	remaining: 12m 10s
# 492:	learn: 0.2511179	total: 1m 19s	remaining: 12m 9s
# 493:	learn: 0.2509123	total: 1m 19s	remaining: 12m 9s
# 494:	learn: 0.2508146	total: 1m 20s	remaining: 12m 8s
# 495:	learn: 0.2507525	total: 1m 20s	remaining: 12m 8s
# 496:	learn: 0.2505557	total: 1m 20s	remaining: 12m 7s
# 497:	learn: 0.2504586	total: 1m 20s	remaining: 12m 7s
# 498:	learn: 0.2503453	total: 1m 20s	remaining: 12m 7s
# 499:	learn: 0.2502483	total: 1m 20s	remaining: 12m 6s
# 500:	learn: 0.2501393	total: 1m 20s	remaining: 12m 6s
# 501:	learn: 0.2500150	total: 1m 20s	remaining: 12m 5s
# 502:	learn: 0.2498780	total: 1m 21s	remaining: 12m 5s
# 503:	learn: 0.2497946	total: 1m 21s	remaining: 12m 4s
# 504:	learn: 0.2496182	total: 1m 21s	remaining: 12m 4s
# 505:	learn: 0.2495404	total: 1m 21s	remaining: 12m 4s
# 506:	learn: 0.2494162	total: 1m 21s	remaining: 12m 3s
# 507:	learn: 0.2492838	total: 1m 21s	remaining: 12m 3s
# 508:	learn: 0.2491679	total: 1m 21s	remaining: 12m 3s
# 509:	learn: 0.2490128	total: 1m 22s	remaining: 12m 3s
# 510:	learn: 0.2489345	total: 1m 22s	remaining: 12m 2s
# 511:	learn: 0.2487696	total: 1m 22s	remaining: 12m 2s
# 512:	learn: 0.2486697	total: 1m 22s	remaining: 12m 1s
# 513:	learn: 0.2485389	total: 1m 22s	remaining: 12m 1s
# 514:	learn: 0.2484594	total: 1m 22s	remaining: 12m 1s
# 515:	learn: 0.2483847	total: 1m 22s	remaining: 12m
# 516:	learn: 0.2482608	total: 1m 23s	remaining: 12m
# 517:	learn: 0.2481501	total: 1m 23s	remaining: 11m 59s
# 518:	learn: 0.2480285	total: 1m 23s	remaining: 11m 59s
# 519:	learn: 0.2479406	total: 1m 23s	remaining: 11m 58s
# 520:	learn: 0.2478540	total: 1m 23s	remaining: 11m 58s
# 521:	learn: 0.2477008	total: 1m 23s	remaining: 11m 58s
# 522:	learn: 0.2475843	total: 1m 23s	remaining: 11m 57s
# 523:	learn: 0.2474795	total: 1m 23s	remaining: 11m 57s
# 524:	learn: 0.2473566	total: 1m 24s	remaining: 11m 57s
# 525:	learn: 0.2472600	total: 1m 24s	remaining: 11m 56s
# 526:	learn: 0.2470911	total: 1m 24s	remaining: 11m 55s
# 527:	learn: 0.2469304	total: 1m 24s	remaining: 11m 55s
# 528:	learn: 0.2468533	total: 1m 24s	remaining: 11m 54s
# 529:	learn: 0.2467955	total: 1m 24s	remaining: 11m 54s
# 530:	learn: 0.2466742	total: 1m 24s	remaining: 11m 53s
# 531:	learn: 0.2465942	total: 1m 24s	remaining: 11m 53s
# 532:	learn: 0.2464987	total: 1m 25s	remaining: 11m 53s
# 533:	learn: 0.2463931	total: 1m 25s	remaining: 11m 52s
# 534:	learn: 0.2462742	total: 1m 25s	remaining: 11m 52s
# 535:	learn: 0.2462048	total: 1m 25s	remaining: 11m 51s
# 536:	learn: 0.2460890	total: 1m 25s	remaining: 11m 51s
# 537:	learn: 0.2460241	total: 1m 25s	remaining: 11m 51s
# 538:	learn: 0.2458955	total: 1m 25s	remaining: 11m 51s
# 539:	learn: 0.2458047	total: 1m 26s	remaining: 11m 50s
# 540:	learn: 0.2456850	total: 1m 26s	remaining: 11m 50s
# 541:	learn: 0.2456157	total: 1m 26s	remaining: 11m 50s
# 542:	learn: 0.2454199	total: 1m 26s	remaining: 11m 49s
# 543:	learn: 0.2453107	total: 1m 26s	remaining: 11m 49s
# 544:	learn: 0.2451844	total: 1m 26s	remaining: 11m 48s
# 545:	learn: 0.2450793	total: 1m 26s	remaining: 11m 48s
# 546:	learn: 0.2450008	total: 1m 26s	remaining: 11m 47s
# 547:	learn: 0.2449074	total: 1m 27s	remaining: 11m 47s
# 548:	learn: 0.2448216	total: 1m 27s	remaining: 11m 47s
# 549:	learn: 0.2446889	total: 1m 27s	remaining: 11m 47s
# 550:	learn: 0.2445698	total: 1m 27s	remaining: 11m 46s
# 551:	learn: 0.2445033	total: 1m 27s	remaining: 11m 46s
# 552:	learn: 0.2444254	total: 1m 27s	remaining: 11m 46s
# 553:	learn: 0.2443444	total: 1m 27s	remaining: 11m 45s
# 554:	learn: 0.2442080	total: 1m 28s	remaining: 11m 45s
# 555:	learn: 0.2441309	total: 1m 28s	remaining: 11m 45s
# 556:	learn: 0.2440311	total: 1m 28s	remaining: 11m 44s
# 557:	learn: 0.2439073	total: 1m 28s	remaining: 11m 44s
# 558:	learn: 0.2438261	total: 1m 28s	remaining: 11m 44s
# 559:	learn: 0.2437089	total: 1m 28s	remaining: 11m 43s
# 560:	learn: 0.2435808	total: 1m 28s	remaining: 11m 43s
# 561:	learn: 0.2434725	total: 1m 29s	remaining: 11m 44s
# 562:	learn: 0.2433641	total: 1m 29s	remaining: 11m 44s
# 563:	learn: 0.2432678	total: 1m 29s	remaining: 11m 44s
# 564:	learn: 0.2431981	total: 1m 29s	remaining: 11m 43s
# 565:	learn: 0.2431314	total: 1m 29s	remaining: 11m 43s
# 566:	learn: 0.2429761	total: 1m 29s	remaining: 11m 42s
# 567:	learn: 0.2428958	total: 1m 30s	remaining: 11m 42s
# 568:	learn: 0.2428150	total: 1m 30s	remaining: 11m 41s
# 569:	learn: 0.2426603	total: 1m 30s	remaining: 11m 41s
# 570:	learn: 0.2425450	total: 1m 30s	remaining: 11m 41s
# 571:	learn: 0.2424416	total: 1m 30s	remaining: 11m 41s
# 572:	learn: 0.2423627	total: 1m 30s	remaining: 11m 40s
# 573:	learn: 0.2422560	total: 1m 30s	remaining: 11m 40s
# 574:	learn: 0.2421601	total: 1m 31s	remaining: 11m 40s
# 575:	learn: 0.2420968	total: 1m 31s	remaining: 11m 39s
# 576:	learn: 0.2420314	total: 1m 31s	remaining: 11m 39s
# 577:	learn: 0.2419793	total: 1m 31s	remaining: 11m 38s
# 578:	learn: 0.2419027	total: 1m 31s	remaining: 11m 38s
# 579:	learn: 0.2418001	total: 1m 31s	remaining: 11m 38s
# 580:	learn: 0.2417188	total: 1m 31s	remaining: 11m 37s
# 581:	learn: 0.2416300	total: 1m 31s	remaining: 11m 36s
# 582:	learn: 0.2415426	total: 1m 31s	remaining: 11m 37s
# 583:	learn: 0.2414007	total: 1m 32s	remaining: 11m 36s
# 584:	learn: 0.2412885	total: 1m 32s	remaining: 11m 36s
# 585:	learn: 0.2412021	total: 1m 32s	remaining: 11m 36s
# 586:	learn: 0.2411177	total: 1m 32s	remaining: 11m 36s
# 587:	learn: 0.2410421	total: 1m 32s	remaining: 11m 35s
# 588:	learn: 0.2409336	total: 1m 32s	remaining: 11m 35s
# 589:	learn: 0.2408644	total: 1m 32s	remaining: 11m 35s
# 590:	learn: 0.2407551	total: 1m 33s	remaining: 11m 34s
# 591:	learn: 0.2406775	total: 1m 33s	remaining: 11m 34s
# 592:	learn: 0.2405864	total: 1m 33s	remaining: 11m 34s
# 593:	learn: 0.2405168	total: 1m 33s	remaining: 11m 34s
# 594:	learn: 0.2404257	total: 1m 33s	remaining: 11m 34s
# 595:	learn: 0.2403500	total: 1m 33s	remaining: 11m 33s
# 596:	learn: 0.2402664	total: 1m 34s	remaining: 11m 33s
# 597:	learn: 0.2402081	total: 1m 34s	remaining: 11m 33s
# 598:	learn: 0.2400551	total: 1m 34s	remaining: 11m 32s
# 599:	learn: 0.2399835	total: 1m 34s	remaining: 11m 32s
# 600:	learn: 0.2399212	total: 1m 34s	remaining: 11m 32s
# 601:	learn: 0.2398145	total: 1m 34s	remaining: 11m 31s
# 602:	learn: 0.2397443	total: 1m 34s	remaining: 11m 31s
# 603:	learn: 0.2396679	total: 1m 34s	remaining: 11m 31s
# 604:	learn: 0.2395900	total: 1m 35s	remaining: 11m 31s
# 605:	learn: 0.2394700	total: 1m 35s	remaining: 11m 31s
# 606:	learn: 0.2393781	total: 1m 35s	remaining: 11m 30s
# 607:	learn: 0.2393083	total: 1m 35s	remaining: 11m 30s
# 608:	learn: 0.2392037	total: 1m 35s	remaining: 11m 30s
# 609:	learn: 0.2390630	total: 1m 35s	remaining: 11m 30s
# 610:	learn: 0.2389448	total: 1m 36s	remaining: 11m 30s
# 611:	learn: 0.2388355	total: 1m 36s	remaining: 11m 29s
# 612:	learn: 0.2387050	total: 1m 36s	remaining: 11m 29s
# 613:	learn: 0.2386363	total: 1m 36s	remaining: 11m 29s
# 614:	learn: 0.2385611	total: 1m 36s	remaining: 11m 28s
# 615:	learn: 0.2384872	total: 1m 36s	remaining: 11m 28s
# 616:	learn: 0.2384128	total: 1m 36s	remaining: 11m 27s
# 617:	learn: 0.2383484	total: 1m 36s	remaining: 11m 27s
# 618:	learn: 0.2382758	total: 1m 37s	remaining: 11m 27s
# 619:	learn: 0.2382065	total: 1m 37s	remaining: 11m 26s
# 620:	learn: 0.2381051	total: 1m 37s	remaining: 11m 26s
# 621:	learn: 0.2379395	total: 1m 37s	remaining: 11m 25s
# 622:	learn: 0.2378799	total: 1m 37s	remaining: 11m 25s
# 623:	learn: 0.2378074	total: 1m 37s	remaining: 11m 25s
# 624:	learn: 0.2377271	total: 1m 37s	remaining: 11m 24s
# 625:	learn: 0.2376449	total: 1m 37s	remaining: 11m 24s
# 626:	learn: 0.2375781	total: 1m 38s	remaining: 11m 24s
# 627:	learn: 0.2374684	total: 1m 38s	remaining: 11m 24s
# 628:	learn: 0.2373986	total: 1m 38s	remaining: 11m 23s
# 629:	learn: 0.2373119	total: 1m 38s	remaining: 11m 23s
# 630:	learn: 0.2372342	total: 1m 38s	remaining: 11m 22s
# 631:	learn: 0.2371773	total: 1m 38s	remaining: 11m 22s
# 632:	learn: 0.2370890	total: 1m 38s	remaining: 11m 22s
# 633:	learn: 0.2370206	total: 1m 38s	remaining: 11m 21s
# 634:	learn: 0.2369289	total: 1m 39s	remaining: 11m 21s
# 635:	learn: 0.2368630	total: 1m 39s	remaining: 11m 20s
# 636:	learn: 0.2367838	total: 1m 39s	remaining: 11m 20s
# 637:	learn: 0.2366879	total: 1m 39s	remaining: 11m 19s
# 638:	learn: 0.2365983	total: 1m 39s	remaining: 11m 19s
# 639:	learn: 0.2365196	total: 1m 39s	remaining: 11m 19s
# 640:	learn: 0.2364530	total: 1m 39s	remaining: 11m 19s
# 641:	learn: 0.2363776	total: 1m 40s	remaining: 11m 19s
# 642:	learn: 0.2362895	total: 1m 40s	remaining: 11m 18s
# 643:	learn: 0.2362161	total: 1m 40s	remaining: 11m 18s
# 644:	learn: 0.2360169	total: 1m 40s	remaining: 11m 18s
# 645:	learn: 0.2359223	total: 1m 40s	remaining: 11m 18s
# 646:	learn: 0.2358602	total: 1m 40s	remaining: 11m 18s
# 647:	learn: 0.2357707	total: 1m 41s	remaining: 11m 19s
# 648:	learn: 0.2357075	total: 1m 41s	remaining: 11m 19s
# 649:	learn: 0.2356353	total: 1m 41s	remaining: 11m 18s
# 650:	learn: 0.2355742	total: 1m 41s	remaining: 11m 18s
# 651:	learn: 0.2354762	total: 1m 42s	remaining: 11m 20s
# 652:	learn: 0.2354267	total: 1m 42s	remaining: 11m 20s
# 653:	learn: 0.2353590	total: 1m 42s	remaining: 11m 22s
# 654:	learn: 0.2352553	total: 1m 42s	remaining: 11m 22s
# 655:	learn: 0.2351795	total: 1m 43s	remaining: 11m 22s
# 656:	learn: 0.2350395	total: 1m 43s	remaining: 11m 25s
# 657:	learn: 0.2349809	total: 1m 44s	remaining: 11m 28s
# 658:	learn: 0.2348619	total: 1m 44s	remaining: 11m 28s
# 659:	learn: 0.2347924	total: 1m 45s	remaining: 11m 30s
# 660:	learn: 0.2346958	total: 1m 45s	remaining: 11m 31s
# 661:	learn: 0.2345676	total: 1m 45s	remaining: 11m 31s
# 662:	learn: 0.2345176	total: 1m 45s	remaining: 11m 31s
# 663:	learn: 0.2344409	total: 1m 45s	remaining: 11m 31s
# 664:	learn: 0.2343605	total: 1m 46s	remaining: 11m 31s
# 665:	learn: 0.2342631	total: 1m 46s	remaining: 11m 31s
# 666:	learn: 0.2341327	total: 1m 46s	remaining: 11m 33s
# 667:	learn: 0.2340642	total: 1m 47s	remaining: 11m 34s
# 668:	learn: 0.2339978	total: 1m 47s	remaining: 11m 34s
# 669:	learn: 0.2339107	total: 1m 47s	remaining: 11m 34s
# 670:	learn: 0.2337565	total: 1m 47s	remaining: 11m 35s
# 671:	learn: 0.2337077	total: 1m 48s	remaining: 11m 37s
# 672:	learn: 0.2336029	total: 1m 48s	remaining: 11m 39s
# 673:	learn: 0.2335095	total: 1m 48s	remaining: 11m 39s
# 674:	learn: 0.2333988	total: 1m 49s	remaining: 11m 38s
# 675:	learn: 0.2333438	total: 1m 49s	remaining: 11m 38s
# 676:	learn: 0.2332654	total: 1m 49s	remaining: 11m 38s
# 677:	learn: 0.2332305	total: 1m 49s	remaining: 11m 37s
# 678:	learn: 0.2331626	total: 1m 49s	remaining: 11m 37s
# 679:	learn: 0.2331125	total: 1m 49s	remaining: 11m 37s
# 680:	learn: 0.2330154	total: 1m 49s	remaining: 11m 36s
# 681:	learn: 0.2329275	total: 1m 50s	remaining: 11m 36s
# 682:	learn: 0.2328370	total: 1m 50s	remaining: 11m 36s
# 683:	learn: 0.2327451	total: 1m 50s	remaining: 11m 36s
# 684:	learn: 0.2326896	total: 1m 50s	remaining: 11m 36s
# 685:	learn: 0.2326006	total: 1m 50s	remaining: 11m 35s
# 686:	learn: 0.2325126	total: 1m 50s	remaining: 11m 35s
# 687:	learn: 0.2323973	total: 1m 50s	remaining: 11m 34s
# 688:	learn: 0.2323248	total: 1m 50s	remaining: 11m 34s
# 689:	learn: 0.2321404	total: 1m 51s	remaining: 11m 34s
# 690:	learn: 0.2320324	total: 1m 51s	remaining: 11m 33s
# 691:	learn: 0.2319650	total: 1m 51s	remaining: 11m 34s
# 692:	learn: 0.2319007	total: 1m 51s	remaining: 11m 34s
# 693:	learn: 0.2318139	total: 1m 52s	remaining: 11m 35s
# 694:	learn: 0.2317676	total: 1m 52s	remaining: 11m 34s
# 695:	learn: 0.2316723	total: 1m 52s	remaining: 11m 34s
# 696:	learn: 0.2315797	total: 1m 52s	remaining: 11m 34s
# 697:	learn: 0.2315270	total: 1m 52s	remaining: 11m 33s
# 698:	learn: 0.2314455	total: 1m 52s	remaining: 11m 33s
# 699:	learn: 0.2313458	total: 1m 52s	remaining: 11m 32s
# 700:	learn: 0.2312803	total: 1m 52s	remaining: 11m 32s
# 701:	learn: 0.2312003	total: 1m 53s	remaining: 11m 32s
# 702:	learn: 0.2310708	total: 1m 53s	remaining: 11m 31s
# 703:	learn: 0.2310153	total: 1m 53s	remaining: 11m 31s
# 704:	learn: 0.2309231	total: 1m 53s	remaining: 11m 31s
# 705:	learn: 0.2308424	total: 1m 53s	remaining: 11m 31s
# 706:	learn: 0.2307586	total: 1m 53s	remaining: 11m 31s
# 707:	learn: 0.2306766	total: 1m 53s	remaining: 11m 30s
# 708:	learn: 0.2306265	total: 1m 54s	remaining: 11m 30s
# 709:	learn: 0.2305436	total: 1m 54s	remaining: 11m 30s
# 710:	learn: 0.2304415	total: 1m 54s	remaining: 11m 30s
# 711:	learn: 0.2303536	total: 1m 54s	remaining: 11m 30s
# 712:	learn: 0.2302923	total: 1m 54s	remaining: 11m 30s
# 713:	learn: 0.2302092	total: 1m 54s	remaining: 11m 30s
# 714:	learn: 0.2301367	total: 1m 55s	remaining: 11m 30s
# 715:	learn: 0.2300494	total: 1m 55s	remaining: 11m 30s
# 716:	learn: 0.2299945	total: 1m 55s	remaining: 11m 29s
# 717:	learn: 0.2299431	total: 1m 55s	remaining: 11m 29s
# 718:	learn: 0.2298331	total: 1m 55s	remaining: 11m 28s
# 719:	learn: 0.2297885	total: 1m 55s	remaining: 11m 28s
# 720:	learn: 0.2297503	total: 1m 55s	remaining: 11m 27s
# 721:	learn: 0.2296978	total: 1m 56s	remaining: 11m 27s
# 722:	learn: 0.2296384	total: 1m 56s	remaining: 11m 27s
# 723:	learn: 0.2295298	total: 1m 56s	remaining: 11m 26s
# 724:	learn: 0.2294312	total: 1m 56s	remaining: 11m 26s
# 725:	learn: 0.2293610	total: 1m 56s	remaining: 11m 26s
# 726:	learn: 0.2292612	total: 1m 56s	remaining: 11m 25s
# 727:	learn: 0.2291751	total: 1m 56s	remaining: 11m 25s
# 728:	learn: 0.2291130	total: 1m 56s	remaining: 11m 25s
# 729:	learn: 0.2290209	total: 1m 57s	remaining: 11m 24s
# 730:	learn: 0.2289573	total: 1m 57s	remaining: 11m 24s
# 731:	learn: 0.2288596	total: 1m 57s	remaining: 11m 25s
# 732:	learn: 0.2286734	total: 1m 57s	remaining: 11m 25s
# 733:	learn: 0.2285832	total: 1m 57s	remaining: 11m 25s
# 734:	learn: 0.2285116	total: 1m 58s	remaining: 11m 25s
# 735:	learn: 0.2283897	total: 1m 58s	remaining: 11m 25s
# 736:	learn: 0.2283058	total: 1m 58s	remaining: 11m 24s
# 737:	learn: 0.2282389	total: 1m 58s	remaining: 11m 24s
# 738:	learn: 0.2281707	total: 1m 58s	remaining: 11m 24s
# 739:	learn: 0.2280881	total: 1m 58s	remaining: 11m 23s
# 740:	learn: 0.2280370	total: 1m 58s	remaining: 11m 23s
# 741:	learn: 0.2279806	total: 1m 59s	remaining: 11m 23s
# 742:	learn: 0.2278744	total: 1m 59s	remaining: 11m 22s
# 743:	learn: 0.2278191	total: 1m 59s	remaining: 11m 22s
# 744:	learn: 0.2277441	total: 1m 59s	remaining: 11m 21s
# 745:	learn: 0.2276857	total: 1m 59s	remaining: 11m 21s
# 746:	learn: 0.2276330	total: 1m 59s	remaining: 11m 21s
# 747:	learn: 0.2275644	total: 1m 59s	remaining: 11m 21s
# 748:	learn: 0.2275069	total: 1m 59s	remaining: 11m 20s
# 749:	learn: 0.2274501	total: 1m 59s	remaining: 11m 19s
# 750:	learn: 0.2273777	total: 2m	remaining: 11m 19s
# 751:	learn: 0.2272989	total: 2m	remaining: 11m 19s
# 752:	learn: 0.2272312	total: 2m	remaining: 11m 18s
# 753:	learn: 0.2271528	total: 2m	remaining: 11m 18s
# 754:	learn: 0.2270953	total: 2m	remaining: 11m 18s
# 755:	learn: 0.2270451	total: 2m	remaining: 11m 17s
# 756:	learn: 0.2269922	total: 2m	remaining: 11m 17s
# 757:	learn: 0.2269379	total: 2m	remaining: 11m 17s
# 758:	learn: 0.2268631	total: 2m 1s	remaining: 11m 16s
# 759:	learn: 0.2267772	total: 2m 1s	remaining: 11m 16s
# 760:	learn: 0.2266338	total: 2m 1s	remaining: 11m 16s
# 761:	learn: 0.2265244	total: 2m 1s	remaining: 11m 16s
# 762:	learn: 0.2264461	total: 2m 1s	remaining: 11m 16s
# 763:	learn: 0.2263817	total: 2m 1s	remaining: 11m 16s
# 764:	learn: 0.2263162	total: 2m 2s	remaining: 11m 15s
# 765:	learn: 0.2262679	total: 2m 2s	remaining: 11m 15s
# 766:	learn: 0.2261939	total: 2m 2s	remaining: 11m 15s
# 767:	learn: 0.2261187	total: 2m 2s	remaining: 11m 15s
# 768:	learn: 0.2260730	total: 2m 2s	remaining: 11m 15s
# 769:	learn: 0.2260153	total: 2m 2s	remaining: 11m 15s
# 770:	learn: 0.2259151	total: 2m 3s	remaining: 11m 14s
# 771:	learn: 0.2258503	total: 2m 3s	remaining: 11m 14s
# 772:	learn: 0.2257902	total: 2m 3s	remaining: 11m 14s
# 773:	learn: 0.2256947	total: 2m 3s	remaining: 11m 14s
# 774:	learn: 0.2256390	total: 2m 3s	remaining: 11m 14s
# 775:	learn: 0.2255754	total: 2m 3s	remaining: 11m 13s
# 776:	learn: 0.2255166	total: 2m 3s	remaining: 11m 13s
# 777:	learn: 0.2254497	total: 2m 4s	remaining: 11m 13s
# 778:	learn: 0.2253522	total: 2m 4s	remaining: 11m 13s
# 779:	learn: 0.2252888	total: 2m 4s	remaining: 11m 13s
# 780:	learn: 0.2252117	total: 2m 4s	remaining: 11m 13s
# 781:	learn: 0.2251234	total: 2m 4s	remaining: 11m 13s
# 782:	learn: 0.2250351	total: 2m 4s	remaining: 11m 12s
# 783:	learn: 0.2249604	total: 2m 5s	remaining: 11m 12s
# 784:	learn: 0.2248892	total: 2m 5s	remaining: 11m 12s
# 785:	learn: 0.2248271	total: 2m 5s	remaining: 11m 12s
# 786:	learn: 0.2247703	total: 2m 5s	remaining: 11m 11s
# 787:	learn: 0.2246945	total: 2m 5s	remaining: 11m 11s
# 788:	learn: 0.2246478	total: 2m 5s	remaining: 11m 11s
# 789:	learn: 0.2245752	total: 2m 5s	remaining: 11m 10s
# 790:	learn: 0.2245054	total: 2m 6s	remaining: 11m 10s
# 791:	learn: 0.2244522	total: 2m 6s	remaining: 11m 10s
# 792:	learn: 0.2243970	total: 2m 6s	remaining: 11m 9s
# 793:	learn: 0.2243220	total: 2m 6s	remaining: 11m 9s
# 794:	learn: 0.2242727	total: 2m 6s	remaining: 11m 9s
# 795:	learn: 0.2242222	total: 2m 6s	remaining: 11m 9s
# 796:	learn: 0.2241608	total: 2m 6s	remaining: 11m 9s
# 797:	learn: 0.2241283	total: 2m 7s	remaining: 11m 8s
# 798:	learn: 0.2240435	total: 2m 7s	remaining: 11m 8s
# 799:	learn: 0.2239718	total: 2m 7s	remaining: 11m 8s
# 800:	learn: 0.2239089	total: 2m 7s	remaining: 11m 8s
# 801:	learn: 0.2238530	total: 2m 7s	remaining: 11m 7s
# 802:	learn: 0.2238009	total: 2m 7s	remaining: 11m 7s
# 803:	learn: 0.2237586	total: 2m 7s	remaining: 11m 7s
# 804:	learn: 0.2237113	total: 2m 7s	remaining: 11m 6s
# 805:	learn: 0.2236531	total: 2m 8s	remaining: 11m 6s
# 806:	learn: 0.2236061	total: 2m 8s	remaining: 11m 7s
# 807:	learn: 0.2234993	total: 2m 8s	remaining: 11m 6s
# 808:	learn: 0.2234377	total: 2m 8s	remaining: 11m 6s
# 809:	learn: 0.2232990	total: 2m 8s	remaining: 11m 6s
# 810:	learn: 0.2232420	total: 2m 8s	remaining: 11m 6s
# 811:	learn: 0.2231470	total: 2m 9s	remaining: 11m 6s
# 812:	learn: 0.2230755	total: 2m 9s	remaining: 11m 6s
# 813:	learn: 0.2230339	total: 2m 9s	remaining: 11m 6s
# 814:	learn: 0.2229180	total: 2m 9s	remaining: 11m 6s
# 815:	learn: 0.2228713	total: 2m 9s	remaining: 11m 5s
# 816:	learn: 0.2228102	total: 2m 9s	remaining: 11m 5s
# 817:	learn: 0.2227682	total: 2m 10s	remaining: 11m 5s
# 818:	learn: 0.2227120	total: 2m 10s	remaining: 11m 4s
# 819:	learn: 0.2226582	total: 2m 10s	remaining: 11m 4s
# 820:	learn: 0.2226036	total: 2m 10s	remaining: 11m 4s
# 821:	learn: 0.2225527	total: 2m 10s	remaining: 11m 4s
# 822:	learn: 0.2224841	total: 2m 10s	remaining: 11m 3s
# 823:	learn: 0.2224358	total: 2m 10s	remaining: 11m 3s
# 824:	learn: 0.2223366	total: 2m 11s	remaining: 11m 3s
# 825:	learn: 0.2222630	total: 2m 11s	remaining: 11m 2s
# 826:	learn: 0.2222172	total: 2m 11s	remaining: 11m 2s
# 827:	learn: 0.2221568	total: 2m 11s	remaining: 11m 2s
# 828:	learn: 0.2221025	total: 2m 11s	remaining: 11m 2s
# 829:	learn: 0.2220570	total: 2m 11s	remaining: 11m 2s
# 830:	learn: 0.2220002	total: 2m 11s	remaining: 11m 1s
# 831:	learn: 0.2219379	total: 2m 12s	remaining: 11m 1s
# 832:	learn: 0.2218472	total: 2m 12s	remaining: 11m 2s
# 833:	learn: 0.2217938	total: 2m 12s	remaining: 11m 1s
# 834:	learn: 0.2217248	total: 2m 12s	remaining: 11m 1s
# 835:	learn: 0.2216796	total: 2m 12s	remaining: 11m 1s
# 836:	learn: 0.2216314	total: 2m 12s	remaining: 11m
# 837:	learn: 0.2215775	total: 2m 12s	remaining: 11m
# 838:	learn: 0.2214994	total: 2m 13s	remaining: 11m
# 839:	learn: 0.2214304	total: 2m 13s	remaining: 10m 59s
# 840:	learn: 0.2213654	total: 2m 13s	remaining: 10m 59s
# 841:	learn: 0.2213235	total: 2m 13s	remaining: 10m 59s
# 842:	learn: 0.2212418	total: 2m 13s	remaining: 10m 59s
# 843:	learn: 0.2211922	total: 2m 13s	remaining: 10m 59s
# 844:	learn: 0.2211127	total: 2m 14s	remaining: 10m 59s
# 845:	learn: 0.2210521	total: 2m 14s	remaining: 10m 59s
# 846:	learn: 0.2209824	total: 2m 14s	remaining: 10m 58s
# 847:	learn: 0.2209174	total: 2m 14s	remaining: 10m 58s
# 848:	learn: 0.2208736	total: 2m 14s	remaining: 10m 58s
# 849:	learn: 0.2208207	total: 2m 14s	remaining: 10m 57s
# 850:	learn: 0.2207691	total: 2m 14s	remaining: 10m 57s
# 851:	learn: 0.2206864	total: 2m 14s	remaining: 10m 57s
# 852:	learn: 0.2205972	total: 2m 15s	remaining: 10m 56s
# 853:	learn: 0.2205497	total: 2m 15s	remaining: 10m 56s
# 854:	learn: 0.2204584	total: 2m 15s	remaining: 10m 56s
# 855:	learn: 0.2204003	total: 2m 15s	remaining: 10m 56s
# 856:	learn: 0.2203089	total: 2m 15s	remaining: 10m 56s
# 857:	learn: 0.2202638	total: 2m 15s	remaining: 10m 56s
# 858:	learn: 0.2201928	total: 2m 16s	remaining: 10m 56s
# 859:	learn: 0.2201450	total: 2m 16s	remaining: 10m 55s
# 860:	learn: 0.2200756	total: 2m 16s	remaining: 10m 55s
# 861:	learn: 0.2199790	total: 2m 16s	remaining: 10m 55s
# 862:	learn: 0.2199292	total: 2m 16s	remaining: 10m 55s
# 863:	learn: 0.2198681	total: 2m 16s	remaining: 10m 55s
# 864:	learn: 0.2198190	total: 2m 17s	remaining: 10m 55s
# 865:	learn: 0.2197560	total: 2m 17s	remaining: 10m 55s
# 866:	learn: 0.2197011	total: 2m 17s	remaining: 10m 54s
# 867:	learn: 0.2196327	total: 2m 17s	remaining: 10m 55s
# 868:	learn: 0.2195470	total: 2m 17s	remaining: 10m 54s
# 869:	learn: 0.2194712	total: 2m 17s	remaining: 10m 54s
# 870:	learn: 0.2194299	total: 2m 18s	remaining: 10m 54s
# 871:	learn: 0.2193831	total: 2m 18s	remaining: 10m 54s
# 872:	learn: 0.2193171	total: 2m 18s	remaining: 10m 54s
# 873:	learn: 0.2192606	total: 2m 18s	remaining: 10m 54s
# 874:	learn: 0.2192071	total: 2m 18s	remaining: 10m 54s
# 875:	learn: 0.2191646	total: 2m 18s	remaining: 10m 53s
# 876:	learn: 0.2190940	total: 2m 18s	remaining: 10m 53s
# 877:	learn: 0.2190365	total: 2m 19s	remaining: 10m 53s
# 878:	learn: 0.2189924	total: 2m 19s	remaining: 10m 53s
# 879:	learn: 0.2189127	total: 2m 19s	remaining: 10m 52s
# 880:	learn: 0.2188634	total: 2m 19s	remaining: 10m 52s
# 881:	learn: 0.2187758	total: 2m 19s	remaining: 10m 52s
# 882:	learn: 0.2187220	total: 2m 19s	remaining: 10m 52s
# 883:	learn: 0.2186635	total: 2m 20s	remaining: 10m 52s
# 884:	learn: 0.2185771	total: 2m 20s	remaining: 10m 52s
# 885:	learn: 0.2185248	total: 2m 20s	remaining: 10m 52s
# 886:	learn: 0.2184699	total: 2m 20s	remaining: 10m 52s
# 887:	learn: 0.2184084	total: 2m 20s	remaining: 10m 52s
# ...
# 4707:	learn: 0.1343274	total: 10m 45s	remaining: 40s
# 4708:	learn: 0.1343167	total: 10m 45s	remaining: 39.9s
# 4709:	learn: 0.1343081	total: 10m 45s	remaining: 39.8s
# 4710:	learn: 0.1342938	total: 10m 45s	remaining: 39.6s
# 4711:	learn: 0.1342829	total: 10m 46s	remaining: 39.5s
# 4712:	learn: 0.1342707	total: 10m 46s	remaining: 39.3s
# 4713:	learn: 0.1342588	total: 10m 46s	remaining: 39.2s
# 4714:	learn: 0.1342538	total: 10m 46s	remaining: 39.1s
# 4715:	learn: 0.1342426	total: 10m 46s	remaining: 38.9s
# 4716:	learn: 0.1342295	total: 10m 46s	remaining: 38.8s
# 4717:	learn: 0.1342189	total: 10m 46s	remaining: 38.7s
# 4718:	learn: 0.1342116	total: 10m 46s	remaining: 38.5s
# 4719:	learn: 0.1341993	total: 10m 47s	remaining: 38.4s
# 4720:	learn: 0.1341842	total: 10m 47s	remaining: 38.3s
# 4721:	learn: 0.1341742	total: 10m 47s	remaining: 38.1s
# 4722:	learn: 0.1341629	total: 10m 47s	remaining: 38s
# 4723:	learn: 0.1341520	total: 10m 47s	remaining: 37.8s
# 4724:	learn: 0.1341428	total: 10m 47s	remaining: 37.7s
# 4725:	learn: 0.1341313	total: 10m 47s	remaining: 37.6s
# 4726:	learn: 0.1341180	total: 10m 47s	remaining: 37.4s
# 4727:	learn: 0.1341110	total: 10m 48s	remaining: 37.3s
# 4728:	learn: 0.1340969	total: 10m 48s	remaining: 37.2s
# 4729:	learn: 0.1340841	total: 10m 48s	remaining: 37s
# 4730:	learn: 0.1340715	total: 10m 48s	remaining: 36.9s
# 4731:	learn: 0.1340641	total: 10m 48s	remaining: 36.7s
# 4732:	learn: 0.1340509	total: 10m 48s	remaining: 36.6s
# 4733:	learn: 0.1340432	total: 10m 49s	remaining: 36.5s
# 4734:	learn: 0.1340354	total: 10m 49s	remaining: 36.3s
# 4735:	learn: 0.1340257	total: 10m 49s	remaining: 36.2s
# 4736:	learn: 0.1340114	total: 10m 49s	remaining: 36.1s
# 4737:	learn: 0.1340003	total: 10m 49s	remaining: 35.9s
# 4738:	learn: 0.1339876	total: 10m 49s	remaining: 35.8s
# 4739:	learn: 0.1339749	total: 10m 49s	remaining: 35.6s
# 4740:	learn: 0.1339659	total: 10m 50s	remaining: 35.5s
# 4741:	learn: 0.1339554	total: 10m 50s	remaining: 35.4s
# 4742:	learn: 0.1339422	total: 10m 50s	remaining: 35.2s
# 4743:	learn: 0.1339368	total: 10m 50s	remaining: 35.1s
# 4744:	learn: 0.1339242	total: 10m 50s	remaining: 35s
# 4745:	learn: 0.1339107	total: 10m 50s	remaining: 34.8s
# 4746:	learn: 0.1339048	total: 10m 50s	remaining: 34.7s
# 4747:	learn: 0.1338940	total: 10m 51s	remaining: 34.6s
# 4748:	learn: 0.1338869	total: 10m 51s	remaining: 34.4s
# 4749:	learn: 0.1338697	total: 10m 51s	remaining: 34.3s
# 4750:	learn: 0.1338621	total: 10m 51s	remaining: 34.1s
# 4751:	learn: 0.1338472	total: 10m 51s	remaining: 34s
# 4752:	learn: 0.1338422	total: 10m 51s	remaining: 33.9s
# 4753:	learn: 0.1338302	total: 10m 51s	remaining: 33.7s
# 4754:	learn: 0.1338207	total: 10m 52s	remaining: 33.6s
# 4755:	learn: 0.1338158	total: 10m 52s	remaining: 33.5s
# 4756:	learn: 0.1338084	total: 10m 52s	remaining: 33.3s
# 4757:	learn: 0.1338004	total: 10m 52s	remaining: 33.2s
# 4758:	learn: 0.1337896	total: 10m 52s	remaining: 33s
# 4759:	learn: 0.1337788	total: 10m 52s	remaining: 32.9s
# 4760:	learn: 0.1337677	total: 10m 52s	remaining: 32.8s
# 4761:	learn: 0.1337522	total: 10m 52s	remaining: 32.6s
# 4762:	learn: 0.1337407	total: 10m 52s	remaining: 32.5s
# 4763:	learn: 0.1337269	total: 10m 53s	remaining: 32.4s
# 4764:	learn: 0.1337104	total: 10m 53s	remaining: 32.2s
# 4765:	learn: 0.1337054	total: 10m 53s	remaining: 32.1s
# 4766:	learn: 0.1336979	total: 10m 53s	remaining: 31.9s
# 4767:	learn: 0.1336893	total: 10m 53s	remaining: 31.8s
# 4768:	learn: 0.1336798	total: 10m 53s	remaining: 31.7s
# 4769:	learn: 0.1336648	total: 10m 53s	remaining: 31.5s
# 4770:	learn: 0.1336536	total: 10m 53s	remaining: 31.4s
# 4771:	learn: 0.1336355	total: 10m 54s	remaining: 31.3s
# 4772:	learn: 0.1336245	total: 10m 54s	remaining: 31.1s
# 4773:	learn: 0.1336121	total: 10m 54s	remaining: 31s
# 4774:	learn: 0.1335959	total: 10m 54s	remaining: 30.8s
# 4775:	learn: 0.1335803	total: 10m 54s	remaining: 30.7s
# 4776:	learn: 0.1335713	total: 10m 54s	remaining: 30.6s
# 4777:	learn: 0.1335618	total: 10m 54s	remaining: 30.4s
# 4778:	learn: 0.1335560	total: 10m 54s	remaining: 30.3s
# 4779:	learn: 0.1335425	total: 10m 55s	remaining: 30.1s
# 4780:	learn: 0.1335365	total: 10m 55s	remaining: 30s
# 4781:	learn: 0.1335305	total: 10m 55s	remaining: 29.9s
# 4782:	learn: 0.1335108	total: 10m 55s	remaining: 29.7s
# 4783:	learn: 0.1335058	total: 10m 55s	remaining: 29.6s
# 4784:	learn: 0.1334938	total: 10m 55s	remaining: 29.5s
# 4785:	learn: 0.1334830	total: 10m 55s	remaining: 29.3s
# 4786:	learn: 0.1334761	total: 10m 55s	remaining: 29.2s
# 4787:	learn: 0.1334646	total: 10m 56s	remaining: 29.1s
# 4788:	learn: 0.1334549	total: 10m 56s	remaining: 28.9s
# 4789:	learn: 0.1334386	total: 10m 56s	remaining: 28.8s
# 4790:	learn: 0.1334311	total: 10m 56s	remaining: 28.6s
# 4791:	learn: 0.1334206	total: 10m 56s	remaining: 28.5s
# 4792:	learn: 0.1334042	total: 10m 56s	remaining: 28.4s
# 4793:	learn: 0.1333967	total: 10m 56s	remaining: 28.2s
# 4794:	learn: 0.1333851	total: 10m 57s	remaining: 28.1s
# 4795:	learn: 0.1333751	total: 10m 57s	remaining: 28s
# 4796:	learn: 0.1333712	total: 10m 57s	remaining: 27.8s
# 4797:	learn: 0.1333653	total: 10m 57s	remaining: 27.7s
# 4798:	learn: 0.1333570	total: 10m 57s	remaining: 27.5s
# 4799:	learn: 0.1333432	total: 10m 57s	remaining: 27.4s
# 4800:	learn: 0.1333332	total: 10m 57s	remaining: 27.3s
# 4801:	learn: 0.1333109	total: 10m 57s	remaining: 27.1s
# 4802:	learn: 0.1333018	total: 10m 58s	remaining: 27s
# 4803:	learn: 0.1332868	total: 10m 58s	remaining: 26.9s
# 4804:	learn: 0.1332787	total: 10m 58s	remaining: 26.7s
# 4805:	learn: 0.1332669	total: 10m 58s	remaining: 26.6s
# 4806:	learn: 0.1332521	total: 10m 58s	remaining: 26.4s
# 4807:	learn: 0.1332455	total: 10m 58s	remaining: 26.3s
# 4808:	learn: 0.1332316	total: 10m 58s	remaining: 26.2s
# 4809:	learn: 0.1332248	total: 10m 58s	remaining: 26s
# 4810:	learn: 0.1332176	total: 10m 59s	remaining: 25.9s
# 4811:	learn: 0.1332051	total: 10m 59s	remaining: 25.8s
# 4812:	learn: 0.1331941	total: 10m 59s	remaining: 25.6s
# 4813:	learn: 0.1331678	total: 10m 59s	remaining: 25.5s
# 4814:	learn: 0.1331571	total: 10m 59s	remaining: 25.3s
# 4815:	learn: 0.1331498	total: 10m 59s	remaining: 25.2s
# 4816:	learn: 0.1331410	total: 10m 59s	remaining: 25.1s
# 4817:	learn: 0.1331229	total: 10m 59s	remaining: 24.9s
# 4818:	learn: 0.1331096	total: 10m 59s	remaining: 24.8s
# 4819:	learn: 0.1331029	total: 11m	remaining: 24.7s
# 4820:	learn: 0.1330937	total: 11m	remaining: 24.5s
# 4821:	learn: 0.1330756	total: 11m	remaining: 24.4s
# 4822:	learn: 0.1330662	total: 11m	remaining: 24.2s
# 4823:	learn: 0.1330548	total: 11m	remaining: 24.1s
# 4824:	learn: 0.1330412	total: 11m	remaining: 24s
# 4825:	learn: 0.1330305	total: 11m	remaining: 23.8s
# 4826:	learn: 0.1330196	total: 11m	remaining: 23.7s
# 4827:	learn: 0.1330137	total: 11m 1s	remaining: 23.5s
# 4828:	learn: 0.1330010	total: 11m 1s	remaining: 23.4s
# 4829:	learn: 0.1329856	total: 11m 1s	remaining: 23.3s
# 4830:	learn: 0.1329761	total: 11m 1s	remaining: 23.1s
# 4831:	learn: 0.1329665	total: 11m 1s	remaining: 23s
# 4832:	learn: 0.1329555	total: 11m 1s	remaining: 22.9s
# 4833:	learn: 0.1329430	total: 11m 1s	remaining: 22.7s
# 4834:	learn: 0.1329289	total: 11m 1s	remaining: 22.6s
# 4835:	learn: 0.1329218	total: 11m 2s	remaining: 22.4s
# 4836:	learn: 0.1329139	total: 11m 2s	remaining: 22.3s
# 4837:	learn: 0.1329002	total: 11m 2s	remaining: 22.2s
# 4838:	learn: 0.1328896	total: 11m 2s	remaining: 22s
# 4839:	learn: 0.1328768	total: 11m 2s	remaining: 21.9s
# 4840:	learn: 0.1328677	total: 11m 2s	remaining: 21.8s
# 4841:	learn: 0.1328595	total: 11m 2s	remaining: 21.6s
# 4842:	learn: 0.1328477	total: 11m 2s	remaining: 21.5s
# 4843:	learn: 0.1328386	total: 11m 2s	remaining: 21.3s
# 4844:	learn: 0.1328334	total: 11m 2s	remaining: 21.2s
# 4845:	learn: 0.1328257	total: 11m 3s	remaining: 21.1s
# 4846:	learn: 0.1328181	total: 11m 3s	remaining: 20.9s
# 4847:	learn: 0.1328133	total: 11m 3s	remaining: 20.8s
# 4848:	learn: 0.1328052	total: 11m 3s	remaining: 20.7s
# 4849:	learn: 0.1327995	total: 11m 3s	remaining: 20.5s
# 4850:	learn: 0.1327903	total: 11m 3s	remaining: 20.4s
# 4851:	learn: 0.1327797	total: 11m 3s	remaining: 20.2s
# 4852:	learn: 0.1327703	total: 11m 3s	remaining: 20.1s
# 4853:	learn: 0.1327616	total: 11m 3s	remaining: 20s
# 4854:	learn: 0.1327494	total: 11m 4s	remaining: 19.8s
# 4855:	learn: 0.1327350	total: 11m 4s	remaining: 19.7s
# 4856:	learn: 0.1327306	total: 11m 4s	remaining: 19.6s
# 4857:	learn: 0.1327182	total: 11m 4s	remaining: 19.4s
# 4858:	learn: 0.1327075	total: 11m 4s	remaining: 19.3s
# 4859:	learn: 0.1326989	total: 11m 4s	remaining: 19.1s
# 4860:	learn: 0.1326850	total: 11m 4s	remaining: 19s
# 4861:	learn: 0.1326790	total: 11m 4s	remaining: 18.9s
# 4862:	learn: 0.1326690	total: 11m 5s	remaining: 18.7s
# 4863:	learn: 0.1326562	total: 11m 5s	remaining: 18.6s
# 4864:	learn: 0.1326484	total: 11m 5s	remaining: 18.5s
# 4865:	learn: 0.1326317	total: 11m 5s	remaining: 18.3s
# 4866:	learn: 0.1326242	total: 11m 5s	remaining: 18.2s
# 4867:	learn: 0.1326133	total: 11m 5s	remaining: 18.1s
# 4868:	learn: 0.1325998	total: 11m 5s	remaining: 17.9s
# 4869:	learn: 0.1325923	total: 11m 5s	remaining: 17.8s
# 4870:	learn: 0.1325853	total: 11m 6s	remaining: 17.6s
# 4871:	learn: 0.1325717	total: 11m 6s	remaining: 17.5s
# 4872:	learn: 0.1325641	total: 11m 6s	remaining: 17.4s
# 4873:	learn: 0.1325502	total: 11m 6s	remaining: 17.2s
# 4874:	learn: 0.1325370	total: 11m 6s	remaining: 17.1s
# 4875:	learn: 0.1325217	total: 11m 6s	remaining: 17s
# 4876:	learn: 0.1325092	total: 11m 6s	remaining: 16.8s
# 4877:	learn: 0.1324956	total: 11m 6s	remaining: 16.7s
# 4878:	learn: 0.1324890	total: 11m 7s	remaining: 16.5s
# 4879:	learn: 0.1324725	total: 11m 7s	remaining: 16.4s
# 4880:	learn: 0.1324626	total: 11m 7s	remaining: 16.3s
# 4881:	learn: 0.1324549	total: 11m 7s	remaining: 16.1s
# 4882:	learn: 0.1324466	total: 11m 7s	remaining: 16s
# 4883:	learn: 0.1324414	total: 11m 7s	remaining: 15.9s
# 4884:	learn: 0.1324298	total: 11m 7s	remaining: 15.7s
# 4885:	learn: 0.1324211	total: 11m 7s	remaining: 15.6s
# 4886:	learn: 0.1324091	total: 11m 7s	remaining: 15.4s
# 4887:	learn: 0.1323959	total: 11m 8s	remaining: 15.3s
# 4888:	learn: 0.1323858	total: 11m 8s	remaining: 15.2s
# 4889:	learn: 0.1323728	total: 11m 8s	remaining: 15s
# 4890:	learn: 0.1323541	total: 11m 8s	remaining: 14.9s
# 4891:	learn: 0.1323384	total: 11m 8s	remaining: 14.8s
# 4892:	learn: 0.1323219	total: 11m 8s	remaining: 14.6s
# 4893:	learn: 0.1323156	total: 11m 8s	remaining: 14.5s
# 4894:	learn: 0.1323059	total: 11m 8s	remaining: 14.3s
# 4895:	learn: 0.1323029	total: 11m 8s	remaining: 14.2s
# 4896:	learn: 0.1322919	total: 11m 9s	remaining: 14.1s
# 4897:	learn: 0.1322838	total: 11m 9s	remaining: 13.9s
# 4898:	learn: 0.1322793	total: 11m 9s	remaining: 13.8s
# 4899:	learn: 0.1322671	total: 11m 9s	remaining: 13.7s
# 4900:	learn: 0.1322543	total: 11m 9s	remaining: 13.5s
# 4901:	learn: 0.1322444	total: 11m 9s	remaining: 13.4s
# 4902:	learn: 0.1322330	total: 11m 9s	remaining: 13.3s
# 4903:	learn: 0.1322286	total: 11m 9s	remaining: 13.1s
# 4904:	learn: 0.1322200	total: 11m 10s	remaining: 13s
# 4905:	learn: 0.1322067	total: 11m 10s	remaining: 12.8s
# 4906:	learn: 0.1321959	total: 11m 10s	remaining: 12.7s
# 4907:	learn: 0.1321863	total: 11m 10s	remaining: 12.6s
# 4908:	learn: 0.1321743	total: 11m 10s	remaining: 12.4s
# 4909:	learn: 0.1321618	total: 11m 10s	remaining: 12.3s
# 4910:	learn: 0.1321535	total: 11m 10s	remaining: 12.2s
# 4911:	learn: 0.1321390	total: 11m 10s	remaining: 12s
# 4912:	learn: 0.1321261	total: 11m 10s	remaining: 11.9s
# 4913:	learn: 0.1321122	total: 11m 11s	remaining: 11.7s
# 4914:	learn: 0.1321040	total: 11m 11s	remaining: 11.6s
# 4915:	learn: 0.1320973	total: 11m 11s	remaining: 11.5s
# 4916:	learn: 0.1320882	total: 11m 11s	remaining: 11.3s
# 4917:	learn: 0.1320825	total: 11m 11s	remaining: 11.2s
# 4918:	learn: 0.1320675	total: 11m 11s	remaining: 11.1s
# 4919:	learn: 0.1320563	total: 11m 11s	remaining: 10.9s
# 4920:	learn: 0.1320463	total: 11m 12s	remaining: 10.8s
# 4921:	learn: 0.1320408	total: 11m 12s	remaining: 10.7s
# 4922:	learn: 0.1320315	total: 11m 12s	remaining: 10.5s
# 4923:	learn: 0.1320247	total: 11m 12s	remaining: 10.4s
# 4924:	learn: 0.1320181	total: 11m 12s	remaining: 10.2s
# 4925:	learn: 0.1320029	total: 11m 12s	remaining: 10.1s
# 4926:	learn: 0.1319875	total: 11m 12s	remaining: 9.97s
# 4927:	learn: 0.1319834	total: 11m 12s	remaining: 9.83s
# 4928:	learn: 0.1319761	total: 11m 13s	remaining: 9.7s
# 4929:	learn: 0.1319644	total: 11m 13s	remaining: 9.56s
# 4930:	learn: 0.1319593	total: 11m 13s	remaining: 9.42s
# 4931:	learn: 0.1319547	total: 11m 13s	remaining: 9.29s
# 4932:	learn: 0.1319422	total: 11m 13s	remaining: 9.15s
# 4933:	learn: 0.1319361	total: 11m 13s	remaining: 9.01s
# 4934:	learn: 0.1319261	total: 11m 13s	remaining: 8.88s
# 4935:	learn: 0.1319205	total: 11m 13s	remaining: 8.74s
# 4936:	learn: 0.1319100	total: 11m 14s	remaining: 8.6s
# 4937:	learn: 0.1319073	total: 11m 14s	remaining: 8.46s
# 4938:	learn: 0.1318957	total: 11m 14s	remaining: 8.33s
# 4939:	learn: 0.1318847	total: 11m 14s	remaining: 8.19s
# 4940:	learn: 0.1318765	total: 11m 14s	remaining: 8.06s
# 4941:	learn: 0.1318682	total: 11m 14s	remaining: 7.92s
# 4942:	learn: 0.1318520	total: 11m 14s	remaining: 7.78s
# 4943:	learn: 0.1318362	total: 11m 15s	remaining: 7.64s
# 4944:	learn: 0.1318254	total: 11m 15s	remaining: 7.51s
# 4945:	learn: 0.1318102	total: 11m 15s	remaining: 7.37s
# 4946:	learn: 0.1318019	total: 11m 15s	remaining: 7.24s
# 4947:	learn: 0.1317947	total: 11m 15s	remaining: 7.1s
# 4948:	learn: 0.1317830	total: 11m 15s	remaining: 6.96s
# 4949:	learn: 0.1317738	total: 11m 15s	remaining: 6.83s
# 4950:	learn: 0.1317657	total: 11m 15s	remaining: 6.69s
# 4951:	learn: 0.1317508	total: 11m 15s	remaining: 6.55s
# 4952:	learn: 0.1317441	total: 11m 16s	remaining: 6.42s
# 4953:	learn: 0.1317254	total: 11m 16s	remaining: 6.28s
# 4954:	learn: 0.1317148	total: 11m 16s	remaining: 6.14s
# 4955:	learn: 0.1317099	total: 11m 16s	remaining: 6s
# 4956:	learn: 0.1317036	total: 11m 16s	remaining: 5.87s
# 4957:	learn: 0.1316953	total: 11m 16s	remaining: 5.73s
# 4958:	learn: 0.1316875	total: 11m 16s	remaining: 5.59s
# 4959:	learn: 0.1316740	total: 11m 16s	remaining: 5.46s
# 4960:	learn: 0.1316644	total: 11m 16s	remaining: 5.32s
# 4961:	learn: 0.1316567	total: 11m 17s	remaining: 5.18s
# 4962:	learn: 0.1316398	total: 11m 17s	remaining: 5.05s
# 4963:	learn: 0.1316258	total: 11m 17s	remaining: 4.91s
# 4964:	learn: 0.1316195	total: 11m 17s	remaining: 4.78s
# 4965:	learn: 0.1316037	total: 11m 17s	remaining: 4.64s
# 4966:	learn: 0.1315877	total: 11m 17s	remaining: 4.5s
# 4967:	learn: 0.1315797	total: 11m 17s	remaining: 4.37s
# 4968:	learn: 0.1315635	total: 11m 17s	remaining: 4.23s
# 4969:	learn: 0.1315583	total: 11m 18s	remaining: 4.09s
# 4970:	learn: 0.1315456	total: 11m 18s	remaining: 3.96s
# 4971:	learn: 0.1315358	total: 11m 18s	remaining: 3.82s
# 4972:	learn: 0.1315269	total: 11m 18s	remaining: 3.68s
# 4973:	learn: 0.1315182	total: 11m 18s	remaining: 3.55s
# 4974:	learn: 0.1315003	total: 11m 18s	remaining: 3.41s
# 4975:	learn: 0.1314925	total: 11m 18s	remaining: 3.27s
# 4976:	learn: 0.1314819	total: 11m 18s	remaining: 3.14s
# 4977:	learn: 0.1314756	total: 11m 18s	remaining: 3s
# 4978:	learn: 0.1314714	total: 11m 18s	remaining: 2.86s
# 4979:	learn: 0.1314428	total: 11m 19s	remaining: 2.73s
# 4980:	learn: 0.1314371	total: 11m 19s	remaining: 2.59s
# 4981:	learn: 0.1314324	total: 11m 19s	remaining: 2.45s
# 4982:	learn: 0.1314249	total: 11m 19s	remaining: 2.32s
# 4983:	learn: 0.1314202	total: 11m 19s	remaining: 2.18s
# 4984:	learn: 0.1314054	total: 11m 19s	remaining: 2.04s
# 4985:	learn: 0.1314015	total: 11m 19s	remaining: 1.91s
# 4986:	learn: 0.1313919	total: 11m 19s	remaining: 1.77s
# 4987:	learn: 0.1313828	total: 11m 19s	remaining: 1.64s
# 4988:	learn: 0.1313631	total: 11m 20s	remaining: 1.5s
# 4989:	learn: 0.1313508	total: 11m 20s	remaining: 1.36s
# 4990:	learn: 0.1313432	total: 11m 20s	remaining: 1.23s
# 4991:	learn: 0.1313366	total: 11m 20s	remaining: 1.09s
# 4992:	learn: 0.1313253	total: 11m 20s	remaining: 954ms
# 4993:	learn: 0.1313137	total: 11m 20s	remaining: 818ms
# 4994:	learn: 0.1312997	total: 11m 20s	remaining: 681ms
# 4995:	learn: 0.1312918	total: 11m 20s	remaining: 545ms
# 4996:	learn: 0.1312808	total: 11m 21s	remaining: 409ms
# 4997:	learn: 0.1312673	total: 11m 21s	remaining: 273ms
# 4998:	learn: 0.1312545	total: 11m 21s	remaining: 136ms
# 4999:	learn: 0.1312449	total: 11m 21s	remaining: 0us

# %%
cat_model.save_model('./data/softvoting_cat_xgb변수_6_12_24.cbm')

# %% [markdown]
# # 7. 모델예측 - Soft voting

# %%
test_df = pd.read_parquet("./test_data.parquet")

# 변수 400개 사용
top400_df = pd.read_csv("./data/top400_features_XGB_balanced.csv")
top400_features = top400_df['feature'].tolist()

# %%
# 학습한 모델들 불러오기
xgb_model_loaded = xgb.XGBClassifier()
xgb_model_loaded.load_model('./data/softvoting_xgb_xgb변수_3_3_25.json')

lgb_model_loaded = lgb.Booster(model_file='./data/softvoting_lgbm_model_3_3_25.txt')

cat_model_loaded = CatBoostClassifier()
cat_model_loaded.load_model('./data/softvoting_cat_xgb변수_6_12_24.cbm')

# %%
# test 데이터 준비
X_test = test_df[top400_features]

# XGB predict_proba (iteration_range)
proba_xgb = xgb_model_loaded.predict_proba(X_test, iteration_range=(0, 5000))

# LGB Booster (predict가 proba)
proba_lgb = lgb_model_loaded.predict(X_test, num_iteration=3348)

# CAT predict_proba
proba_cat = cat_model_loaded.predict_proba(X_test)

# soft voting
ensemble_proba = (0.4 * proba_xgb) + (0.3 * proba_lgb) + (0.3 * proba_cat)
ensemble_preds = np.argmax(ensemble_proba, axis=1)
inverse_label_map = {0: 'A', 1: 'B', 2: 'C', 3: 'D', 4: 'E'}
ensemble_preds_label = pd.Series(ensemble_preds).map(inverse_label_map)

# %%
pred = pd.read_csv("./data/sample_submission.csv")

# %%
pred["Segment"] = ensemble_preds_label.iloc[0:100000]
pred.to_csv("./data/submission.csv", index=False)
